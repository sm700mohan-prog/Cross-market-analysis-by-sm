# %% [markdown]
# <a href="https://colab.research.google.com/github/sm700mohan-prog/Cross-market-analysis-by-sm/blob/main/crossmarket_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Market Analysis Dashboard
#
# This project provides a comprehensive web-based dashboard for analyzing market trends across cryptocurrencies, crude oil, and stock indices. Built using Streamlit, it offers interactive data exploration, SQL query execution, and detailed cryptocurrency analysis, all accessible through a user-friendly interface.
#
# ## Live Application
#
# Access the live Streamlit application here: [https://concha-coreless-habitably.ngrok-free.dev](https://concha-coreless-habitably.ngrok-free.dev)
#
# ## Features
#
# The dashboard is organized into three main pages:
#
# ### 1. Filters & Data Exploration
# - **Date Range Selection**: Customize the period for data analysis.
# - **Average Prices**: View average prices for Bitcoin, Crude Oil, S&P 500 (`^GSPC`), and NIFTY 50 (`^NSEI`).
# - **Daily Market Snapshot**: Visualize daily price trends of selected assets with interactive Altair charts.
#
# ### 2. SQL Query Runner
# - **Predefined Queries**: Execute a variety of pre-configured SQL queries against the underlying SQLite database.
# - **Data Display**: Results are presented in a clear, tabular format.
#
# ### 3. Top Crypto Analysis
# - **Cryptocurrency Selection**: Choose up to three top cryptocurrencies (Bitcoin, Ethereum, Tether) for detailed analysis.
# - **Daily Price Trends**: Visualize historical daily price movements for selected cryptocurrencies.
# - **Raw Data**: View the raw historical price data.
#
# ## Data Sources
#
# The application integrates data from several sources:
# - **CoinGecko API**: Cryptocurrency market data and historical prices.
# - **datasets/oil-prices (GitHub)**: Historical WTI crude oil prices.
# - **Yahoo Finance API (`yfinance`)**: Historical stock prices for S&P 500 (`^GSPC`), NASDAQ (`^IXIC`), and NIFTY 50 (`^NSEI`).
#
# ## Technologies Used
# - **Python**: Primary programming language.
# - **Streamlit**: For building the interactive web application.
# - **Pandas**: Data manipulation and analysis.
# - **SQLite**: Local database for storing and querying market data.
# - **Altair**: Declarative statistical visualizations.
# - **Requests**: For API interactions.
# - **`yfinance`**: Python library for fetching Yahoo Finance data.
# - **`pyngrok`**: For exposing the local Streamlit application publicly.
#
# ## How to Run Locally (or in Colab)
#
# To set up and run this project, follow these steps:
#
# ### 1. Environment Setup
#
# First, install the required Python libraries:
#
# ```bash
# pip install streamlit pyngrok requests pandas yfinance
# ```
#
# ### 2. Ngrok Authentication
#
# To expose your Streamlit app publicly (necessary for sharing or if running in environments like Colab), you need an Ngrok authtoken.
#
# 1.  **Get your authtoken**: Sign up at [ngrok.com](https://ngrok.com/) and retrieve your authtoken from the dashboard.
# 2.  **Set authtoken**: In Google Colab, add your authtoken to the 'Secrets' tab (🔑 icon on the left panel) with the name `NGROK_AUTH_TOKEN`.
#
# ### 3. Data Collection and Database Setup
#
# The project requires a SQLite database named `mydatabase.db` populated with cryptocurrency, oil, and stock data. The necessary Python code to fetch this data from APIs and populate the database is provided within the Colab notebook.
#
# ### 4. Run the Streamlit Application
#
# Once the `app.py` file is created (as demonstrated in the Colab notebook) and the database is populated, run the Streamlit application. If running in a local terminal, use:
#
# ```bash
# streamlit run app.py
# ```
#
# If running in Google Colab, the notebook provides a Python cell that starts Streamlit in the background and sets up the Ngrok tunnel, printing the public URL for access. This cell handles killing previous Streamlit processes, configuring Ngrok, and launching the app:
#
# ```python
# import subprocess
# import time
# from pyngrok import ngrok
# import os
# from google.colab import userdata
#
# # ... (code to kill processes, start Streamlit, configure ngrok, and connect tunnel) ...
#
# NGROK_AUTH_TOKEN = userdata.get('NGROK_AUTH_TOKEN') # Fetches from Colab secrets
# ngrok.set_auth_token(NGROK_AUTH_TOKEN)
#
# tunnel = ngrok.connect(8501) # Connects to Streamlit's default port
# public_url = tunnel.public_url
# print(f"Streamlit App is live at: {public_url}")
# ```
#
# ## Project Structure
#
# - `app.py`: The main Streamlit application script containing all dashboard logic.
# - `mydatabase.db`: SQLite database file storing all collected market data.
# - `README.md`: This file, providing an overview of the project.
#
# ## Contact
#
# For any questions or suggestions, please open an issue in the repository.

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.1.4)

# %%
all_records = []
import requests
import time

base_url = "https://api.coingecko.com/api/v3/coins/markets?vs_currency=inr&per_page=250&order=market_cap_desc&sparkline=False&page="

for page_num in range(1, 6): # Loop for pages 1 to 5
    url = f"{base_url}{page_num}"
    response = requests.get(url)
    if response.status_code == 200:
        page_data = response.json()
        all_records.extend(page_data)
    else:
        print(f"Failed to fetch data for page {page_num}. Status code: {response.status_code}")
    time.sleep(10) # Increased delay to 10 seconds between requests to avoid rate limiting

cryptocurrency = all_records

print(f"Total records collected: {len(cryptocurrency)}")
print("First 3 records:")
display(cryptocurrency)
# Out:
# Failed to fetch data for page 5. Status code: 429
# Total records collected: 1000
# First 3 records:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400',
#   'current_price': 6275065,
#   'market_cap': 125599657273485,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 125599657273485,
#   'total_volume': 4480093453444,
#   'high_24h': 6445246,
#   'low_24h': 6195677,
#   'price_change_24h': 48068,
#   'price_change_percentage_24h': 0.77193,
#   'market_cap_change_24h': 1484743139255,
#   'market_cap_change_percentage_24h': 1.19626,
#   'circulating_supply': 19987200.0,
#   'total_supply': 19987200.0,
#   'max_supply': 21000000.0,
#   'ath': 11187013,
#   'ath_change_percentage': -43.90759,
#   'ath_date': '2025-10-06T18:57:42.558Z',
#   'atl': 3993.42,
#   'atl_change_percentage': 157035.14472,
#   'atl_date': '2013-07-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:41.794Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'image': 'https://coin-images.coingecko.com/coins/images/279/large/ethereum.png?1696501628',
#   'current_price': 183804,
#   'market_cap': 22204293665548,
#   'market_cap_rank': 2,
#   'fully_diluted_valuation': 22204293665548,
#   'total_volume': 2610841377798,
#   'high_24h': 194194,
#   'low_24h': 181150,
#   'price_change_24h': 660.16,
#   'price_change_percentage_24h': 0.36046,
#   'market_cap_change_24h': 161914472413,
#   'market_cap_change_percentage_24h': 0.73456,
#   'circulating_supply': 120692588.7575344,
#   'total_supply': 120692588.7575344,
#   'max_supply': None,
#   'ath': 431946,
#   'ath_change_percentage': -57.44733,
#   'ath_date': '2025-08-24T19:21:03.333Z',
#   'atl': 28.13,
#   'atl_change_percentage': 653281.77944,
#   'atl_date': '2015-10-20T00:00:00.000Z',
#   'roi': {'times': 38.16580686489964,
#    'currency': 'btc',
#    'percentage': 3816.5806864899646},
#   'last_updated': '2026-02-10T14:25:41.567Z'},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://coin-images.coingecko.com/coins/images/325/large/Tether.png?1696501661',
#   'current_price': 90.51,
#   'market_cap': 16700897819975,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': 17195715622995,
#   'total_volume': 7765371860719,
#   'high_24h': 90.77,
#   'low_24h': 90.41,
#   'price_change_24h': -0.09153138770922453,
#   'price_change_percentage_24h': -0.10103,
#   'market_cap_change_24h': -19332859164.117188,
#   'market_cap_change_percentage_24h': -0.11563,
#   'circulating_supply': 184517936950.033,
#   'total_supply': 189984874186.7962,
#   'max_supply': None,
#   'ath': 105.52,
#   'ath_change_percentage': -14.2306,
#   'ath_date': '2025-01-25T16:51:57.989Z',
#   'atl': 36.86,
#   'atl_change_percentage': 145.53387,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:37.222Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://coin-images.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442',
#   'current_price': 128.48,
#   'market_cap': 7826869690438,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': 12846515067811,
#   'total_volume': 251539484784,
#   'high_24h': 132.36,
#   'low_24h': 127.29,
#   'price_change_24h': 1.059,
#   'price_change_percentage_24h': 0.83144,
#   'market_cap_change_24h': 101133178625,
#   'market_cap_change_percentage_24h': 1.30904,
#   'circulating_supply': 60917315351.0,
#   'total_supply': 99985721048.0,
#   'max_supply': 100000000000.0,
#   'ath': 313.99,
#   'ath_change_percentage': -59.08141,
#   'ath_date': '2025-07-21T15:02:00.541Z',
#   'atl': 0.159343,
#   'atl_change_percentage': 80530.54786,
#   'atl_date': '2013-08-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.907Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'BNB',
#   'image': 'https://coin-images.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970',
#   'current_price': 56547,
#   'market_cap': 7719397063749,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': 7719397063749,
#   'total_volume': 110216717199,
#   'high_24h': 58322,
#   'low_24h': 56381,
#   'price_change_24h': -8.8899630479209,
#   'price_change_percentage_24h': -0.01572,
#   'market_cap_change_24h': 13554578070,
#   'market_cap_change_percentage_24h': 0.1759,
#   'circulating_supply': 136359527.5799999,
#   'total_supply': 136359527.5799999,
#   'max_supply': 200000000.0,
#   'ath': 121422,
#   'ath_change_percentage': -53.4293,
#   'ath_date': '2025-10-13T08:41:24.131Z',
#   'atl': 2.58,
#   'atl_change_percentage': 2187629.56559,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:41.474Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USDC',
#   'image': 'https://coin-images.coingecko.com/coins/images/6319/large/USDC.png?1769615602',
#   'current_price': 90.55,
#   'market_cap': 6622452954035,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 6622682803751,
#   'total_volume': 1011775776682,
#   'high_24h': 90.8,
#   'low_24h': 90.47,
#   'price_change_24h': -0.08335170166159855,
#   'price_change_percentage_24h': -0.09196,
#   'market_cap_change_24h': 19445267887,
#   'market_cap_change_percentage_24h': 0.29449,
#   'circulating_supply': 73137440593.27045,
#   'total_supply': 73139979021.2632,
#   'max_supply': None,
#   'ath': 1327.87,
#   'ath_change_percentage': -93.18072,
#   'ath_date': '2025-01-23T04:45:51.184Z',
#   'atl': 65.31,
#   'atl_change_percentage': 38.65283,
#   'atl_date': '2021-05-19T13:14:05.611Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:49.056Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://coin-images.coingecko.com/coins/images/4128/large/solana.png?1718769756',
#   'current_price': 7666.65,
#   'market_cap': 4354023844649,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': 4757559994915,
#   'total_volume': 363126931495,
#   'high_24h': 8011.52,
#   'low_24h': 7590.36,
#   'price_change_24h': 73.25,
#   'price_change_percentage_24h': 0.96461,
#   'market_cap_change_24h': 48391182096,
#   'market_cap_change_percentage_24h': 1.1239,
#   'circulating_supply': 567523885.1499375,
#   'total_supply': 620122679.2697487,
#   'max_supply': None,
#   'ath': 25396,
#   'ath_change_percentage': -69.81197,
#   'ath_date': '2025-01-19T11:15:27.957Z',
#   'atl': 38.03,
#   'atl_change_percentage': 20061.7561,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.836Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://coin-images.coingecko.com/coins/images/1094/large/tron-logo.png?1696502193',
#   'current_price': 25.17,
#   'market_cap': 2383363317978,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': 2383365639571,
#   'total_volume': 53077987326,
#   'high_24h': 25.4,
#   'low_24h': 25.0,
#   'price_change_24h': 0.112938,
#   'price_change_percentage_24h': 0.45074,
#   'market_cap_change_24h': 10003013702,
#   'market_cap_change_percentage_24h': 0.42147,
#   'circulating_supply': 94720982243.3949,
#   'total_supply': 94721074509.4697,
#   'max_supply': None,
#   'ath': 36.53,
#   'ath_change_percentage': -31.09186,
#   'ath_date': '2024-12-04T00:10:40.323Z',
#   'atl': 0.117589,
#   'atl_change_percentage': 21304.18014,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 145.27677945326374,
#    'currency': 'usd',
#    'percentage': 14527.677945326373},
#   'last_updated': '2026-02-10T14:25:48.907Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/5/large/dogecoin.png?1696501409',
#   'current_price': 8.45,
#   'market_cap': 1426225828642,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': 1426340065800,
#   'total_volume': 85509722863,
#   'high_24h': 8.78,
#   'low_24h': 8.4,
#   'price_change_24h': -0.05328178211684609,
#   'price_change_percentage_24h': -0.62641,
#   'market_cap_change_24h': -5313758682.243408,
#   'market_cap_change_percentage_24h': -0.37119,
#   'circulating_supply': 168669383126.5791,
#   'total_supply': 168682893126.5791,
#   'max_supply': None,
#   'ath': 53.62,
#   'ath_change_percentage': -84.23536,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 0.00552883,
#   'atl_change_percentage': 152782.93551,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:37.134Z'},
#  {'id': 'figure-heloc',
#   'symbol': 'figr_heloc',
#   'name': 'Figure Heloc',
#   'image': 'https://coin-images.coingecko.com/coins/images/68480/large/figure.png?1755863954',
#   'current_price': 93.65,
#   'market_cap': 1404883375617,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': 1404883375617,
#   'total_volume': 844940964,
#   'high_24h': 94.03,
#   'low_24h': 92.47,
#   'price_change_24h': 1.19,
#   'price_change_percentage_24h': 1.28229,
#   'market_cap_change_24h': 17392568320,
#   'market_cap_change_percentage_24h': 1.25353,
#   'circulating_supply': 15001825015.047,
#   'total_supply': 15001825015.047,
#   'max_supply': None,
#   'ath': 120.96,
#   'ath_change_percentage': -22.58193,
#   'ath_date': '2025-10-28T06:00:43.161Z',
#   'atl': 13.78,
#   'atl_change_percentage': 579.35038,
#   'atl_date': '2025-10-31T14:57:19.271Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.435Z'},
#  {'id': 'whitebit',
#   'symbol': 'wbt',
#   'name': 'WhiteBIT Coin',
#   'image': 'https://coin-images.coingecko.com/coins/images/27045/large/wbt_token.png?1696526096',
#   'current_price': 4716.89,
#   'market_cap': 1008062491520,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': 1510372631720,
#   'total_volume': 11429520770,
#   'high_24h': 4873.93,
#   'low_24h': 4657.05,
#   'price_change_24h': -14.835141281111646,
#   'price_change_percentage_24h': -0.31353,
#   'market_cap_change_24h': -3151533162.6834717,
#   'market_cap_change_percentage_24h': -0.31166,
#   'circulating_supply': 213729819.0,
#   'total_supply': 320229819.0,
#   'max_supply': 400000000.0,
#   'ath': 5758.63,
#   'ath_change_percentage': -18.12503,
#   'ath_date': '2025-12-10T20:16:13.582Z',
#   'atl': 245.71,
#   'atl_change_percentage': 1818.89781,
#   'atl_date': '2022-09-21T23:38:03.675Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.456Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://coin-images.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1696501932',
#   'current_price': 47086,
#   'market_cap': 941751372118,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': 941764473050,
#   'total_volume': 31997245533,
#   'high_24h': 48693,
#   'low_24h': 46688,
#   'price_change_24h': 397.77,
#   'price_change_percentage_24h': 0.85197,
#   'market_cap_change_24h': 9448171425,
#   'market_cap_change_percentage_24h': 1.01342,
#   'circulating_supply': 19992821.77165078,
#   'total_supply': 19993099.89665078,
#   'max_supply': 21000000.0,
#   'ath': 242198,
#   'ath_change_percentage': -80.55893,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 5536.54,
#   'atl_change_percentage': 750.45694,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.661Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://coin-images.coingecko.com/coins/images/975/large/cardano.png?1696502090',
#   'current_price': 23.98,
#   'market_cap': 881001246004,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': 1077477875776,
#   'total_volume': 35200515221,
#   'high_24h': 24.72,
#   'low_24h': 23.71,
#   'price_change_24h': 0.176786,
#   'price_change_percentage_24h': 0.74269,
#   'market_cap_change_24h': 5782042728,
#   'market_cap_change_percentage_24h': 0.66064,
#   'circulating_supply': 36794311012.29324,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 225.26,
#   'ath_change_percentage': -89.35448,
#   'ath_date': '2021-09-02T06:00:10.474Z',
#   'atl': 1.38,
#   'atl_change_percentage': 1643.49638,
#   'atl_date': '2017-11-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.942Z'},
#  {'id': 'usds',
#   'symbol': 'usds',
#   'name': 'USDS',
#   'image': 'https://coin-images.coingecko.com/coins/images/39926/large/usds.webp?1726666683',
#   'current_price': 90.55,
#   'market_cap': 871086006403,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': 871086006403,
#   'total_volume': 133550398,
#   'high_24h': 90.89,
#   'low_24h': 90.32,
#   'price_change_24h': -0.08728575991477783,
#   'price_change_percentage_24h': -0.0963,
#   'market_cap_change_24h': 3193824904,
#   'market_cap_change_percentage_24h': 0.368,
#   'circulating_supply': 9627904133.778423,
#   'total_supply': 9627904133.778423,
#   'max_supply': None,
#   'ath': 92.23,
#   'ath_change_percentage': -1.90618,
#   'ath_date': '2026-01-29T16:30:24.390Z',
#   'atl': 79.67,
#   'atl_change_percentage': 13.55766,
#   'atl_date': '2024-10-03T13:19:28.826Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.504Z'},
#  {'id': 'leo-token',
#   'symbol': 'leo',
#   'name': 'LEO Token',
#   'image': 'https://coin-images.coingecko.com/coins/images/8418/large/leo-token.png?1696508607',
#   'current_price': 778.65,
#   'market_cap': 717436400109,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': 767141731733,
#   'total_volume': 82093562,
#   'high_24h': 780.95,
#   'low_24h': 755.84,
#   'price_change_24h': 22.81,
#   'price_change_percentage_24h': 3.01765,
#   'market_cap_change_24h': 21003799670,
#   'market_cap_change_percentage_24h': 3.01591,
#   'circulating_supply': 921402986.9,
#   'total_supply': 985239504.0,
#   'max_supply': None,
#   'ath': 888.26,
#   'ath_change_percentage': -12.36203,
#   'ath_date': '2025-12-01T06:16:28.002Z',
#   'atl': 56.97,
#   'atl_change_percentage': 1266.33681,
#   'atl_date': '2019-12-24T15:14:35.376Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.474Z'},
#  {'id': 'hyperliquid',
#   'symbol': 'hype',
#   'name': 'Hyperliquid',
#   'image': 'https://coin-images.coingecko.com/coins/images/50882/large/hyperliquid.jpg?1729431300',
#   'current_price': 2708.18,
#   'market_cap': 646200642306,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': 2608474826128,
#   'total_volume': 28192237651,
#   'high_24h': 2907.0,
#   'low_24h': 2659.76,
#   'price_change_24h': -138.31651450078652,
#   'price_change_percentage_24h': -4.85918,
#   'market_cap_change_24h': -32233951128.963745,
#   'market_cap_change_percentage_24h': -4.75122,
#   'circulating_supply': 238385315.9541414,
#   'total_supply': 962274028.9541414,
#   'max_supply': 1000000000.0,
#   'ath': 5213.52,
#   'ath_change_percentage': -48.05467,
#   'ath_date': '2025-09-18T03:30:30.650Z',
#   'atl': 321.88,
#   'atl_change_percentage': 741.36572,
#   'atl_date': '2024-11-29T09:30:30.871Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.552Z'},
#  {'id': 'ethena-usde',
#   'symbol': 'usde',
#   'name': 'Ethena USDe',
#   'image': 'https://coin-images.coingecko.com/coins/images/33613/large/usde.png?1733810059',
#   'current_price': 90.43,
#   'market_cap': 581666175550,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 581666175550,
#   'total_volume': 6379244414,
#   'high_24h': 90.72,
#   'low_24h': 90.32,
#   'price_change_24h': -0.11057934966686389,
#   'price_change_percentage_24h': -0.12213,
#   'market_cap_change_24h': -1043098113.3914795,
#   'market_cap_change_percentage_24h': -0.17901,
#   'circulating_supply': 6432668579.898262,
#   'total_supply': 6432668579.898262,
#   'max_supply': None,
#   'ath': 92.91,
#   'ath_change_percentage': -2.67758,
#   'ath_date': '2025-12-09T17:10:12.652Z',
#   'atl': 78.05,
#   'atl_change_percentage': 15.86292,
#   'atl_date': '2024-10-04T07:57:15.809Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.679Z'},
#  {'id': 'canton-network',
#   'symbol': 'cc',
#   'name': 'Canton',
#   'image': 'https://coin-images.coingecko.com/coins/images/70468/large/Canton-Ticker_%281%29.png?1762826299',
#   'current_price': 14.87,
#   'market_cap': 560804048140,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': 560804048140,
#   'total_volume': 1282258850,
#   'high_24h': 15.57,
#   'low_24h': 14.58,
#   'price_change_24h': 0.152189,
#   'price_change_percentage_24h': 1.03372,
#   'market_cap_change_24h': 5735393676,
#   'market_cap_change_percentage_24h': 1.03328,
#   'circulating_supply': 37711955931.79735,
#   'total_supply': 37711955931.79735,
#   'max_supply': None,
#   'ath': 17.72,
#   'ath_change_percentage': -16.09644,
#   'ath_date': '2026-01-31T16:41:41.560Z',
#   'atl': 5.31,
#   'atl_change_percentage': 180.10605,
#   'atl_date': '2025-12-06T10:32:09.784Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.494Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://coin-images.coingecko.com/coins/images/877/large/Chainlink_Logo_500.png?1760023405',
#   'current_price': 782.06,
#   'market_cap': 553373760762,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': 781491009536,
#   'total_volume': 31697150815,
#   'high_24h': 814.35,
#   'low_24h': 768.31,
#   'price_change_24h': 7.91,
#   'price_change_percentage_24h': 1.02165,
#   'market_cap_change_24h': 5506551069,
#   'market_cap_change_percentage_24h': 1.00509,
#   'circulating_supply': 708099970.4525867,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 3862.15,
#   'ath_change_percentage': -79.7506,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 9.55,
#   'atl_change_percentage': 8091.9983,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:37.600Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://coin-images.coingecko.com/coins/images/69/large/monero_logo.png?1696501460',
#   'current_price': 29963,
#   'market_cap': 553149711914,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 553149711914,
#   'total_volume': 7764897283,
#   'high_24h': 31573,
#   'low_24h': 28754,
#   'price_change_24h': 1209.49,
#   'price_change_percentage_24h': 4.20639,
#   'market_cap_change_24h': 23816885568,
#   'market_cap_change_percentage_24h': 4.49942,
#   'circulating_supply': 18446744.07370955,
#   'total_supply': 18446744.07370955,
#   'max_supply': None,
#   'ath': 72026,
#   'ath_change_percentage': -58.39957,
#   'ath_date': '2026-01-14T19:34:07.049Z',
#   'atl': 13.57,
#   'atl_change_percentage': 220689.53064,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.663Z'},
#  {'id': 'usd1-wlfi',
#   'symbol': 'usd1',
#   'name': 'USD1',
#   'image': 'https://coin-images.coingecko.com/coins/images/54977/large/USD1_1000x1000_transparent.png?1749297002',
#   'current_price': 90.52,
#   'market_cap': 486597362869,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': 486597362869,
#   'total_volume': 150950635740,
#   'high_24h': 90.83,
#   'low_24h': 90.44,
#   'price_change_24h': -0.12169255348089791,
#   'price_change_percentage_24h': -0.13425,
#   'market_cap_change_24h': 1821813067,
#   'market_cap_change_percentage_24h': 0.37581,
#   'circulating_supply': 5376667544.155274,
#   'total_supply': 5376667544.155274,
#   'max_supply': None,
#   'ath': 92.17,
#   'ath_change_percentage': -1.77427,
#   'ath_date': '2026-01-28T15:56:38.616Z',
#   'atl': 83.75,
#   'atl_change_percentage': 8.09926,
#   'atl_date': '2025-05-02T03:46:49.689Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:49.038Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://coin-images.coingecko.com/coins/images/100/large/fmpFRHHQ_400x400.jpg?1735231350',
#   'current_price': 14.23,
#   'market_cap': 465468757924,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': 711341927958,
#   'total_volume': 9471087507,
#   'high_24h': 14.69,
#   'low_24h': 14.03,
#   'price_change_24h': 0.01312806,
#   'price_change_percentage_24h': 0.09236,
#   'market_cap_change_24h': 688147258,
#   'market_cap_change_percentage_24h': 0.14806,
#   'circulating_supply': 32718821596.16952,
#   'total_supply': 50001786883.65895,
#   'max_supply': None,
#   'ath': 58.01,
#   'ath_change_percentage': -75.55756,
#   'ath_date': '2021-05-16T09:48:45.220Z',
#   'atl': 0.02966141,
#   'atl_change_percentage': 47700.70208,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:37.734Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://coin-images.coingecko.com/coins/images/9956/large/Badge_Dai.png?1696509996',
#   'current_price': 90.51,
#   'market_cap': 377842067727,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': 377842067727,
#   'total_volume': 7109590108,
#   'high_24h': 90.89,
#   'low_24h': 90.44,
#   'price_change_24h': -0.08250000518059153,
#   'price_change_percentage_24h': -0.09106,
#   'market_cap_change_24h': -1245351267.2324219,
#   'market_cap_change_percentage_24h': -0.32851,
#   'circulating_supply': 4174732189.038614,
#   'total_supply': 4174732189.038614,
#   'max_supply': None,
#   'ath': 92.29,
#   'ath_change_percentage': -1.82274,
#   'ath_date': '2026-01-31T18:56:20.998Z',
#   'atl': 64.85,
#   'atl_change_percentage': 39.72034,
#   'atl_date': '2019-11-25T00:04:18.137Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:37.753Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/2/large/litecoin.png?1696501400',
#   'current_price': 4851.55,
#   'market_cap': 372634785981,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': 372648669309,
#   'total_volume': 28352954359,
#   'high_24h': 4988.38,
#   'low_24h': 4786.49,
#   'price_change_24h': 9.63,
#   'price_change_percentage_24h': 0.19885,
#   'market_cap_change_24h': 886756726,
#   'market_cap_change_percentage_24h': 0.23854,
#   'circulating_supply': 76830789.48347135,
#   'total_supply': 76833651.98347135,
#   'max_supply': 84000000.0,
#   'ath': 30082,
#   'ath_change_percentage': -83.90751,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 72.12,
#   'atl_change_percentage': 6612.12978,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.961Z'},
#  {'id': 'zcash',
#   'symbol': 'zec',
#   'name': 'Zcash',
#   'image': 'https://coin-images.coingecko.com/coins/images/486/large/circle-zcash-color.png?1696501740',
#   'current_price': 21577,
#   'market_cap': 356546599781,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': 356546599781,
#   'total_volume': 30829841903,
#   'high_24h': 22174,
#   'low_24h': 21003,
#   'price_change_24h': 573.74,
#   'price_change_percentage_24h': 2.73169,
#   'market_cap_change_24h': 11037317381,
#   'market_cap_change_percentage_24h': 3.19451,
#   'circulating_supply': 16511426.7280448,
#   'total_supply': 16511426.7280448,
#   'max_supply': 21000000.0,
#   'ath': 211171,
#   'ath_change_percentage': -89.7823,
#   'ath_date': '2016-10-29T00:00:00.000Z',
#   'atl': 1342.38,
#   'atl_change_percentage': 1507.35302,
#   'atl_date': '2024-07-05T04:22:29.321Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.743Z'},
#  {'id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'name': 'Hedera',
#   'image': 'https://coin-images.coingecko.com/coins/images/3688/large/hbar.png?1696504364',
#   'current_price': 8.23,
#   'market_cap': 354288842178,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': 411933702019,
#   'total_volume': 9753737917,
#   'high_24h': 8.51,
#   'low_24h': 8.08,
#   'price_change_24h': 0.152887,
#   'price_change_percentage_24h': 1.89181,
#   'market_cap_change_24h': 7309553396,
#   'market_cap_change_percentage_24h': 2.10663,
#   'circulating_supply': 43003138665.42289,
#   'total_supply': 50000000000.0,
#   'max_supply': 50000000000.0,
#   'ath': 41.81,
#   'ath_change_percentage': -80.31791,
#   'ath_date': '2021-09-15T10:40:28.318Z',
#   'atl': 0.703644,
#   'atl_change_percentage': 1069.37483,
#   'atl_date': '2020-01-02T17:30:24.852Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.751Z'},
#  {'id': 'paypal-usd',
#   'symbol': 'pyusd',
#   'name': 'PayPal USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/31212/large/PYUSD_Token_Logo_2x.png?1765987788',
#   'current_price': 90.5,
#   'market_cap': 348567954862,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': 348567954862,
#   'total_volume': 27092581538,
#   'high_24h': 90.89,
#   'low_24h': 90.43,
#   'price_change_24h': -0.10663985269037823,
#   'price_change_percentage_24h': -0.1177,
#   'market_cap_change_24h': -1089616278.9089355,
#   'market_cap_change_percentage_24h': -0.31162,
#   'circulating_supply': 3850644512.306796,
#   'total_supply': 3850644512.306796,
#   'max_supply': None,
#   'ath': 92.2,
#   'ath_change_percentage': -1.81499,
#   'ath_date': '2026-01-28T19:05:21.799Z',
#   'atl': 80.95,
#   'atl_change_percentage': 11.82581,
#   'atl_date': '2023-08-25T16:10:42.670Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.679Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'avax',
#   'name': 'Avalanche',
#   'image': 'https://coin-images.coingecko.com/coins/images/12559/large/Avalanche_Circle_RedWhite_Trans.png?1696512369',
#   'current_price': 800.46,
#   'market_cap': 345603659374,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': 370952588515,
#   'total_volume': 21363223113,
#   'high_24h': 830.11,
#   'low_24h': 793.27,
#   'price_change_24h': 6.14,
#   'price_change_percentage_24h': 0.77363,
#   'market_cap_change_24h': 2909669604,
#   'market_cap_change_percentage_24h': 0.84906,
#   'circulating_supply': 431771961.1772119,
#   'total_supply': 463441061.1772119,
#   'max_supply': 720000000.0,
#   'ath': 10772.35,
#   'ath_change_percentage': -92.57785,
#   'ath_date': '2021-11-21T14:18:56.538Z',
#   'atl': 204.63,
#   'atl_change_percentage': 290.72572,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:37.474Z'},
#  {'id': 'sui',
#   'symbol': 'sui',
#   'name': 'Sui',
#   'image': 'https://coin-images.coingecko.com/coins/images/26375/large/sui-ocean-square.png?1727791290',
#   'current_price': 84.76,
#   'market_cap': 326049929838,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': 847725700064,
#   'total_volume': 57082770735,
#   'high_24h': 88.34,
#   'low_24h': 84.27,
#   'price_change_24h': 0.412099,
#   'price_change_percentage_24h': 0.48857,
#   'market_cap_change_24h': 1754582858,
#   'market_cap_change_percentage_24h': 0.54104,
#   'circulating_supply': 3846172527.429665,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 458.6,
#   'ath_change_percentage': -81.51741,
#   'ath_date': '2025-01-04T22:56:18.063Z',
#   'atl': 30.36,
#   'atl_change_percentage': 179.15171,
#   'atl_date': '2023-10-19T22:05:15.703Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:42.726Z'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'image': 'https://coin-images.coingecko.com/coins/images/11939/large/shiba.png?1696511800',
#   'current_price': 0.00054615,
#   'market_cap': 321795520724,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': 321935619007,
#   'total_volume': 11911084617,
#   'high_24h': 0.00056071,
#   'low_24h': 0.00053942,
#   'price_change_24h': 5.13e-06,
#   'price_change_percentage_24h': 0.9479,
#   'market_cap_change_24h': 3242822498,
#   'market_cap_change_percentage_24h': 1.01799,
#   'circulating_supply': 589243884482636.6,
#   'total_supply': 589500420235133.5,
#   'max_supply': None,
#   'ath': 0.00645756,
#   'ath_change_percentage': -91.54246,
#   'ath_date': '2021-10-28T03:54:55.568Z',
#   'atl': 4.169e-09,
#   'atl_change_percentage': 13100196.03486,
#   'atl_date': '2020-11-28T11:26:25.838Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.865Z'},
#  {'id': 'rain',
#   'symbol': 'rain',
#   'name': 'Rain',
#   'image': 'https://coin-images.coingecko.com/coins/images/69134/large/Rain_logo_1_.png?1762952191',
#   'current_price': 0.933679,
#   'market_cap': 321418321294,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': 1087522329125,
#   'total_volume': 2882298354,
#   'high_24h': 0.989197,
#   'low_24h': 0.863851,
#   'price_change_24h': 0.03731074,
#   'price_change_percentage_24h': 4.16244,
#   'market_cap_change_24h': 16784508802,
#   'market_cap_change_percentage_24h': 5.50973,
#   'circulating_supply': 339863029409.591,
#   'total_supply': 1149930196382.051,
#   'max_supply': 1150000000000.0,
#   'ath': 0.989197,
#   'ath_change_percentage': -4.39426,
#   'ath_date': '2026-02-09T17:46:22.209Z',
#   'atl': 0.196087,
#   'atl_change_percentage': 382.30023,
#   'atl_date': '2025-09-14T08:56:57.416Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.848Z'},
#  {'id': 'the-open-network',
#   'symbol': 'ton',
#   'name': 'Toncoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/17980/large/photo_2024-09-10_17.09.00.jpeg?1725963446',
#   'current_price': 122.42,
#   'market_cap': 299682386824,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': 630884528431,
#   'total_volume': 9558458054,
#   'high_24h': 125.29,
#   'low_24h': 121.09,
#   'price_change_24h': 0.821113,
#   'price_change_percentage_24h': 0.67525,
#   'market_cap_change_24h': 2209464253,
#   'market_cap_change_percentage_24h': 0.74274,
#   'circulating_supply': 2448129765.515805,
#   'total_supply': 5153746968.663904,
#   'max_supply': None,
#   'ath': 689.6,
#   'ath_change_percentage': -82.25762,
#   'ath_date': '2024-06-15T00:36:51.509Z',
#   'atl': 38.25,
#   'atl_change_percentage': 219.83631,
#   'atl_date': '2021-09-21T00:33:11.092Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.892Z'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Cronos',
#   'image': 'https://coin-images.coingecko.com/coins/images/7310/large/cro_token_logo.png?1696507599',
#   'current_price': 7.14,
#   'market_cap': 284394157169,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': 702104094667,
#   'total_volume': 1515501103,
#   'high_24h': 7.31,
#   'low_24h': 7.02,
#   'price_change_24h': 0.11098,
#   'price_change_percentage_24h': 1.57989,
#   'market_cap_change_24h': 4849790899,
#   'market_cap_change_percentage_24h': 1.73489,
#   'circulating_supply': 39851874354.01433,
#   'total_supply': 98385158269.84421,
#   'max_supply': 100000000000.0,
#   'ath': 72.06,
#   'ath_change_percentage': -90.11123,
#   'ath_date': '2021-11-24T15:53:54.855Z',
#   'atl': 0.864137,
#   'atl_change_percentage': 724.63745,
#   'atl_date': '2019-02-08T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.677Z'},
#  {'id': 'world-liberty-financial',
#   'symbol': 'wlfi',
#   'name': 'World Liberty Financial',
#   'image': 'https://coin-images.coingecko.com/coins/images/50767/large/wlfi.png?1756438915',
#   'current_price': 9.78,
#   'market_cap': 266151252187,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': 976924024516,
#   'total_volume': 10687725865,
#   'high_24h': 10.24,
#   'low_24h': 9.57,
#   'price_change_24h': 0.090422,
#   'price_change_percentage_24h': 0.93326,
#   'market_cap_change_24h': 2135128767,
#   'market_cap_change_percentage_24h': 0.80871,
#   'circulating_supply': 27243802538.151154,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 29.22,
#   'ath_change_percentage': -66.53213,
#   'ath_date': '2025-09-01T12:20:09.597Z',
#   'atl': 8.91,
#   'atl_change_percentage': 9.8006,
#   'atl_date': '2026-02-08T17:02:14.734Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.823Z'},
#  {'id': 'tether-gold',
#   'symbol': 'xaut',
#   'name': 'Tether Gold',
#   'image': 'https://coin-images.coingecko.com/coins/images/10481/large/Tether_Gold.png?1696510471',
#   'current_price': 456761,
#   'market_cap': 237241183872,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': 325287845831,
#   'total_volume': 33538499021,
#   'high_24h': 459422,
#   'low_24h': 452538,
#   'price_change_24h': 4223.24,
#   'price_change_percentage_24h': 0.93323,
#   'market_cap_change_24h': 2111826189,
#   'market_cap_change_percentage_24h': 0.89816,
#   'circulating_supply': 519825.641699,
#   'total_supply': 712747.089,
#   'max_supply': None,
#   'ath': 514631,
#   'ath_change_percentage': -11.3154,
#   'ath_date': '2026-01-29T06:25:57.628Z',
#   'atl': 108167,
#   'atl_change_percentage': 321.94033,
#   'atl_date': '2020-03-17T09:39:32.572Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:37.805Z'},
#  {'id': 'memecore',
#   'symbol': 'm',
#   'name': 'MemeCore',
#   'image': 'https://coin-images.coingecko.com/coins/images/53247/large/square-bg-transparent.png?1752637478',
#   'current_price': 132.67,
#   'market_cap': 230143955886,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': 707911013706,
#   'total_volume': 817440214,
#   'high_24h': 139.38,
#   'low_24h': 123.73,
#   'price_change_24h': 8.18,
#   'price_change_percentage_24h': 6.57468,
#   'market_cap_change_24h': 14617160914,
#   'market_cap_change_percentage_24h': 6.78206,
#   'circulating_supply': 1734139432.850167,
#   'total_supply': 5334124022.888754,
#   'max_supply': 10000000000.0,
#   'ath': 260.79,
#   'ath_change_percentage': -49.04588,
#   'ath_date': '2025-09-18T07:27:06.144Z',
#   'atl': 4.05,
#   'atl_change_percentage': 3179.61222,
#   'atl_date': '2025-07-04T03:56:17.448Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.933Z'},
#  {'id': 'pax-gold',
#   'symbol': 'paxg',
#   'name': 'PAX Gold',
#   'image': 'https://coin-images.coingecko.com/coins/images/9519/large/paxgold.png?1696509604',
#   'current_price': 459340,
#   'market_cap': 210825696584,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': 210825696584,
#   'total_volume': 41457006217,
#   'high_24h': 461763,
#   'low_24h': 455045,
#   'price_change_24h': 4037.72,
#   'price_change_percentage_24h': 0.88682,
#   'market_cap_change_24h': 1941606563,
#   'market_cap_change_percentage_24h': 0.92951,
#   'circulating_supply': 459009.975,
#   'total_supply': 459009.975,
#   'max_supply': None,
#   'ath': 516779,
#   'ath_change_percentage': -11.214,
#   'ath_date': '2026-01-29T06:30:56.612Z',
#   'atl': 100361,
#   'atl_change_percentage': 357.17695,
#   'atl_date': '2019-10-26T15:58:49.353Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.867Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://coin-images.coingecko.com/coins/images/12504/large/uniswap-logo.png?1720676669',
#   'current_price': 303.96,
#   'market_cap': 192694885460,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': 273240390586,
#   'total_volume': 14351575097,
#   'high_24h': 322.06,
#   'low_24h': 300.49,
#   'price_change_24h': 3.47,
#   'price_change_percentage_24h': 1.15634,
#   'market_cap_change_24h': 2228925937,
#   'market_cap_change_percentage_24h': 1.17025,
#   'circulating_supply': 633943278.1680214,
#   'total_supply': 898928420.0366304,
#   'max_supply': 1000000000.0,
#   'ath': 3333.06,
#   'ath_change_percentage': -90.89001,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 75.81,
#   'atl_change_percentage': 300.54086,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:38.117Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://coin-images.coingecko.com/coins/images/12171/large/polkadot.jpg?1766533446',
#   'current_price': 115.8,
#   'market_cap': 192667588437,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': 192667588437,
#   'total_volume': 9530862178,
#   'high_24h': 121.53,
#   'low_24h': 114.7,
#   'price_change_24h': -1.7221233972648662,
#   'price_change_percentage_24h': -1.4654,
#   'market_cap_change_24h': -2532937097.273529,
#   'market_cap_change_percentage_24h': -1.29761,
#   'circulating_supply': 1663985944.950637,
#   'total_supply': 1663985944.950637,
#   'max_supply': 2100000000.0,
#   'ath': 4095.22,
#   'ath_change_percentage': -97.17696,
#   'ath_date': '2021-11-04T14:10:09.301Z',
#   'atl': 103.91,
#   'atl_change_percentage': 11.25597,
#   'atl_date': '2026-02-06T00:25:45.413Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.982Z'},
#  {'id': 'mantle',
#   'symbol': 'mnt',
#   'name': 'Mantle',
#   'image': 'https://coin-images.coingecko.com/coins/images/30980/large/MNT_Token_Logo.png?1765516974',
#   'current_price': 57.94,
#   'market_cap': 188348500344,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': 360104253700,
#   'total_volume': 2629244497,
#   'high_24h': 59.07,
#   'low_24h': 57.1,
#   'price_change_24h': 0.832104,
#   'price_change_percentage_24h': 1.45719,
#   'market_cap_change_24h': 2619296740,
#   'market_cap_change_percentage_24h': 1.41028,
#   'circulating_supply': 3252944055.636841,
#   'total_supply': 6219316794.89,
#   'max_supply': 6219316794.89,
#   'ath': 253.43,
#   'ath_change_percentage': -77.15311,
#   'ath_date': '2025-10-09T01:04:46.659Z',
#   'atl': 25.64,
#   'atl_change_percentage': 125.84607,
#   'atl_date': '2023-10-18T02:50:46.942Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:49.013Z'},
#  {'id': 'blackrock-usd-institutional-digital-liquidity-fund',
#   'symbol': 'buidl',
#   'name': 'BlackRock USD Institutional Digital Liquidity Fund',
#   'image': 'https://coin-images.coingecko.com/coins/images/36291/large/blackrock.png?1711013223',
#   'current_price': 90.55,
#   'market_cap': 163240971833,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': 163240971833,
#   'total_volume': None,
#   'high_24h': 90.81,
#   'low_24h': 90.48,
#   'price_change_24h': -0.1078420000000051,
#   'price_change_percentage_24h': -0.11895,
#   'market_cap_change_24h': -785720994.7224731,
#   'market_cap_change_percentage_24h': -0.47902,
#   'circulating_supply': 1802635529.690448,
#   'total_supply': 1802635529.690448,
#   'max_supply': None,
#   'ath': 92.2,
#   'ath_change_percentage': -1.77921,
#   'ath_date': '2026-01-28T16:00:11.347Z',
#   'atl': 83.81,
#   'atl_change_percentage': 8.05584,
#   'atl_date': '2025-05-02T06:30:16.890Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:03.498Z'},
#  {'id': 'bitget-token',
#   'symbol': 'bgb',
#   'name': 'Bitget Token',
#   'image': 'https://coin-images.coingecko.com/coins/images/11610/large/Bitget_logo.png?1736925727',
#   'current_price': 229.96,
#   'market_cap': 160957485779,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': 210840979823,
#   'total_volume': 1753726729,
#   'high_24h': 234.19,
#   'low_24h': 228.42,
#   'price_change_24h': 1.31,
#   'price_change_percentage_24h': 0.57469,
#   'market_cap_change_24h': 978067182,
#   'market_cap_change_percentage_24h': 0.61137,
#   'circulating_supply': 699992035.9787906,
#   'total_supply': 916931610.9787906,
#   'max_supply': 2000000000.0,
#   'ath': 722.65,
#   'ath_change_percentage': -68.15775,
#   'ath_date': '2024-12-27T11:41:24.992Z',
#   'atl': 1.081,
#   'atl_change_percentage': 21184.24602,
#   'atl_date': '2020-06-25T04:17:05.895Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:37.955Z'},
#  {'id': 'falcon-finance',
#   'symbol': 'usdf',
#   'name': 'Falcon USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/54558/large/ff_200_X_200.png?1740741076',
#   'current_price': 90.28,
#   'market_cap': 159059631335,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': 159059631335,
#   'total_volume': 83923958,
#   'high_24h': 90.56,
#   'low_24h': 90.11,
#   'price_change_24h': -0.05857932272473931,
#   'price_change_percentage_24h': -0.06484,
#   'market_cap_change_24h': -351918709.63153076,
#   'market_cap_change_percentage_24h': -0.22076,
#   'circulating_supply': 1761528348.31948,
#   'total_supply': 1761528348.31948,
#   'max_supply': None,
#   'ath': 92.45,
#   'ath_change_percentage': -2.37919,
#   'ath_date': '2025-05-08T21:25:42.071Z',
#   'atl': 80.47,
#   'atl_change_percentage': 12.15394,
#   'atl_date': '2025-05-13T17:40:35.908Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.727Z'},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'image': 'https://coin-images.coingecko.com/coins/images/12645/large/aave-token-round.png?1720472354',
#   'current_price': 9900.03,
#   'market_cap': 150331763253,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': 158345383181,
#   'total_volume': 30795347030,
#   'high_24h': 10415.02,
#   'low_24h': 9795.99,
#   'price_change_24h': -37.207539411374455,
#   'price_change_percentage_24h': -0.37443,
#   'market_cap_change_24h': -590015532.7298889,
#   'market_cap_change_percentage_24h': -0.39094,
#   'circulating_supply': 15190264.242195014,
#   'total_supply': 16000000.0,
#   'max_supply': 16000000.0,
#   'ath': 48387,
#   'ath_change_percentage': -79.56495,
#   'ath_date': '2021-05-18T21:19:59.514Z',
#   'atl': 1933.39,
#   'atl_change_percentage': 411.4319,
#   'atl_date': '2020-11-05T09:20:11.928Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:37.959Z'},
#  {'id': 'aster-2',
#   'symbol': 'aster',
#   'name': 'Aster',
#   'image': 'https://coin-images.coingecko.com/coins/images/69040/large/_ASTER.png?1757326782',
#   'current_price': 58.92,
#   'market_cap': 144436188250,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': 460263216649,
#   'total_volume': 32816855473,
#   'high_24h': 59.81,
#   'low_24h': 53.89,
#   'price_change_24h': 4.73,
#   'price_change_percentage_24h': 8.72552,
#   'market_cap_change_24h': 11101733485,
#   'market_cap_change_percentage_24h': 8.32623,
#   'circulating_supply': 2454947754.91,
#   'total_supply': 7822985112.446448,
#   'max_supply': 8000000000.0,
#   'ath': 213.7,
#   'ath_change_percentage': -72.42987,
#   'ath_date': '2025-09-24T11:18:14.634Z',
#   'atl': 8.76,
#   'atl_change_percentage': 572.5951,
#   'atl_date': '2025-09-17T12:05:36.771Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:37.515Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://coin-images.coingecko.com/coins/images/4463/large/WeChat_Image_20220118095654.png?1696505053',
#   'current_price': 6874.98,
#   'market_cap': 144369426476,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': 144369426476,
#   'total_volume': 1848878140,
#   'high_24h': 6973.33,
#   'low_24h': 6726.71,
#   'price_change_24h': 142.81,
#   'price_change_percentage_24h': 2.12137,
#   'market_cap_change_24h': 3250958480,
#   'market_cap_change_percentage_24h': 2.30371,
#   'circulating_supply': 21000000.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 22313,
#   'ath_change_percentage': -69.17014,
#   'ath_date': '2025-08-22T01:56:37.898Z',
#   'atl': 40.86,
#   'atl_change_percentage': 16734.94482,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:38.260Z'},
#  {'id': 'sky',
#   'symbol': 'sky',
#   'name': 'Sky',
#   'image': 'https://coin-images.coingecko.com/coins/images/39925/large/sky.jpg?1724827980',
#   'current_price': 6.24,
#   'market_cap': 143775440733,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': 146554401126,
#   'total_volume': 3568790892,
#   'high_24h': 6.46,
#   'low_24h': 6.0,
#   'price_change_24h': 0.246221,
#   'price_change_percentage_24h': 4.10623,
#   'market_cap_change_24h': 5737404345,
#   'market_cap_change_percentage_24h': 4.15639,
#   'circulating_supply': 23017766757.010494,
#   'total_supply': 23462665147.36596,
#   'max_supply': 23462665147.3,
#   'ath': 8.62,
#   'ath_change_percentage': -27.51813,
#   'ath_date': '2025-07-28T05:30:56.088Z',
#   'atl': 3.12,
#   'atl_change_percentage': 100.02436,
#   'atl_date': '2025-02-03T05:01:48.626Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:31.190Z'},
#  {'id': 'global-dollar',
#   'symbol': 'usdg',
#   'name': 'Global Dollar',
#   'image': 'https://coin-images.coingecko.com/coins/images/51281/large/GDN_USDG_Token_200x200.png?1730484111',
#   'current_price': 90.56,
#   'market_cap': 143046249181,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': 143046249181,
#   'total_volume': 2512699613,
#   'high_24h': 90.81,
#   'low_24h': 90.47,
#   'price_change_24h': -0.07228524158313121,
#   'price_change_percentage_24h': -0.07976,
#   'market_cap_change_24h': 2130339306,
#   'market_cap_change_percentage_24h': 1.51178,
#   'circulating_supply': 1579822398.475023,
#   'total_supply': 1579822398.475023,
#   'max_supply': None,
#   'ath': 143.35,
#   'ath_change_percentage': -36.8331,
#   'ath_date': '2025-01-30T00:11:05.728Z',
#   'atl': 76.61,
#   'atl_change_percentage': 18.19489,
#   'atl_date': '2024-11-11T23:55:50.604Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:37.861Z'},
#  {'id': 'hashnote-usyc',
#   'symbol': 'usyc',
#   'name': 'Circle USYC',
#   'image': 'https://coin-images.coingecko.com/coins/images/51054/large/Hashnote_SDYC_200x200.png?1730370965',
#   'current_price': 101.11,
#   'market_cap': 143213236071,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': 143213236071,
#   'total_volume': 4044.32,
#   'high_24h': 101.23,
#   'low_24h': 101.07,
#   'price_change_24h': -0.07245162095830437,
#   'price_change_percentage_24h': -0.07161,
#   'market_cap_change_24h': -106220923.03701782,
#   'market_cap_change_percentage_24h': -0.07411,
#   'circulating_supply': 1416438587.362307,
#   'total_supply': 1416438587.362307,
#   'max_supply': None,
#   'ath': 102.4,
#   'ath_change_percentage': -1.25715,
#   'ath_date': '2026-01-30T13:28:05.498Z',
#   'atl': 86.89,
#   'atl_change_percentage': 16.3626,
#   'atl_date': '2024-12-05T22:31:20.475Z',
#   'roi': None,
#   'last_updated': '2026-02-10T05:42:11.457Z'},
#  {'id': 'pepe',
#   'symbol': 'pepe',
#   'name': 'Pepe',
#   'image': 'https://coin-images.coingecko.com/coins/images/29850/large/pepe-token.jpeg?1696528776',
#   'current_price': 0.00033194,
#   'market_cap': 139641958140,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': 139641958140,
#   'total_volume': 28105216001,
#   'high_24h': 0.00034851,
#   'low_24h': 0.00032859,
#   'price_change_24h': -8.3147728846e-07,
#   'price_change_percentage_24h': -0.24986,
#   'market_cap_change_24h': -606968182.3276978,
#   'market_cap_change_percentage_24h': -0.43278,
#   'circulating_supply': 420690000000000.0,
#   'total_supply': 420690000000000.0,
#   'max_supply': 420690000000000.0,
#   'ath': 0.00237833,
#   'ath_change_percentage': -86.04315,
#   'ath_date': '2024-12-09T16:30:35.828Z',
#   'atl': 4.52e-06,
#   'atl_change_percentage': 7243.23273,
#   'atl_date': '2023-04-18T02:14:41.591Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.944Z'},
#  {'id': 'htx-dao',
#   'symbol': 'htx',
#   'name': 'HTX DAO',
#   'image': 'https://coin-images.coingecko.com/coins/images/35491/large/Frame_1321318576.png?1708908626',
#   'current_price': 0.00015118,
#   'market_cap': 138546666721,
#   'market_cap_rank': 51,
#   'fully_diluted_valuation': 138546666721,
#   'total_volume': 656689531,
#   'high_24h': 0.00015145,
#   'low_24h': 0.00015038,
#   'price_change_24h': 3.2292e-08,
#   'price_change_percentage_24h': 0.02136,
#   'market_cap_change_24h': 78494967,
#   'market_cap_change_percentage_24h': 0.05669,
#   'circulating_supply': 916533066327098.8,
#   'total_supply': 916533066327098.8,
#   'max_supply': 999990000000000.0,
#   'ath': 0.00031771,
#   'ath_change_percentage': -52.42019,
#   'ath_date': '2024-12-04T00:16:20.770Z',
#   'atl': 6.739e-05,
#   'atl_change_percentage': 124.30295,
#   'atl_date': '2024-08-05T13:31:33.427Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:37.540Z'},
#  {'id': 'ripple-usd',
#   'symbol': 'rlusd',
#   'name': 'Ripple USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/39651/large/RLUSD_200x200_%281%29.png?1727376633',
#   'current_price': 90.53,
#   'market_cap': 137772240144,
#   'market_cap_rank': 52,
#   'fully_diluted_valuation': 137772240144,
#   'total_volume': 12149531234,
#   'high_24h': 90.8,
#   'low_24h': 90.49,
#   'price_change_24h': -0.10956614502714501,
#   'price_change_percentage_24h': -0.12088,
#   'market_cap_change_24h': 2544825981,
#   'market_cap_change_percentage_24h': 1.88189,
#   'circulating_supply': 1521941230.127497,
#   'total_supply': 1521941230.127497,
#   'max_supply': None,
#   'ath': 92.15,
#   'ath_change_percentage': -1.76863,
#   'ath_date': '2026-01-28T19:15:21.035Z',
#   'atl': 81.72,
#   'atl_change_percentage': 10.77333,
#   'atl_date': '2024-12-18T04:40:40.880Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:48.837Z'},
#  {'id': 'bittensor',
#   'symbol': 'tao',
#   'name': 'Bittensor',
#   'image': 'https://coin-images.coingecko.com/coins/images/28452/large/ARUsPeNQ_400x400.jpeg?1696527447',
#   'current_price': 14287.58,
#   'market_cap': 137138281527,
#   'market_cap_rank': 53,
#   'fully_diluted_valuation': 300068414971,
#   'total_volume': 8694052833,
#   'high_24h': 14773.53,
#   'low_24h': 14029.06,
#   'price_change_24h': 130.26,
#   'price_change_percentage_24h': 0.92011,
#   'market_cap_change_24h': 1263586577,
#   'market_cap_change_percentage_24h': 0.92996,
#   'circulating_supply': 9597491.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 62722,
#   'ath_change_percentage': -77.22422,
#   'ath_date': '2024-12-06T12:15:28.199Z',
#   'atl': 2535.93,
#   'atl_change_percentage': 463.32196,
#   'atl_date': '2023-05-14T08:57:53.732Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:25:38.531Z'},
#  {'id': 'bfusd',
#   'symbol': 'bfusd',
#   'name': 'BFUSD',
#   'image': 'https://coin-images.coingecko.com/coins/images/68227/large/bfusd.png?1755132827',
#   'current_price': 90.49,
#   'market_cap': 119437163582,
#   'market_cap_rank': 54,
#   'fully_diluted_valuation': 119437163582,
#   'total_volume': 569953037,
#   'high_24h': 90.75,
#   'low_24h': 90.39,
#   'price_change_24h': -0.0849481105708918,
#   'price_change_percentage_24h': -0.09379,
#   'market_cap_change_24h': -113299830.96159363,
#   'market_cap_change_percentage_24h': -0.09477,
#   'circulating_supply': 1320000000.0,
#   'total_supply': 1320000000.0,
#   'max_supply': None,
#   'ath': 92.02,
#   'ath_change_percentage': -1.67076,
# ...
#  {'id': 'nillion',
#   'symbol': 'nil',
#   'name': 'Nillion',
#   'image': 'https://coin-images.coingecko.com/coins/images/39082/large/nillion.jpg?1723033507',
#   'current_price': 4.1,
#   'market_cap': 1246504561,
#   'market_cap_rank': 983,
#   'fully_diluted_valuation': 4105405934,
#   'total_volume': 166286664,
#   'high_24h': 4.28,
#   'low_24h': 4.06,
#   'price_change_24h': 0.04341419,
#   'price_change_percentage_24h': 1.07001,
#   'market_cap_change_24h': 16813380,
#   'market_cap_change_percentage_24h': 1.36728,
#   'circulating_supply': 303625166.664,
#   'total_supply': 1000000000.0,
#   'max_supply': None,
#   'ath': 76.79,
#   'ath_change_percentage': -94.65445,
#   'ath_date': '2025-03-24T13:30:35.773Z',
#   'atl': 3.5,
#   'atl_change_percentage': 17.43728,
#   'atl_date': '2026-02-06T00:25:15.698Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:26:17.323Z'},
#  {'id': 'insure',
#   'symbol': 'sure',
#   'name': 'inSure DeFi',
#   'image': 'https://coin-images.coingecko.com/coins/images/10354/large/logo-grey-circle.png?1696510355',
#   'current_price': 0.0470572,
#   'market_cap': 1245778134,
#   'market_cap_rank': 984,
#   'fully_diluted_valuation': 4139723282,
#   'total_volume': 46321,
#   'high_24h': 0.04893898,
#   'low_24h': 0.03949585,
#   'price_change_24h': 0.00756135,
#   'price_change_percentage_24h': 19.14466,
#   'market_cap_change_24h': 199848786,
#   'market_cap_change_percentage_24h': 19.10729,
#   'circulating_supply': 26482078217.416843,
#   'total_supply': 88000000000.0,
#   'max_supply': 88000000000.0,
#   'ath': 8.34,
#   'ath_change_percentage': -99.43561,
#   'ath_date': '2021-01-06T21:22:32.766Z',
#   'atl': 0.00410963,
#   'atl_change_percentage': 1044.68512,
#   'atl_date': '2025-12-31T20:56:06.581Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:26:17.213Z'},
#  {'id': '69420',
#   'symbol': '69420',
#   'name': '69420',
#   'image': 'https://coin-images.coingecko.com/coins/images/32830/large/bg_f8f8f8-flat_750x_075_f-pad_750x1000_f8f8f8.jpg?1699585611',
#   'current_price': 0.01900858,
#   'market_cap': 1188080197,
#   'market_cap_rank': 985,
#   'fully_diluted_valuation': 1319575939,
#   'total_volume': 0.0,
#   'high_24h': None,
#   'low_24h': None,
#   'price_change_24h': None,
#   'price_change_percentage_24h': None,
#   'market_cap_change_24h': None,
#   'market_cap_change_percentage_24h': None,
#   'circulating_supply': 62502297000.0,
#   'total_supply': 69420000000.0,
#   'max_supply': 69420000000.0,
#   'ath': 0.04419058,
#   'ath_change_percentage': -56.98498,
#   'ath_date': '2025-07-21T19:21:50.847Z',
#   'atl': 1.043e-05,
#   'atl_change_percentage': 182112.04389,
#   'atl_date': '2023-12-29T18:00:11.737Z',
#   'roi': None,
#   'last_updated': '2026-02-06T21:38:24.350Z'},
#  {'id': 'gems-vip',
#   'symbol': 'gems',
#   'name': 'Gems VIP',
#   'image': 'https://coin-images.coingecko.com/coins/images/38725/large/200x200.png?1718478016',
#   'current_price': 1.92,
#   'market_cap': 1233103382,
#   'market_cap_rank': 986,
#   'fully_diluted_valuation': 1604856027,
#   'total_volume': 89186964,
#   'high_24h': 2.04,
#   'low_24h': 1.89,
#   'price_change_24h': -0.004124063327350047,
#   'price_change_percentage_24h': -0.21422,
#   'market_cap_change_24h': -4620581.6029372215,
#   'market_cap_change_percentage_24h': -0.37331,
#   'circulating_supply': 643831656.8930804,
#   'total_supply': 837932269.1767285,
#   'max_supply': 843303980.0,
#   'ath': 26.92,
#   'ath_change_percentage': -92.88621,
#   'ath_date': '2024-10-18T18:32:07.704Z',
#   'atl': 1.18,
#   'atl_change_percentage': 62.16279,
#   'atl_date': '2025-04-03T11:16:29.438Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:26:17.313Z'},
#  {'id': 'alchemix-usd',
#   'symbol': 'alusd',
#   'name': 'Alchemix USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/14114/large/Alchemix_USD.png?1696513835',
#   'current_price': 89.36,
#   'market_cap': 1232093356,
#   'market_cap_rank': 987,
#   'fully_diluted_valuation': 1232093356,
#   'total_volume': 5041238,
#   'high_24h': 89.77,
#   'low_24h': 89.22,
#   'price_change_24h': -0.09040514215783446,
#   'price_change_percentage_24h': -0.10107,
#   'market_cap_change_24h': -259495.0895242691,
#   'market_cap_change_percentage_24h': -0.02106,
#   'circulating_supply': 13777964.77508556,
#   'total_supply': 13777964.77508556,
#   'max_supply': None,
#   'ath': 154.11,
#   'ath_change_percentage': -41.97458,
#   'ath_date': '2021-03-21T19:53:32.860Z',
#   'atl': 4.36,
#   'atl_change_percentage': 1949.16768,
#   'atl_date': '2021-03-19T22:40:28.697Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:26:17.318Z'},
#  {'id': 'dent',
#   'symbol': 'dent',
#   'name': 'Dent',
#   'image': 'https://coin-images.coingecko.com/coins/images/1152/large/DENT_Token.png?1718837065',
#   'current_price': 0.01289361,
#   'market_cap': 1228556842,
#   'market_cap_rank': 988,
#   'fully_diluted_valuation': 1284362919,
#   'total_volume': 112961993,
#   'high_24h': 0.01360898,
#   'low_24h': 0.01276972,
#   'price_change_24h': -0.000249965193725129,
#   'price_change_percentage_24h': -1.90181,
#   'market_cap_change_24h': -26142159.37727642,
#   'market_cap_change_percentage_24h': -2.08354,
#   'circulating_supply': 95654960452.73587,
#   'total_supply': 100000000000.0,
#   'max_supply': None,
#   'ath': 6.4,
#   'ath_change_percentage': -99.79949,
#   'ath_date': '2018-01-09T00:00:00.000Z',
#   'atl': 0.00533579,
#   'atl_change_percentage': 140.6162,
#   'atl_date': '2020-03-13T02:29:09.754Z',
#   'roi': {'times': -0.719365541949684,
#    'currency': 'eth',
#    'percentage': -71.93655419496841},
#   'last_updated': '2026-02-10T14:26:17.330Z'},
#  {'id': 'real-token',
#   'symbol': 'real',
#   'name': 'Real Token',
#   'image': 'https://coin-images.coingecko.com/coins/images/71260/large/logo_%2813%29.png?1766740872',
#   'current_price': 1.22,
#   'market_cap': 1224890220,
#   'market_cap_rank': 989,
#   'fully_diluted_valuation': 1224890220,
#   'total_volume': 2159777,
#   'high_24h': 1.33,
#   'low_24h': 1.17,
#   'price_change_24h': -0.06277476507449697,
#   'price_change_percentage_24h': -4.87473,
#   'market_cap_change_24h': -57620324.007036924,
#   'market_cap_change_percentage_24h': -4.49278,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 3.73,
#   'ath_change_percentage': -67.20221,
#   'ath_date': '2026-01-15T20:21:47.763Z',
#   'atl': 1.11,
#   'atl_change_percentage': 10.2822,
#   'atl_date': '2026-02-05T18:51:56.887Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:26:17.261Z'},
#  {'id': 'stablr-euro',
#   'symbol': 'eurr',
#   'name': 'StablR Euro',
#   'image': 'https://coin-images.coingecko.com/coins/images/53720/large/stablreuro-logo.png?1737125898',
#   'current_price': 105.83,
#   'market_cap': 1224061242,
#   'market_cap_rank': 990,
#   'fully_diluted_valuation': 1224061242,
#   'total_volume': 432995888,
#   'high_24h': 107.4,
#   'low_24h': 105.64,
#   'price_change_24h': 0.128307,
#   'price_change_percentage_24h': 0.12139,
#   'market_cap_change_24h': 1592631,
#   'market_cap_change_percentage_24h': 0.13028,
#   'circulating_supply': 11566644.46,
#   'total_supply': 11566644.46,
#   'max_supply': None,
#   'ath': 129.83,
#   'ath_change_percentage': -18.50334,
#   'ath_date': '2025-02-16T06:45:52.930Z',
#   'atl': 87.68,
#   'atl_change_percentage': 20.6777,
#   'atl_date': '2025-02-03T01:55:45.484Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:26:17.365Z'},
#  {'id': 'pulsechain-peacock',
#   'symbol': 'pcock',
#   'name': 'PulseChain Peacock',
#   'image': 'https://coin-images.coingecko.com/coins/images/67981/large/1000021208.png?1754479800',
#   'current_price': 1.45,
#   'market_cap': 1222031900,
#   'market_cap_rank': 994,
#   'fully_diluted_valuation': 1222031900,
#   'total_volume': 8841560,
#   'high_24h': 1.52,
#   'low_24h': 1.4,
#   'price_change_24h': -0.021273373858168965,
#   'price_change_percentage_24h': -1.45069,
#   'market_cap_change_24h': -17990123.150916576,
#   'market_cap_change_percentage_24h': -1.45079,
#   'circulating_supply': 845603820.3082316,
#   'total_supply': 845603820.3082316,
#   'max_supply': 1000000000.0,
#   'ath': 2.55,
#   'ath_change_percentage': -43.62735,
#   'ath_date': '2025-11-03T21:02:08.838Z',
#   'atl': 0.168783,
#   'atl_change_percentage': 751.93088,
#   'atl_date': '2025-09-22T16:10:22.122Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:26:17.419Z'},
#  {'id': 'usdm-2',
#   'symbol': 'usdm',
#   'name': 'USDM',
#   'image': 'https://coin-images.coingecko.com/coins/images/38755/large/USDM_Logo_01.jpg?1744966625',
#   'current_price': 92.34,
#   'market_cap': 1218956739,
#   'market_cap_rank': 992,
#   'fully_diluted_valuation': 1218956739,
#   'total_volume': 35910845,
#   'high_24h': 94.09,
#   'low_24h': 89.85,
#   'price_change_24h': 0.452436,
#   'price_change_percentage_24h': 0.49236,
#   'market_cap_change_24h': 23715337,
#   'market_cap_change_percentage_24h': 1.98415,
#   'circulating_supply': 13199684.31,
#   'total_supply': 13199684.31,
#   'max_supply': None,
#   'ath': 122.91,
#   'ath_change_percentage': -24.8664,
#   'ath_date': '2025-03-02T16:41:52.531Z',
#   'atl': 46.98,
#   'atl_change_percentage': 96.5566,
#   'atl_date': '2025-10-10T21:27:48.867Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:26:17.354Z'},
#  {'id': 'funfair',
#   'symbol': 'fun',
#   'name': 'FUNToken',
#   'image': 'https://coin-images.coingecko.com/coins/images/761/large/FUN.png?1696501914',
#   'current_price': 0.114938,
#   'market_cap': 1218216318,
#   'market_cap_rank': 991,
#   'fully_diluted_valuation': 1264305904,
#   'total_volume': 174210908,
#   'high_24h': 0.118861,
#   'low_24h': 0.112707,
#   'price_change_24h': 0.00139501,
#   'price_change_percentage_24h': 1.22862,
#   'market_cap_change_24h': 14799787,
#   'market_cap_change_percentage_24h': 1.22981,
#   'circulating_supply': 10598879189.265394,
#   'total_supply': 10999873621.0,
#   'max_supply': None,
#   'ath': 12.13,
#   'ath_change_percentage': -99.04944,
#   'ath_date': '2018-01-08T00:00:00.000Z',
#   'atl': 0.079657,
#   'atl_change_percentage': 44.69725,
#   'atl_date': '2020-03-13T02:22:42.216Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:26:17.344Z'},
#  {'id': 'intuition',
#   'symbol': 'trust',
#   'name': 'Intuition',
#   'image': 'https://coin-images.coingecko.com/coins/images/55976/large/intuition_trust.jpg?1747904133',
#   'current_price': 6.78,
#   'market_cap': 1217980746,
#   'market_cap_rank': 998,
#   'fully_diluted_valuation': 6779824354,
#   'total_volume': 441608311,
#   'high_24h': 7.02,
#   'low_24h': 6.41,
#   'price_change_24h': 0.368624,
#   'price_change_percentage_24h': 5.74968,
#   'market_cap_change_24h': 63492591,
#   'market_cap_change_percentage_24h': 5.49963,
#   'circulating_supply': 179647832.0,
#   'total_supply': 1000000000.0,
#   'max_supply': None,
#   'ath': 53.71,
#   'ath_change_percentage': -87.39888,
#   'ath_date': '2025-11-05T09:29:25.680Z',
#   'atl': 5.78,
#   'atl_change_percentage': 17.18568,
#   'atl_date': '2026-02-06T00:26:31.129Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:26:17.439Z'},
#  {'id': 'the-innovation-game',
#   'symbol': 'tig',
#   'name': 'The Innovation Game',
#   'image': 'https://coin-images.coingecko.com/coins/images/50669/large/tiglogo-clean_200x200.png?1739955821',
#   'current_price': 45.57,
#   'market_cap': 1217169139,
#   'market_cap_rank': 993,
#   'fully_diluted_valuation': 2159105912,
#   'total_volume': 259168529,
#   'high_24h': 47.09,
#   'low_24h': 43.3,
#   'price_change_24h': 1.69,
#   'price_change_percentage_24h': 3.8552,
#   'market_cap_change_24h': 37716288,
#   'market_cap_change_percentage_24h': 3.19778,
#   'circulating_supply': 26709353.501361884,
#   'total_supply': 47379054.54261072,
#   'max_supply': 131040000.0,
#   'ath': 364.24,
#   'ath_change_percentage': -87.48903,
#   'ath_date': '2024-12-02T03:15:45.258Z',
#   'atl': 9.92,
#   'atl_change_percentage': 359.19519,
#   'atl_date': '2025-05-26T17:55:47.832Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:26:17.507Z'},
#  {'id': 'marinade',
#   'symbol': 'mnde',
#   'name': 'Marinade',
#   'image': 'https://coin-images.coingecko.com/coins/images/18867/large/c1.png?1750668234',
#   'current_price': 2.24,
#   'market_cap': 1215292690,
#   'market_cap_rank': 995,
#   'fully_diluted_valuation': 1556922165,
#   'total_volume': 68116902,
#   'high_24h': 2.37,
#   'low_24h': 2.21,
#   'price_change_24h': -0.0846748823621577,
#   'price_change_percentage_24h': -3.63872,
#   'market_cap_change_24h': -46929212.03810477,
#   'market_cap_change_percentage_24h': -3.71798,
#   'circulating_supply': 546399977.0,
#   'total_supply': 699997821.3403481,
#   'max_supply': 1000000000.0,
#   'ath': 123.52,
#   'ath_change_percentage': -98.19288,
#   'ath_date': '2021-10-09T00:00:00.000Z',
#   'atl': 2.01,
#   'atl_change_percentage': 11.209,
#   'atl_date': '2026-02-06T00:30:57.431Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:26:17.250Z'},
#  {'id': 'vanar-chain',
#   'symbol': 'vanry',
#   'name': 'Vanar Chain',
#   'image': 'https://coin-images.coingecko.com/coins/images/33466/large/apple-touch-icon.png?1701942541',
#   'current_price': 0.565075,
#   'market_cap': 1214307001,
#   'market_cap_rank': 996,
#   'fully_diluted_valuation': 1220629521,
#   'total_volume': 287152161,
#   'high_24h': 0.570666,
#   'low_24h': 0.548508,
#   'price_change_24h': 0.01636031,
#   'price_change_percentage_24h': 2.98157,
#   'market_cap_change_24h': 37476837,
#   'market_cap_change_percentage_24h': 3.18456,
#   'circulating_supply': 2150121599.0,
#   'total_supply': 2161316616.0,
#   'max_supply': 2400000000.0,
#   'ath': 30.84,
#   'ath_change_percentage': -98.16973,
#   'ath_date': '2024-03-13T13:00:51.153Z',
#   'atl': 0.462367,
#   'atl_change_percentage': 22.07599,
#   'atl_date': '2026-02-06T00:22:20.881Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:26:17.322Z'},
#  {'id': 'renzo',
#   'symbol': 'rez',
#   'name': 'Renzo',
#   'image': 'https://coin-images.coingecko.com/coins/images/37327/large/renzo_200x200.png?1714025012',
#   'current_price': 0.269308,
#   'market_cap': 1210304645,
#   'market_cap_rank': 997,
#   'fully_diluted_valuation': 2641420957,
#   'total_volume': 387338970,
#   'high_24h': 0.282179,
#   'low_24h': 0.266549,
#   'price_change_24h': -0.001957632499163642,
#   'price_change_percentage_24h': -0.72167,
#   'market_cap_change_24h': -8397921.687683344,
#   'market_cap_change_percentage_24h': -0.68909,
#   'circulating_supply': 4497083777.41274,
#   'total_supply': 9814629224.482912,
#   'max_supply': 10000000000.0,
#   'ath': 23.21,
#   'ath_change_percentage': -98.84073,
#   'ath_date': '2024-04-30T11:50:54.665Z',
#   'atl': 0.257682,
#   'atl_change_percentage': 4.403,
#   'atl_date': '2026-02-06T00:26:20.323Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:26:17.381Z'},
#  {'id': 'researchcoin',
#   'symbol': 'rsc',
#   'name': 'ResearchCoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/28146/large/RH_BOTTLE_CLEAN_Aug_2024_1.png?1732742001',
#   'current_price': 8.99,
#   'market_cap': 1206155870,
#   'market_cap_rank': 999,
#   'fully_diluted_valuation': 8990606385,
#   'total_volume': 48868213,
#   'high_24h': 9.16,
#   'low_24h': 8.76,
#   'price_change_24h': 0.204744,
#   'price_change_percentage_24h': 2.3301,
#   'market_cap_change_24h': 27446035,
#   'market_cap_change_percentage_24h': 2.32848,
#   'circulating_supply': 134157343.59847884,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 129.28,
#   'ath_change_percentage': -93.0491,
#   'ath_date': '2025-01-05T01:15:48.083Z',
#   'atl': 0.255189,
#   'atl_change_percentage': 3421.25421,
#   'atl_date': '2022-12-27T08:35:37.428Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:26:17.343Z'},
#  {'id': 'xborg',
#   'symbol': 'xbg',
#   'name': 'XBorg',
#   'image': 'https://coin-images.coingecko.com/coins/images/39830/large/Frame_1430106660.png?1760774022',
#   'current_price': 3.0,
#   'market_cap': 1205269973,
#   'market_cap_rank': 1000,
#   'fully_diluted_valuation': 3004349656,
#   'total_volume': 1860275,
#   'high_24h': 3.22,
#   'low_24h': 2.94,
#   'price_change_24h': -0.14553166656691818,
#   'price_change_percentage_24h': -4.61987,
#   'market_cap_change_24h': -58482595.13450217,
#   'market_cap_change_percentage_24h': -4.62769,
#   'circulating_supply': 401175000.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 35.3,
#   'ath_change_percentage': -91.491,
#   'ath_date': '2024-12-16T01:05:28.253Z',
#   'atl': 1.98,
#   'atl_change_percentage': 52.06845,
#   'atl_date': '2026-02-06T00:52:09.045Z',
#   'roi': None,
#   'last_updated': '2026-02-10T14:26:17.339Z'}]

# %%
import datetime

filtered_cryptocurrency = []

for coin in cryptocurrency:
    filtered_coin = {
        'id': coin.get('id'),
        'symbol': coin.get('symbol'),
        'name': coin.get('name'),
        'current_price': coin.get('current_price'),
        'market_cap': coin.get('market_cap'),
        'market_cap_rank': coin.get('market_cap_rank'),
        'total_volume': coin.get('total_volume'),
        'circulating_supply': coin.get('circulating_supply'),
        'total_supply': coin.get('total_supply'),
        'ath': coin.get('ath'),
        'atl': coin.get('atl')
    }

    # Extract only the date part from 'last_updated'
    last_updated_str = coin.get('last_updated')
    if last_updated_str:
        try:
            # Assuming format like '2026-02-06T13:19:11.648Z'
            dt_object = datetime.datetime.fromisoformat(last_updated_str.replace('Z', '+00:00'))
            filtered_coin['last_updated_date'] = dt_object.date().isoformat()
        except ValueError:
            filtered_coin['last_updated_date'] = None # Handle cases where date format might differ
    else:
        filtered_coin['last_updated_date'] = None

    filtered_cryptocurrency.append(filtered_coin)

cryptocurrency = filtered_cryptocurrency

print(f"Total filtered records: {len(cryptocurrency)}")
display(cryptocurrency)
# Out:
# Total filtered records: 1000
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'current_price': 6275065,
#   'market_cap': 125599657273485,
#   'market_cap_rank': 1,
#   'total_volume': 4480093453444,
#   'circulating_supply': 19987200.0,
#   'total_supply': 19987200.0,
#   'ath': 11187013,
#   'atl': 3993.42,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'current_price': 183804,
#   'market_cap': 22204293665548,
#   'market_cap_rank': 2,
#   'total_volume': 2610841377798,
#   'circulating_supply': 120692588.7575344,
#   'total_supply': 120692588.7575344,
#   'ath': 431946,
#   'atl': 28.13,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'current_price': 90.51,
#   'market_cap': 16700897819975,
#   'market_cap_rank': 3,
#   'total_volume': 7765371860719,
#   'circulating_supply': 184517936950.033,
#   'total_supply': 189984874186.7962,
#   'ath': 105.52,
#   'atl': 36.86,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'current_price': 128.48,
#   'market_cap': 7826869690438,
#   'market_cap_rank': 4,
#   'total_volume': 251539484784,
#   'circulating_supply': 60917315351.0,
#   'total_supply': 99985721048.0,
#   'ath': 313.99,
#   'atl': 0.159343,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'BNB',
#   'current_price': 56547,
#   'market_cap': 7719397063749,
#   'market_cap_rank': 5,
#   'total_volume': 110216717199,
#   'circulating_supply': 136359527.5799999,
#   'total_supply': 136359527.5799999,
#   'ath': 121422,
#   'atl': 2.58,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USDC',
#   'current_price': 90.55,
#   'market_cap': 6622452954035,
#   'market_cap_rank': 6,
#   'total_volume': 1011775776682,
#   'circulating_supply': 73137440593.27045,
#   'total_supply': 73139979021.2632,
#   'ath': 1327.87,
#   'atl': 65.31,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'current_price': 7666.65,
#   'market_cap': 4354023844649,
#   'market_cap_rank': 7,
#   'total_volume': 363126931495,
#   'circulating_supply': 567523885.1499375,
#   'total_supply': 620122679.2697487,
#   'ath': 25396,
#   'atl': 38.03,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'current_price': 25.17,
#   'market_cap': 2383363317978,
#   'market_cap_rank': 8,
#   'total_volume': 53077987326,
#   'circulating_supply': 94720982243.3949,
#   'total_supply': 94721074509.4697,
#   'ath': 36.53,
#   'atl': 0.117589,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'current_price': 8.45,
#   'market_cap': 1426225828642,
#   'market_cap_rank': 9,
#   'total_volume': 85509722863,
#   'circulating_supply': 168669383126.5791,
#   'total_supply': 168682893126.5791,
#   'ath': 53.62,
#   'atl': 0.00552883,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'figure-heloc',
#   'symbol': 'figr_heloc',
#   'name': 'Figure Heloc',
#   'current_price': 93.65,
#   'market_cap': 1404883375617,
#   'market_cap_rank': 10,
#   'total_volume': 844940964,
#   'circulating_supply': 15001825015.047,
#   'total_supply': 15001825015.047,
#   'ath': 120.96,
#   'atl': 13.78,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'whitebit',
#   'symbol': 'wbt',
#   'name': 'WhiteBIT Coin',
#   'current_price': 4716.89,
#   'market_cap': 1008062491520,
#   'market_cap_rank': 11,
#   'total_volume': 11429520770,
#   'circulating_supply': 213729819.0,
#   'total_supply': 320229819.0,
#   'ath': 5758.63,
#   'atl': 245.71,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'current_price': 47086,
#   'market_cap': 941751372118,
#   'market_cap_rank': 12,
#   'total_volume': 31997245533,
#   'circulating_supply': 19992821.77165078,
#   'total_supply': 19993099.89665078,
#   'ath': 242198,
#   'atl': 5536.54,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'current_price': 23.98,
#   'market_cap': 881001246004,
#   'market_cap_rank': 13,
#   'total_volume': 35200515221,
#   'circulating_supply': 36794311012.29324,
#   'total_supply': 45000000000.0,
#   'ath': 225.26,
#   'atl': 1.38,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'usds',
#   'symbol': 'usds',
#   'name': 'USDS',
#   'current_price': 90.55,
#   'market_cap': 871086006403,
#   'market_cap_rank': 14,
#   'total_volume': 133550398,
#   'circulating_supply': 9627904133.778423,
#   'total_supply': 9627904133.778423,
#   'ath': 92.23,
#   'atl': 79.67,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'leo-token',
#   'symbol': 'leo',
#   'name': 'LEO Token',
#   'current_price': 778.65,
#   'market_cap': 717436400109,
#   'market_cap_rank': 15,
#   'total_volume': 82093562,
#   'circulating_supply': 921402986.9,
#   'total_supply': 985239504.0,
#   'ath': 888.26,
#   'atl': 56.97,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'hyperliquid',
#   'symbol': 'hype',
#   'name': 'Hyperliquid',
#   'current_price': 2708.18,
#   'market_cap': 646200642306,
#   'market_cap_rank': 16,
#   'total_volume': 28192237651,
#   'circulating_supply': 238385315.9541414,
#   'total_supply': 962274028.9541414,
#   'ath': 5213.52,
#   'atl': 321.88,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'ethena-usde',
#   'symbol': 'usde',
#   'name': 'Ethena USDe',
#   'current_price': 90.43,
#   'market_cap': 581666175550,
#   'market_cap_rank': 17,
#   'total_volume': 6379244414,
#   'circulating_supply': 6432668579.898262,
#   'total_supply': 6432668579.898262,
#   'ath': 92.91,
#   'atl': 78.05,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'canton-network',
#   'symbol': 'cc',
#   'name': 'Canton',
#   'current_price': 14.87,
#   'market_cap': 560804048140,
#   'market_cap_rank': 18,
#   'total_volume': 1282258850,
#   'circulating_supply': 37711955931.79735,
#   'total_supply': 37711955931.79735,
#   'ath': 17.72,
#   'atl': 5.31,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'current_price': 782.06,
#   'market_cap': 553373760762,
#   'market_cap_rank': 19,
#   'total_volume': 31697150815,
#   'circulating_supply': 708099970.4525867,
#   'total_supply': 1000000000.0,
#   'ath': 3862.15,
#   'atl': 9.55,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'current_price': 29963,
#   'market_cap': 553149711914,
#   'market_cap_rank': 20,
#   'total_volume': 7764897283,
#   'circulating_supply': 18446744.07370955,
#   'total_supply': 18446744.07370955,
#   'ath': 72026,
#   'atl': 13.57,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'usd1-wlfi',
#   'symbol': 'usd1',
#   'name': 'USD1',
#   'current_price': 90.52,
#   'market_cap': 486597362869,
#   'market_cap_rank': 21,
#   'total_volume': 150950635740,
#   'circulating_supply': 5376667544.155274,
#   'total_supply': 5376667544.155274,
#   'ath': 92.17,
#   'atl': 83.75,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'current_price': 14.23,
#   'market_cap': 465468757924,
#   'market_cap_rank': 22,
#   'total_volume': 9471087507,
#   'circulating_supply': 32718821596.16952,
#   'total_supply': 50001786883.65895,
#   'ath': 58.01,
#   'atl': 0.02966141,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'current_price': 90.51,
#   'market_cap': 377842067727,
#   'market_cap_rank': 23,
#   'total_volume': 7109590108,
#   'circulating_supply': 4174732189.038614,
#   'total_supply': 4174732189.038614,
#   'ath': 92.29,
#   'atl': 64.85,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'current_price': 4851.55,
#   'market_cap': 372634785981,
#   'market_cap_rank': 24,
#   'total_volume': 28352954359,
#   'circulating_supply': 76830789.48347135,
#   'total_supply': 76833651.98347135,
#   'ath': 30082,
#   'atl': 72.12,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'zcash',
#   'symbol': 'zec',
#   'name': 'Zcash',
#   'current_price': 21577,
#   'market_cap': 356546599781,
#   'market_cap_rank': 25,
#   'total_volume': 30829841903,
#   'circulating_supply': 16511426.7280448,
#   'total_supply': 16511426.7280448,
#   'ath': 211171,
#   'atl': 1342.38,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'name': 'Hedera',
#   'current_price': 8.23,
#   'market_cap': 354288842178,
#   'market_cap_rank': 26,
#   'total_volume': 9753737917,
#   'circulating_supply': 43003138665.42289,
#   'total_supply': 50000000000.0,
#   'ath': 41.81,
#   'atl': 0.703644,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'paypal-usd',
#   'symbol': 'pyusd',
#   'name': 'PayPal USD',
#   'current_price': 90.5,
#   'market_cap': 348567954862,
#   'market_cap_rank': 27,
#   'total_volume': 27092581538,
#   'circulating_supply': 3850644512.306796,
#   'total_supply': 3850644512.306796,
#   'ath': 92.2,
#   'atl': 80.95,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'avalanche-2',
#   'symbol': 'avax',
#   'name': 'Avalanche',
#   'current_price': 800.46,
#   'market_cap': 345603659374,
#   'market_cap_rank': 28,
#   'total_volume': 21363223113,
#   'circulating_supply': 431771961.1772119,
#   'total_supply': 463441061.1772119,
#   'ath': 10772.35,
#   'atl': 204.63,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'sui',
#   'symbol': 'sui',
#   'name': 'Sui',
#   'current_price': 84.76,
#   'market_cap': 326049929838,
#   'market_cap_rank': 29,
#   'total_volume': 57082770735,
#   'circulating_supply': 3846172527.429665,
#   'total_supply': 10000000000.0,
#   'ath': 458.6,
#   'atl': 30.36,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'current_price': 0.00054615,
#   'market_cap': 321795520724,
#   'market_cap_rank': 30,
#   'total_volume': 11911084617,
#   'circulating_supply': 589243884482636.6,
#   'total_supply': 589500420235133.5,
#   'ath': 0.00645756,
#   'atl': 4.169e-09,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'rain',
#   'symbol': 'rain',
#   'name': 'Rain',
#   'current_price': 0.933679,
#   'market_cap': 321418321294,
#   'market_cap_rank': 31,
#   'total_volume': 2882298354,
#   'circulating_supply': 339863029409.591,
#   'total_supply': 1149930196382.051,
#   'ath': 0.989197,
#   'atl': 0.196087,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'the-open-network',
#   'symbol': 'ton',
#   'name': 'Toncoin',
#   'current_price': 122.42,
#   'market_cap': 299682386824,
#   'market_cap_rank': 32,
#   'total_volume': 9558458054,
#   'circulating_supply': 2448129765.515805,
#   'total_supply': 5153746968.663904,
#   'ath': 689.6,
#   'atl': 38.25,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Cronos',
#   'current_price': 7.14,
#   'market_cap': 284394157169,
#   'market_cap_rank': 33,
#   'total_volume': 1515501103,
#   'circulating_supply': 39851874354.01433,
#   'total_supply': 98385158269.84421,
#   'ath': 72.06,
#   'atl': 0.864137,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'world-liberty-financial',
#   'symbol': 'wlfi',
#   'name': 'World Liberty Financial',
#   'current_price': 9.78,
#   'market_cap': 266151252187,
#   'market_cap_rank': 34,
#   'total_volume': 10687725865,
#   'circulating_supply': 27243802538.151154,
#   'total_supply': 100000000000.0,
#   'ath': 29.22,
#   'atl': 8.91,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'tether-gold',
#   'symbol': 'xaut',
#   'name': 'Tether Gold',
#   'current_price': 456761,
#   'market_cap': 237241183872,
#   'market_cap_rank': 35,
#   'total_volume': 33538499021,
#   'circulating_supply': 519825.641699,
#   'total_supply': 712747.089,
#   'ath': 514631,
#   'atl': 108167,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'memecore',
#   'symbol': 'm',
#   'name': 'MemeCore',
#   'current_price': 132.67,
#   'market_cap': 230143955886,
#   'market_cap_rank': 36,
#   'total_volume': 817440214,
#   'circulating_supply': 1734139432.850167,
#   'total_supply': 5334124022.888754,
#   'ath': 260.79,
#   'atl': 4.05,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'pax-gold',
#   'symbol': 'paxg',
#   'name': 'PAX Gold',
#   'current_price': 459340,
#   'market_cap': 210825696584,
#   'market_cap_rank': 37,
#   'total_volume': 41457006217,
#   'circulating_supply': 459009.975,
#   'total_supply': 459009.975,
#   'ath': 516779,
#   'atl': 100361,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'current_price': 303.96,
#   'market_cap': 192694885460,
#   'market_cap_rank': 38,
#   'total_volume': 14351575097,
#   'circulating_supply': 633943278.1680214,
#   'total_supply': 898928420.0366304,
#   'ath': 3333.06,
#   'atl': 75.81,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'current_price': 115.8,
#   'market_cap': 192667588437,
#   'market_cap_rank': 39,
#   'total_volume': 9530862178,
#   'circulating_supply': 1663985944.950637,
#   'total_supply': 1663985944.950637,
#   'ath': 4095.22,
#   'atl': 103.91,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'mantle',
#   'symbol': 'mnt',
#   'name': 'Mantle',
#   'current_price': 57.94,
#   'market_cap': 188348500344,
#   'market_cap_rank': 40,
#   'total_volume': 2629244497,
#   'circulating_supply': 3252944055.636841,
#   'total_supply': 6219316794.89,
#   'ath': 253.43,
#   'atl': 25.64,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'blackrock-usd-institutional-digital-liquidity-fund',
#   'symbol': 'buidl',
#   'name': 'BlackRock USD Institutional Digital Liquidity Fund',
#   'current_price': 90.55,
#   'market_cap': 163240971833,
#   'market_cap_rank': 41,
#   'total_volume': None,
#   'circulating_supply': 1802635529.690448,
#   'total_supply': 1802635529.690448,
#   'ath': 92.2,
#   'atl': 83.81,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'bitget-token',
#   'symbol': 'bgb',
#   'name': 'Bitget Token',
#   'current_price': 229.96,
#   'market_cap': 160957485779,
#   'market_cap_rank': 42,
#   'total_volume': 1753726729,
#   'circulating_supply': 699992035.9787906,
#   'total_supply': 916931610.9787906,
#   'ath': 722.65,
#   'atl': 1.081,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'falcon-finance',
#   'symbol': 'usdf',
#   'name': 'Falcon USD',
#   'current_price': 90.28,
#   'market_cap': 159059631335,
#   'market_cap_rank': 43,
#   'total_volume': 83923958,
#   'circulating_supply': 1761528348.31948,
#   'total_supply': 1761528348.31948,
#   'ath': 92.45,
#   'atl': 80.47,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'current_price': 9900.03,
#   'market_cap': 150331763253,
#   'market_cap_rank': 44,
#   'total_volume': 30795347030,
#   'circulating_supply': 15190264.242195014,
#   'total_supply': 16000000.0,
#   'ath': 48387,
#   'atl': 1933.39,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'aster-2',
#   'symbol': 'aster',
#   'name': 'Aster',
#   'current_price': 58.92,
#   'market_cap': 144436188250,
#   'market_cap_rank': 45,
#   'total_volume': 32816855473,
#   'circulating_supply': 2454947754.91,
#   'total_supply': 7822985112.446448,
#   'ath': 213.7,
#   'atl': 8.76,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'current_price': 6874.98,
#   'market_cap': 144369426476,
#   'market_cap_rank': 46,
#   'total_volume': 1848878140,
#   'circulating_supply': 21000000.0,
#   'total_supply': 21000000.0,
#   'ath': 22313,
#   'atl': 40.86,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'sky',
#   'symbol': 'sky',
#   'name': 'Sky',
#   'current_price': 6.24,
#   'market_cap': 143775440733,
#   'market_cap_rank': 47,
#   'total_volume': 3568790892,
#   'circulating_supply': 23017766757.010494,
#   'total_supply': 23462665147.36596,
#   'ath': 8.62,
#   'atl': 3.12,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'global-dollar',
#   'symbol': 'usdg',
#   'name': 'Global Dollar',
#   'current_price': 90.56,
#   'market_cap': 143046249181,
#   'market_cap_rank': 48,
#   'total_volume': 2512699613,
#   'circulating_supply': 1579822398.475023,
#   'total_supply': 1579822398.475023,
#   'ath': 143.35,
#   'atl': 76.61,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'hashnote-usyc',
#   'symbol': 'usyc',
#   'name': 'Circle USYC',
#   'current_price': 101.11,
#   'market_cap': 143213236071,
#   'market_cap_rank': 49,
#   'total_volume': 4044.32,
#   'circulating_supply': 1416438587.362307,
#   'total_supply': 1416438587.362307,
#   'ath': 102.4,
#   'atl': 86.89,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'pepe',
#   'symbol': 'pepe',
#   'name': 'Pepe',
#   'current_price': 0.00033194,
#   'market_cap': 139641958140,
#   'market_cap_rank': 50,
#   'total_volume': 28105216001,
#   'circulating_supply': 420690000000000.0,
#   'total_supply': 420690000000000.0,
#   'ath': 0.00237833,
#   'atl': 4.52e-06,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'htx-dao',
#   'symbol': 'htx',
#   'name': 'HTX DAO',
#   'current_price': 0.00015118,
#   'market_cap': 138546666721,
#   'market_cap_rank': 51,
#   'total_volume': 656689531,
#   'circulating_supply': 916533066327098.8,
#   'total_supply': 916533066327098.8,
#   'ath': 0.00031771,
#   'atl': 6.739e-05,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'ripple-usd',
#   'symbol': 'rlusd',
#   'name': 'Ripple USD',
#   'current_price': 90.53,
#   'market_cap': 137772240144,
#   'market_cap_rank': 52,
#   'total_volume': 12149531234,
#   'circulating_supply': 1521941230.127497,
#   'total_supply': 1521941230.127497,
#   'ath': 92.15,
#   'atl': 81.72,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'bittensor',
#   'symbol': 'tao',
#   'name': 'Bittensor',
#   'current_price': 14287.58,
#   'market_cap': 137138281527,
#   'market_cap_rank': 53,
#   'total_volume': 8694052833,
#   'circulating_supply': 9597491.0,
#   'total_supply': 21000000.0,
#   'ath': 62722,
#   'atl': 2535.93,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'bfusd',
#   'symbol': 'bfusd',
#   'name': 'BFUSD',
#   'current_price': 90.49,
#   'market_cap': 119437163582,
#   'market_cap_rank': 54,
#   'total_volume': 569953037,
#   'circulating_supply': 1320000000.0,
#   'total_supply': 1320000000.0,
#   'ath': 92.02,
#   'atl': 86.85,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'ethereum-classic',
#   'symbol': 'etc',
#   'name': 'Ethereum Classic',
#   'current_price': 762.04,
#   'market_cap': 118451491739,
#   'market_cap_rank': 55,
#   'total_volume': 4902247082,
#   'circulating_supply': 155475741.3118733,
#   'total_supply': 155475741.3118733,
#   'ath': 12296.58,
#   'atl': 41.44,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'internet-computer',
#   'symbol': 'icp',
#   'name': 'Internet Computer',
#   'current_price': 214.47,
#   'market_cap': 117544715046,
#   'market_cap_rank': 56,
#   'total_volume': 5135501763,
#   'circulating_supply': 548114924.1787055,
#   'total_supply': 548114924.1787055,
#   'ath': 51433,
#   'atl': 187.57,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'near',
#   'symbol': 'near',
#   'name': 'NEAR Protocol',
#   'current_price': 90.09,
#   'market_cap': 116006002692,
#   'market_cap_rank': 57,
#   'total_volume': 10394317741,
#   'circulating_supply': 1287402469.0,
#   'total_supply': 1287402507.0,
#   'ath': 1518.16,
#   'atl': 39.17,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'pi-network',
#   'symbol': 'pi',
#   'name': 'Pi Network',
#   'current_price': 12.6,
#   'market_cap': 112903558020,
#   'market_cap_rank': 58,
#   'total_volume': 1126658083,
#   'circulating_supply': 8962600829.918295,
#   'total_supply': 13788616661.41276,
#   'ath': 260.4,
#   'atl': 12.08,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'ondo-finance',
#   'symbol': 'ondo',
#   'name': 'Ondo',
#   'current_price': 22.44,
#   'market_cap': 109234948875,
#   'market_cap_rank': 59,
#   'total_volume': 4543092866,
#   'circulating_supply': 4869330647.0,
#   'total_supply': 10000000000.0,
#   'ath': 181.52,
#   'atl': 6.83,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'pump-fun',
#   'symbol': 'pump',
#   'name': 'Pump.fun',
#   'current_price': 0.176768,
#   'market_cap': 104315479625,
#   'market_cap_rank': 60,
#   'total_volume': 8604258127,
#   'circulating_supply': 590000000000.0,
#   'total_supply': 999989199210.6805,
#   'ath': 0.77853,
#   'atl': 0.150889,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'gatechain-token',
#   'symbol': 'gt',
#   'name': 'Gate',
#   'current_price': 635.48,
#   'market_cap': 103919175936,
#   'market_cap_rank': 61,
#   'total_volume': 216549497,
#   'circulating_supply': 115180573.04885802,
#   'total_supply': 115180573.04885802,
#   'ath': 2235.58,
#   'atl': 19.44,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'myx-finance',
#   'symbol': 'myx',
#   'name': 'MYX Finance',
#   'current_price': 517.58,
#   'market_cap': 98603806247,
#   'market_cap_rank': 62,
#   'total_volume': 1820289151,
#   'circulating_supply': 190768939.69,
#   'total_supply': 1000000000.0,
#   'ath': 1677.44,
#   'atl': 4.08,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'worldcoin-wld',
#   'symbol': 'wld',
#   'name': 'Worldcoin',
#   'current_price': 34.55,
#   'market_cap': 97383036957,
#   'market_cap_rank': 63,
#   'total_volume': 9896312435,
#   'circulating_supply': 2822045061.813433,
#   'total_supply': 10000000000.0,
#   'ath': 971.56,
#   'atl': 28.73,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'kucoin-shares',
#   'symbol': 'kcs',
#   'name': 'KuCoin',
#   'current_price': 728.51,
#   'market_cap': 96281797208,
#   'market_cap_rank': 64,
#   'total_volume': 365157513,
#   'circulating_supply': 132155021.7355671,
#   'total_supply': 142155021.7355671,
#   'ath': 2158.41,
#   'atl': 24.48,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'usdd',
#   'symbol': 'usdd',
#   'name': 'USDD',
#   'current_price': 90.51,
#   'market_cap': 91836033738,
#   'market_cap_rank': 65,
#   'total_volume': 217387811,
#   'circulating_supply': 1014497325.0,
#   'total_supply': 1014501547.0,
#   'ath': 92.2,
#   'atl': 72.35,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'quant-network',
#   'symbol': 'qnt',
#   'name': 'Quant',
#   'current_price': 6288.13,
#   'market_cap': 91429389862,
#   'market_cap_rank': 66,
#   'total_volume': 1793670443,
#   'circulating_supply': 14544176.164081175,
#   'total_supply': 14612493.0,
#   'ath': 31427,
#   'atl': 15.06,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'polygon-ecosystem-token',
#   'symbol': 'pol',
#   'name': 'POL (ex-MATIC)',
#   'current_price': 8.46,
#   'market_cap': 89351716054,
#   'market_cap_rank': 67,
#   'total_volume': 6257077209,
#   'circulating_supply': 10588860889.28637,
#   'total_supply': 10588860889.28637,
#   'ath': 106.68,
#   'atl': 7.85,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'cosmos',
#   'symbol': 'atom',
#   'name': 'Cosmos Hub',
#   'current_price': 173.9,
#   'market_cap': 85665843570,
#   'market_cap_rank': 68,
#   'total_volume': 3638351031,
#   'circulating_supply': 492584762.127476,
#   'total_supply': 492584762.127476,
#   'ath': 3301.61,
#   'atl': 87.61,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'ethena',
#   'symbol': 'ena',
#   'name': 'Ethena',
#   'current_price': 10.42,
#   'market_cap': 85663482293,
#   'market_cap_rank': 69,
#   'total_volume': 7905024635,
#   'circulating_supply': 8225000000.0,
#   'total_supply': 15000000000.0,
#   'ath': 126.48,
#   'atl': 9.4,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'hash-2',
#   'symbol': 'hash',
#   'name': 'Provenance Blockchain',
#   'current_price': 1.57,
#   'market_cap': 85516612551,
#   'market_cap_rank': 70,
#   'total_volume': 1213270,
#   'circulating_supply': 54456015273.0,
#   'total_supply': 100000000000.0,
#   'ath': 5.31,
#   'atl': 0.877643,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'usdtb',
#   'symbol': 'usdtb',
#   'name': 'USDtb',
#   'current_price': 90.41,
#   'market_cap': 77290700041,
#   'market_cap_rank': 71,
#   'total_volume': 574257242,
#   'circulating_supply': 854316092.1961825,
#   'total_supply': 854316092.1961825,
#   'ath': 95.66,
#   'atl': 77.41,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'kaspa',
#   'symbol': 'kas',
#   'name': 'Kaspa',
#   'current_price': 2.82,
#   'market_cap': 75419982672,
#   'market_cap_rank': 72,
#   'total_volume': 1553065219,
#   'circulating_supply': 26777148610.50726,
#   'total_supply': 27191295679.38603,
#   'ath': 17.36,
#   'atl': 0.01327337,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'algorand',
#   'symbol': 'algo',
#   'name': 'Algorand',
#   'current_price': 8.47,
#   'market_cap': 75025928368,
#   'market_cap_rank': 73,
#   'total_volume': 2599038017,
#   'circulating_supply': 8870434813.738161,
#   'total_supply': 8870604122.858517,
#   'ath': 247.29,
#   'atl': 7.26,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'midnight-3',
#   'symbol': 'night',
#   'name': 'Midnight',
#   'current_price': 4.51,
#   'market_cap': 74954145756,
#   'market_cap_rank': 74,
#   'total_volume': 926514730,
#   'circulating_supply': 16607399400.63495,
#   'total_supply': 24000000000.0,
#   'ath': 10.66,
#   'atl': 2.14,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'flare-networks',
#   'symbol': 'flr',
#   'name': 'Flare',
#   'current_price': 0.882334,
#   'market_cap': 74718574586,
#   'market_cap_rank': 75,
#   'total_volume': 386616457,
#   'circulating_supply': 84692675866.3467,
#   'total_supply': 104892358530.528,
#   'ath': 12.35,
#   'atl': 0.687929,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'nexo',
#   'symbol': 'nexo',
#   'name': 'NEXO',
#   'current_price': 74.39,
#   'market_cap': 74365375066,
#   'market_cap_rank': 76,
#   'total_volume': 1186255956,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'ath': 298.99,
#   'atl': 3.25,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'superstate-short-duration-us-government-securities-fund-ustb',
#   'symbol': 'ustb',
#   'name': 'Superstate Short Duration U.S. Government Securities Fund (USTB)',
#   'current_price': 994.82,
#   'market_cap': 73812480889,
#   'market_cap_rank': 77,
#   'total_volume': None,
#   'circulating_supply': 74197903.427472,
#   'total_supply': 74197903.427472,
#   'ath': 1011.63,
#   'atl': 876.83,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'aptos',
#   'symbol': 'apt',
#   'name': 'Aptos',
#   'current_price': 90.92,
#   'market_cap': 69678147517,
#   'market_cap_rank': 78,
#   'total_volume': 5742597788,
#   'circulating_supply': 766783174.5820781,
#   'total_supply': 1195701650.732267,
#   'ath': 1622.34,
#   'atl': 84.41,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'official-trump',
#   'symbol': 'trump',
#   'name': 'Official Trump',
#   'current_price': 299.04,
#   'market_cap': 69473124869,
#   'market_cap_rank': 79,
#   'total_volume': 6847052932,
#   'circulating_supply': 232498807.465716,
#   'total_supply': 1000000000.0,
#   'ath': 6357.94,
#   'atl': 290.18,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'janus-henderson-anemoy-aaa-clo-fund',
#   'symbol': 'jaaa',
#   'name': 'Janus Henderson Anemoy AAA CLO Fund',
#   'current_price': 92.89,
#   'market_cap': 65946060120,
#   'market_cap_rank': 80,
#   'total_volume': None,
#   'circulating_supply': 710021691.915383,
#   'total_supply': 710021691.915383,
#   'ath': 94.38,
#   'atl': 89.64,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'eutbl',
#   'symbol': 'eutbl',
#   'name': 'Spiko EU T-Bills Money Market Fund',
#   'current_price': 112.93,
#   'market_cap': 64824892751,
#   'market_cap_rank': 81,
#   'total_volume': None,
#   'circulating_supply': 574034711.71872,
#   'total_supply': 574034711.71872,
#   'ath': 115.38,
#   'atl': 84.72,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'xdce-crowd-sale',
#   'symbol': 'xdc',
#   'name': 'XDC Network',
#   'current_price': 3.22,
#   'market_cap': 64327980452,
#   'market_cap_rank': 82,
#   'total_volume': 1858426283,
#   'circulating_supply': 19931573698.62,
#   'total_supply': 38050590785.85,
#   'ath': 14.32,
#   'atl': 0.02721364,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'ousg',
#   'symbol': 'ousg',
#   'name': 'OUSG',
#   'current_price': 10344.83,
#   'market_cap': 63473548912,
#   'market_cap_rank': 83,
#   'total_volume': 0.0,
#   'circulating_supply': 6135549.864477077,
#   'total_supply': 6135549.864477077,
#   'ath': 10520.12,
#   'atl': 7844.42,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'ondo-us-dollar-yield',
#   'symbol': 'usdy',
#   'name': 'Ondo US Dollar Yield',
#   'current_price': 100.55,
#   'market_cap': 63262711534,
#   'market_cap_rank': 84,
#   'total_volume': 218327753,
#   'circulating_supply': 629239542.3596164,
#   'total_supply': 1164752243.712908,
#   'ath': 105.8,
#   'atl': 77.42,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'filecoin',
#   'symbol': 'fil',
#   'name': 'Filecoin',
#   'current_price': 82.9,
#   'market_cap': 62361433493,
#   'market_cap_rank': 85,
#   'total_volume': 6843293666,
#   'circulating_supply': 752177606.0,
#   'total_supply': 1958295302.0,
#   'ath': 17367.85,
#   'atl': 73.41,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'render-token',
#   'symbol': 'render',
#   'name': 'Render',
#   'current_price': 119.6,
#   'market_cap': 62045765720,
#   'market_cap_rank': 86,
#   'total_volume': 3762669376,
#   'circulating_supply': 518714713.0140741,
#   'total_supply': 533474886.2940741,
#   'ath': 1121.89,
#   'atl': 2.79,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'vechain',
#   'symbol': 'vet',
#   'name': 'VeChain',
#   'current_price': 0.707105,
#   'market_cap': 60810018681,
#   'market_cap_rank': 87,
#   'total_volume': 1452117270,
#   'circulating_supply': 85985041177.0,
#   'total_supply': 85985041177.0,
#   'ath': 20.95,
#   'atl': 0.144791,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'arbitrum',
#   'symbol': 'arb',
#   'name': 'Arbitrum',
#   'current_price': 10.02,
#   'market_cap': 58367910950,
#   'market_cap_rank': 88,
#   'total_volume': 8032020604,
#   'circulating_supply': 5826785045.0,
#   'total_supply': 10000000000.0,
#   'ath': 198.19,
#   'atl': 8.93,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'morpho',
#   'symbol': 'morpho',
#   'name': 'Morpho',
#   'current_price': 103.65,
#   'market_cap': 56607557590,
#   'market_cap_rank': 89,
#   'total_volume': 1245601640,
#   'circulating_supply': 546147346.9693644,
#   'total_supply': 1000000000.0,
#   'ath': 361.23,
#   'atl': 60.2,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'beldex',
#   'symbol': 'bdx',
#   'name': 'Beldex',
#   'current_price': 7.26,
#   'market_cap': 55234227963,
#   'market_cap_rank': 90,
#   'total_volume': 1097086761,
#   'circulating_supply': 7605562967.435734,
#   'total_supply': 9935862619.166403,
#   'ath': 32.42,
#   'atl': 0.01949843,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'usual-usd',
#   'symbol': 'usd0',
#   'name': 'Usual USD',
#   'current_price': 90.37,
#   'market_cap': 51726194909,
#   'market_cap_rank': 91,
#   'total_volume': 91238866,
#   'circulating_supply': 572709324.5323287,
#   'total_supply': 572709324.5323287,
#   'ath': 110.74,
#   'atl': 81.88,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'janus-henderson-anemoy-treasury-fund',
#   'symbol': 'jtrsy',
#   'name': 'Janus Henderson Anemoy Treasury Fund',
#   'current_price': 99.06,
#   'market_cap': 51339859494,
#   'market_cap_rank': 92,
#   'total_volume': None,
#   'circulating_supply': 518328892.305495,
#   'total_supply': 518328892.305495,
#   'ath': 100.75,
#   'atl': 95.98,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'usdai',
#   'symbol': 'usdai',
#   'name': 'USDai',
#   'current_price': 90.54,
#   'market_cap': 49946710071,
#   'market_cap_rank': 93,
#   'total_volume': 211195957,
#   'circulating_supply': 551638697.9365121,
#   'total_supply': 551638697.9365121,
#   'ath': 104.92,
#   'atl': 68.25,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'bonk',
#   'symbol': 'bonk',
#   'name': 'Bonk',
#   'current_price': 0.00054937,
#   'market_cap': 48348015021,
#   'market_cap_rank': 94,
#   'total_volume': 4786503560,
#   'circulating_supply': 87995156457995.5,
#   'total_supply': 87995156458995.5,
#   'ath': 0.00491619,
#   'atl': 7.14e-06,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'gho',
#   'symbol': 'gho',
#   'name': 'GHO',
#   'current_price': 90.57,
#   'market_cap': 47774175848,
#   'market_cap_rank': 95,
#   'total_volume': 1622465982,
#   'circulating_supply': 527437881.2934199,
#   'total_supply': 527437881.2934199,
#   'ath': 92.12,
#   'atl': 76.18,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'a7a5',
#   'symbol': 'a7a5',
#   'name': 'A7A5',
#   'current_price': 1.16,
#   'market_cap': 45490666886,
#   'market_cap_rank': 96,
#   'total_volume': 123480,
#   'circulating_supply': 39188879519.39074,
#   'total_supply': 39188879519.39074,
#   'ath': 20.14,
#   'atl': 0.00091492,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'true-usd',
#   'symbol': 'tusd',
#   'name': 'TrueUSD',
#   'current_price': 90.38,
#   'market_cap': 44692962722,
#   'market_cap_rank': 97,
#   'total_volume': 643308629,
#   'circulating_supply': 494515083.0,
#   'total_supply': 494515083.0,
#   'ath': 112.93,
#   'atl': 64.32,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'sei-network',
#   'symbol': 'sei',
#   'name': 'Sei',
#   'current_price': 6.61,
#   'market_cap': 43697363442,
#   'market_cap_rank': 98,
#   'total_volume': 3248363932,
#   'circulating_supply': 6612222222.0,
#   'total_supply': 10000000000.0,
#   'ath': 94.47,
#   'atl': 6.23,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'jupiter-exchange-solana',
#   'symbol': 'jup',
#   'name': 'Jupiter',
#   'current_price': 13.25,
#   'market_cap': 42993854977,
#   'market_cap_rank': 99,
#   'total_volume': 2587857533,
#   'circulating_supply': 3243891294.88,
#   'total_supply': 6863982889.972334,
#   'ath': 166.05,
#   'atl': 13.04,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'fasttoken',
#   'symbol': 'ftn',
#   'name': 'Fasttoken',
#   'current_price': 98.68,
#   'market_cap': 42808851675,
#   'market_cap_rank': 100,
#   'total_volume': 1004215950,
#   'circulating_supply': 433857414.6,
#   'total_supply': 870742437.0,
#   'ath': 403.42,
#   'atl': 30.21,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'euro-coin',
#   'symbol': 'eurc',
#   'name': 'EURC',
#   'current_price': 107.75,
#   'market_cap': 41531595026,
#   'market_cap_rank': 101,
#   'total_volume': 3135892915,
#   'circulating_supply': 385545697.6135361,
#   'total_supply': 385545697.6135361,
#   'ath': 111.47,
#   'atl': 4.35,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'blockstack',
#   'symbol': 'stx',
#   'name': 'Stacks',
#   'current_price': 23.13,
#   'market_cap': 41128632739,
#   'market_cap_rank': 102,
#   'total_volume': 1202535770,
#   'circulating_supply': 1776252429.22042,
#   'total_supply': 1776252429.22042,
#   'ath': 322.23,
#   'atl': 3.44,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'pancakeswap-token',
#   'symbol': 'cake',
#   'name': 'PancakeSwap',
#   'current_price': 121.27,
#   'market_cap': 40296276416,
#   'market_cap_rank': 103,
#   'total_volume': 3270121075,
#   'circulating_supply': 332118564.0817582,
#   'total_supply': 345453343.5106674,
#   'ath': 3259.75,
#   'atl': 14.48,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'dash',
#   'symbol': 'dash',
#   'name': 'Dash',
#   'current_price': 3180.67,
#   'market_cap': 40176622119,
#   'market_cap_rank': 104,
#   'total_volume': 5283939178,
#   'circulating_supply': 12583429.59098425,
#   'total_supply': 12584595.60397022,
#   'ath': 95552,
#   'atl': 13.82,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'decred',
#   'symbol': 'dcr',
#   'name': 'Decred',
#   'current_price': 2317.02,
#   'market_cap': 39956820525,
#   'market_cap_rank': 105,
#   'total_volume': 632803355,
#   'circulating_supply': 17268445.75003602,
#   'total_supply': 17268684.7461489,
#   'ath': 18443.33,
#   'atl': 29.25,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'tezos',
#   'symbol': 'xtz',
#   'name': 'Tezos',
#   'current_price': 36.71,
#   'market_cap': 39463783769,
#   'market_cap_rank': 106,
#   'total_volume': 1441253222,
#   'circulating_supply': 1074969669.221785,
#   'total_supply': 1095028521.599833,
#   'ath': 676.89,
#   'atl': 24.73,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'story-2',
#   'symbol': 'ip',
#   'name': 'Story',
#   'current_price': 106.47,
#   'market_cap': 37312104227,
#   'market_cap_rank': 107,
#   'total_volume': 3145582205,
#   'circulating_supply': 350215676.71,
#   'total_supply': 1023741766.66,
#   'ath': 1302.35,
#   'atl': 87.81,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'stable-2',
#   'symbol': 'stable',
#   'name': '\u200b\u200bStable',
#   'current_price': 2.06,
#   'market_cap': 37178021484,
#   'market_cap_rank': 108,
#   'total_volume': 4303263533,
#   'circulating_supply': 18000000000.0,
#   'total_supply': 100000000000.0,
#   'ath': 2.93,
#   'atl': 0.827533,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'chiliz',
#   'symbol': 'chz',
#   'name': 'Chiliz',
#   'current_price': 3.56,
#   'market_cap': 36576210156,
#   'market_cap_rank': 109,
#   'total_volume': 4022856489,
#   'circulating_supply': 10267860244.0,
#   'total_supply': 10267860244.0,
#   'ath': 63.87,
#   'atl': 0.290329,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'first-digital-usd',
#   'symbol': 'fdusd',
#   'name': 'First Digital USD',
#   'current_price': 90.44,
#   'market_cap': 35968419910,
#   'market_cap_rank': 110,
#   'total_volume': 3939577242,
#   'circulating_supply': 397715236.2794249,
#   'total_supply': 397715236.2794249,
#   'ath': 100.07,
#   'atl': 78.29,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'pippin',
#   'symbol': 'pippin',
#   'name': 'pippin',
#   'current_price': 35.53,
#   'market_cap': 35525141297,
#   'market_cap_rank': 111,
#   'total_volume': 4286023612,
#   'circulating_supply': 999937508.337785,
#   'total_supply': 999937508.337785,
#   'ath': 50.39,
#   'atl': 0.473545,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'optimism',
#   'symbol': 'op',
#   'name': 'Optimism',
#   'current_price': 16.64,
#   'market_cap': 35207937514,
#   'market_cap_rank': 112,
#   'total_volume': 4216822939,
#   'circulating_supply': 2116007431.0,
#   'total_supply': 4294967296.0,
#   'ath': 401.58,
#   'atl': 14.88,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'kinesis-gold',
#   'symbol': 'kau',
#   'name': 'Kinesis Gold',
#   'current_price': 14753.35,
#   'market_cap': 35204865853,
#   'market_cap_rank': 113,
#   'total_volume': 28638406,
#   'circulating_supply': 2386227.8342,
#   'total_supply': 2386227.8342,
#   'ath': 16353.61,
#   'atl': 3614.27,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'pudgy-penguins',
#   'symbol': 'pengu',
#   'name': 'Pudgy Penguins',
#   'current_price': 0.558671,
#   'market_cap': 35113700218,
#   'market_cap_rank': 114,
#   'total_volume': 6153248096,
#   'circulating_supply': 62860396090.0,
#   'total_supply': 79726927831.42148,
#   'ath': 5.81,
#   'atl': 0.320882,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'river',
#   'symbol': 'river',
#   'name': 'River',
#   'current_price': 1771.84,
#   'market_cap': 34752324695,
#   'market_cap_rank': 115,
#   'total_volume': 7227439480,
#   'circulating_supply': 19600000.0,
#   'total_supply': 100000000.0,
#   'ath': 8042.31,
#   'atl': 140.15,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'just',
#   'symbol': 'jst',
#   'name': 'JUST',
#   'current_price': 3.91,
#   'market_cap': 34485180858,
#   'market_cap_rank': 116,
#   'total_volume': 2550900112,
#   'circulating_supply': 8815108920.581306,
#   'total_supply': 8815108920.581306,
#   'ath': 14.19,
#   'atl': 0.359754,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'lighter',
#   'symbol': 'lit',
#   'name': 'Lighter',
#   'current_price': 135.3,
#   'market_cap': 33828535688,
#   'market_cap_rank': 117,
#   'total_volume': 2049925249,
#   'circulating_supply': 250000000.0,
#   'total_supply': 1000000000.0,
#   'ath': 705.52,
#   'atl': 123.01,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'virtual-protocol',
#   'symbol': 'virtual',
#   'name': 'Virtuals Protocol',
#   'current_price': 51.07,
#   'market_cap': 33521152657,
#   'market_cap_rank': 118,
#   'total_volume': 4281087520,
#   'circulating_supply': 656282621.3333926,
#   'total_supply': 1000000000.0,
#   'ath': 434.45,
#   'atl': 0.622571,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'c8ntinuum',
#   'symbol': 'ctm',
#   'name': 'c8ntinuum',
#   'current_price': 7.67,
#   'market_cap': 33456054950,
#   'market_cap_rank': 119,
#   'total_volume': 99619563,
#   'circulating_supply': 4359542107.432732,
#   'total_supply': 8888888888.0,
#   'ath': 13.05,
#   'atl': 0.709073,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'fetch-ai',
#   'symbol': 'fet',
#   'name': 'Artificial Superintelligence Alliance',
#   'current_price': 14.22,
#   'market_cap': 32453873088,
#   'market_cap_rank': 120,
#   'total_volume': 3631779900,
#   'circulating_supply': 2282862924.9715047,
#   'total_supply': 2714384546.672,
#   'ath': 287.87,
#   'atl': 0.616804,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'layerzero',
#   'symbol': 'zro',
#   'name': 'LayerZero',
#   'current_price': 157.41,
#   'market_cap': 31922687454,
#   'market_cap_rank': 121,
#   'total_volume': 21874815243,
#   'circulating_supply': 202629028.12286997,
#   'total_supply': 1000000000.0,
#   'ath': 632.92,
#   'atl': 99.55,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'curve-dao-token',
#   'symbol': 'crv',
#   'name': 'Curve DAO',
#   'current_price': 21.61,
#   'market_cap': 31881286463,
#   'market_cap_rank': 122,
#   'total_volume': 4898439157,
#   'circulating_supply': 1475142810.0,
#   'total_supply': 2351160101.594569,
#   'ath': 1150.14,
#   'atl': 15.17,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'resolv-usr',
#   'symbol': 'usr',
#   'name': 'Resolv USR',
#   'current_price': 90.38,
#   'market_cap': 31452498375,
#   'market_cap_rank': 123,
#   'total_volume': 72913869,
#   'circulating_supply': 347190764.088195,
#   'total_supply': 347190764.088195,
#   'ath': 92.16,
#   'atl': 82.39,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'bittorrent',
#   'symbol': 'btt',
#   'name': 'BitTorrent',
#   'current_price': 3.09e-05,
#   'market_cap': 30498951478,
#   'market_cap_rank': 124,
#   'total_volume': 2837080121,
#   'circulating_supply': 987037885840674.8,
#   'total_supply': 990000000000000.0,
#   'ath': 0.00025579,
#   'atl': 2.748e-05,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'gnosis',
#   'symbol': 'gno',
#   'name': 'Gnosis',
#   'current_price': 11393.05,
#   'market_cap': 30075571723,
#   'market_cap_rank': 125,
#   'total_volume': 478563347,
#   'circulating_supply': 2639589.0,
#   'total_supply': 3000000.0,
#   'ath': 47603,
#   'atl': 519.75,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'sun-token',
#   'symbol': 'sun',
#   'name': 'Sun Token',
#   'current_price': 1.51,
#   'market_cap': 29046592504,
#   'market_cap_rank': 126,
#   'total_volume': 3233517212,
#   'circulating_supply': 19208361904.29119,
#   'total_supply': 19900730000.0,
#   'ath': 4880.96,
#   'atl': 0.374246,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'syrup',
#   'symbol': 'syrup',
#   'name': 'Maple Finance',
#   'current_price': 24.92,
#   'market_cap': 28833964182,
#   'market_cap_rank': 127,
#   'total_volume': 689161518,
#   'circulating_supply': 1157190702.5885315,
#   'total_supply': 1216127147.998563,
#   'ath': 56.23,
#   'atl': 7.31,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'kaia',
#   'symbol': 'kaia',
#   'name': 'Kaia',
#   'current_price': 4.89,
#   'market_cap': 28648736262,
#   'market_cap_rank': 128,
#   'total_volume': 857884327,
#   'circulating_supply': 5856641747.106198,
#   'total_supply': 5856641936.044253,
#   'ath': 34.46,
#   'atl': 4.23,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'kite-2',
#   'symbol': 'kite',
#   'name': 'Kite',
#   'current_price': 15.81,
#   'market_cap': 28506244515,
#   'market_cap_rank': 129,
#   'total_volume': 7371411366,
#   'circulating_supply': 1800000000.0,
#   'total_supply': 10000000000.0,
#   'ath': 17.65,
#   'atl': 5.48,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'apenft',
#   'symbol': 'nft',
#   'name': 'AINFT',
#   'current_price': 2.843e-05,
#   'market_cap': 28149512330,
#   'market_cap_rank': 130,
#   'total_volume': 1389400235,
#   'circulating_supply': 990105667256391.5,
#   'total_supply': 990105667256391.5,
#   'ath': 0.00054965,
#   'atl': 2.463e-05,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'kinesis-silver',
#   'symbol': 'kag',
#   'name': 'Kinesis Silver',
#   'current_price': 7478.49,
#   'market_cap': 27834679725,
#   'market_cap_rank': 131,
#   'total_volume': 202450695,
#   'circulating_supply': 3721963.8196,
#   'total_supply': 3721963.8196,
#   'ath': 11907.44,
#   'atl': 362.2,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'injective-protocol',
#   'symbol': 'inj',
#   'name': 'Injective',
#   'current_price': 277.65,
#   'market_cap': 27825353171,
#   'market_cap_rank': 132,
#   'total_volume': 3458659526,
#   'circulating_supply': 100000000.0,
#   'total_supply': 100000000.0,
#   'ath': 4364.19,
#   'atl': 49.02,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'ether-fi',
#   'symbol': 'ethfi',
#   'name': 'Ether.fi',
#   'current_price': 39.55,
#   'market_cap': 27642815011,
#   'market_cap_rank': 133,
#   'total_volume': 2985178475,
#   'circulating_supply': 699363510.0,
#   'total_supply': 998535999.0,
#   'ath': 711.06,
#   'atl': 34.7,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'usx',
#   'symbol': 'usx',
#   'name': 'USX',
#   'current_price': 90.53,
#   'market_cap': 26609034844,
#   'market_cap_rank': 134,
#   'total_volume': 1068321721,
#   'circulating_supply': 293956089.295914,
#   'total_supply': 293956089.295914,
#   'ath': 95.56,
#   'atl': 74.4,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'crvusd',
#   'symbol': 'crvusd',
#   'name': 'crvUSD',
#   'current_price': 90.19,
#   'market_cap': 26415978238,
#   'market_cap_rank': 135,
#   'total_volume': 1739149727,
#   'circulating_supply': 292897943.5563817,
#   'total_supply': 292897943.5563817,
#   'ath': 96.91,
#   'atl': 78.57,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'lido-dao',
#   'symbol': 'ldo',
#   'name': 'Lido DAO',
#   'current_price': 30.94,
#   'market_cap': 26238036822,
#   'market_cap_rank': 136,
#   'total_volume': 2218803943,
#   'circulating_supply': 848066802.5927889,
#   'total_supply': 1000000000.0,
#   'ath': 543.56,
#   'atl': 26.78,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'iota',
#   'symbol': 'iota',
#   'name': 'IOTA',
#   'current_price': 6.12,
#   'market_cap': 26171568520,
#   'market_cap_rank': 137,
#   'total_volume': 672181149,
#   'circulating_supply': 4283522973.0,
#   'total_supply': 4815450646.0,
#   'ath': 336.22,
#   'atl': 5.75,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'floki',
#   'symbol': 'floki',
#   'name': 'FLOKI',
#   'current_price': 0.00270708,
#   'market_cap': 26134301743,
#   'market_cap_rank': 138,
#   'total_volume': 2867908665,
#   'circulating_supply': 9655017704304.0,
#   'total_supply': 10000000000000.0,
#   'ath': 0.02877055,
#   'atl': 6.26e-06,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'the-graph',
#   'symbol': 'grt',
#   'name': 'The Graph',
#   'current_price': 2.41,
#   'market_cap': 25764726167,
#   'market_cap_rank': 139,
#   'total_volume': 1131068606,
#   'circulating_supply': 10706905069.99121,
#   'total_supply': 10800262816.04821,
#   'ath': 206.81,
#   'atl': 2.12,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'celestia',
#   'symbol': 'tia',
#   'name': 'Celestia',
#   'current_price': 28.95,
#   'market_cap': 25405014333,
#   'market_cap_rank': 140,
#   'total_volume': 2012292105,
#   'circulating_supply': 878101911.507557,
#   'total_supply': 1161312926.437195,
#   'ath': 1730.96,
#   'atl': 25.29,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'bitcoin-cash-sv',
#   'symbol': 'bsv',
#   'name': 'Bitcoin SV',
#   'current_price': 1268.63,
#   'market_cap': 25347335855,
#   'market_cap_rank': 141,
#   'total_volume': 687428002,
#   'circulating_supply': 19986575.0,
#   'total_supply': 19986640.625,
#   'ath': 36495,
#   'atl': 1043.89,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'aerodrome-finance',
#   'symbol': 'aero',
#   'name': 'Aerodrome Finance',
#   'current_price': 27.6,
#   'market_cap': 25310764980,
#   'market_cap_rank': 142,
#   'total_volume': 966817263,
#   'circulating_supply': 917039694.7084008,
#   'total_supply': 1835471885.041677,
#   'ath': 196.44,
#   'atl': 0.0015484,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'humanity',
#   'symbol': 'h',
#   'name': 'Humanity',
#   'current_price': 13.75,
#   'market_cap': 25065072038,
#   'market_cap_rank': 143,
#   'total_volume': 2713347693,
#   'circulating_supply': 1825000000.0,
#   'total_supply': 10000000000.0,
#   'ath': 34.11,
#   'atl': 1.55,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'doublezero',
#   'symbol': '2z',
#   'name': 'DoubleZero',
#   'current_price': 7.17,
#   'market_cap': 24886279816,
#   'market_cap_rank': 144,
#   'total_volume': 1653608817,
#   'circulating_supply': 3471417500.0,
#   'total_supply': 10000000000.0,
#   'ath': 79.28,
#   'atl': 7.04,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'frax',
#   'symbol': 'frax',
#   'name': 'Legacy Frax Dollar',
#   'current_price': 89.83,
#   'market_cap': 24798369140,
#   'market_cap_rank': 145,
#   'total_volume': 576224607,
#   'circulating_supply': 276015184.0102677,
#   'total_supply': 276015184.0102677,
#   'ath': 91.66,
#   'atl': 67.16,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'olympus',
#   'symbol': 'ohm',
#   'name': 'Olympus',
#   'current_price': 1578.86,
#   'market_cap': 24700232374,
#   'market_cap_rank': 146,
#   'total_volume': 22463053,
#   'circulating_supply': 15645551.38895166,
#   'total_supply': 21038288.00422259,
#   'ath': 121096,
#   'atl': 616.08,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'telcoin',
#   'symbol': 'tel',
#   'name': 'Telcoin',
#   'current_price': 0.25798,
#   'market_cap': 24505270280,
#   'market_cap_rank': 147,
#   'total_volume': 127974613,
#   'circulating_supply': 95077236366.71,
#   'total_supply': 100000000000.0,
#   'ath': 4.74,
#   'atl': 0.00488759,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'jasmycoin',
#   'symbol': 'jasmy',
#   'name': 'JasmyCoin',
#   'current_price': 0.494175,
#   'market_cap': 24440601265,
#   'market_cap_rank': 148,
#   'total_volume': 1746831163,
#   'circulating_supply': 49444999677.59027,
#   'total_supply': 50000000000.0,
#   'ath': 347.8,
#   'atl': 0.227783,
#   'last_updated_date': '2026-02-10'},
# ...
#   'total_volume': 55347270,
#   'circulating_supply': 3625965.852979233,
#   'total_supply': 3625965.852979233,
#   'ath': 846.81,
#   'atl': 198.58,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'gods-unchained',
#   'symbol': 'gods',
#   'name': 'Gods Unchained',
#   'current_price': 3.38,
#   'market_cap': 1332969001,
#   'market_cap_rank': 952,
#   'total_volume': 34655967,
#   'circulating_supply': 394027780.0649,
#   'total_supply': 500000000.0,
#   'ath': 667.09,
#   'atl': 3.17,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'argentine-football-association-fan-token',
#   'symbol': 'arg',
#   'name': 'Argentine Football Association Fan Token',
#   'current_price': 81.29,
#   'market_cap': 1330313541,
#   'market_cap_rank': 953,
#   'total_volume': 79873477,
#   'circulating_supply': 16345491.0,
#   'total_supply': 20000000.0,
#   'ath': 750.3,
#   'atl': 32.91,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'metaplex',
#   'symbol': 'mplx',
#   'name': 'Metaplex',
#   'current_price': 2.55,
#   'market_cap': 1327197203,
#   'market_cap_rank': 954,
#   'total_volume': 104402155,
#   'circulating_supply': 520020619.0,
#   'total_supply': 1000000000.0,
#   'ath': 71.48,
#   'atl': 2.07,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'newton-protocol',
#   'symbol': 'newt',
#   'name': 'Newton Protocol',
#   'current_price': 6.17,
#   'market_cap': 1325835976,
#   'market_cap_rank': 955,
#   'total_volume': 480458664,
#   'circulating_supply': 215000000.0,
#   'total_supply': 1000000000.0,
#   'ath': 70.55,
#   'atl': 5.46,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'ready',
#   'symbol': 'ready',
#   'name': 'READY!',
#   'current_price': 1.32,
#   'market_cap': 1320962267,
#   'market_cap_rank': 956,
#   'total_volume': 12748883,
#   'circulating_supply': 999993698.8951708,
#   'total_supply': 999993698.8951708,
#   'ath': 6.95,
#   'atl': 0.173847,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'diamond-token-2',
#   'symbol': 'dit',
#   'name': 'DIAMOND TOKEN 💎',
#   'current_price': 13.15,
#   'market_cap': 1315036014,
#   'market_cap_rank': 957,
#   'total_volume': 11202791,
#   'circulating_supply': 100000000.0,
#   'total_supply': 100000000.0,
#   'ath': 13.19,
#   'atl': 3.53,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'polyswarm',
#   'symbol': 'nct',
#   'name': 'PolySwarm',
#   'current_price': 0.691394,
#   'market_cap': 1313791890,
#   'market_cap_rank': 958,
#   'total_volume': 200829801,
#   'circulating_supply': 1885500781.9581056,
#   'total_supply': 1885913076.0,
#   'ath': 12.71,
#   'atl': 0.04545871,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'dogs-2',
#   'symbol': 'dogs',
#   'name': 'Dogs',
#   'current_price': 0.00253882,
#   'market_cap': 1311842452,
#   'market_cap_rank': 959,
#   'total_volume': 382900389,
#   'circulating_supply': 516750000000.0,
#   'total_supply': 550000000000.0,
#   'ath': 0.137103,
#   'atl': 0.00215186,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'tensor',
#   'symbol': 'tnsr',
#   'name': 'Tensor',
#   'current_price': 3.92,
#   'market_cap': 1310980606,
#   'market_cap_rank': 960,
#   'total_volume': 639850045,
#   'circulating_supply': 334607238.97717,
#   'total_supply': 1000000000.0,
#   'ath': 185.93,
#   'atl': 3.01,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'ishares-core-us-aggregate-bond-etf-ondo-tokenized-etf',
#   'symbol': 'aggon',
#   'name': 'iShares Core US Aggregate Bond ETF (Ondo Tokenized ETF)',
#   'current_price': 9255.55,
#   'market_cap': 1308407008,
#   'market_cap_rank': 961,
#   'total_volume': 160467618,
#   'circulating_supply': 141374.3140796161,
#   'total_supply': 141374.3140796161,
#   'ath': 9461.67,
#   'atl': 8670.46,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'yield-basis',
#   'symbol': 'yb',
#   'name': 'Yield Basis',
#   'current_price': 14.88,
#   'market_cap': 1308120204,
#   'market_cap_rank': 962,
#   'total_volume': 1601861795,
#   'circulating_supply': 87910000.0,
#   'total_supply': 719772009.5038918,
#   'ath': 72.07,
#   'atl': 11.9,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'dodo',
#   'symbol': 'dodo',
#   'name': 'DODO',
#   'current_price': 1.31,
#   'market_cap': 1306164766,
#   'market_cap_rank': 963,
#   'total_volume': 134133336,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'ath': 607.77,
#   'atl': 1.17,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'moonbeam',
#   'symbol': 'glmr',
#   'name': 'Moonbeam',
#   'current_price': 1.23,
#   'market_cap': 1306011157,
#   'market_cap_rank': 964,
#   'total_volume': 138303742,
#   'circulating_supply': 1059588817.0,
#   'total_supply': 1216301502.0,
#   'ath': 1441.64,
#   'atl': 1.16,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'velodrome-finance',
#   'symbol': 'velo',
#   'name': 'Velodrome Finance',
#   'current_price': 1.22,
#   'market_cap': 1304282122,
#   'market_cap_rank': 965,
#   'total_volume': 265410514,
#   'circulating_supply': 1069793825.517995,
#   'total_supply': 2363801190.596332,
#   'ath': 34.56,
#   'atl': 0.442327,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'firmachain',
#   'symbol': 'fct',
#   'name': 'Firmachain',
#   'current_price': 1.17,
#   'market_cap': 1304171637,
#   'market_cap_rank': 966,
#   'total_volume': 18869572,
#   'circulating_supply': 1118287810.613243,
#   'total_supply': 1134323786.8345,
#   'ath': 32.36,
#   'atl': 0.907916,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'b3',
#   'symbol': 'b3',
#   'name': 'B3 (Base)',
#   'current_price': 0.04007241,
#   'market_cap': 1301530571,
#   'market_cap_rank': 967,
#   'total_volume': 271518322,
#   'circulating_supply': 32446375000.0,
#   'total_supply': 100000000000.0,
#   'ath': 1.59,
#   'atl': 0.03937594,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'cetus-protocol',
#   'symbol': 'cetus',
#   'name': 'Cetus Protocol',
#   'current_price': 1.41,
#   'market_cap': 1284665924,
#   'market_cap_rank': 968,
#   'total_volume': 206936624,
#   'circulating_supply': 909782608.0,
#   'total_supply': 1000000000.0,
#   'ath': 41.16,
#   'atl': 1.29,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'nvidia-ondo-tokenized-stock',
#   'symbol': 'nvdaon',
#   'name': 'NVIDIA (Ondo Tokenized Stock)',
#   'current_price': 17346.21,
#   'market_cap': 1279345366,
#   'market_cap_rank': 969,
#   'total_volume': 921009666,
#   'circulating_supply': 73773.4090348095,
#   'total_supply': 73773.4090348095,
#   'ath': 18732.02,
#   'atl': 14520.78,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'von',
#   'symbol': 'von',
#   'name': 'VON',
#   'current_price': 0.0025377,
#   'market_cap': 1277237734,
#   'market_cap_rank': 970,
#   'total_volume': 18933895,
#   'circulating_supply': 503450000000.0,
#   'total_supply': 1000000000000.0,
#   'ath': 0.080574,
#   'atl': 0.00043115,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'storj',
#   'symbol': 'storj',
#   'name': 'Storj',
#   'current_price': 8.86,
#   'market_cap': 1274566448,
#   'market_cap_rank': 972,
#   'total_volume': 463996820,
#   'circulating_supply': 143787438.7,
#   'total_supply': 424999998.0,
#   'ath': 275.76,
#   'atl': 3.79,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'origin-protocol',
#   'symbol': 'ogn',
#   'name': 'Origin Token',
#   'current_price': 1.94,
#   'market_cap': 1273672233,
#   'market_cap_rank': 971,
#   'total_volume': 182990979,
#   'circulating_supply': 658214557.0,
#   'total_supply': 1409664846.0,
#   'ath': 249.5,
#   'atl': 1.74,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'reactive-network',
#   'symbol': 'react',
#   'name': 'Reactive Network',
#   'current_price': 2.74,
#   'market_cap': 1271282884,
#   'market_cap_rank': 973,
#   'total_volume': 50847449,
#   'circulating_supply': 462500272.2331728,
#   'total_supply': 500000000.0,
#   'ath': 20.6,
#   'atl': 1.53,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'corgiai',
#   'symbol': 'corgiai',
#   'name': 'CorgiAI',
#   'current_price': 0.00388564,
#   'market_cap': 1265902771,
#   'market_cap_rank': 974,
#   'total_volume': 785800,
#   'circulating_supply': 325790034835.1111,
#   'total_supply': 372500000000.0,
#   'ath': 0.350448,
#   'atl': 0.00366161,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'xsgd',
#   'symbol': 'xsgd',
#   'name': 'XSGD',
#   'current_price': 71.56,
#   'market_cap': 1265359521,
#   'market_cap_rank': 975,
#   'total_volume': 51947993,
#   'circulating_supply': 17672293.065569,
#   'total_supply': 17672293.065569,
#   'ath': 100.85,
#   'atl': 45.45,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'yochi',
#   'symbol': 'yochi',
#   'name': 'Yochi',
#   'current_price': 0.00248403,
#   'market_cap': 1265211436,
#   'market_cap_rank': 976,
#   'total_volume': 1628339,
#   'circulating_supply': 509369929146.27686,
#   'total_supply': 509369929146.27686,
#   'ath': 0.00248386,
#   'atl': 0.00170076,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'celer-network',
#   'symbol': 'celr',
#   'name': 'Celer Network',
#   'current_price': 0.223259,
#   'market_cap': 1260693476,
#   'market_cap_rank': 977,
#   'total_volume': 165214899,
#   'circulating_supply': 5645454935.82688,
#   'total_supply': 10000000000.0,
#   'ath': 14.38,
#   'atl': 0.072159,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'mubarak',
#   'symbol': 'mubarak',
#   'name': 'Mubarak',
#   'current_price': 1.26,
#   'market_cap': 1260508985,
#   'market_cap_rank': 978,
#   'total_volume': 738076513,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'ath': 18.32,
#   'atl': 0.888149,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'qie',
#   'symbol': 'qie',
#   'name': 'QIE Blockchain',
#   'current_price': 14.83,
#   'market_cap': 1252067284,
#   'market_cap_rank': 980,
#   'total_volume': 2718321,
#   'circulating_supply': 84419690.163596,
#   'total_supply': 150000565.0,
#   'ath': 19.27,
#   'atl': 0.00860564,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'naoris',
#   'symbol': 'naoris',
#   'name': 'Naoris Protocol',
#   'current_price': 2.09,
#   'market_cap': 1252118820,
#   'market_cap_rank': 979,
#   'total_volume': 75380370,
#   'circulating_supply': 599260000.0,
#   'total_supply': 4000000000.0,
#   'ath': 13.47,
#   'atl': 1.28,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'elastos',
#   'symbol': 'ela',
#   'name': 'Elastos',
#   'current_price': 54.23,
#   'market_cap': 1250067322,
#   'market_cap_rank': 981,
#   'total_volume': 15854801,
#   'circulating_supply': 23075596.0,
#   'total_supply': 26197377.0,
#   'ath': 5785.42,
#   'atl': 52.48,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'maverick-protocol',
#   'symbol': 'mav',
#   'name': 'Maverick Protocol',
#   'current_price': 1.48,
#   'market_cap': 1247549197,
#   'market_cap_rank': 982,
#   'total_volume': 133376839,
#   'circulating_supply': 842955680.1811638,
#   'total_supply': 2000000000.0,
#   'ath': 67.05,
#   'atl': 1.36,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'nillion',
#   'symbol': 'nil',
#   'name': 'Nillion',
#   'current_price': 4.1,
#   'market_cap': 1246504561,
#   'market_cap_rank': 983,
#   'total_volume': 166286664,
#   'circulating_supply': 303625166.664,
#   'total_supply': 1000000000.0,
#   'ath': 76.79,
#   'atl': 3.5,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'insure',
#   'symbol': 'sure',
#   'name': 'inSure DeFi',
#   'current_price': 0.0470572,
#   'market_cap': 1245778134,
#   'market_cap_rank': 984,
#   'total_volume': 46321,
#   'circulating_supply': 26482078217.416843,
#   'total_supply': 88000000000.0,
#   'ath': 8.34,
#   'atl': 0.00410963,
#   'last_updated_date': '2026-02-10'},
#  {'id': '69420',
#   'symbol': '69420',
#   'name': '69420',
#   'current_price': 0.01900858,
#   'market_cap': 1188080197,
#   'market_cap_rank': 985,
#   'total_volume': 0.0,
#   'circulating_supply': 62502297000.0,
#   'total_supply': 69420000000.0,
#   'ath': 0.04419058,
#   'atl': 1.043e-05,
#   'last_updated_date': '2026-02-06'},
#  {'id': 'gems-vip',
#   'symbol': 'gems',
#   'name': 'Gems VIP',
#   'current_price': 1.92,
#   'market_cap': 1233103382,
#   'market_cap_rank': 986,
#   'total_volume': 89186964,
#   'circulating_supply': 643831656.8930804,
#   'total_supply': 837932269.1767285,
#   'ath': 26.92,
#   'atl': 1.18,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'alchemix-usd',
#   'symbol': 'alusd',
#   'name': 'Alchemix USD',
#   'current_price': 89.36,
#   'market_cap': 1232093356,
#   'market_cap_rank': 987,
#   'total_volume': 5041238,
#   'circulating_supply': 13777964.77508556,
#   'total_supply': 13777964.77508556,
#   'ath': 154.11,
#   'atl': 4.36,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'dent',
#   'symbol': 'dent',
#   'name': 'Dent',
#   'current_price': 0.01289361,
#   'market_cap': 1228556842,
#   'market_cap_rank': 988,
#   'total_volume': 112961993,
#   'circulating_supply': 95654960452.73587,
#   'total_supply': 100000000000.0,
#   'ath': 6.4,
#   'atl': 0.00533579,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'real-token',
#   'symbol': 'real',
#   'name': 'Real Token',
#   'current_price': 1.22,
#   'market_cap': 1224890220,
#   'market_cap_rank': 989,
#   'total_volume': 2159777,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'ath': 3.73,
#   'atl': 1.11,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'stablr-euro',
#   'symbol': 'eurr',
#   'name': 'StablR Euro',
#   'current_price': 105.83,
#   'market_cap': 1224061242,
#   'market_cap_rank': 990,
#   'total_volume': 432995888,
#   'circulating_supply': 11566644.46,
#   'total_supply': 11566644.46,
#   'ath': 129.83,
#   'atl': 87.68,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'pulsechain-peacock',
#   'symbol': 'pcock',
#   'name': 'PulseChain Peacock',
#   'current_price': 1.45,
#   'market_cap': 1222031900,
#   'market_cap_rank': 994,
#   'total_volume': 8841560,
#   'circulating_supply': 845603820.3082316,
#   'total_supply': 845603820.3082316,
#   'ath': 2.55,
#   'atl': 0.168783,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'usdm-2',
#   'symbol': 'usdm',
#   'name': 'USDM',
#   'current_price': 92.34,
#   'market_cap': 1218956739,
#   'market_cap_rank': 992,
#   'total_volume': 35910845,
#   'circulating_supply': 13199684.31,
#   'total_supply': 13199684.31,
#   'ath': 122.91,
#   'atl': 46.98,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'funfair',
#   'symbol': 'fun',
#   'name': 'FUNToken',
#   'current_price': 0.114938,
#   'market_cap': 1218216318,
#   'market_cap_rank': 991,
#   'total_volume': 174210908,
#   'circulating_supply': 10598879189.265394,
#   'total_supply': 10999873621.0,
#   'ath': 12.13,
#   'atl': 0.079657,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'intuition',
#   'symbol': 'trust',
#   'name': 'Intuition',
#   'current_price': 6.78,
#   'market_cap': 1217980746,
#   'market_cap_rank': 998,
#   'total_volume': 441608311,
#   'circulating_supply': 179647832.0,
#   'total_supply': 1000000000.0,
#   'ath': 53.71,
#   'atl': 5.78,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'the-innovation-game',
#   'symbol': 'tig',
#   'name': 'The Innovation Game',
#   'current_price': 45.57,
#   'market_cap': 1217169139,
#   'market_cap_rank': 993,
#   'total_volume': 259168529,
#   'circulating_supply': 26709353.501361884,
#   'total_supply': 47379054.54261072,
#   'ath': 364.24,
#   'atl': 9.92,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'marinade',
#   'symbol': 'mnde',
#   'name': 'Marinade',
#   'current_price': 2.24,
#   'market_cap': 1215292690,
#   'market_cap_rank': 995,
#   'total_volume': 68116902,
#   'circulating_supply': 546399977.0,
#   'total_supply': 699997821.3403481,
#   'ath': 123.52,
#   'atl': 2.01,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'vanar-chain',
#   'symbol': 'vanry',
#   'name': 'Vanar Chain',
#   'current_price': 0.565075,
#   'market_cap': 1214307001,
#   'market_cap_rank': 996,
#   'total_volume': 287152161,
#   'circulating_supply': 2150121599.0,
#   'total_supply': 2161316616.0,
#   'ath': 30.84,
#   'atl': 0.462367,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'renzo',
#   'symbol': 'rez',
#   'name': 'Renzo',
#   'current_price': 0.269308,
#   'market_cap': 1210304645,
#   'market_cap_rank': 997,
#   'total_volume': 387338970,
#   'circulating_supply': 4497083777.41274,
#   'total_supply': 9814629224.482912,
#   'ath': 23.21,
#   'atl': 0.257682,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'researchcoin',
#   'symbol': 'rsc',
#   'name': 'ResearchCoin',
#   'current_price': 8.99,
#   'market_cap': 1206155870,
#   'market_cap_rank': 999,
#   'total_volume': 48868213,
#   'circulating_supply': 134157343.59847884,
#   'total_supply': 1000000000.0,
#   'ath': 129.28,
#   'atl': 0.255189,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'xborg',
#   'symbol': 'xbg',
#   'name': 'XBorg',
#   'current_price': 3.0,
#   'market_cap': 1205269973,
#   'market_cap_rank': 1000,
#   'total_volume': 1860275,
#   'circulating_supply': 401175000.0,
#   'total_supply': 1000000000.0,
#   'ath': 35.3,
#   'atl': 1.98,
#   'last_updated_date': '2026-02-10'}]

# %%
import pandas as pd

df_cryptocurrency = pd.DataFrame(cryptocurrency)

display(df_cryptocurrency)
# Out:
#                id symbol          name  current_price       market_cap  \
# 0         bitcoin    btc       Bitcoin     6275065.00  125599657273485
# 1        ethereum    eth      Ethereum      183804.00   22204293665548
# 2          tether   usdt        Tether          90.51   16700897819975
# 3          ripple    xrp           XRP         128.48    7826869690438
# 4     binancecoin    bnb           BNB       56547.00    7719397063749
# ..            ...    ...           ...            ...              ...
# 995      marinade   mnde      Marinade           2.24       1215292690
# 996   vanar-chain  vanry   Vanar Chain           0.57       1214307001
# 997         renzo    rez         Renzo           0.27       1210304645
# 998  researchcoin    rsc  ResearchCoin           8.99       1206155870
# 999         xborg    xbg         XBorg           3.00       1205269973
#
#      market_cap_rank     total_volume  circulating_supply    total_supply  \
# 0                  1 4480093453444.00         19987200.00     19987200.00
# 1                  2 2610841377798.00        120692588.76    120692588.76
# 2                  3 7765371860719.00     184517936950.03 189984874186.80
# 3                  4  251539484784.00      60917315351.00  99985721048.00
# 4                  5  110216717199.00        136359527.58    136359527.58
# ..               ...              ...                 ...             ...
# 995              995      68116902.00        546399977.00    699997821.34
# 996              996     287152161.00       2150121599.00   2161316616.00
# 997              997     387338970.00       4497083777.41   9814629224.48
# 998              999      48868213.00        134157343.60   1000000000.00
# 999             1000       1860275.00        401175000.00   1000000000.00
#
#             ath     atl last_updated_date
# 0   11187013.00 3993.42        2026-02-10
# 1     431946.00   28.13        2026-02-10
# 2        105.52   36.86        2026-02-10
# 3        313.99    0.16        2026-02-10
# 4     121422.00    2.58        2026-02-10
# ..          ...     ...               ...
# 995      123.52    2.01        2026-02-10
# 996       30.84    0.46        2026-02-10
# 997       23.21    0.26        2026-02-10
# 998      129.28    0.26        2026-02-10
# 999       35.30    1.98        2026-02-10
#
# [1000 rows x 12 columns]

# %%
top_3_coin_ids = df_cryptocurrency.sort_values(by='market_cap_rank').head(3)['id'].tolist()
print(top_3_coin_ids)
# Out:
# ['bitcoin', 'ethereum', 'tether']

# %%
all_historical_data = []
import time
import requests

for coin_id in top_3_coin_ids:
    url = f"https://api.coingecko.com/api/v3/coins/{coin_id}/market_chart?vs_currency=inr&days=365"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        all_historical_data.append(data)
    else:
        print(f"Failed to fetch historical data for {coin_id}. Status code: {response.status_code}")
    time.sleep(10)

print(f"Collected historical data for {len(all_historical_data)} cryptocurrencies.")
# Out:
# Failed to fetch historical data for bitcoin. Status code: 429
# Failed to fetch historical data for ethereum. Status code: 429
# Collected historical data for 1 cryptocurrencies.

# %%
historical_prices_list = []

for i, coin_data in enumerate(all_historical_data):
    coin_id = top_3_coin_ids[i]

    # Check if 'prices' key exists in coin_data
    if 'prices' in coin_data:
        # Extract price entries from the current coin's historical data
        prices = coin_data['prices']

        for price_record in prices:
            timestamp = price_record[0]
            price_inr = price_record[1]

            # Convert timestamp (milliseconds) to datetime object and format to YYYY-MM-DD
            date = pd.to_datetime(timestamp, unit='ms').strftime('%Y-%m-%d')

            # Create a dictionary for the current record
            record = {
                'coin_id': coin_id,
                'date': date,
                'price_inr': price_inr
            }
            historical_prices_list.append(record)
    else:
        print(f"Warning: 'prices' data not found for coin_id: {coin_id}. Skipping this coin.")

print(f"Processed {len(historical_prices_list)} historical price records.")
# Out:
# Processed 366 historical price records.

# %%
import pandas as pd
pd.set_option('display.float_format', '{:.2f}'.format)

df_historical_prices = pd.DataFrame(historical_prices_list)
display(df_historical_prices)
# Out:
#      coin_id        date  price_inr
# 0    bitcoin  2025-02-11      87.49
# 1    bitcoin  2025-02-12      86.77
# 2    bitcoin  2025-02-13      86.98
# 3    bitcoin  2025-02-14      86.75
# 4    bitcoin  2025-02-15      86.67
# ..       ...         ...        ...
# 361  bitcoin  2026-02-07      90.54
# 362  bitcoin  2026-02-08      90.54
# 363  bitcoin  2026-02-09      90.52
# 364  bitcoin  2026-02-10      90.74
# 365  bitcoin  2026-02-10      90.51
#
# [366 rows x 3 columns]

# %%
import pandas as pd

# Load the dataset from the GitHub URL
url = "https://raw.githubusercontent.com/datasets/oil-prices/main/data/wti-daily.csv"
df_oil = pd.read_csv(url)

# Display the original DataFrame info and head to inspect it
print("Original DataFrame Info:")
df_oil.info()
print("\nOriginal DataFrame Head:")
display(df_oil)
# Out:
# Original DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10090 entries, 0 to 10089
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    10090 non-null  object
#  1   Price   10090 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 157.8+ KB
#
# Original DataFrame Head:
#              Date  Price
# 0      1986-01-02  25.56
# 1      1986-01-03  26.00
# 2      1986-01-06  26.53
# 3      1986-01-07  25.85
# 4      1986-01-08  25.87
# ...           ...    ...
# 10085  2026-01-27  62.04
# 10086  2026-01-28  62.75
# 10087  2026-01-29  64.77
# 10088  2026-01-30  64.50
# 10089  2026-02-02  61.60
#
# [10090 rows x 2 columns]

# %%
df_oil['Date'] = pd.to_datetime(df_oil['Date'])

start_date = '2020-01-01'
end_date = '2026-02-05'

# Filter df_oil in place
df_oil = df_oil[(df_oil['Date'] >= start_date) & (df_oil['Date'] <= end_date)]

print(f"Filtered df_oil DataFrame shape: {df_oil.shape}")
display(df_oil)
# Out:
# Filtered df_oil DataFrame shape: (1521, 2)
#             Date  Price
# 8569  2020-01-02  61.17
# 8570  2020-01-03  63.00
# 8571  2020-01-06  63.27
# 8572  2020-01-07  62.70
# 8573  2020-01-08  59.65
# ...          ...    ...
# 10085 2026-01-27  62.04
# 10086 2026-01-28  62.75
# 10087 2026-01-29  64.77
# 10088 2026-01-30  64.50
# 10089 2026-02-02  61.60
#
# [1521 rows x 2 columns]

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.12/dist-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.5.1)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance) (3.19.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.14.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (5.29.5)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2026.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)

# %%
import yfinance as yf
import pandas as pd

tickers = ["^GSPC", "^IXIC", "^NSEI"]
start_date = "2020-01-01"
end_date = "2026-02-05"

df_stocks = yf.download(tickers, start=start_date, end=end_date)

print(f"Downloaded stock data for {len(tickers)} tickers from {start_date} to {end_date}.")
display(df_stocks)
# Out:
# /tmp/ipython-input-301512804.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_stocks = yf.download(tickers, start=start_date, end=end_date)
# [*********************100%***********************]  3 of 3 completed
# Downloaded stock data for 3 tickers from 2020-01-01 to 2026-02-05.
# Price        Close                      High                       Low  \
# Ticker       ^GSPC    ^IXIC    ^NSEI   ^GSPC    ^IXIC    ^NSEI   ^GSPC
# Date
# 2020-01-01     NaN      NaN 12182.50     NaN      NaN 12222.20     NaN
# 2020-01-02 3257.85  9092.19 12282.20 3258.14  9093.43 12289.90 3235.53
# 2020-01-03 3234.85  9020.77 12226.65 3246.15  9065.76 12265.60 3222.34
# 2020-01-06 3246.28  9071.47 11993.05 3246.84  9072.41 12179.10 3214.64
# 2020-01-07 3237.18  9068.58 12052.95 3244.91  9091.93 12152.15 3232.43
# ...            ...      ...      ...     ...      ...      ...     ...
# 2026-01-29 6969.01 23685.12 25418.90 6992.84 23840.55 25458.15 6870.80
# 2026-01-30 6939.03 23461.82 25320.65 6964.09 23662.25 25370.70 6893.48
# 2026-02-02 6976.44 23592.11 25088.40 6991.92 23686.83 25108.10 6914.34
# 2026-02-03 6917.81 23255.19 25727.55 6993.08 23691.60 26341.20 6862.05
# 2026-02-04 6882.72 22904.58 25776.00 6936.09 23270.07 25818.55 6838.80
#
# Price                           Open                          Volume  \
# Ticker        ^IXIC    ^NSEI   ^GSPC    ^IXIC    ^NSEI         ^GSPC
# Date
# 2020-01-01      NaN 12165.30     NaN      NaN 12202.15           NaN
# 2020-01-02  9010.89 12195.25 3244.67  9039.46 12198.55 3459930000.00
# 2020-01-03  8976.43 12191.35 3226.36  8976.43 12261.10 3484700000.00
# 2020-01-06  8943.50 11974.20 3217.55  8943.50 12170.60 3702460000.00
# 2020-01-07  9042.55 12005.35 3241.86  9076.64 12079.10 3435910000.00
# ...             ...      ...     ...      ...      ...           ...
# 2026-01-29 23232.78 25159.80 6977.74 23830.92 25345.00 6877780000.00
# 2026-01-30 23351.55 25213.65 6947.27 23578.96 25247.55 6697340000.00
# 2026-02-02 23356.40 24679.40 6916.64 23370.54 24796.50 5772050000.00
# 2026-02-03 23027.21 25641.30 6985.45 23667.44 26308.05 7017660000.00
# 2026-02-04 22684.51 25563.95 6924.50 23217.02 25675.05 7475750000.00
#
# Price
# Ticker              ^IXIC     ^NSEI
# Date
# 2020-01-01            NaN 304100.00
# 2020-01-02  2862700000.00 407700.00
# 2020-01-03  2586520000.00 428800.00
# 2020-01-06  2810450000.00 396500.00
# 2020-01-07  2381740000.00 447800.00
# ...                   ...       ...
# 2026-01-29  8782210000.00 582400.00
# 2026-01-30  9255930000.00 508400.00
# 2026-02-02  8882530000.00 449200.00
# 2026-02-03 10306320000.00 637300.00
# 2026-02-04 10862000000.00 429800.00
#
# [1581 rows x 15 columns]

# %%
print("Missing values before handling:")
display(df_stocks.isnull().sum())
# Out:
# Missing values before handling:
# Price   Ticker
# Close   ^GSPC     50
#         ^IXIC     50
#         ^NSEI     72
# High    ^GSPC     50
#         ^IXIC     50
#         ^NSEI     72
# Low     ^GSPC     50
#         ^IXIC     50
#         ^NSEI     72
# Open    ^GSPC     50
#         ^IXIC     50
#         ^NSEI     72
# Volume  ^GSPC     50
#         ^IXIC     50
#         ^NSEI     72
# dtype: int64

# %%
# Forward-fill missing values in df_stocks
df_stocks_filled = df_stocks.ffill()

# Reset the index and rename columns for easier access
df_stocks_filled = df_stocks_filled.stack(level=1).reset_index()
df_stocks_filled.columns = ['Date', 'Ticker', 'Price_Close', 'Price_High', 'Price_Low', 'Price_Open', 'Price_Volume']

print("Missing values after handling:")
display(df_stocks_filled.isnull().sum())

display(df_stocks_filled.head())
# Out:
# Missing values after handling:
# /tmp/ipython-input-2246665882.py:5: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_stocks_filled = df_stocks_filled.stack(level=1).reset_index()
# Date            0
# Ticker          0
# Price_Close     0
# Price_High      0
# Price_Low       0
# Price_Open      0
# Price_Volume    0
# dtype: int64
#         Date Ticker  Price_Close  Price_High  Price_Low  Price_Open  \
# 0 2020-01-01  ^NSEI     12182.50    12222.20   12165.30    12202.15
# 1 2020-01-02  ^GSPC      3257.85     3258.14    3235.53     3244.67
# 2 2020-01-02  ^IXIC      9092.19     9093.43    9010.89     9039.46
# 3 2020-01-02  ^NSEI     12282.20    12289.90   12195.25    12198.55
# 4 2020-01-03  ^GSPC      3234.85     3246.15    3222.34     3226.36
#
#    Price_Volume
# 0     304100.00
# 1 3459930000.00
# 2 2862700000.00
# 3     407700.00
# 4 3484700000.00

# %%
df_stocks = df_stocks_filled
print("df_stocks now contains the cleaned and processed data:")
display(df_stocks)
# Out:
# df_stocks now contains the cleaned and processed data:
#            Date Ticker  Price_Close  Price_High  Price_Low  Price_Open  \
# 0    2020-01-01  ^NSEI     12182.50    12222.20   12165.30    12202.15
# 1    2020-01-02  ^GSPC      3257.85     3258.14    3235.53     3244.67
# 2    2020-01-02  ^IXIC      9092.19     9093.43    9010.89     9039.46
# 3    2020-01-02  ^NSEI     12282.20    12289.90   12195.25    12198.55
# 4    2020-01-03  ^GSPC      3234.85     3246.15    3222.34     3226.36
# ...         ...    ...          ...         ...        ...         ...
# 4736 2026-02-03  ^IXIC     23255.19    23691.60   23027.21    23667.44
# 4737 2026-02-03  ^NSEI     25727.55    26341.20   25641.30    26308.05
# 4738 2026-02-04  ^GSPC      6882.72     6936.09    6838.80     6924.50
# 4739 2026-02-04  ^IXIC     22904.58    23270.07   22684.51    23217.02
# 4740 2026-02-04  ^NSEI     25776.00    25818.55   25563.95    25675.05
#
#        Price_Volume
# 0         304100.00
# 1     3459930000.00
# 2     2862700000.00
# 3         407700.00
# 4     3484700000.00
# ...             ...
# 4736 10306320000.00
# 4737      637300.00
# 4738  7475750000.00
# 4739 10862000000.00
# 4740      429800.00
#
# [4741 rows x 7 columns]

# %%
import sqlite3

conn = sqlite3.connect("mydatabase.db")
cursor = conn.cursor()

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')
cursor = conn.cursor()

# Drop the table if it already exists to ensure the schema is updated
cursor.execute('DROP TABLE IF EXISTS cryptocurrency;')

# Create the cryptocurrency table with the specified schema
cursor.execute('''
CREATE TABLE cryptocurrency (
    id TEXT PRIMARY KEY,
    symbol TEXT,
    name TEXT,
    current_price REAL,
    market_cap INTEGER,
    market_cap_rank INTEGER,
    total_volume INTEGER,
    circulating_supply REAL,
    total_supply REAL,
    ath REAL,
    atl REAL,
    date TEXT
);
''')

# Prepare data for insertion by renaming the 'last_updated_date' column to 'date'
cryptocurrency_data_for_sql = df_cryptocurrency.rename(columns={'last_updated_date': 'date'})

# Insert data into the cryptocurrency table
# Using executemany for better performance and to handle potential DataFrame NaNs
# which should become NULL in SQL

# Ensure all columns exist, fill missing with None for SQL insertion
columns_to_insert = [
    'id', 'symbol', 'name', 'current_price', 'market_cap',
    'market_cap_rank', 'total_volume', 'circulating_supply',
    'total_supply', 'ath', 'atl', 'date'
]

# Replace NaN with None for SQLite compatibility
records = cryptocurrency_data_for_sql[columns_to_insert].where(pd.notnull(cryptocurrency_data_for_sql[columns_to_insert]), None).values.tolist()

insert_query = '''
INSERT OR REPLACE INTO cryptocurrency (
    id, symbol, name, current_price, market_cap, market_cap_rank,
    total_volume, circulating_supply, total_supply, ath, atl, date
)
VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
'''

cursor.executemany(insert_query, records)

conn.commit()
conn.close()
print("df_cryptocurrency successfully pushed to the 'cryptocurrency' table.")
# Out:
# df_cryptocurrency successfully pushed to the 'cryptocurrency' table.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')
cursor = conn.cursor()

# Drop the table if it already exists to ensure the schema is updated
cursor.execute('DROP TABLE IF EXISTS historical_prices;')

# Create the historical_prices table with the specified schema
cursor.execute('''
CREATE TABLE historical_prices (
    coin_id TEXT,
    date TEXT,
    price_inr REAL,
    PRIMARY KEY (coin_id, date),
    FOREIGN KEY (coin_id) REFERENCES cryptocurrency(id)
);
''')

# Prepare data for insertion
# Ensure all columns exist, fill missing with None for SQL insertion
columns_to_insert = ['coin_id', 'date', 'price_inr']

# Replace NaN with None for SQLite compatibility
records = df_historical_prices[columns_to_insert].where(pd.notnull(df_historical_prices[columns_to_insert]), None).values.tolist()

insert_query = '''
INSERT OR REPLACE INTO historical_prices (
    coin_id, date, price_inr
)
VALUES (?, ?, ?)
'''

cursor.executemany(insert_query, records)

conn.commit()
conn.close()
print("df_historical_prices successfully pushed to the 'historical_prices' table.")
# Out:
# df_historical_prices successfully pushed to the 'historical_prices' table.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')
cursor = conn.cursor()

# Drop the table if it already exists to ensure the schema is updated
cursor.execute('DROP TABLE IF EXISTS oil_prices;')

# Create the oil_prices table with the specified schema
cursor.execute('''
CREATE TABLE oil_prices (
    date TEXT PRIMARY KEY,
    price_usd REAL
);
''')

# Prepare data for insertion: rename 'Price' to 'price_usd' and ensure 'Date' is text for PRIMARY KEY
df_oil_for_sql = df_oil.copy()
df_oil_for_sql['date'] = df_oil_for_sql['Date'].dt.strftime('%Y-%m-%d')
df_oil_for_sql = df_oil_for_sql.rename(columns={'Price': 'price_usd'})

# Ensure only the necessary columns are selected and handle potential NaNs
columns_to_insert = ['date', 'price_usd']
records = df_oil_for_sql[columns_to_insert].where(pd.notnull(df_oil_for_sql[columns_to_insert]), None).values.tolist()

insert_query = '''
INSERT OR REPLACE INTO oil_prices (
    date, price_usd
)
VALUES (?, ?)
'''

cursor.executemany(insert_query, records)

conn.commit()
conn.close()
print("df_oil successfully pushed to the 'oil_prices' table.")
# Out:
# df_oil successfully pushed to the 'oil_prices' table.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')
cursor = conn.cursor()

# Drop the table if it already exists to ensure the schema is updated
cursor.execute('DROP TABLE IF EXISTS stock_prices;')

# Create the stock_prices table with the specified schema
cursor.execute('''
CREATE TABLE stock_prices (
    date TEXT,
    open REAL,
    high REAL,
    low REAL,
    close REAL,
    volume INTEGER,
    ticker TEXT,
    PRIMARY KEY (date, ticker)
);
''')

# Prepare data for insertion: rename DataFrame columns to match SQL table columns
df_stocks_for_sql = df_stocks.copy()
df_stocks_for_sql['date'] = df_stocks_for_sql['Date'].dt.strftime('%Y-%m-%d')
df_stocks_for_sql = df_stocks_for_sql.rename(columns={
    'Price_Open': 'open',
    'Price_High': 'high',
    'Price_Low': 'low',
    'Price_Close': 'close',
    'Price_Volume': 'volume',
    'Ticker': 'ticker'
})

# Ensure only the necessary columns are selected and handle potential NaNs
columns_to_insert = ['date', 'open', 'high', 'low', 'close', 'volume', 'ticker']
records = df_stocks_for_sql[columns_to_insert].where(pd.notnull(df_stocks_for_sql[columns_to_insert]), None).values.tolist()

insert_query = '''
INSERT OR REPLACE INTO stock_prices (
    date, open, high, low, close, volume, ticker
)
VALUES (?, ?, ?, ?, ?, ?, ?)
'''

cursor.executemany(insert_query, records)

conn.commit()
conn.close()
print("df_stocks successfully pushed to the 'stock_prices' table.")
# Out:
# df_stocks successfully pushed to the 'stock_prices' table.

# %%
import sqlite3

conn = sqlite3.connect('mydatabase.db')
cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

print("Tables in the database:")
if tables:
    for table in tables:
        print(table[0])
else:
    print("No tables found in the database.")

conn.close()
# Out:
# Tables in the database:
# cryptocurrency
# historical_prices
# oil_prices
# stock_prices

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query the stock_prices table
oil_prices_sql = pd.read_sql_query("SELECT * FROM oil_prices", conn)

conn.close()

print("Contents of the 'oil_prices' table:")
display(oil_prices_sql)
# Out:
# Contents of the 'oil_prices' table:
#             date  price_usd
# 0     2020-01-02      61.17
# 1     2020-01-03      63.00
# 2     2020-01-06      63.27
# 3     2020-01-07      62.70
# 4     2020-01-08      59.65
# ...          ...        ...
# 1516  2026-01-27      62.04
# 1517  2026-01-28      62.75
# 1518  2026-01-29      64.77
# 1519  2026-01-30      64.50
# 1520  2026-02-02      61.60
#
# [1521 rows x 2 columns]

# %%
#top 3 cryptocurrencies by market cap

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')
cursor = conn.cursor()

# Query to find the top 3 cryptocurrencies by market cap
query = """
SELECT id, name, market_cap, market_cap_rank
FROM cryptocurrency
ORDER BY market_cap_rank ASC
LIMIT 3;
"""

top_3_cryptos = pd.read_sql_query(query, conn)

conn.close()

print("Top 3 Cryptocurrencies by Market Cap:")
display(top_3_cryptos)
# Out:
# Top 3 Cryptocurrencies by Market Cap:
#          id      name       market_cap  market_cap_rank
# 0   bitcoin   Bitcoin  125599657273485                1
# 1  ethereum  Ethereum   22204293665548                2
# 2    tether    Tether   16700897819975                3

# %% [markdown]
# coins where circulating_supply > 90% of total_supply

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find coins where circulating_supply > 90% of total_supply
query = """
SELECT id, name, circulating_supply, total_supply
FROM cryptocurrency
WHERE (circulating_supply * 1.0 / total_supply) > 0.9 AND total_supply IS NOT NULL AND total_supply > 0;
"""

high_circulating_supply_coins = pd.read_sql_query(query, conn)

conn.close()

print("Cryptocurrencies with circulating supply > 90% of total supply:")
display(high_circulating_supply_coins)
# Out:
# Cryptocurrencies with circulating supply > 90% of total supply:
#                      id                name  circulating_supply  \
# 0               bitcoin             Bitcoin         19987200.00
# 1              ethereum            Ethereum        120692588.76
# 2                tether              Tether     184517936950.03
# 3           binancecoin                 BNB        136359527.58
# 4              usd-coin                USDC      73137440593.27
# ..                  ...                 ...                 ...
# 505         stablr-euro         StablR Euro         11566644.46
# 506  pulsechain-peacock  PulseChain Peacock        845603820.31
# 507              usdm-2                USDM         13199684.31
# 508             funfair            FUNToken      10598879189.27
# 509         vanar-chain         Vanar Chain       2150121599.00
#
#        total_supply
# 0       19987200.00
# 1      120692588.76
# 2   189984874186.80
# 3      136359527.58
# 4    73139979021.26
# ..              ...
# 505     11566644.46
# 506    845603820.31
# 507     13199684.31
# 508  10999873621.00
# 509   2161316616.00
#
# [510 rows x 4 columns]

# %% [markdown]
# coins within 10% of their all-time-high (ATH)

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find coins within 10% of their all-time-high (ATH)
query = """
SELECT id, name, current_price, ath
FROM cryptocurrency
WHERE current_price >= (ath * 0.9) AND ath IS NOT NULL;
"""

coins_near_ath = pd.read_sql_query(query, conn)

conn.close()

print("Cryptocurrencies within 10% of their All-Time-High (ATH):")
display(coins_near_ath)
# Out:
# Cryptocurrencies within 10% of their All-Time-High (ATH):
#                                                     id  \
# 0                                                 usds
# 1                                          ethena-usde
# 2                                            usd1-wlfi
# 3                                                  dai
# 4                                           paypal-usd
# ..                                                 ...
# 116                                 f-x-protocol-fxusd
# 117                                    diamond-token-2
# 118  ishares-core-us-aggregate-bond-etf-ondo-tokeni...
# 119                        nvidia-ondo-tokenized-stock
# 120                                              yochi
#
#                                                   name  current_price      ath
# 0                                                 USDS          90.55    92.23
# 1                                          Ethena USDe          90.43    92.91
# 2                                                 USD1          90.52    92.17
# 3                                                  Dai          90.51    92.29
# 4                                           PayPal USD          90.50    92.20
# ..                                                 ...            ...      ...
# 116                                f(x) Protocol fxUSD          90.68    93.77
# 117                                    DIAMOND TOKEN 💎          13.15    13.19
# 118  iShares Core US Aggregate Bond ETF (Ondo Token...        9255.55  9461.67
# 119                      NVIDIA (Ondo Tokenized Stock)       17346.21 18732.02
# 120                                              Yochi           0.00     0.00
#
# [121 rows x 4 columns]

# %% [markdown]
# Average market cap rank of coins with total volume above $1 Billion(100crore.inr)

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find the average market cap rank of coins with volume above $1B
query = """
SELECT AVG(market_cap_rank) as average_market_cap_rank
FROM cryptocurrency
WHERE total_volume > 1000000000;
"""

average_rank_high_volume = pd.read_sql_query(query, conn)

conn.close()

print("Average market cap rank of coins with total volume above $1 Billion:")
display(average_rank_high_volume)
# Out:
# Average market cap rank of coins with total volume above $1 Billion:
#    average_market_cap_rank
# 0                   269.21

# %% [markdown]
# #most recently updated coin

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find the most recently updated coin
query = """
SELECT id, name, date
FROM cryptocurrency
ORDER BY date DESC
LIMIT 1;
"""

most_recent_coin = pd.read_sql_query(query, conn)

conn.close()

print("Most recently updated coin:")
display(most_recent_coin)
# Out:
# Most recently updated coin:
#         id     name        date
# 0  bitcoin  Bitcoin  2026-02-10

# %% [markdown]
# The highest daily price of Bitcoin in the last 365 days.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find the highest daily price of Bitcoin in the last 365 days
query = """
SELECT coin_id, date, price_inr
FROM historical_prices
WHERE coin_id = 'bitcoin'
ORDER BY price_inr DESC
LIMIT 1;
"""

bitcoin_highest_price = pd.read_sql_query(query, conn)

conn.close()

print("Highest daily price of Bitcoin in the last 365 days:")
display(bitcoin_highest_price)
# Out:
# Highest daily price of Bitcoin in the last 365 days:
#    coin_id        date  price_inr
# 0  bitcoin  2026-01-29      91.91

# %% [markdown]
# The average daily price of Ethereum in the past 1 year.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find the average daily price of Ethereum in the past 1 year
query = """
SELECT AVG(price_inr) as average_ethereum_price
FROM historical_prices
WHERE coin_id = 'ethereum';
"""

ethereum_average_price = pd.read_sql_query(query, conn)

conn.close()

print("Average daily price of Ethereum in the past 1 year:")
display(ethereum_average_price)
# Out:
# Average daily price of Ethereum in the past 1 year:
#   average_ethereum_price
# 0                   None

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find the daily price trend of Bitcoin in January 2025
query = """
SELECT date, price_inr
FROM historical_prices
WHERE coin_id = 'bitcoin'
  AND date BETWEEN '2025-02-01' AND '2025-02-31'
ORDER BY date ASC;
"""

bitcoin_jan_2025_prices = pd.read_sql_query(query, conn)

conn.close()

print("Daily price trend of Bitcoin in January 2025:")
display(bitcoin_jan_2025_prices)
# Out:
# Daily price trend of Bitcoin in January 2025:
#           date  price_inr
# 0   2025-02-11      87.49
# 1   2025-02-12      86.77
# 2   2025-02-13      86.98
# 3   2025-02-14      86.75
# 4   2025-02-15      86.67
# 5   2025-02-16      86.64
# 6   2025-02-17      86.65
# 7   2025-02-18      86.85
# 8   2025-02-19      86.83
# 9   2025-02-20      86.87
# 10  2025-02-21      86.48
# 11  2025-02-22      86.60
# 12  2025-02-23      86.61
# 13  2025-02-24      86.60
# 14  2025-02-25      86.66
# 15  2025-02-26      86.99
# 16  2025-02-27      87.05
# 17  2025-02-28      87.24

# %% [markdown]
# The coin with the highest average price over 1 year

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find the coin with the highest average price over 1 year
query = """
SELECT
    coin_id,
    AVG(price_inr) AS average_price
FROM
    historical_prices
GROUP BY
    coin_id
ORDER BY
    average_price DESC
LIMIT 1;
"""

highest_avg_price_coin = pd.read_sql_query(query, conn)

conn.close()

print("Coin with the highest average price over 1 year:")
display(highest_avg_price_coin)
# Out:
# Coin with the highest average price over 1 year:
#    coin_id  average_price
# 0  bitcoin          87.62

# %% [markdown]
#  % change in Bitcoin’s price between Sep 2025 and jan 2026.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Get the price for Bitcoin at the start of September 2025
query_start_price = """
SELECT price_inr
FROM historical_prices
WHERE coin_id = 'bitcoin' AND date >= '2025-09-01'
ORDER BY date ASC
LIMIT 1;
"""

start_price_df = pd.read_sql_query(query_start_price, conn)
start_price = start_price_df['price_inr'].iloc[0] if not start_price_df.empty else None

# Get the price for Bitcoin at the end of January 2026
query_end_price = """
SELECT price_inr
FROM historical_prices
WHERE coin_id = 'bitcoin' AND date <= '2026-01-31'
ORDER BY date DESC
LIMIT 1;
"""

end_price_df = pd.read_sql_query(query_end_price, conn)
end_price = end_price_df['price_inr'].iloc[0] if not end_price_df.empty else None

conn.close()

if start_price is not None and end_price is not None:
    percentage_change = ((end_price - start_price) / start_price) * 100
    print(f"Bitcoin price at the start of Sep 2025: {start_price:.2f} INR")
    print(f"Bitcoin price at the end of Jan 2026: {end_price:.2f} INR")
    print(f"Percentage change in Bitcoin's price between Sep 2025 and Jan 2026: {percentage_change:.2f}%")
else:
    print("Could not retrieve prices for the specified period. Please check data availability.")
# Out:
# Bitcoin price at the start of Sep 2025: 88.19 INR
# Bitcoin price at the end of Jan 2026: 91.55 INR
# Percentage change in Bitcoin's price between Sep 2025 and Jan 2026: 3.81%

# %% [markdown]
# The highest oil price in the last 5 years.

# %%
import sqlite3
import pandas as pd
import datetime

conn = sqlite3.connect('mydatabase.db')

# Calculate the date 5 years ago from the latest date in the oil_prices table
# First, find the maximum date in the table
max_date_query = "SELECT MAX(date) FROM oil_prices;"
max_date_result = pd.read_sql_query(max_date_query, conn)
latest_date_str = max_date_result.iloc[0, 0]

# Convert to datetime object and subtract 5 years
latest_date = datetime.datetime.strptime(latest_date_str, '%Y-%m-%d').date()
five_years_ago = latest_date - datetime.timedelta(days=5*365) # Approximate 5 years

# Query to find the highest oil price in the last 5 years
query = f"""
SELECT date, price_usd
FROM oil_prices
WHERE date >= '{five_years_ago.isoformat()}'
ORDER BY price_usd DESC
LIMIT 1;
"""

highest_oil_price = pd.read_sql_query(query, conn)

conn.close()

print("Highest oil price in the last 5 years:")
display(highest_oil_price)
# Out:
# Highest oil price in the last 5 years:
#          date  price_usd
# 0  2022-03-08     123.64

# %% [markdown]
# The average oil price per year.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to get the average oil price per year
query = """
SELECT
    STRFTIME('%Y', date) AS year,
    AVG(price_usd) AS average_price_usd
FROM
    oil_prices
GROUP BY
    year
ORDER BY
    year ASC;
"""

average_oil_price_per_year = pd.read_sql_query(query, conn)

conn.close()

print("Average oil price per year:")
display(average_oil_price_per_year)
# Out:
# Average oil price per year:
#    year  average_price_usd
# 0  2020              39.16
# 1  2021              68.14
# 2  2022              94.90
# 3  2023              77.58
# 4  2024              76.63
# 5  2025              65.39
# 6  2026              60.11

# %% [markdown]
# The oil prices during COVID crash (March–April 2020).

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find oil prices during the COVID crash (March-April 2020)
query = """
SELECT date, price_usd
FROM oil_prices
WHERE date BETWEEN '2020-03-01' AND '2020-04-30'
ORDER BY date ASC;
"""

oil_prices_covid_crash = pd.read_sql_query(query, conn)

conn.close()

print("Oil prices during COVID crash (March–April 2020):")
display(oil_prices_covid_crash)
# Out:
# Oil prices during COVID crash (March–April 2020):
#           date  price_usd
# 0   2020-03-02      46.78
# 1   2020-03-03      47.27
# 2   2020-03-04      46.78
# 3   2020-03-05      45.90
# 4   2020-03-06      41.14
# 5   2020-03-09      31.05
# 6   2020-03-10      34.47
# 7   2020-03-11      33.13
# 8   2020-03-12      31.56
# 9   2020-03-13      31.72
# 10  2020-03-16      28.96
# 11  2020-03-17      26.96
# 12  2020-03-18      20.48
# 13  2020-03-19      25.09
# 14  2020-03-20      19.48
# 15  2020-03-23      23.33
# 16  2020-03-24      21.03
# 17  2020-03-25      20.75
# 18  2020-03-26      16.60
# 19  2020-03-27      15.48
# 20  2020-03-30      14.10
# 21  2020-03-31      20.51
# 22  2020-04-01      20.28
# 23  2020-04-02      25.18
# 24  2020-04-03      28.36
# 25  2020-04-06      26.21
# 26  2020-04-07      23.54
# 27  2020-04-08      24.97
# 28  2020-04-09      22.90
# 29  2020-04-13      22.36
# 30  2020-04-14      20.15
# 31  2020-04-15      19.96
# 32  2020-04-16      19.82
# 33  2020-04-17      18.31
# 34  2020-04-20     -36.98
# 35  2020-04-21       8.91
# 36  2020-04-22      13.64
# 37  2020-04-23      15.06
# 38  2020-04-24      15.99
# 39  2020-04-27      12.17
# 40  2020-04-28      12.40
# 41  2020-04-29      15.04
# 42  2020-04-30      19.23

# %% [markdown]
#  lowest price of oil in the last 10 years.

# %%
import sqlite3
import pandas as pd
import datetime

conn = sqlite3.connect('mydatabase.db')

# Calculate the date 10 years ago from the latest date in the oil_prices table
# First, find the maximum date in the table
max_date_query = "SELECT MAX(date) FROM oil_prices;"
max_date_result = pd.read_sql_query(max_date_query, conn)
latest_date_str = max_date_result.iloc[0, 0]

# Convert to datetime object and subtract 10 years
latest_date = datetime.datetime.strptime(latest_date_str, '%Y-%m-%d').date()
ten_years_ago = latest_date - datetime.timedelta(days=10*365) # Approximate 10 years

# Query to find the lowest oil price in the last 10 years
query = f"""
SELECT date, price_usd
FROM oil_prices
WHERE date >= '{ten_years_ago.isoformat()}'
ORDER BY price_usd ASC
LIMIT 1;
"""

lowest_oil_price = pd.read_sql_query(query, conn)

conn.close()

print("Lowest oil price in the last 10 years:")
display(lowest_oil_price)
# Out:
# Lowest oil price in the last 10 years:
#          date  price_usd
# 0  2020-04-20     -36.98

# %% [markdown]
# The volatility of oil prices (max-min difference per year).

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to calculate the volatility of oil prices (max-min difference per year)
query = """
SELECT
    STRFTIME('%Y', date) AS year,
    MAX(price_usd) - MIN(price_usd) AS volatility_usd
FROM
    oil_prices
GROUP BY
    year
ORDER BY
    year ASC;
"""

oil_price_volatility = pd.read_sql_query(query, conn)

conn.close()

print("Volatility of oil prices (max-min difference per year):")
display(oil_price_volatility)
# Out:
# Volatility of oil prices (max-min difference per year):
#    year  volatility_usd
# 0  2020          100.25
# 1  2021           38.17
# 2  2022           52.59
# 3  2023           27.06
# 4  2024           20.96
# 5  2025           25.29
# 6  2026            8.76

# %% [markdown]
#  all stock prices for a given ticker

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Get all unique tickers from the stock_prices table
query_tickers = """
SELECT DISTINCT ticker
FROM stock_prices;
"""
available_tickers_df = pd.read_sql_query(query_tickers, conn)
available_tickers = available_tickers_df['ticker'].tolist()

print(f"Retrieving data for tickers: {', '.join(available_tickers)}")

for ticker in available_tickers:
    print(f"\n--- Stock Prices for {ticker} ---")
    query = f"""
    SELECT date, open, high, low, close, volume
    FROM stock_prices
    WHERE ticker = '{ticker}'
    ORDER BY date ASC;
    """
    stock_prices_by_ticker = pd.read_sql_query(query, conn)

    if not stock_prices_by_ticker.empty:
        display(stock_prices_by_ticker)
    else:
        print(f"No stock data found for ticker: {ticker}.")

conn.close()
# Out:
# Retrieving data for tickers: ^NSEI, ^GSPC, ^IXIC
#
# --- Stock Prices for ^NSEI ---
#             date     open     high      low    close  volume
# 0     2020-01-01 12202.15 12222.20 12165.30 12182.50  304100
# 1     2020-01-02 12198.55 12289.90 12195.25 12282.20  407700
# 2     2020-01-03 12261.10 12265.60 12191.35 12226.65  428800
# 3     2020-01-06 12170.60 12179.10 11974.20 11993.05  396500
# 4     2020-01-07 12079.10 12152.15 12005.35 12052.95  447800
# ...          ...      ...      ...      ...      ...     ...
# 1576  2026-01-29 25345.00 25458.15 25159.80 25418.90  582400
# 1577  2026-01-30 25247.55 25370.70 25213.65 25320.65  508400
# 1578  2026-02-02 24796.50 25108.10 24679.40 25088.40  449200
# 1579  2026-02-03 26308.05 26341.20 25641.30 25727.55  637300
# 1580  2026-02-04 25675.05 25818.55 25563.95 25776.00  429800
#
# [1581 rows x 6 columns]
# --- Stock Prices for ^GSPC ---
#             date    open    high     low   close      volume
# 0     2020-01-02 3244.67 3258.14 3235.53 3257.85  3459930000
# 1     2020-01-03 3226.36 3246.15 3222.34 3234.85  3484700000
# 2     2020-01-06 3217.55 3246.84 3214.64 3246.28  3702460000
# 3     2020-01-07 3241.86 3244.91 3232.43 3237.18  3435910000
# 4     2020-01-08 3238.59 3267.07 3236.67 3253.05  3726840000
# ...          ...     ...     ...     ...     ...         ...
# 1575  2026-01-29 6977.74 6992.84 6870.80 6969.01  6877780000
# 1576  2026-01-30 6947.27 6964.09 6893.48 6939.03  6697340000
# 1577  2026-02-02 6916.64 6991.92 6914.34 6976.44  5772050000
# 1578  2026-02-03 6985.45 6993.08 6862.05 6917.81  7017660000
# 1579  2026-02-04 6924.50 6936.09 6838.80 6882.72  7475750000
#
# [1580 rows x 6 columns]
# --- Stock Prices for ^IXIC ---
#             date     open     high      low    close       volume
# 0     2020-01-02  9039.46  9093.43  9010.89  9092.19   2862700000
# 1     2020-01-03  8976.43  9065.76  8976.43  9020.77   2586520000
# 2     2020-01-06  8943.50  9072.41  8943.50  9071.47   2810450000
# 3     2020-01-07  9076.64  9091.93  9042.55  9068.58   2381740000
# 4     2020-01-08  9068.03  9168.89  9059.38  9129.24   2472620000
# ...          ...      ...      ...      ...      ...          ...
# 1575  2026-01-29 23830.92 23840.55 23232.78 23685.12   8782210000
# 1576  2026-01-30 23578.96 23662.25 23351.55 23461.82   9255930000
# 1577  2026-02-02 23370.54 23686.83 23356.40 23592.11   8882530000
# 1578  2026-02-03 23667.44 23691.60 23027.21 23255.19  10306320000
# 1579  2026-02-04 23217.02 23270.07 22684.51 22904.58  10862000000
#
# [1580 rows x 6 columns]

# %% [markdown]
# ### Highest closing price for NASDAQ (^IXIC)

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find the highest closing price for NASDAQ (^IXIC)
query = """
SELECT date, close
FROM stock_prices
WHERE ticker = '^IXIC'
ORDER BY close DESC
LIMIT 1;
"""

highest_nasdaq_close = pd.read_sql_query(query, conn)

conn.close()

print("Highest closing price for NASDAQ (^IXIC):")
display(highest_nasdaq_close)
# Out:
# Highest closing price for NASDAQ (^IXIC):
#          date    close
# 0  2025-10-29 23958.47

# %% [markdown]
# ### Top 5 days with highest price difference (high - low) for S&P 500 (^GSPC)

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find the top 5 days with the highest price difference (high - low) for S&P 500 (^GSPC)
query = """
SELECT
    date,
    (high - low) AS price_difference
FROM
    stock_prices
WHERE
    ticker = '^GSPC'
ORDER BY
    price_difference DESC
LIMIT 5;
"""

top_5_gspc_diff = pd.read_sql_query(query, conn)

conn.close()

print("Top 5 days with highest price difference for S&P 500 (^GSPC):")
display(top_5_gspc_diff)
# Out:
# Top 5 days with highest price difference for S&P 500 (^GSPC):
#          date  price_difference
# 0  2025-04-09            532.91
# 1  2025-04-07            411.53
# 2  2025-04-08            357.05
# 3  2025-04-10            237.88
# 4  2025-11-20            236.30

# %% [markdown]
# ### Monthly Average Closing Price for Each Ticker

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to get the monthly average closing price for each ticker
query = """
SELECT
    ticker,
    STRFTIME('%Y-%m', date) AS year_month,
    AVG(close) AS average_closing_price
FROM
    stock_prices
GROUP BY
    ticker, year_month
ORDER BY
    ticker, year_month ASC;
"""

monthly_avg_close_price = pd.read_sql_query(query, conn)

conn.close()

print("Monthly average closing price for each ticker:")
display(monthly_avg_close_price)
# Out:
# Monthly average closing price for each ticker:
#     ticker year_month  average_closing_price
# 0    ^GSPC    2020-01                3280.54
# 1    ^GSPC    2020-02                3282.46
# 2    ^GSPC    2020-03                2652.39
# 3    ^GSPC    2020-04                2761.98
# 4    ^GSPC    2020-05                2919.61
# ..     ...        ...                    ...
# 217  ^NSEI    2025-10               25481.77
# 218  ^NSEI    2025-11               25879.98
# 219  ^NSEI    2025-12               25997.74
# 220  ^NSEI    2026-01               25626.07
# 221  ^NSEI    2026-02               25530.65
#
# [222 rows x 3 columns]

# %% [markdown]
# ### Average trading volume of NSEI in 2024

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to get the average trading volume of NSEI in 2024
query = """
SELECT
    AVG(volume) AS average_volume
FROM
    stock_prices
WHERE
    ticker = '^NSEI' AND STRFTIME('%Y', date) = '2024';
"""

nsei_avg_volume_2024 = pd.read_sql_query(query, conn)

conn.close()

print("Average trading volume of NSEI in 2024:")
display(nsei_avg_volume_2024)
# Out:
# Average trading volume of NSEI in 2024:
#    average_volume
# 0       313371.15

# %% [markdown]
# ### Compare Bitcoin vs Oil average price in 2025

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query for Bitcoin's average price in 2025
query_bitcoin_avg = """
SELECT AVG(price_inr) AS average_bitcoin_price_2025
FROM historical_prices
WHERE coin_id = 'bitcoin' AND STRFTIME('%Y', date) = '2025';
"""
bitcoin_avg_price = pd.read_sql_query(query_bitcoin_avg, conn)

# Query for Oil's average price in 2025
query_oil_avg = """
SELECT AVG(price_usd) AS average_oil_price_2025
FROM oil_prices
WHERE STRFTIME('%Y', date) = '2025';
"""
oil_avg_price = pd.read_sql_query(query_oil_avg, conn)

conn.close()

print("Average prices for 2025:")
display(bitcoin_avg_price)
display(oil_avg_price)
# Out:
# Average prices for 2025:
#    average_bitcoin_price_2025
# 0                       87.23
#    average_oil_price_2025
# 0                   65.39

# %% [markdown]
# ## Calculate Bitcoin Average Price for 2025

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query for Bitcoin's average price in 2025
query_bitcoin_avg = """
SELECT AVG(price_inr) AS average_bitcoin_price_2025
FROM historical_prices
WHERE coin_id = 'bitcoin' AND STRFTIME('%Y', date) = '2025';
"""
bitcoin_avg_price = pd.read_sql_query(query_bitcoin_avg, conn)

# Query for Oil's average price in 2025
query_oil_avg = """
SELECT AVG(price_usd) AS average_oil_price_2025
FROM oil_prices
WHERE STRFTIME('%Y', date) = '2025';
"""
oil_avg_price = pd.read_sql_query(query_oil_avg, conn)

conn.close()

print("Average prices for 2025:")
display(bitcoin_avg_price)
display(oil_avg_price)
# Out:
# Average prices for 2025:
#    average_bitcoin_price_2025
# 0                       87.23
#    average_oil_price_2025
# 0                   65.39

# %%
combined_avg_prices = pd.concat([bitcoin_avg_price, oil_avg_price], axis=1)

# Rename columns for clarity
combined_avg_prices = combined_avg_prices.rename(columns={
    'average_bitcoin_price_2025': 'Bitcoin_Avg_Price_2025',
    'average_oil_price_2025': 'Oil_Avg_Price_2025'
})

# Convert to a tidy format if preferred for presentation, though not strictly required by the prompt.
# For direct comparison, the current wide format is also good.
# If a long format is desired:
# combined_avg_prices_long = combined_avg_prices.melt(var_name='Asset', value_name='Average Price (2025)')
# display(combined_avg_prices_long)

print("Comparison of Average Bitcoin and Oil Prices in 2025:")
display(combined_avg_prices)
# Out:
# Comparison of Average Bitcoin and Oil Prices in 2025:
#    Bitcoin_Avg_Price_2025  Oil_Avg_Price_2025
# 0                   87.23               65.39

# %% [markdown]
# Ethereum and NASDAQ Daily Prices for 2025

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

query_combined_prices = """
SELECT
    hp.date,
    hp.price_inr AS ethereum_price,
    sp.close AS nasdaq_close
FROM
    historical_prices AS hp
INNER JOIN
    stock_prices AS sp ON hp.date = sp.date
WHERE
    hp.coin_id = 'ethereum'
    AND sp.ticker = '^IXIC'
    AND STRFTIME('%Y', hp.date) = '2025'
ORDER BY
    hp.date ASC;
"""

combined_prices_2025 = pd.read_sql_query(query_combined_prices, conn)

conn.close()

print("Combined Ethereum and NASDAQ daily prices for 2025:")
display(combined_prices_2025)
# Out:
# Combined Ethereum and NASDAQ daily prices for 2025:
# Empty DataFrame
# Columns: [date, ethereum_price, nasdaq_close]
# Index: []

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')
cursor = conn.cursor()

# Drop the table if it already exists to ensure the schema is updated
cursor.execute('DROP TABLE IF EXISTS historical_prices;')

# Create the historical_prices table with the specified schema
cursor.execute('''
CREATE TABLE historical_prices (
    coin_id TEXT,
    date TEXT,
    price_inr REAL,
    PRIMARY KEY (coin_id, date),
    FOREIGN KEY (coin_id) REFERENCES cryptocurrency(id)
);
''')

# Prepare data for insertion
# Ensure all columns exist, fill missing with None for SQL insertion
columns_to_insert = ['coin_id', 'date', 'price_inr']

# Replace NaN with None for SQLite compatibility
records = df_historical_prices[columns_to_insert].where(pd.notnull(df_historical_prices[columns_to_insert]), None).values.tolist()

insert_query = '''
INSERT OR REPLACE INTO historical_prices (
    coin_id, date, price_inr
)
VALUES (?, ?, ?)
'''

cursor.executemany(insert_query, records)

conn.commit()
conn.close()
print("df_historical_prices successfully pushed to the 'historical_prices' table.")
# Out:
# df_historical_prices successfully pushed to the 'historical_prices' table.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

query_combined_prices = """
SELECT
    hp.date,
    hp.price_inr AS ethereum_price,
    sp.close AS nasdaq_close
FROM
    historical_prices AS hp
INNER JOIN
    stock_prices AS sp ON hp.date = sp.date
WHERE
    hp.coin_id = 'ethereum'
    AND sp.ticker = '^IXIC'
    AND STRFTIME('%Y', hp.date) = '2025'
ORDER BY
    hp.date ASC;
"""

combined_prices_2025 = pd.read_sql_query(query_combined_prices, conn)

conn.close()

print("Combined Ethereum and NASDAQ daily prices for 2025:")
display(combined_prices_2025)
# Out:
# Combined Ethereum and NASDAQ daily prices for 2025:
# Empty DataFrame
# Columns: [date, ethereum_price, nasdaq_close]
# Index: []

# %%
import pandas as pd

# Calculate descriptive statistics for both price series
ethereum_stats = combined_prices_2025['ethereum_price'].describe().to_frame(name='Ethereum Price (INR)')
nasdaq_stats = combined_prices_2025['nasdaq_close'].describe().to_frame(name='NASDAQ Close (USD)')

# Combine the descriptive statistics for display
price_stats = pd.concat([ethereum_stats, nasdaq_stats], axis=1)

# Calculate the Pearson correlation coefficient
correlation = combined_prices_2025['ethereum_price'].corr(combined_prices_2025['nasdaq_close'])

print("Descriptive Statistics for Ethereum Price and NASDAQ Close (2025):")
display(price_stats)

print(f"\nPearson Correlation between Ethereum Price and NASDAQ Close: {correlation:.4f}")
# Out:
# Descriptive Statistics for Ethereum Price and NASDAQ Close (2025):
#        Ethereum Price (INR) NASDAQ Close (USD)
# count                     0                  0
# unique                    0                  0
# top                     NaN                NaN
# freq                    NaN                NaN
# Pearson Correlation between Ethereum Price and NASDAQ Close: nan

# %% [markdown]
# ## Calculate Daily Oil Price Change

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query the oil_prices table
df_oil_prices = pd.read_sql_query("SELECT date, price_usd FROM oil_prices", conn)

# Convert 'date' column to datetime objects
df_oil_prices['date'] = pd.to_datetime(df_oil_prices['date'])

# Sort the DataFrame by date
df_oil_prices = df_oil_prices.sort_values(by='date').reset_index(drop=True)

conn.close()

print("Oil prices data loaded and sorted:")
display(df_oil_prices.head())
# Out:
# Oil prices data loaded and sorted:
#         date  price_usd
# 0 2020-01-02      61.17
# 1 2020-01-03      63.00
# 2 2020-01-06      63.27
# 3 2020-01-07      62.70
# 4 2020-01-08      59.65

# %%
df_oil_prices['daily_price_change'] = df_oil_prices['price_usd'].pct_change() * 100

print("Oil prices with daily percentage change:")
display(df_oil_prices.head())
# Out:
# Oil prices with daily percentage change:
#         date  price_usd  daily_price_change
# 0 2020-01-02      61.17                 NaN
# 1 2020-01-03      63.00                2.99
# 2 2020-01-06      63.27                0.43
# 3 2020-01-07      62.70               -0.90
# 4 2020-01-08      59.65               -4.86

# %% [markdown]
# ## Identify Oil Price Spikes

# %%
import numpy as np

# Calculate the 99th percentile of the absolute daily_price_change values
spike_threshold = df_oil_prices['daily_price_change'].abs().quantile(0.99)

# Filter df_oil_prices to select rows where the absolute daily_price_change is greater than or equal to spike_threshold
df_oil_spikes = df_oil_prices[df_oil_prices['daily_price_change'].abs() >= spike_threshold]

print(f"Calculated spike threshold (99th percentile of absolute daily change): {spike_threshold:.2f}%")
print(f"Total number of oil price spikes identified: {len(df_oil_spikes)}")
print("Identified oil price spikes (first 5 rows):")
display(df_oil_spikes.head())
# Out:
# Calculated spike threshold (99th percentile of absolute daily change): 12.51%
# Total number of oil price spikes identified: 16
# Identified oil price spikes (first 5 rows):
#          date  price_usd  daily_price_change
# 45 2020-03-09      31.05              -24.53
# 52 2020-03-18      20.48              -24.04
# 53 2020-03-19      25.09               22.51
# 54 2020-03-20      19.48              -22.36
# 55 2020-03-23      23.33               19.76

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Extract the 'date' column from df_oil_spikes and convert it to a list of date strings
oil_spike_dates = df_oil_spikes['date'].dt.strftime('%Y-%m-%d').tolist()

# Construct an SQL query to select Bitcoin's prices on these dates
# Using IN clause for the list of dates, correctly formatting the date strings
query = f"""
SELECT date, price_inr
FROM historical_prices
WHERE coin_id = 'bitcoin' AND date IN ({','.join([f"'{d}'" for d in oil_spike_dates])})
ORDER BY date ASC;
"""

df_bitcoin_spike_prices = pd.read_sql_query(query, conn)

conn.close()

print("Bitcoin prices on oil price spike days:")
display(df_bitcoin_spike_prices.head())
# Out:
# Bitcoin prices on oil price spike days:
# Empty DataFrame
# Columns: [date, price_inr]
# Index: []

# %% [markdown]
# ## Compare and Analyze Prices on Spike Days

# %%
import pandas as pd

# Ensure 'date' column in df_oil_spikes is datetime
df_oil_spikes['date'] = pd.to_datetime(df_oil_spikes['date'])

# Ensure 'date' column in df_bitcoin_spike_prices is datetime
df_bitcoin_spike_prices['date'] = pd.to_datetime(df_bitcoin_spike_prices['date'])

# Merge the two DataFrames on the 'date' column
df_combined_spike_data = pd.merge(df_oil_spikes, df_bitcoin_spike_prices, on='date', how='inner')

print("Combined oil price spikes and Bitcoin prices (first 5 rows):")
display(df_combined_spike_data.head())

print(f"Number of rows in df_combined_spike_data: {len(df_combined_spike_data)}")
# Out:
# Combined oil price spikes and Bitcoin prices (first 5 rows):
# /tmp/ipython-input-2776312890.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_oil_spikes['date'] = pd.to_datetime(df_oil_spikes['date'])
# Empty DataFrame
# Columns: [date, price_usd, daily_price_change, price_inr]
# Index: []
# Number of rows in df_combined_spike_data: 0

# %%
import sqlite3
import pandas as pd
import numpy as np

# Establish a connection to the database
conn = sqlite3.connect('mydatabase.db')

# --- RECALCULATE df_oil_prices and df_oil_spikes to ensure date overlap with Bitcoin data ---

# 1. Get all oil prices from the database and ensure datetime format
df_oil_prices = pd.read_sql_query("SELECT date, price_usd FROM oil_prices", conn)
df_oil_prices['date'] = pd.to_datetime(df_oil_prices['date'])
df_oil_prices = df_oil_prices.sort_values(by='date').reset_index(drop=True)

# 2. Get the date range for Bitcoin historical prices available in the database
# df_historical_prices is available in the kernel, so we can use it.
# Ensure 'date' column in df_historical_prices is treated as datetime for min/max comparison
df_historical_prices['date_dt'] = pd.to_datetime(df_historical_prices['date'])
min_bitcoin_date = df_historical_prices[df_historical_prices['coin_id'] == 'bitcoin']['date_dt'].min()
max_bitcoin_date = df_historical_prices[df_historical_prices['coin_id'] == 'bitcoin']['date_dt'].max()

# 3. Filter df_oil_prices to this common period
# Use .copy() to prevent SettingWithCopyWarning
df_oil_prices_filtered_to_bitcoin_range = df_oil_prices[
    (df_oil_prices['date'] >= min_bitcoin_date) &
    (df_oil_prices['date'] <= max_bitcoin_date)
].copy()

# 4. Recalculate daily_price_change for the relevant oil prices
df_oil_prices_filtered_to_bitcoin_range['daily_price_change'] = df_oil_prices_filtered_to_bitcoin_range['price_usd'].pct_change() * 100

# 5. Recalculate df_oil_spikes using the newly filtered data
# Handle cases where the filtered DataFrame might be too small for quantile
if not df_oil_prices_filtered_to_bitcoin_range.empty and len(df_oil_prices_filtered_to_bitcoin_range) > 1:
    spike_threshold = df_oil_prices_filtered_to_bitcoin_range['daily_price_change'].abs().quantile(0.99)
    df_oil_spikes = df_oil_prices_filtered_to_bitcoin_range[
        df_oil_prices_filtered_to_bitcoin_range['daily_price_change'].abs() >= spike_threshold
    ].copy()
else:
    df_oil_spikes = pd.DataFrame(columns=['date', 'price_usd', 'daily_price_change'])
    print("Not enough oil price data in the Bitcoin historical range to identify spikes.")


# --- ORIGINAL SUBTASK LOGIC STARTS HERE, now with correctly prepared df_oil_spikes ---

# Ensure 'date' column in df_oil_spikes is datetime (already handled above, but for clarity/safety)
df_oil_spikes['date'] = pd.to_datetime(df_oil_spikes['date'])

# Extract the 'date' column from df_oil_spikes and convert it to a list of date strings
oil_spike_dates = df_oil_spikes['date'].dt.strftime('%Y-%m-%d').tolist()

# Query Bitcoin prices for these spike dates
df_bitcoin_spike_prices = pd.DataFrame() # Initialize as empty
if oil_spike_dates: # Only query if there are spike dates
    query_bitcoin_spike_prices = f"""
    SELECT date, price_inr
    FROM historical_prices
    WHERE coin_id = 'bitcoin' AND date IN ({','.join([f"'{d}'" for d in oil_spike_dates])})
    ORDER BY date ASC;
    """
    df_bitcoin_spike_prices = pd.read_sql_query(query_bitcoin_spike_prices, conn)
    # Ensure 'date' column is datetime for merging
    df_bitcoin_spike_prices['date'] = pd.to_datetime(df_bitcoin_spike_prices['date'])

conn.close() # Close the connection after all queries

# Merge the two DataFrames on the 'date' column
# Only merge if both DataFrames have data
if not df_oil_spikes.empty and not df_bitcoin_spike_prices.empty:
    df_combined_spike_data = pd.merge(df_oil_spikes, df_bitcoin_spike_prices, on='date', how='inner')
else:
    df_combined_spike_data = pd.DataFrame(columns=['date', 'price_usd', 'daily_price_change', 'price_inr'])
    print("No valid oil spikes or corresponding Bitcoin prices found for merging.")


print("Combined oil price spikes and Bitcoin prices (first 5 rows):")
display(df_combined_spike_data.head())

print(f"Number of rows in df_combined_spike_data: {len(df_combined_spike_data)}")

# Optional: Add analysis as requested in the subtask
if not df_combined_spike_data.empty:
    print("\nAnalysis of Oil Price Spikes and Corresponding Bitcoin Prices:")
    display(df_combined_spike_data[['date', 'daily_price_change', 'price_inr']])
    # Calculate correlation if there's enough data
    if len(df_combined_spike_data) > 1:
        correlation_spikes = df_combined_spike_data['daily_price_change'].corr(df_combined_spike_data['price_inr'])
        print(f"\nCorrelation between Oil Daily Price Change and Bitcoin Price on spike days: {correlation_spikes:.4f}")
    else:
        print("\nNot enough data points to calculate correlation.")
# Out:
# Combined oil price spikes and Bitcoin prices (first 5 rows):
#         date  price_usd  daily_price_change  price_inr
# 0 2025-04-04      62.42               -7.43      85.25
# 1 2025-06-13      73.84                7.43      85.71
# 2 2025-06-23      69.36               -8.40      86.60
# Number of rows in df_combined_spike_data: 3
#
# Analysis of Oil Price Spikes and Corresponding Bitcoin Prices:
#         date  daily_price_change  price_inr
# 0 2025-04-04               -7.43      85.25
# 1 2025-06-13                7.43      85.71
# 2 2025-06-23               -8.40      86.60
# Correlation between Oil Daily Price Change and Bitcoin Price on spike days: -0.2291

# %% [markdown]
# ## Retrieve Top 3 Coin Daily Prices

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to get daily prices for Bitcoin, Ethereum, and Tether
query = """
SELECT date, coin_id, price_inr
FROM historical_prices
WHERE coin_id IN ('bitcoin', 'ethereum', 'tether')
ORDER BY date ASC;
"""

df_crypto_prices = pd.read_sql_query(query, conn)

# Convert 'date' column to datetime objects
df_crypto_prices['date'] = pd.to_datetime(df_crypto_prices['date'])

conn.close()

print("Daily prices for Bitcoin, Ethereum, and Tether:")
display(df_crypto_prices.head())
# Out:
# Daily prices for Bitcoin, Ethereum, and Tether:
#         date  coin_id  price_inr
# 0 2025-02-11  bitcoin      87.49
# 1 2025-02-12  bitcoin      86.77
# 2 2025-02-13  bitcoin      86.98
# 3 2025-02-14  bitcoin      86.75
# 4 2025-02-15  bitcoin      86.67

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to get daily closing prices for the Nifty index (^NSEI)
query = """
SELECT date, close
FROM stock_prices
WHERE ticker = '^NSEI'
ORDER BY date ASC;
"""

df_nifty_prices = pd.read_sql_query(query, conn)

# Convert 'date' column to datetime objects
df_nifty_prices['date'] = pd.to_datetime(df_nifty_prices['date'])

conn.close()

print("Daily closing prices for Nifty index (^NSEI):")
display(df_nifty_prices.head())
# Out:
# Daily closing prices for Nifty index (^NSEI):
#         date    close
# 0 2020-01-01 12182.50
# 1 2020-01-02 12282.20
# 2 2020-01-03 12226.65
# 3 2020-01-06 11993.05
# 4 2020-01-07 12052.95

# %%
import pandas as pd

# Pivot df_crypto_prices to have coin_id as columns
df_crypto_pivoted = df_crypto_prices.pivot_table(index='date', columns='coin_id', values='price_inr')

# Flatten the column names and rename them for clarity
df_crypto_pivoted.columns = [f'{col}_price' for col in df_crypto_pivoted.columns]

# Reset index to make 'date' a column again for merging
df_crypto_pivoted = df_crypto_pivoted.reset_index()

print("Pivoted cryptocurrency prices (first 5 rows):")
display(df_crypto_pivoted.head())
# Out:
# Pivoted cryptocurrency prices (first 5 rows):
#         date  bitcoin_price
# 0 2025-02-11          87.49
# 1 2025-02-12          86.77
# 2 2025-02-13          86.98
# 3 2025-02-14          86.75
# 4 2025-02-15          86.67

# %%
import pandas as pd

# Merge the pivoted cryptocurrency DataFrame with df_nifty_prices on 'date'
df_merged_prices = pd.merge(df_crypto_pivoted, df_nifty_prices, on='date', how='inner')

# Rename the 'close' column to 'nifty_close'
df_merged_prices = df_merged_prices.rename(columns={'close': 'nifty_close'})

print("Merged cryptocurrency and Nifty prices (first 5 rows):")
display(df_merged_prices.head())
# Out:
# Merged cryptocurrency and Nifty prices (first 5 rows):
#         date  bitcoin_price  nifty_close
# 0 2025-02-11          87.49     23071.80
# 1 2025-02-12          86.77     23045.25
# 2 2025-02-13          86.98     23031.40
# 3 2025-02-14          86.75     22929.25
# 4 2025-02-17          86.65     22959.50

# %%
import pandas as pd

# Calculate daily percentage change for each price series
if 'bitcoin_price' in df_merged_prices.columns:
    df_merged_prices['bitcoin_daily_change'] = df_merged_prices['bitcoin_price'].pct_change() * 100
else:
    print("Warning: 'bitcoin_price' column not found in df_merged_prices. Skipping daily change calculation for Bitcoin.")

if 'ethereum_price' in df_merged_prices.columns:
    df_merged_prices['ethereum_daily_change'] = df_merged_prices['ethereum_price'].pct_change() * 100
else:
    print("Warning: 'ethereum_price' column not found in df_merged_prices. Skipping daily change calculation for Ethereum.")

if 'tether_price' in df_merged_prices.columns:
    df_merged_prices['tether_daily_change'] = df_merged_prices['tether_price'].pct_change() * 100
else:
    print("Warning: 'tether_price' column not found in df_merged_prices. Skipping daily change calculation for Tether.")

df_merged_prices['nifty_daily_change'] = df_merged_prices['nifty_close'].pct_change() * 100

print("Merged prices with daily percentage changes")
display(df_merged_prices)
# Out:
# Warning: 'ethereum_price' column not found in df_merged_prices. Skipping daily change calculation for Ethereum.
# Warning: 'tether_price' column not found in df_merged_prices. Skipping daily change calculation for Tether.
# Merged prices with daily percentage changes
#           date  bitcoin_price  nifty_close  bitcoin_daily_change  \
# 0   2025-02-11          87.49     23071.80                   NaN
# 1   2025-02-12          86.77     23045.25                 -0.82
# 2   2025-02-13          86.98     23031.40                  0.24
# 3   2025-02-14          86.75     22929.25                 -0.27
# 4   2025-02-17          86.65     22959.50                 -0.11
# ..         ...            ...          ...                   ...
# 250 2026-01-29          91.91     25418.90                  0.54
# 251 2026-01-30          91.64     25320.65                 -0.29
# 252 2026-02-02          91.60     25088.40                 -0.04
# 253 2026-02-03          90.38     25727.55                 -1.34
# 254 2026-02-04          90.31     25776.00                 -0.08
#
#      nifty_daily_change
# 0                   NaN
# 1                 -0.12
# 2                 -0.06
# 3                 -0.44
# 4                  0.13
# ..                  ...
# 250                0.30
# 251               -0.39
# 252               -0.92
# 253                2.55
# 254                0.19
#
# [255 rows x 5 columns]

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to get daily oil prices
query = """
SELECT date, price_usd
FROM oil_prices
ORDER BY date ASC;
"""

df_oil_prices_gspc = pd.read_sql_query(query, conn)

# Convert 'date' column to datetime objects
df_oil_prices_gspc['date'] = pd.to_datetime(df_oil_prices_gspc['date'])

conn.close()

print("Daily crude oil prices:")
display(df_oil_prices_gspc.head())
# Out:
# Daily crude oil prices:
#         date  price_usd
# 0 2020-01-02      61.17
# 1 2020-01-03      63.00
# 2 2020-01-06      63.27
# 3 2020-01-07      62.70
# 4 2020-01-08      59.65

# %%
import pandas as pd

# Query to get daily closing prices for S&P 500 (^GSPC)
import sqlite3
conn = sqlite3.connect('mydatabase.db')
query_gspc = """
SELECT date, close
FROM stock_prices
WHERE ticker = '^GSPC'
ORDER BY date ASC;
"""
df_gspc_prices = pd.read_sql_query(query_gspc, conn)
df_gspc_prices['date'] = pd.to_datetime(df_gspc_prices['date'])
conn.close()

# Merge the GSPC prices DataFrame with the oil prices DataFrame on the 'date' column
df_combined_gspc_oil = pd.merge(df_gspc_prices, df_oil_prices_gspc, on='date', how='inner')

# Rename the 'close' column to 'gspc_close' for clarity
df_combined_gspc_oil = df_combined_gspc_oil.rename(columns={'close': 'gspc_close'})

print("Combined GSPC stock prices and crude oil prices (first 5 rows):")
display(df_combined_gspc_oil)
# Out:
# Combined GSPC stock prices and crude oil prices (first 5 rows):
#            date  gspc_close  price_usd
# 0    2020-01-02     3257.85      61.17
# 1    2020-01-03     3234.85      63.00
# 2    2020-01-06     3246.28      63.27
# 3    2020-01-07     3237.18      62.70
# 4    2020-01-08     3253.05      59.65
# ...         ...         ...        ...
# 1516 2026-01-27     6978.60      62.04
# 1517 2026-01-28     6978.03      62.75
# 1518 2026-01-29     6969.01      64.77
# 1519 2026-01-30     6939.03      64.50
# 1520 2026-02-02     6976.44      61.60
#
# [1521 rows x 3 columns]

# %%
import pandas as pd

# Calculate daily percentage change for GSPC closing prices
df_combined_gspc_oil['gspc_daily_change'] = df_combined_gspc_oil['gspc_close'].pct_change() * 100

# Calculate daily percentage change for crude oil prices
df_combined_gspc_oil['oil_daily_change'] = df_combined_gspc_oil['price_usd'].pct_change() * 100

print("Combined GSPC and oil prices with daily percentage changes (first 5 rows):")
display(df_combined_gspc_oil)
# Out:
# Combined GSPC and oil prices with daily percentage changes (first 5 rows):
#            date  gspc_close  price_usd  gspc_daily_change  oil_daily_change
# 0    2020-01-02     3257.85      61.17                NaN               NaN
# 1    2020-01-03     3234.85      63.00              -0.71              2.99
# 2    2020-01-06     3246.28      63.27               0.35              0.43
# 3    2020-01-07     3237.18      62.70              -0.28             -0.90
# 4    2020-01-08     3253.05      59.65               0.49             -4.86
# ...         ...         ...        ...                ...               ...
# 1516 2026-01-27     6978.60      62.04               0.41              2.61
# 1517 2026-01-28     6978.03      62.75              -0.01              1.14
# 1518 2026-01-29     6969.01      64.77              -0.13              3.22
# 1519 2026-01-30     6939.03      64.50              -0.43             -0.42
# 1520 2026-02-02     6976.44      61.60               0.54             -4.50
#
# [1521 rows x 5 columns]

# %% [markdown]
# Correlate Bitcoin closing price with crude oil closing price (same date)

# %%
import pandas as pd

# 1. Create df_bitcoin_prices
df_bitcoin_prices = df_historical_prices[df_historical_prices['coin_id'] == 'bitcoin'][['date_dt', 'price_inr']].copy()
df_bitcoin_prices = df_bitcoin_prices.rename(columns={'date_dt': 'date'})
df_bitcoin_prices['date'] = pd.to_datetime(df_bitcoin_prices['date']).dt.normalize() # Normalize date

# 2. Create df_crude_oil_prices
df_crude_oil_prices = df_oil_prices[['date', 'price_usd']].copy()
df_crude_oil_prices['date'] = pd.to_datetime(df_crude_oil_prices['date']).dt.normalize() # Normalize date

# 3. Display the first few rows of both DataFrames
print("Bitcoin prices (first 5 rows):")
display(df_bitcoin_prices.head())

print("\nCrude oil prices (first 5 rows):")
display(df_crude_oil_prices.head())
# Out:
# Bitcoin prices (first 5 rows):
#         date  price_inr
# 0 2025-02-11      87.49
# 1 2025-02-12      86.77
# 2 2025-02-13      86.98
# 3 2025-02-14      86.75
# 4 2025-02-15      86.67
# Crude oil prices (first 5 rows):
#         date  price_usd
# 0 2020-01-02      61.17
# 1 2020-01-03      63.00
# 2 2020-01-06      63.27
# 3 2020-01-07      62.70
# 4 2020-01-08      59.65

# %%
import pandas as pd

# Merge the two DataFrames on the 'date' column
df_combined_btc_oil = pd.merge(df_bitcoin_prices, df_crude_oil_prices, on='date', how='inner')

# Calculate the Pearson correlation coefficient between Bitcoin price and crude oil price
correlation = df_combined_btc_oil['price_inr'].corr(df_combined_btc_oil['price_usd'])

print("Combined Bitcoin and Crude Oil Prices (first 5 rows):")
display(df_combined_btc_oil.head())

print(f"\nPearson Correlation between Bitcoin Price and Crude Oil Price: {correlation:.4f}")
# Out:
# Combined Bitcoin and Crude Oil Prices (first 5 rows):
#         date  price_inr  price_usd
# 0 2025-02-11      87.49      73.67
# 1 2025-02-12      86.77      71.72
# 2 2025-02-13      86.98      71.66
# 3 2025-02-14      86.75      71.05
# 4 2025-02-18      86.85      72.21
# Pearson Correlation between Bitcoin Price and Crude Oil Price: -0.5417

# %% [markdown]
# Comparision on NASDAQ (^IXIC) with Ethereum price trends

# %%
import pandas as pd

# 1. Filter df_historical_prices for Ethereum and select relevant columns
df_ethereum_prices = df_historical_prices[df_historical_prices['coin_id'] == 'ethereum'][['date_dt', 'price_inr']].copy()
# 2. Rename the 'date_dt' column to 'date'
df_ethereum_prices = df_ethereum_prices.rename(columns={'date_dt': 'date'})

# 3. Filter df_stocks for NASDAQ (^IXIC) and select relevant columns
df_nasdaq_prices = df_stocks[df_stocks['Ticker'] == '^IXIC'][['Date', 'Price_Close']].copy()
# 4. Rename 'Date' to 'date' and 'Price_Close' to 'nasdaq_close'
df_nasdaq_prices = df_nasdaq_prices.rename(columns={'Date': 'date', 'Price_Close': 'nasdaq_close'})

# Ensure 'date' columns are datetime objects for proper merging later
df_ethereum_prices['date'] = pd.to_datetime(df_ethereum_prices['date'])
df_nasdaq_prices['date'] = pd.to_datetime(df_nasdaq_prices['date'])

print("Ethereum daily prices (first 5 rows):")
display(df_ethereum_prices.head())

print("\nNASDAQ daily closing prices (first 5 rows):")
display(df_nasdaq_prices.head())
# Out:
# Ethereum daily prices (first 5 rows):
# Empty DataFrame
# Columns: [date, price_inr]
# Index: []
# NASDAQ daily closing prices (first 5 rows):
#          date  nasdaq_close
# 2  2020-01-02       9092.19
# 5  2020-01-03       9020.77
# 8  2020-01-06       9071.47
# 11 2020-01-07       9068.58
# 14 2020-01-08       9129.24

# %%
import pandas as pd

# Merge df_ethereum_prices and df_nasdaq_prices on the 'date' column
df_merged_eth_nasdaq = pd.merge(df_ethereum_prices, df_nasdaq_prices, on='date', how='inner')

print("Combined Ethereum and NASDAQ daily prices (first 5 rows):")
display(df_merged_eth_nasdaq.head())
# Out:
# Combined Ethereum and NASDAQ daily prices (first 5 rows):
# Empty DataFrame
# Columns: [date, price_inr, nasdaq_close]
# Index: []

# %%
import pandas as pd

# Calculate descriptive statistics for both price series
etherum_stats = df_merged_eth_nasdaq['price_inr'].describe().to_frame(name='Ethereum Price (INR)')
nasdaq_stats = df_merged_eth_nasdaq['nasdaq_close'].describe().to_frame(name='NASDAQ Close (USD)')

# Combine the descriptive statistics for display
price_stats = pd.concat([etherum_stats, nasdaq_stats], axis=1)

# Calculate the Pearson correlation coefficient
correlation = df_merged_eth_nasdaq['price_inr'].corr(df_merged_eth_nasdaq['nasdaq_close'])

print("Descriptive Statistics for Ethereum Price and NASDAQ Close:")
display(price_stats)

print(f"\nPearson Correlation between Ethereum Price and NASDAQ Close: {correlation:.4f}")
# Out:
# Descriptive Statistics for Ethereum Price and NASDAQ Close:
#        Ethereum Price (INR)  NASDAQ Close (USD)
# count                  0.00                0.00
# mean                    NaN                 NaN
# std                     NaN                 NaN
# min                     NaN                 NaN
# 25%                     NaN                 NaN
# 50%                     NaN                 NaN
# 75%                     NaN                 NaN
# max                     NaN                 NaN
# Pearson Correlation between Ethereum Price and NASDAQ Close: nan

# %% [markdown]
# The top 3 crypto coins with stock indices for 2025

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

query_combined = """
WITH crypto_prices_2025 AS (
    SELECT
        date,
        MAX(CASE WHEN coin_id = 'bitcoin' THEN price_inr ELSE NULL END) AS bitcoin_price,
        MAX(CASE WHEN coin_id = 'ethereum' THEN price_inr ELSE NULL END) AS ethereum_price,
        MAX(CASE WHEN coin_id = 'tether' THEN price_inr ELSE NULL END) AS tether_price
    FROM
        historical_prices
    WHERE
        STRFTIME('%Y', date) = '2025'
        AND coin_id IN ('bitcoin', 'ethereum', 'tether')
    GROUP BY
        date
),
stock_prices_2025 AS (
    SELECT
        date,
        MAX(CASE WHEN ticker = '^GSPC' THEN close ELSE NULL END) AS gspc_close,
        MAX(CASE WHEN ticker = '^IXIC' THEN close ELSE NULL END) AS ixic_close,
        MAX(CASE WHEN ticker = '^NSEI' THEN close ELSE NULL END) AS nsei_close
    FROM
        stock_prices
    WHERE
        STRFTIME('%Y', date) = '2025'
        AND ticker IN ('^GSPC', '^IXIC', '^NSEI')
    GROUP BY
        date
)
SELECT
    cp.date,
    cp.bitcoin_price,
    cp.ethereum_price,
    cp.tether_price,
    sp.gspc_close,
    sp.ixic_close,
    sp.nsei_close
FROM
    crypto_prices_2025 AS cp
LEFT JOIN
    stock_prices_2025 AS sp ON cp.date = sp.date
ORDER BY
    cp.date ASC;
"""

df_combined_crypto_stocks_2025 = pd.read_sql_query(query_combined, conn)

conn.close()

print("Combined daily prices for top 3 cryptocurrencies and stock indices for 2025:")
display(df_combined_crypto_stocks_2025.head())
print(f"DataFrame shape: {df_combined_crypto_stocks_2025.shape}")
# Out:
# Combined daily prices for top 3 cryptocurrencies and stock indices for 2025:
#          date  bitcoin_price ethereum_price tether_price  gspc_close  \
# 0  2025-02-11          87.49           None         None     6068.50
# 1  2025-02-12          86.77           None         None     6051.97
# 2  2025-02-13          86.98           None         None     6115.07
# 3  2025-02-14          86.75           None         None     6114.63
# 4  2025-02-15          86.67           None         None         NaN
#
#    ixic_close  nsei_close
# 0    19643.86    23071.80
# 1    19649.95    23045.25
# 2    19945.64    23031.40
# 3    20026.77    22929.25
# 4         NaN         NaN
# DataFrame shape: (324, 7)

# %% [markdown]
# stock prices, oil prices, and Bitcoin prices for daily comparison

# %%
import pandas as pd

# 1. Prepare df_bitcoin_prices
df_bitcoin_prices = df_historical_prices[df_historical_prices['coin_id'] == 'bitcoin'][['date_dt', 'price_inr']].copy()
df_bitcoin_prices = df_bitcoin_prices.rename(columns={'date_dt': 'date'})
# Ensure 'date' column is datetime (it was created from date_dt which is already datetime)
df_bitcoin_prices['date'] = pd.to_datetime(df_bitcoin_prices['date'])

# 2. Prepare df_crude_oil_prices
df_crude_oil_prices = df_oil_prices[['date', 'price_usd']].copy()
# Ensure 'date' column is datetime (it already is from previous steps)
df_crude_oil_prices['date'] = pd.to_datetime(df_crude_oil_prices['date'])

# 3. Prepare df_gspc_prices
df_gspc_prices = df_stocks[df_stocks['Ticker'] == '^GSPC'][['Date', 'Price_Close']].copy()
df_gspc_prices = df_gspc_prices.rename(columns={'Date': 'date', 'Price_Close': 'close'})
# Ensure 'date' column is datetime
df_gspc_prices['date'] = pd.to_datetime(df_gspc_prices['date'])

print("Bitcoin prices (first 5 rows):")
display(df_bitcoin_prices.head())

print("\nCrude oil prices (first 5 rows):")
display(df_crude_oil_prices.head())

print("\nS&P 500 (^GSPC) closing prices (first 5 rows):")
display(df_gspc_prices)
# Out:
# Bitcoin prices (first 5 rows):
#         date  price_inr
# 0 2025-02-11      87.49
# 1 2025-02-12      86.77
# 2 2025-02-13      86.98
# 3 2025-02-14      86.75
# 4 2025-02-15      86.67
# Crude oil prices (first 5 rows):
#         date  price_usd
# 0 2020-01-02      61.17
# 1 2020-01-03      63.00
# 2 2020-01-06      63.27
# 3 2020-01-07      62.70
# 4 2020-01-08      59.65
# S&P 500 (^GSPC) closing prices (first 5 rows):
#            date   close
# 1    2020-01-02 3257.85
# 4    2020-01-03 3234.85
# 7    2020-01-06 3246.28
# 10   2020-01-07 3237.18
# 13   2020-01-08 3253.05
# ...         ...     ...
# 4726 2026-01-29 6969.01
# 4729 2026-01-30 6939.03
# 4732 2026-02-02 6976.44
# 4735 2026-02-03 6917.81
# 4738 2026-02-04 6882.72
#
# [1580 rows x 2 columns]

# %%
import pandas as pd

# 1. Merge df_bitcoin_prices and df_crude_oil_prices
df_merged_btc_oil = pd.merge(df_bitcoin_prices, df_crude_oil_prices, on='date', how='inner')

# 2. Merge df_merged_btc_oil with df_gspc_prices
df_final_merged_data = pd.merge(df_merged_btc_oil, df_gspc_prices, on='date', how='inner')

# Rename columns for clarity
df_final_merged_data = df_final_merged_data.rename(columns={
    'price_inr': 'bitcoin_price_inr',
    'price_usd': 'oil_price_usd',
    'close': 'gspc_close'
})

# 3. Display the first 5 rows of df_final_merged_data
print("Final Merged DataFrame (Bitcoin, Oil, S&P 500 prices) head:")
display(df_final_merged_data)
# Out:
# Final Merged DataFrame (Bitcoin, Oil, S&P 500 prices) head:
#           date  bitcoin_price_inr  oil_price_usd  gspc_close
# 0   2025-02-11              87.49          73.67     6068.50
# 1   2025-02-12              86.77          71.72     6051.97
# 2   2025-02-13              86.98          71.66     6115.07
# 3   2025-02-14              86.75          71.05     6114.63
# 4   2025-02-18              86.85          72.21     6129.58
# ..         ...                ...            ...         ...
# 238 2026-01-27              91.62          62.04     6978.60
# 239 2026-01-28              91.42          62.75     6978.03
# 240 2026-01-29              91.91          64.77     6969.01
# 241 2026-01-30              91.64          64.50     6939.03
# 242 2026-02-02              91.60          61.60     6976.44
#
# [243 rows x 4 columns]

# %% [markdown]
# # Task
# Create a Streamlit application with three pages: "Filters & Data Exploration" to display average prices and a daily market snapshot of Bitcoin, Oil, S&P 500, and NIFTY based on a user-selected date range; "SQL Query Runner" to allow users to select and execute predefined SQL queries against the loaded data; and "Top Crypto Analysis" to visualize and present daily price trends and raw data for selected top cryptocurrencies within a specified period. Finally, expose this application publicly using Ngrok, and provide the generated Ngrok URL along with a summary of the application's features.

# %% [markdown]
# ## Install Streamlit and Pyngrok
#
# ### Subtask:
# Install the `streamlit` and `pyngrok` libraries which are essential for building and exposing the web application.

# %% [markdown]
# **Reasoning**:
# The subtask requires installing two libraries: `streamlit` and `pyngrok`. I will use `!pip install` commands within a code block to install these packages.

# %%
# !pip install streamlit pyngrok
# Out:
# Requirement already satisfied: streamlit in /usr/local/lib/python3.12/dist-packages (1.54.0)
# Requirement already satisfied: pyngrok in /usr/local/lib/python3.12/dist-packages (7.5.0)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (1.9.0)
# Requirement already satisfied: cachetools<7,>=5.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.2.6)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (26.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<13,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (11.3.0)
# Requirement already satisfied: pydeck<1,>=0.8.0b4 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.9.1)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.29.5)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (9.1.2)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.5.1)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from pyngrok) (6.0.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2026.1.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)

# %% [markdown]
# ## Create Streamlit App File
#
# ### Subtask:
# Generate a Python script named `app.py` that will house all the Streamlit application's code. This file will serve as the entry point for the web application.

# %% [markdown]
# **Reasoning**:
# To generate the `app.py` file as specified in the instructions, I will use the `%%writefile` magic command and include the necessary imports and the basic structure of the Streamlit application within the `app()` function.

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd

def app():
    st.set_page_config(layout="wide")
    st.title("Market Analysis Dashboard")

if __name__ == '__main__':
    app()
# Out:
# Overwriting app.py

# %% [markdown]
# **Reasoning**:
# The previous step created a basic `app.py` file. Now, I need to populate this file with the actual Streamlit application logic, including database connection, data loading functions, and the implementation of the three required pages: 'Filters & Data Exploration', 'SQL Query Runner', and 'Top Crypto Analysis'. This will replace the placeholder `app.py` content with the complete application structure.

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import sqlite3
import altair as alt
import datetime

# Database connection function
@st.cache_resource
def get_db_connection():
    conn = sqlite3.connect('mydatabase.db')
    return conn

# --- Data Loading Functions ---
@st.cache_data(ttl=600)
def load_cryptocurrency_data():
    conn = get_db_connection()
    df = pd.read_sql_query("SELECT * FROM cryptocurrency", conn)
    return df

@st.cache_data(ttl=600)
def load_historical_prices(coin_id=None, start_date=None, end_date=None):
    conn = get_db_connection()
    query = "SELECT coin_id, date, price_inr FROM historical_prices WHERE 1=1"
    params = []
    if coin_id:
        query += " AND coin_id = ?"
        params.append(coin_id)
    if start_date:
        query += " AND date >= ?"
        params.append(start_date)
    if end_date:
        query += " AND date <= ?"
        params.append(end_date)
    query += " ORDER BY date ASC"
    df = pd.read_sql_query(query, conn, params=params)
    df['date'] = pd.to_datetime(df['date'])
    return df

@st.cache_data(ttl=600)
def load_oil_prices(start_date=None, end_date=None):
    conn = get_db_connection()
    query = "SELECT date, price_usd FROM oil_prices WHERE 1=1"
    params = []
    if start_date:
        query += " AND date >= ?"
        params.append(start_date)
    if end_date:
        query += " AND date <= ?"
        params.append(end_date)
    query += " ORDER BY date ASC"
    df = pd.read_sql_query(query, conn, params=params)
    df['date'] = pd.to_datetime(df['date'])
    return df

@st.cache_data(ttl=600)
def load_stock_prices(ticker=None, start_date=None, end_date=None):
    conn = get_db_connection()
    query = "SELECT date, ticker, open, high, low, close, volume FROM stock_prices WHERE 1=1"
    params = []
    if ticker:
        query += " AND ticker = ?"
        params.append(ticker)
    if start_date:
        query += " AND date >= ?"
        params.append(start_date)
    if end_date:
        query += " AND date <= ?"
        params.append(end_date)
    query += " ORDER BY date ASC"
    df = pd.read_sql_query(query, conn, params=params)
    df['date'] = pd.to_datetime(df['date'])
    return df


# --- Page 1: Filters & Data Exploration ---
def filters_and_data_exploration_page():
    st.title("Filters & Data Exploration")

    st.header("Global Market Snapshot")

    # Date Range Selector
    col1, col2 = st.columns(2)
    with col1:
        default_start_date = datetime.date(2025, 1, 1)
        start_date = st.date_input("Start Date", value=default_start_date)
    with col2:
        default_end_date = datetime.date(2026, 2, 9)
        end_date = st.date_input("End Date", value=default_end_date)

    start_date_str = start_date.isoformat()
    end_date_str = end_date.isoformat()

    st.subheader("Average Prices within Selected Date Range")

    # Load and display average prices
    df_bitcoin = load_historical_prices(coin_id='bitcoin', start_date=start_date_str, end_date=end_date_str)
    df_oil = load_oil_prices(start_date=start_date_str, end_date=end_date_str)
    df_gspc = load_stock_prices(ticker='^GSPC', start_date=start_date_str, end_date=end_date_str)
    df_nsei = load_stock_prices(ticker='^NSEI', start_date=start_date_str, end_date=end_date_str)

    st.info(f"Bitcoin data shape: {df_bitcoin.shape}")
    st.info(f"Oil data shape: {df_oil.shape}")
    st.info(f"GSPC data shape: {df_gspc.shape}")
    st.info(f"NSEI data shape: {df_nsei.shape}")

    avg_bitcoin_price = df_bitcoin['price_inr'].mean() if not df_bitcoin.empty else 0
    avg_oil_price = df_oil['price_usd'].mean() if not df_oil.empty else 0
    avg_gspc_close = df_gspc['close'].mean() if not df_gspc.empty else 0
    avg_nsei_close = df_nsei['close'].mean() if not df_nsei.empty else 0

    st.info(f"Avg Bitcoin: {avg_bitcoin_price}")
    st.info(f"Avg Oil: {avg_oil_price}")
    st.info(f"Avg GSPC: {avg_gspc_close}")
    st.info(f"Avg NSEI: {avg_nsei_close}")

    avg_data = {
        'Asset': ['Bitcoin (INR)', 'Crude Oil (USD)', 'S&P 500 (^GSPC)', 'NIFTY 50 (^NSEI)']
    }

    if avg_bitcoin_price != 0:
        avg_data['Average Price'] = [f'{avg_bitcoin_price:,.2f}', f'{avg_oil_price:,.2f}', f'{avg_gspc_close:,.2f}', f'{avg_nsei_close:,.2f}']
    else:
        avg_data['Average Price'] = ['N/A', 'N/A', 'N/A', 'N/A']

    st.dataframe(pd.DataFrame(avg_data), hide_index=True)

    st.subheader("Daily Market Snapshot")

    # Prepare data for plotting
    # Bitcoin
    if not df_bitcoin.empty:
        df_bitcoin_plot = df_bitcoin[['date', 'price_inr']].copy()
        df_bitcoin_plot.columns = ['date', 'value']
        df_bitcoin_plot['asset'] = 'Bitcoin'

    # Crude Oil
    if not df_oil.empty:
        df_oil_plot = df_oil[['date', 'price_usd']].copy()
        df_oil_plot.columns = ['date', 'value']
        df_oil_plot['asset'] = 'Crude Oil'

    # S&P 500
    if not df_gspc.empty:
        df_gspc_plot = df_gspc[['date', 'close']].copy()
        df_gspc_plot.columns = ['date', 'value']
        df_gspc_plot['asset'] = 'S&P 500'

    # NIFTY 50
    if not df_nsei.empty:
        df_nsei_plot = df_nsei[['date', 'close']].copy()
        df_nsei_plot.columns = ['date', 'value']
        df_nsei_plot['asset'] = 'NIFTY 50'

    # Combine all plot dataframes for Altair
    all_plot_data = []
    if 'df_bitcoin_plot' in locals() and not df_bitcoin_plot.empty: all_plot_data.append(df_bitcoin_plot)
    if 'df_oil_plot' in locals() and not df_oil_plot.empty: all_plot_data.append(df_oil_plot)
    if 'df_gspc_plot' in locals() and not df_gspc_plot.empty: all_plot_data.append(df_gspc_plot)
    if 'df_nsei_plot' in locals() and not df_nsei_plot.empty: all_plot_data.append(df_nsei_plot)

    if all_plot_data:
        df_combined_plot = pd.concat(all_plot_data)

        # Create the interactive chart
        chart = alt.Chart(df_combined_plot).mark_line().encode(
            x=alt.X('date:T', axis=alt.Axis(title='Date')),
            y=alt.Y('value:Q', axis=alt.Axis(title='Price')),
            color='asset:N',
            tooltip=['date:T', 'asset:N', alt.Tooltip('value:Q', format='.2f')]
        ).properties(
            title='Daily Prices Over Time'
        ).interactive()

        st.altair_chart(chart, width='stretch')
    else:
        st.warning("No data available for the selected date range.")


# --- Page 2: SQL Query Runner ---
def sql_query_runner_page():
    st.title("SQL Query Runner")
    st.markdown("Execute predefined SQL queries against the database.")

    # Predefined queries
    predefined_queries = {
        "Top 3 Cryptocurrencies by Market Cap": "SELECT id, name, market_cap, market_cap_rank FROM cryptocurrency ORDER BY market_cap_rank ASC LIMIT 3;",
        "Coins with >90% Circulating Supply": "SELECT id, name, circulating_supply, total_supply FROM cryptocurrency WHERE (circulating_supply * 1.0 / total_supply) > 0.9 AND total_supply IS NOT NULL AND total_supply > 0;",
        "Coins within 10% of ATH": "SELECT id, name, current_price, ath FROM cryptocurrency WHERE current_price >= (ath * 0.9) AND ath IS NOT NULL;",
        "Average Market Cap Rank of High Volume Coins (>$1B)": "SELECT AVG(market_cap_rank) as average_market_cap_rank FROM cryptocurrency WHERE total_volume > 1000000000;",
        "Most Recently Updated Coin": "SELECT id, name, date FROM cryptocurrency ORDER BY date DESC LIMIT 1;",
        "Highest Bitcoin Price (Last Year)": "SELECT coin_id, date, price_inr FROM historical_prices WHERE coin_id = 'bitcoin' ORDER BY price_inr DESC LIMIT 1;",
        "Average Ethereum Price (Last Year)": "SELECT AVG(price_inr) as average_ethereum_price FROM historical_prices WHERE coin_id = 'ethereum';",
        "Daily Bitcoin Price (Feb 2025)": "SELECT date, price_inr FROM historical_prices WHERE coin_id = 'bitcoin' AND date BETWEEN '2025-02-01' AND '2025-02-28' ORDER BY date ASC;",
        "Coin with Highest Average Price (Last Year)": "SELECT coin_id, AVG(price_inr) AS average_price FROM historical_prices GROUP BY coin_id ORDER BY average_price DESC LIMIT 1;",
        "Bitcoin % Change (Sep 2025 - Jan 2026)": "SELECT ( (SELECT price_inr FROM historical_prices WHERE coin_id = 'bitcoin' AND date <= '2026-01-31' ORDER BY date DESC LIMIT 1) - (SELECT price_inr FROM historical_prices WHERE coin_id = 'bitcoin' AND date >= '2025-09-01' ORDER BY date ASC LIMIT 1) ) * 100.0 / (SELECT price_inr FROM historical_prices WHERE coin_id = 'bitcoin' AND date >= '2025-09-01' ORDER BY date ASC LIMIT 1) AS percentage_change;",
        "Highest Oil Price (Last 5 Years)": "SELECT date, price_usd FROM oil_prices WHERE date >= STRFTIME('%Y-%m-%d', DATE('now', '-5 years')) ORDER BY price_usd DESC LIMIT 1;",
        "Average Oil Price Per Year": "SELECT STRFTIME('%Y', date) AS year, AVG(price_usd) AS average_price_usd FROM oil_prices GROUP BY year ORDER BY year ASC;",
        "Oil Prices During COVID Crash (Mar-Apr 2020)": "SELECT date, price_usd FROM oil_prices WHERE date BETWEEN '2020-03-01' AND '2020-04-30' ORDER BY date ASC;",
        "Lowest Oil Price (Last 10 Years)": "SELECT date, price_usd FROM oil_prices WHERE date >= STRFTIME('%Y-%m-%d', DATE('now', '-10 years')) ORDER BY price_usd ASC LIMIT 1;",
        "Oil Price Volatility (Max-Min per Year)": "SELECT STRFTIME('%Y', date) AS year, MAX(price_usd) - MIN(price_usd) AS volatility_usd FROM oil_prices GROUP BY year ORDER BY year ASC;",
        "Highest NASDAQ Closing Price": "SELECT date, close FROM stock_prices WHERE ticker = '^IXIC' ORDER BY close DESC LIMIT 1;",
        "Top 5 S&P 500 Price Differences (High-Low)": "SELECT date, (high - low) AS price_difference FROM stock_prices WHERE ticker = '^GSPC' ORDER BY price_difference DESC LIMIT 5;",
        "Monthly Average Closing Price for Each Ticker": "SELECT ticker, STRFTIME('%Y-%m', date) AS year_month, AVG(close) AS average_closing_price FROM stock_prices GROUP BY ticker, year_month ORDER BY ticker, year_month ASC;",
        "Average NSEI Volume (2024)": "SELECT AVG(volume) AS average_volume FROM stock_prices WHERE ticker = '^NSEI' AND STRFTIME('%Y', date) = '2024';"
    }

    selected_query_name = st.selectbox("Select a predefined query:", list(predefined_queries.keys()))
    query = predefined_queries[selected_query_name]

    st.code(query, language='sql')

    if st.button("Run Query"):
        if query:
            try:
                conn = get_db_connection()
                result_df = pd.read_sql_query(query, conn)
                if not result_df.empty:
                    st.success("Query executed successfully!")
                    st.dataframe(result_df)
                else:
                    st.info("Query executed successfully, but returned no results.")
            except Exception as e:
                st.error(f"Error executing query: {e}")
        else:
            st.warning("Please select a query to run.")


# --- Page 3: Top Crypto Analysis ---
def top_crypto_analysis_page():
    st.title("Top Cryptocurrency Analysis")
    st.markdown("Visualize daily price trends and raw data for selected top cryptocurrencies.")

    df_crypto = load_cryptocurrency_data()
    top_3_coins = df_crypto.sort_values(by='market_cap_rank').head(3)
    top_3_coin_ids = top_3_coins['id'].tolist()
    top_3_coin_names = top_3_coins['name'].tolist()

    st.subheader("Select Cryptocurrencies to Analyze")
    selected_coins = st.multiselect(
        "Choose cryptocurrencies (up to 3)",
        options=df_crypto['name'].tolist(),
        default=top_3_coin_names,
        max_selections=3
    )

    if not selected_coins:
        st.warning("Please select at least one cryptocurrency.")
        return

    # Get corresponding IDs
    selected_coin_ids = df_crypto[df_crypto['name'].isin(selected_coins)]['id'].tolist()

    st.subheader("Date Range for Analysis")
    col1, col2 = st.columns(2)
    with col1:
        default_start_date = datetime.date(2025, 1, 1)
        start_date = st.date_input("Start Date", value=default_start_date, key='crypto_start_date')
    with col2:
        default_end_date = datetime.date(2026, 2, 9)
        end_date = st.date_input("End Date", value=default_end_date, key='crypto_end_date')

    start_date_str = start_date.isoformat()
    end_date_str = end_date.isoformat()

    all_historical_df = pd.DataFrame()
    for coin_id in selected_coin_ids:
        historical_df = load_historical_prices(coin_id, start_date=start_date_str, end_date=end_date_str)
        if not historical_df.empty:
            all_historical_df = pd.concat([all_historical_df, historical_df])

    if not all_historical_df.empty:
        st.subheader("Daily Price Trends")
        chart = alt.Chart(all_historical_df).mark_line().encode(
            x=alt.X('date:T', axis=alt.Axis(title='Date')),
            y=alt.Y('price_inr:Q', axis=alt.Axis(title='Price in INR')),
            color='coin_id:N',
            tooltip=['date:T', 'coin_id:N', alt.Tooltip('price_inr:Q', format='.2f')]
        ).properties(
            title='Daily Price Trend of Selected Cryptocurrencies'
        ).interactive()
        st.altair_chart(chart, width='stretch')

        st.subheader("Raw Historical Price Data")
        st.dataframe(all_historical_df)
    else:
        st.info("No historical data available for the selected cryptocurrencies in the given date range.")


# --- Main Streamlit App ---
def app():
    st.sidebar.title("Navigation")
    page = st.sidebar.radio(
        "Go to",
        ["Filters & Data Exploration", "SQL Query Runner", "Top Crypto Analysis"]
    )

    if page == "Filters & Data Exploration":
        filters_and_data_exploration_page()
    elif page == "SQL Query Runner":
        sql_query_runner_page()
    elif page == "Top Crypto Analysis":
        top_crypto_analysis_page()

if __name__ == '__main__':
    app()
# Out:
# Overwriting app.py

# %% [markdown]
# **Reasoning**:
# The Streamlit application `app.py` has been created. The next step is to run this application using Streamlit and then expose it publicly using Ngrok, as specified in the main task. I will start the Streamlit app in the background and then use `pyngrok` to create a public URL.

# %%
import subprocess
import time
from pyngrok import ngrok
import os
from google.colab import userdata

print("Attempting to kill any existing Streamlit processes...")
try:
    # Find process IDs listening on port 8501
    lsof_output = subprocess.check_output(['lsof', '-t', '-i:8501'], text=True)
    pids = lsof_output.strip().split('\n')
    for pid in pids:
        if pid:
            try:
                os.kill(int(pid), 9) # Kill with SIGKILL
                print(f"Killed process {pid} on port 8501.")
            except ProcessLookupError:
                print(f"Process {pid} not found.")
    time.sleep(2) # Give some time for processes to terminate
except subprocess.CalledProcessError:
    print("No processes found listening on port 8501.")
except Exception as e:
    print(f"Error while trying to kill processes: {e}")

# Start Streamlit in the background
print("Starting Streamlit app in background...")
# Redirecting output to streamlit.log
# Disabling CORS and XSRF protection for easier public access in a Colab environment
streamlit_command = [
    "streamlit", "run", "app.py",
    "--server.port", "8501",
    "--server.enableCORS", "false",
    "--server.enableXsrfProtection", "false"
]
# Use preexec_fn=os.setsid to create a new session, detaching the process from the current shell
# Redirect stdout and stderr to /dev/null to prevent hanging and clutter
process = subprocess.Popen(streamlit_command, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, preexec_fn=os.setsid)

time.sleep(5) # Give Streamlit some time to start

# Authenticate ngrok
print("Configuring ngrok authentication...")
NGROK_AUTH_TOKEN = userdata.get('NGROK_AUTH_TOKEN')
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# Open a ngrok tunnel to the Streamlit port
print("Opening ngrok tunnel...")
# Ensure any existing tunnels are disconnected before trying to create a new one
ngrok.kill()
tunnel = ngrok.connect(8501)
public_url = tunnel.public_url

print(f"Streamlit App is live at: {public_url}")
print("Please copy this URL and open it in your browser.")
print("If the app doesn't load correctly, try refreshing the Ngrok URL.")
# Out:
# Attempting to kill any existing Streamlit processes...
# Killed process 2819 on port 8501.
# Killed process 2862 on port 8501.
# Starting Streamlit app in background...
# Configuring ngrok authentication...
# Opening ngrok tunnel...
# Streamlit App is live at: https://concha-coreless-habitably.ngrok-free.dev
# Please copy this URL and open it in your browser.
# If the app doesn't load correctly, try refreshing the Ngrok URL.
