# %% [markdown]
# <a href="https://colab.research.google.com/github/sm700mohan-prog/Cross-market-analysis-by-sm/blob/main/crossmarket_analysis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install requests
# Out:
# Requirement already satisfied: requests in /usr/local/lib/python3.12/dist-packages (2.32.4)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests) (2026.1.4)

# %%
all_records = []
import requests
import time

base_url = "https://api.coingecko.com/api/v3/coins/markets?vs_currency=inr&per_page=250&order=market_cap_desc&sparkline=False&page="

for page_num in range(1, 6): # Loop for pages 1 to 5
    url = f"{base_url}{page_num}"
    response = requests.get(url)
    if response.status_code == 200:
        page_data = response.json()
        all_records.extend(page_data)
    else:
        print(f"Failed to fetch data for page {page_num}. Status code: {response.status_code}")
    time.sleep(10) # Increased delay to 10 seconds between requests to avoid rate limiting

cryptocurrency = all_records

print(f"Total records collected: {len(cryptocurrency)}")
print("First 3 records:")
display(cryptocurrency)
# Out:
# Failed to fetch data for page 4. Status code: 429
# Failed to fetch data for page 5. Status code: 429
# Total records collected: 750
# First 3 records:
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/1/large/bitcoin.png?1696501400',
#   'current_price': 6041232,
#   'market_cap': 120766082622498,
#   'market_cap_rank': 1,
#   'fully_diluted_valuation': 120766082622498,
#   'total_volume': 4147390140782,
#   'high_24h': 6327789,
#   'low_24h': 6025602,
#   'price_change_24h': -190685.68293167278,
#   'price_change_percentage_24h': -3.05982,
#   'market_cap_change_24h': -3833280743478.9844,
#   'market_cap_change_percentage_24h': -3.07649,
#   'circulating_supply': 19987525.0,
#   'total_supply': 19987525.0,
#   'max_supply': 21000000.0,
#   'ath': 11187013,
#   'ath_change_percentage': -45.99781,
#   'ath_date': '2025-10-06T18:57:42.558Z',
#   'atl': 3993.42,
#   'atl_change_percentage': 151179.68484,
#   'atl_date': '2013-07-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:41.494Z'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'image': 'https://coin-images.coingecko.com/coins/images/279/large/ethereum.png?1696501628',
#   'current_price': 176026,
#   'market_cap': 21248040341250,
#   'market_cap_rank': 2,
#   'fully_diluted_valuation': 21248040341250,
#   'total_volume': 1571438248607,
#   'high_24h': 184960,
#   'low_24h': 175377,
#   'price_change_24h': -5992.527159652149,
#   'price_change_percentage_24h': -3.29226,
#   'market_cap_change_24h': -748410466623.1172,
#   'market_cap_change_percentage_24h': -3.40241,
#   'circulating_supply': 120692569.8584684,
#   'total_supply': 120692569.8584684,
#   'max_supply': None,
#   'ath': 431946,
#   'ath_change_percentage': -59.24809,
#   'ath_date': '2025-08-24T19:21:03.333Z',
#   'atl': 28.13,
#   'atl_change_percentage': 625631.67911,
#   'atl_date': '2015-10-20T00:00:00.000Z',
#   'roi': {'times': 37.94706156222316,
#    'currency': 'btc',
#    'percentage': 3794.706156222316},
#   'last_updated': '2026-02-11T11:09:44.333Z'},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'image': 'https://coin-images.coingecko.com/coins/images/325/large/Tether.png?1696501661',
#   'current_price': 90.62,
#   'market_cap': 16711108679531,
#   'market_cap_rank': 3,
#   'fully_diluted_valuation': 17206561749681,
#   'total_volume': 6394472496241,
#   'high_24h': 90.71,
#   'low_24h': 90.41,
#   'price_change_24h': 0.124055,
#   'price_change_percentage_24h': 0.13708,
#   'market_cap_change_24h': 12570680222,
#   'market_cap_change_percentage_24h': 0.07528,
#   'circulating_supply': 184394018025.3612,
#   'total_supply': 189860955264.5262,
#   'max_supply': None,
#   'ath': 105.52,
#   'ath_change_percentage': -14.11146,
#   'ath_date': '2025-01-25T16:51:57.989Z',
#   'atl': 36.86,
#   'atl_change_percentage': 145.87493,
#   'atl_date': '2015-03-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.305Z'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'image': 'https://coin-images.coingecko.com/coins/images/44/large/xrp-symbol-white-128.png?1696501442',
#   'current_price': 123.61,
#   'market_cap': 7530697117919,
#   'market_cap_rank': 4,
#   'fully_diluted_valuation': 12360396662111,
#   'total_volume': 219790712184,
#   'high_24h': 129.08,
#   'low_24h': 123.04,
#   'price_change_24h': -4.310798985784302,
#   'price_change_percentage_24h': -3.36997,
#   'market_cap_change_24h': -266277094033.3672,
#   'market_cap_change_percentage_24h': -3.41513,
#   'circulating_supply': 60917315351.0,
#   'total_supply': 99985721048.0,
#   'max_supply': 100000000000.0,
#   'ath': 313.99,
#   'ath_change_percentage': -60.63305,
#   'ath_date': '2025-07-21T15:02:00.541Z',
#   'atl': 0.159343,
#   'atl_change_percentage': 77473.02443,
#   'atl_date': '2013-08-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.203Z'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'BNB',
#   'image': 'https://coin-images.coingecko.com/coins/images/825/large/bnb-icon2_2x.png?1696501970',
#   'current_price': 53462,
#   'market_cap': 7292089686813,
#   'market_cap_rank': 5,
#   'fully_diluted_valuation': 7292089686813,
#   'total_volume': 118219371188,
#   'high_24h': 56984,
#   'low_24h': 53277,
#   'price_change_24h': -3280.3013357454256,
#   'price_change_percentage_24h': -5.78109,
#   'market_cap_change_24h': -445305522788.9385,
#   'market_cap_change_percentage_24h': -5.75524,
#   'circulating_supply': 136359497.93,
#   'total_supply': 136359497.93,
#   'max_supply': 200000000.0,
#   'ath': 121422,
#   'ath_change_percentage': -55.97037,
#   'ath_date': '2025-10-13T08:41:24.131Z',
#   'atl': 2.58,
#   'atl_change_percentage': 2068258.85192,
#   'atl_date': '2017-10-19T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:41.252Z'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USDC',
#   'image': 'https://coin-images.coingecko.com/coins/images/6319/large/USDC.png?1769615602',
#   'current_price': 90.65,
#   'market_cap': 6642217525415,
#   'market_cap_rank': 6,
#   'fully_diluted_valuation': 6642934518280,
#   'total_volume': 1108238216485,
#   'high_24h': 90.74,
#   'low_24h': 90.47,
#   'price_change_24h': 0.112846,
#   'price_change_percentage_24h': 0.12463,
#   'market_cap_change_24h': 18211211509,
#   'market_cap_change_percentage_24h': 0.27493,
#   'circulating_supply': 73269292074.75745,
#   'total_supply': 73277201114.08936,
#   'max_supply': None,
#   'ath': 1327.87,
#   'ath_change_percentage': -93.17351,
#   'ath_date': '2025-01-23T04:45:51.184Z',
#   'atl': 65.31,
#   'atl_change_percentage': 38.79953,
#   'atl_date': '2021-05-19T13:14:05.611Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.301Z'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'image': 'https://coin-images.coingecko.com/coins/images/4128/large/solana.png?1718769756',
#   'current_price': 7330.6,
#   'market_cap': 4161712865370,
#   'market_cap_rank': 7,
#   'fully_diluted_valuation': 4545878267464,
#   'total_volume': 322209752189,
#   'high_24h': 7690.43,
#   'low_24h': 7300.56,
#   'price_change_24h': -291.3607828149725,
#   'price_change_percentage_24h': -3.82265,
#   'market_cap_change_24h': -164341105280.76074,
#   'market_cap_change_percentage_24h': -3.79887,
#   'circulating_supply': 567716500.5575353,
#   'total_supply': 620122095.2652178,
#   'max_supply': None,
#   'ath': 25396,
#   'ath_change_percentage': -71.13517,
#   'ath_date': '2025-01-19T11:15:27.957Z',
#   'atl': 38.03,
#   'atl_change_percentage': 19178.02741,
#   'atl_date': '2020-05-11T19:35:23.449Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:42.949Z'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'image': 'https://coin-images.coingecko.com/coins/images/1094/large/tron-logo.png?1696502193',
#   'current_price': 24.85,
#   'market_cap': 2353376546675,
#   'market_cap_rank': 8,
#   'fully_diluted_valuation': 2353377177180,
#   'total_volume': 47828831965,
#   'high_24h': 25.23,
#   'low_24h': 24.83,
#   'price_change_24h': -0.18041311898739565,
#   'price_change_percentage_24h': -0.7209,
#   'market_cap_change_24h': -17369880876.828125,
#   'market_cap_change_percentage_24h': -0.73268,
#   'circulating_supply': 94721477637.8709,
#   'total_supply': 94721503015.1996,
#   'max_supply': None,
#   'ath': 36.53,
#   'ath_change_percentage': -31.97747,
#   'ath_date': '2024-12-04T00:10:40.323Z',
#   'atl': 0.117589,
#   'atl_change_percentage': 21029.09088,
#   'atl_date': '2017-11-12T00:00:00.000Z',
#   'roi': {'times': 143.23140319500322,
#    'currency': 'usd',
#    'percentage': 14323.14031950032},
#   'last_updated': '2026-02-11T11:09:42.873Z'},
#  {'id': 'figure-heloc',
#   'symbol': 'figr_heloc',
#   'name': 'Figure Heloc',
#   'image': 'https://coin-images.coingecko.com/coins/images/68480/large/figure.png?1755863954',
#   'current_price': 93.43,
#   'market_cap': 1407485365287,
#   'market_cap_rank': 9,
#   'fully_diluted_valuation': 1407485365287,
#   'total_volume': 2600794743,
#   'high_24h': 93.86,
#   'low_24h': 93.38,
#   'price_change_24h': -0.20352355428610736,
#   'price_change_percentage_24h': -0.21737,
#   'market_cap_change_24h': 1180119476,
#   'market_cap_change_percentage_24h': 0.08392,
#   'circulating_supply': 15065146581.537,
#   'total_supply': 15065146581.537,
#   'max_supply': None,
#   'ath': 120.96,
#   'ath_change_percentage': -22.76455,
#   'ath_date': '2025-10-28T06:00:43.161Z',
#   'atl': 13.78,
#   'atl_change_percentage': 577.74788,
#   'atl_date': '2025-10-31T14:57:19.271Z',
#   'roi': None,
#   'last_updated': '2026-02-11T05:20:08.439Z'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/5/large/dogecoin.png?1696501409',
#   'current_price': 8.14,
#   'market_cap': 1373120408430,
#   'market_cap_rank': 10,
#   'fully_diluted_valuation': 1373329385307,
#   'total_volume': 77749413415,
#   'high_24h': 8.51,
#   'low_24h': 8.12,
#   'price_change_24h': -0.3000504138786102,
#   'price_change_percentage_24h': -3.5549,
#   'market_cap_change_24h': -50737430167.274414,
#   'market_cap_change_percentage_24h': -3.56338,
#   'circulating_supply': 168669383126.5791,
#   'total_supply': 168695053126.579,
#   'max_supply': None,
#   'ath': 53.62,
#   'ath_change_percentage': -84.81767,
#   'ath_date': '2021-05-08T05:08:23.458Z',
#   'atl': 0.00552883,
#   'atl_change_percentage': 147135.77673,
#   'atl_date': '2015-05-06T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:42.946Z'},
#  {'id': 'whitebit',
#   'symbol': 'wbt',
#   'name': 'WhiteBIT Coin',
#   'image': 'https://coin-images.coingecko.com/coins/images/27045/large/wbt_token.png?1696526096',
#   'current_price': 4557.84,
#   'market_cap': 974146510209,
#   'market_cap_rank': 11,
#   'fully_diluted_valuation': 1459556565870,
#   'total_volume': 5435225249,
#   'high_24h': 4750.45,
#   'low_24h': 4538.79,
#   'price_change_24h': -115.81446443279401,
#   'price_change_percentage_24h': -2.47803,
#   'market_cap_change_24h': -27441792346.767944,
#   'market_cap_change_percentage_24h': -2.73983,
#   'circulating_supply': 213729819.0,
#   'total_supply': 320229819.0,
#   'max_supply': 400000000.0,
#   'ath': 5758.63,
#   'ath_change_percentage': -21.18281,
#   'ath_date': '2025-12-10T20:16:13.582Z',
#   'atl': 245.71,
#   'atl_change_percentage': 1747.23269,
#   'atl_date': '2022-09-21T23:38:03.675Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:44.697Z'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'image': 'https://coin-images.coingecko.com/coins/images/780/large/bitcoin-cash-circle.png?1696501932',
#   'current_price': 46245,
#   'market_cap': 924603877162,
#   'market_cap_rank': 12,
#   'fully_diluted_valuation': 924604888791,
#   'total_volume': 29469401905,
#   'high_24h': 48021,
#   'low_24h': 46132,
#   'price_change_24h': -1397.4954957155278,
#   'price_change_percentage_24h': -2.93327,
#   'market_cap_change_24h': -27898220251.32837,
#   'market_cap_change_percentage_24h': -2.92894,
#   'circulating_supply': 19993209.27165078,
#   'total_supply': 19993231.14665078,
#   'max_supply': 21000000.0,
#   'ath': 242198,
#   'ath_change_percentage': -80.90592,
#   'ath_date': '2017-12-20T00:00:00.000Z',
#   'atl': 5536.54,
#   'atl_change_percentage': 735.27755,
#   'atl_date': '2018-12-16T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.031Z'},
#  {'id': 'usds',
#   'symbol': 'usds',
#   'name': 'USDS',
#   'image': 'https://coin-images.coingecko.com/coins/images/39926/large/usds.webp?1726666683',
#   'current_price': 90.66,
#   'market_cap': 868175253438,
#   'market_cap_rank': 13,
#   'fully_diluted_valuation': 868175253438,
#   'total_volume': 352790889,
#   'high_24h': 90.75,
#   'low_24h': 90.4,
#   'price_change_24h': 0.148017,
#   'price_change_percentage_24h': 0.16353,
#   'market_cap_change_24h': -981115317.7509766,
#   'market_cap_change_percentage_24h': -0.11288,
#   'circulating_supply': 9575179112.131311,
#   'total_supply': 9575179112.131311,
#   'max_supply': None,
#   'ath': 92.23,
#   'ath_change_percentage': -1.72607,
#   'ath_date': '2026-01-29T16:30:24.390Z',
#   'atl': 79.67,
#   'atl_change_percentage': 13.76617,
#   'atl_date': '2024-10-03T13:19:28.826Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:42.692Z'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'image': 'https://coin-images.coingecko.com/coins/images/975/large/cardano.png?1696502090',
#   'current_price': 23.0,
#   'market_cap': 846326769298,
#   'market_cap_rank': 14,
#   'fully_diluted_valuation': 1035070465259,
#   'total_volume': 29734264559,
#   'high_24h': 24.02,
#   'low_24h': 22.9,
#   'price_change_24h': -0.8609546934203856,
#   'price_change_percentage_24h': -3.60799,
#   'market_cap_change_24h': -31870620714.20581,
#   'market_cap_change_percentage_24h': -3.6291,
#   'circulating_supply': 36794311012.29324,
#   'total_supply': 45000000000.0,
#   'max_supply': 45000000000.0,
#   'ath': 225.26,
#   'ath_change_percentage': -89.78895,
#   'ath_date': '2021-09-02T06:00:10.474Z',
#   'atl': 1.38,
#   'atl_change_percentage': 1572.33989,
#   'atl_date': '2017-11-02T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.778Z'},
#  {'id': 'leo-token',
#   'symbol': 'leo',
#   'name': 'LEO Token',
#   'image': 'https://coin-images.coingecko.com/coins/images/8418/large/leo-token.png?1696508607',
#   'current_price': 754.55,
#   'market_cap': 695239828646,
#   'market_cap_rank': 15,
#   'fully_diluted_valuation': 743415174724,
#   'total_volume': 142730278,
#   'high_24h': 799.78,
#   'low_24h': 739.45,
#   'price_change_24h': -23.8846669764215,
#   'price_change_percentage_24h': -3.06828,
#   'market_cap_change_24h': -22248707927.414795,
#   'market_cap_change_percentage_24h': -3.10091,
#   'circulating_supply': 921393276.9,
#   'total_supply': 985239504.0,
#   'max_supply': None,
#   'ath': 888.26,
#   'ath_change_percentage': -15.04721,
#   'ath_date': '2025-12-01T06:16:28.002Z',
#   'atl': 56.97,
#   'atl_change_percentage': 1224.47301,
#   'atl_date': '2019-12-24T15:14:35.376Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:42.634Z'},
#  {'id': 'hyperliquid',
#   'symbol': 'hype',
#   'name': 'Hyperliquid',
#   'image': 'https://coin-images.coingecko.com/coins/images/50882/large/hyperliquid.jpg?1729431300',
#   'current_price': 2585.41,
#   'market_cap': 616739986042,
#   'market_cap_rank': 16,
#   'fully_diluted_valuation': 2489552969361,
#   'total_volume': 26117737356,
#   'high_24h': 2758.72,
#   'low_24h': 2579.9,
#   'price_change_24h': -101.36493902860366,
#   'price_change_percentage_24h': -3.77273,
#   'market_cap_change_24h': -23062240988.942383,
#   'market_cap_change_percentage_24h': -3.60459,
#   'circulating_supply': 238385315.9541414,
#   'total_supply': 962274028.9541414,
#   'max_supply': 1000000000.0,
#   'ath': 5213.52,
#   'ath_change_percentage': -50.40946,
#   'ath_date': '2025-09-18T03:30:30.650Z',
#   'atl': 321.88,
#   'atl_change_percentage': 703.22486,
#   'atl_date': '2024-11-29T09:30:30.871Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:42.681Z'},
#  {'id': 'ethena-usde',
#   'symbol': 'usde',
#   'name': 'Ethena USDe',
#   'image': 'https://coin-images.coingecko.com/coins/images/33613/large/usde.png?1733810059',
#   'current_price': 90.56,
#   'market_cap': 581978839456,
#   'market_cap_rank': 17,
#   'fully_diluted_valuation': 581978839456,
#   'total_volume': 8034341412,
#   'high_24h': 90.63,
#   'low_24h': 90.32,
#   'price_change_24h': 0.157369,
#   'price_change_percentage_24h': 0.17408,
#   'market_cap_change_24h': 315004793,
#   'market_cap_change_percentage_24h': 0.05416,
#   'circulating_supply': 6424043098.098995,
#   'total_supply': 6424043098.098995,
#   'max_supply': None,
#   'ath': 92.91,
#   'ath_change_percentage': -2.54613,
#   'ath_date': '2025-12-09T17:10:12.652Z',
#   'atl': 78.05,
#   'atl_change_percentage': 16.01941,
#   'atl_date': '2024-10-04T07:57:15.809Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:42.795Z'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'image': 'https://coin-images.coingecko.com/coins/images/69/large/monero_logo.png?1696501460',
#   'current_price': 31115,
#   'market_cap': 573770703296,
#   'market_cap_rank': 18,
#   'fully_diluted_valuation': 573770703296,
#   'total_volume': 9011688065,
#   'high_24h': 32343,
#   'low_24h': 29069,
#   'price_change_24h': 915.05,
#   'price_change_percentage_24h': 3.02998,
#   'market_cap_change_24h': 16915105809,
#   'market_cap_change_percentage_24h': 3.03761,
#   'circulating_supply': 18446744.07370955,
#   'total_supply': 18446744.07370955,
#   'max_supply': None,
#   'ath': 72026,
#   'ath_change_percentage': -56.80028,
#   'ath_date': '2026-01-14T19:34:07.049Z',
#   'atl': 13.57,
#   'atl_change_percentage': 229177.604,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:42.751Z'},
#  {'id': 'canton-network',
#   'symbol': 'cc',
#   'name': 'Canton',
#   'image': 'https://coin-images.coingecko.com/coins/images/70468/large/Canton-Ticker_%281%29.png?1762826299',
#   'current_price': 14.75,
#   'market_cap': 556250531838,
#   'market_cap_rank': 19,
#   'fully_diluted_valuation': 556248849090,
#   'total_volume': 1126169204,
#   'high_24h': 15.54,
#   'low_24h': 14.72,
#   'price_change_24h': -0.16929914167061888,
#   'price_change_percentage_24h': -1.13472,
#   'market_cap_change_24h': -7572454469.6427,
#   'market_cap_change_percentage_24h': -1.34306,
#   'circulating_supply': 37711955931.79735,
#   'total_supply': 37711841846.96147,
#   'max_supply': None,
#   'ath': 17.72,
#   'ath_change_percentage': -16.77692,
#   'ath_date': '2026-01-31T16:41:41.560Z',
#   'atl': 5.31,
#   'atl_change_percentage': 177.83431,
#   'atl_date': '2025-12-06T10:32:09.784Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:42.693Z'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'image': 'https://coin-images.coingecko.com/coins/images/877/large/Chainlink_Logo_500.png?1760023405',
#   'current_price': 746.57,
#   'market_cap': 528384894772,
#   'market_cap_rank': 20,
#   'fully_diluted_valuation': 746200984070,
#   'total_volume': 27238204632,
#   'high_24h': 782.46,
#   'low_24h': 744.08,
#   'price_change_24h': -26.116048530020066,
#   'price_change_percentage_24h': -3.37992,
#   'market_cap_change_24h': -19005465691.276123,
#   'market_cap_change_percentage_24h': -3.47201,
#   'circulating_supply': 708099970.4525867,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 3862.15,
#   'ath_change_percentage': -80.66966,
#   'ath_date': '2021-05-10T00:13:57.214Z',
#   'atl': 9.55,
#   'atl_change_percentage': 7720.1898,
#   'atl_date': '2017-11-29T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.188Z'},
#  {'id': 'usd1-wlfi',
#   'symbol': 'usd1',
#   'name': 'USD1',
#   'image': 'https://coin-images.coingecko.com/coins/images/54977/large/USD1_1000x1000_transparent.png?1749297002',
#   'current_price': 90.61,
#   'market_cap': 488447692120,
#   'market_cap_rank': 21,
#   'fully_diluted_valuation': 488447692120,
#   'total_volume': 158307896614,
#   'high_24h': 90.69,
#   'low_24h': 90.39,
#   'price_change_24h': 0.058758,
#   'price_change_percentage_24h': 0.06489,
#   'market_cap_change_24h': 1627304936,
#   'market_cap_change_percentage_24h': 0.33427,
#   'circulating_supply': 5389664312.189111,
#   'total_supply': 5389664312.189111,
#   'max_supply': None,
#   'ath': 92.17,
#   'ath_change_percentage': -1.67193,
#   'ath_date': '2026-01-28T15:56:38.616Z',
#   'atl': 83.75,
#   'atl_change_percentage': 8.21189,
#   'atl_date': '2025-05-02T03:46:49.689Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.185Z'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'image': 'https://coin-images.coingecko.com/coins/images/100/large/fmpFRHHQ_400x400.jpg?1735231350',
#   'current_price': 13.9,
#   'market_cap': 455062238935,
#   'market_cap_rank': 22,
#   'fully_diluted_valuation': 695268069350,
#   'total_volume': 9795574728,
#   'high_24h': 14.46,
#   'low_24h': 13.84,
#   'price_change_24h': -0.2500626675848725,
#   'price_change_percentage_24h': -1.7666,
#   'market_cap_change_24h': -8519803621.502869,
#   'market_cap_change_percentage_24h': -1.83782,
#   'circulating_supply': 32726837450.34228,
#   'total_supply': 50001786883.65895,
#   'max_supply': None,
#   'ath': 58.01,
#   'ath_change_percentage': -76.10969,
#   'ath_date': '2021-05-16T09:48:45.220Z',
#   'atl': 0.02966141,
#   'atl_change_percentage': 46620.92985,
#   'atl_date': '2015-03-05T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:42.900Z'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'image': 'https://coin-images.coingecko.com/coins/images/9956/large/Badge_Dai.png?1696509996',
#   'current_price': 90.64,
#   'market_cap': 379934915710,
#   'market_cap_rank': 23,
#   'fully_diluted_valuation': 379934915710,
#   'total_volume': 5183010314,
#   'high_24h': 90.72,
#   'low_24h': 90.44,
#   'price_change_24h': 0.170474,
#   'price_change_percentage_24h': 0.18842,
#   'market_cap_change_24h': 2328982551,
#   'market_cap_change_percentage_24h': 0.61678,
#   'circulating_supply': 4191460782.630203,
#   'total_supply': 4191460782.630203,
#   'max_supply': None,
#   'ath': 92.29,
#   'ath_change_percentage': -1.77273,
#   'ath_date': '2026-01-31T18:56:20.998Z',
#   'atl': 64.85,
#   'atl_change_percentage': 39.79151,
#   'atl_date': '2019-11-25T00:04:18.137Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.037Z'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/2/large/litecoin.png?1696501400',
#   'current_price': 4698.24,
#   'market_cap': 360979638147,
#   'market_cap_rank': 24,
#   'fully_diluted_valuation': 361005038721,
#   'total_volume': 24774625605,
#   'high_24h': 4868.44,
#   'low_24h': 4687.71,
#   'price_change_24h': -121.08393978717868,
#   'price_change_percentage_24h': -2.51247,
#   'market_cap_change_24h': -9250386709.10205,
#   'market_cap_change_percentage_24h': -2.49855,
#   'circulating_supply': 76830789.48347135,
#   'total_supply': 76836195.73347135,
#   'max_supply': 84000000.0,
#   'ath': 30082,
#   'ath_change_percentage': -84.41655,
#   'ath_date': '2021-05-10T03:13:07.904Z',
#   'atl': 72.12,
#   'atl_change_percentage': 6399.81334,
#   'atl_date': '2015-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:42.965Z'},
#  {'id': 'paypal-usd',
#   'symbol': 'pyusd',
#   'name': 'PayPal USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/31212/large/PYUSD_Token_Logo_2x.png?1765987788',
#   'current_price': 90.63,
#   'market_cap': 353271682845,
#   'market_cap_rank': 25,
#   'fully_diluted_valuation': 353271682856,
#   'total_volume': 32614916556,
#   'high_24h': 90.72,
#   'low_24h': 90.43,
#   'price_change_24h': 0.084078,
#   'price_change_percentage_24h': 0.09286,
#   'market_cap_change_24h': 3691987618,
#   'market_cap_change_percentage_24h': 1.05612,
#   'circulating_supply': 3898111593.792355,
#   'total_supply': 3898111593.920528,
#   'max_supply': None,
#   'ath': 92.2,
#   'ath_change_percentage': -1.68115,
#   'ath_date': '2026-01-28T19:05:21.799Z',
#   'atl': 80.95,
#   'atl_change_percentage': 11.97826,
#   'atl_date': '2023-08-25T16:10:42.670Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:42.783Z'},
#  {'id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'name': 'Hedera',
#   'image': 'https://coin-images.coingecko.com/coins/images/3688/large/hbar.png?1696504364',
#   'current_price': 8.0,
#   'market_cap': 344019426954,
#   'market_cap_rank': 26,
#   'fully_diluted_valuation': 399993393076,
#   'total_volume': 7412961282,
#   'high_24h': 8.29,
#   'low_24h': 7.97,
#   'price_change_24h': -0.16654244540905871,
#   'price_change_percentage_24h': -2.03919,
#   'market_cap_change_24h': -7186057620.86853,
#   'market_cap_change_percentage_24h': -2.04611,
#   'circulating_supply': 43003138665.46997,
#   'total_supply': 50000000000.0,
#   'max_supply': 50000000000.0,
#   'ath': 41.81,
#   'ath_change_percentage': -80.90899,
#   'ath_date': '2021-09-15T10:40:28.318Z',
#   'atl': 0.703644,
#   'atl_change_percentage': 1034.25724,
#   'atl_date': '2020-01-02T17:30:24.852Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.424Z'},
#  {'id': 'zcash',
#   'symbol': 'zec',
#   'name': 'Zcash',
#   'image': 'https://coin-images.coingecko.com/coins/images/486/large/circle-zcash-color.png?1696501740',
#   'current_price': 20249,
#   'market_cap': 334821510263,
#   'market_cap_rank': 27,
#   'fully_diluted_valuation': 334821510263,
#   'total_volume': 28559191787,
#   'high_24h': 21986,
#   'low_24h': 20292,
#   'price_change_24h': -1737.1697173873617,
#   'price_change_percentage_24h': -7.90135,
#   'market_cap_change_24h': -28272059029.07727,
#   'market_cap_change_percentage_24h': -7.78644,
#   'circulating_supply': 16511426.7280448,
#   'total_supply': 16511426.7280448,
#   'max_supply': 21000000.0,
#   'ath': 211171,
#   'ath_change_percentage': -90.41129,
#   'ath_date': '2016-10-29T00:00:00.000Z',
#   'atl': 1342.38,
#   'atl_change_percentage': 1408.40548,
#   'atl_date': '2024-07-05T04:22:29.321Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:42.980Z'},
#  {'id': 'avalanche-2',
#   'symbol': 'avax',
#   'name': 'Avalanche',
#   'image': 'https://coin-images.coingecko.com/coins/images/12559/large/Avalanche_Circle_RedWhite_Trans.png?1696512369',
#   'current_price': 774.26,
#   'market_cap': 334315558784,
#   'market_cap_rank': 28,
#   'fully_diluted_valuation': 358836541651,
#   'total_volume': 22829599025,
#   'high_24h': 805.42,
#   'low_24h': 770.77,
#   'price_change_24h': -24.33120384491974,
#   'price_change_percentage_24h': -3.04677,
#   'market_cap_change_24h': -10489231957.7547,
#   'market_cap_change_percentage_24h': -3.04208,
#   'circulating_supply': 431771961.1772119,
#   'total_supply': 463441061.1772119,
#   'max_supply': 720000000.0,
#   'ath': 10772.35,
#   'ath_change_percentage': -92.8362,
#   'ath_date': '2021-11-21T14:18:56.538Z',
#   'atl': 204.63,
#   'atl_change_percentage': 277.12559,
#   'atl_date': '2020-12-31T13:15:21.540Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.092Z'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'image': 'https://coin-images.coingecko.com/coins/images/11939/large/shiba.png?1696511800',
#   'current_price': 0.00052534,
#   'market_cap': 309552261426,
#   'market_cap_rank': 30,
#   'fully_diluted_valuation': 309687030179,
#   'total_volume': 12174446638,
#   'high_24h': 0.00054957,
#   'low_24h': 0.00052363,
#   'price_change_24h': -1.5775298762344e-05,
#   'price_change_percentage_24h': -2.91533,
#   'market_cap_change_24h': -9331533773.838257,
#   'market_cap_change_percentage_24h': -2.92631,
#   'circulating_supply': 589243881085228.2,
#   'total_supply': 589500418260677.5,
#   'max_supply': None,
#   'ath': 0.00645756,
#   'ath_change_percentage': -91.86472,
#   'ath_date': '2021-10-28T03:54:55.568Z',
#   'atl': 4.169e-09,
#   'atl_change_percentage': 12601023.03689,
#   'atl_date': '2020-11-28T11:26:25.838Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.529Z'},
#  {'id': 'sui',
#   'symbol': 'sui',
#   'name': 'Sui',
#   'image': 'https://coin-images.coingecko.com/coins/images/26375/large/sui-ocean-square.png?1727791290',
#   'current_price': 80.48,
#   'market_cap': 309478134867,
#   'market_cap_rank': 29,
#   'fully_diluted_valuation': 804639242416,
#   'total_volume': 41743441736,
#   'high_24h': 85.43,
#   'low_24h': 80.23,
#   'price_change_24h': -4.885541499539798,
#   'price_change_percentage_24h': -5.72335,
#   'market_cap_change_24h': -18634381933.782593,
#   'market_cap_change_percentage_24h': -5.67927,
#   'circulating_supply': 3846172527.429665,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 458.6,
#   'ath_change_percentage': -82.45169,
#   'ath_date': '2025-01-04T22:56:18.063Z',
#   'atl': 30.36,
#   'atl_change_percentage': 165.04075,
#   'atl_date': '2023-10-19T22:05:15.703Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.275Z'},
#  {'id': 'rain',
#   'symbol': 'rain',
#   'name': 'Rain',
#   'image': 'https://coin-images.coingecko.com/coins/images/69134/large/Rain_logo_1_.png?1762952191',
#   'current_price': 0.904729,
#   'market_cap': 307277610045,
#   'market_cap_rank': 31,
#   'fully_diluted_valuation': 1039673417563,
#   'total_volume': 3092528408,
#   'high_24h': 0.959154,
#   'low_24h': 0.87393,
#   'price_change_24h': -0.054425100024670825,
#   'price_change_percentage_24h': -5.67428,
#   'market_cap_change_24h': -18622162544.956604,
#   'market_cap_change_percentage_24h': -5.71408,
#   'circulating_supply': 339864219027.60913,
#   'total_supply': 1149930169180.052,
#   'max_supply': 1150000000000.0,
#   'ath': 0.989197,
#   'ath_change_percentage': -8.66724,
#   'ath_date': '2026-02-09T17:46:22.209Z',
#   'atl': 0.196087,
#   'atl_change_percentage': 360.74439,
#   'atl_date': '2025-09-14T08:56:57.416Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:42.826Z'},
#  {'id': 'the-open-network',
#   'symbol': 'ton',
#   'name': 'Toncoin',
#   'image': 'https://coin-images.coingecko.com/coins/images/17980/large/photo_2024-09-10_17.09.00.jpeg?1725963446',
#   'current_price': 117.62,
#   'market_cap': 287926049170,
#   'market_cap_rank': 32,
#   'fully_diluted_valuation': 606053014914,
#   'total_volume': 8677821794,
#   'high_24h': 122.58,
#   'low_24h': 117.16,
#   'price_change_24h': -4.960471303182885,
#   'price_change_percentage_24h': -4.04664,
#   'market_cap_change_24h': -12210923456.239319,
#   'market_cap_change_percentage_24h': -4.06845,
#   'circulating_supply': 2448493143.82322,
#   'total_supply': 5153811737.731104,
#   'max_supply': None,
#   'ath': 689.6,
#   'ath_change_percentage': -83.00764,
#   'ath_date': '2024-06-15T00:36:51.509Z',
#   'atl': 38.25,
#   'atl_change_percentage': 206.31583,
#   'atl_date': '2021-09-21T00:33:11.092Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.573Z'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Cronos',
#   'image': 'https://coin-images.coingecko.com/coins/images/7310/large/cro_token_logo.png?1696507599',
#   'current_price': 6.83,
#   'market_cap': 272373714935,
#   'market_cap_rank': 33,
#   'fully_diluted_valuation': 672402409782,
#   'total_volume': 1452937923,
#   'high_24h': 7.17,
#   'low_24h': 6.83,
#   'price_change_24h': -0.28174834494245626,
#   'price_change_percentage_24h': -3.95953,
#   'market_cap_change_24h': -10828424225.42163,
#   'market_cap_change_percentage_24h': -3.82357,
#   'circulating_supply': 39854177848.64204,
#   'total_supply': 98387046017.4802,
#   'max_supply': 100000000000.0,
#   'ath': 72.06,
#   'ath_change_percentage': -90.51309,
#   'ath_date': '2021-11-24T15:53:54.855Z',
#   'atl': 0.864137,
#   'atl_change_percentage': 691.12576,
#   'atl_date': '2019-02-08T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:45.299Z'},
#  {'id': 'world-liberty-financial',
#   'symbol': 'wlfi',
#   'name': 'World Liberty Financial',
#   'image': 'https://coin-images.coingecko.com/coins/images/50767/large/wlfi.png?1756438915',
#   'current_price': 9.09,
#   'market_cap': 247589731350,
#   'market_cap_rank': 34,
#   'fully_diluted_valuation': 908792856663,
#   'total_volume': 9009231553,
#   'high_24h': 9.91,
#   'low_24h': 9.03,
#   'price_change_24h': -0.6900401856102771,
#   'price_change_percentage_24h': -7.05451,
#   'market_cap_change_24h': -18409363193.960785,
#   'market_cap_change_percentage_24h': -6.92084,
#   'circulating_supply': 27243802538.151154,
#   'total_supply': 100000000000.0,
#   'max_supply': 100000000000.0,
#   'ath': 29.22,
#   'ath_change_percentage': -68.88568,
#   'ath_date': '2025-09-01T12:20:09.597Z',
#   'atl': 8.91,
#   'atl_change_percentage': 2.07915,
#   'atl_date': '2026-02-08T17:02:14.734Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:42.956Z'},
#  {'id': 'tether-gold',
#   'symbol': 'xaut',
#   'name': 'Tether Gold',
#   'image': 'https://coin-images.coingecko.com/coins/images/10481/large/Tether_Gold.png?1696510471',
#   'current_price': 459715,
#   'market_cap': 238916429862,
#   'market_cap_rank': 35,
#   'fully_diluted_valuation': 327584821215,
#   'total_volume': 33349626323,
#   'high_24h': 459925,
#   'low_24h': 451719,
#   'price_change_24h': 4646.53,
#   'price_change_percentage_24h': 1.02106,
#   'market_cap_change_24h': 2429650846,
#   'market_cap_change_percentage_24h': 1.02739,
#   'circulating_supply': 519825.641699,
#   'total_supply': 712747.089,
#   'max_supply': None,
#   'ath': 514631,
#   'ath_change_percentage': -10.67372,
#   'ath_date': '2026-01-29T06:25:57.628Z',
#   'atl': 108167,
#   'atl_change_percentage': 324.99332,
#   'atl_date': '2020-03-17T09:39:32.572Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.382Z'},
#  {'id': 'memecore',
#   'symbol': 'm',
#   'name': 'MemeCore',
#   'image': 'https://coin-images.coingecko.com/coins/images/53247/large/square-bg-transparent.png?1752637478',
#   'current_price': 127.6,
#   'market_cap': 221320653459,
#   'market_cap_rank': 36,
#   'fully_diluted_valuation': 680687278978,
#   'total_volume': 717819089,
#   'high_24h': 136.24,
#   'low_24h': 125.55,
#   'price_change_24h': -8.538253586468059,
#   'price_change_percentage_24h': -6.27167,
#   'market_cap_change_24h': -16024812118.21701,
#   'market_cap_change_percentage_24h': -6.75168,
#   'circulating_supply': 1734462867.741956,
#   'total_supply': 5334462877.634027,
#   'max_supply': 10000000000.0,
#   'ath': 260.79,
#   'ath_change_percentage': -51.05746,
#   'ath_date': '2025-09-18T07:27:06.144Z',
#   'atl': 4.05,
#   'atl_change_percentage': 3050.13927,
#   'atl_date': '2025-07-04T03:56:17.448Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.384Z'},
#  {'id': 'pax-gold',
#   'symbol': 'paxg',
#   'name': 'PAX Gold',
#   'image': 'https://coin-images.coingecko.com/coins/images/9519/large/paxgold.png?1696509604',
#   'current_price': 462158,
#   'market_cap': 212119722307,
#   'market_cap_rank': 37,
#   'fully_diluted_valuation': 212119722307,
#   'total_volume': 23341853420,
#   'high_24h': 462298,
#   'low_24h': 453845,
#   'price_change_24h': 4733.34,
#   'price_change_percentage_24h': 1.03478,
#   'market_cap_change_24h': 2230049477,
#   'market_cap_change_percentage_24h': 1.06249,
#   'circulating_supply': 459009.975,
#   'total_supply': 459009.975,
#   'max_supply': None,
#   'ath': 516779,
#   'ath_change_percentage': -10.557,
#   'ath_date': '2026-01-29T06:30:56.612Z',
#   'atl': 100361,
#   'atl_change_percentage': 360.55995,
#   'atl_date': '2019-10-26T15:58:49.353Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.513Z'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'image': 'https://coin-images.coingecko.com/coins/images/12171/large/polkadot.jpg?1766533446',
#   'current_price': 112.08,
#   'market_cap': 186528671616,
#   'market_cap_rank': 38,
#   'fully_diluted_valuation': 186528671616,
#   'total_volume': 8153389278,
#   'high_24h': 116.85,
#   'low_24h': 111.57,
#   'price_change_24h': -3.2071640729155604,
#   'price_change_percentage_24h': -2.78189,
#   'market_cap_change_24h': -5278405420.842621,
#   'market_cap_change_percentage_24h': -2.75193,
#   'circulating_supply': 1664267932.778928,
#   'total_supply': 1664267932.778928,
#   'max_supply': 2100000000.0,
#   'ath': 4095.22,
#   'ath_change_percentage': -97.27453,
#   'ath_date': '2021-11-04T14:10:09.301Z',
#   'atl': 103.91,
#   'atl_change_percentage': 7.41059,
#   'atl_date': '2026-02-06T00:25:45.413Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.414Z'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'image': 'https://coin-images.coingecko.com/coins/images/12504/large/uniswap-logo.png?1720676669',
#   'current_price': 294.23,
#   'market_cap': 186513494229,
#   'market_cap_rank': 39,
#   'fully_diluted_valuation': 264477668177,
#   'total_volume': 10981115771,
#   'high_24h': 307.59,
#   'low_24h': 292.58,
#   'price_change_24h': -10.620576991738972,
#   'price_change_percentage_24h': -3.48391,
#   'market_cap_change_24h': -6758582366.689331,
#   'market_cap_change_percentage_24h': -3.49693,
#   'circulating_supply': 633923278.1680214,
#   'total_supply': 898908420.0366304,
#   'max_supply': 1000000000.0,
#   'ath': 3333.06,
#   'ath_change_percentage': -91.21428,
#   'ath_date': '2021-05-03T05:25:04.822Z',
#   'atl': 75.81,
#   'atl_change_percentage': 286.28359,
#   'atl_date': '2020-09-17T01:20:38.214Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:45.128Z'},
#  {'id': 'mantle',
#   'symbol': 'mnt',
#   'name': 'Mantle',
#   'image': 'https://coin-images.coingecko.com/coins/images/30980/large/MNT_Token_Logo.png?1765516974',
#   'current_price': 54.88,
#   'market_cap': 178519056784,
#   'market_cap_rank': 40,
#   'fully_diluted_valuation': 341311301109,
#   'total_volume': 2790615298,
#   'high_24h': 57.94,
#   'low_24h': 54.82,
#   'price_change_24h': -2.9513463258605768,
#   'price_change_percentage_24h': -5.10344,
#   'market_cap_change_24h': -9751095373.297607,
#   'market_cap_change_percentage_24h': -5.17931,
#   'circulating_supply': 3252944055.63684,
#   'total_supply': 6219316794.89,
#   'max_supply': 6219316794.89,
#   'ath': 253.43,
#   'ath_change_percentage': -78.35839,
#   'ath_date': '2025-10-09T01:04:46.659Z',
#   'atl': 25.64,
#   'atl_change_percentage': 113.93168,
#   'atl_date': '2023-10-18T02:50:46.942Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.282Z'},
#  {'id': 'blackrock-usd-institutional-digital-liquidity-fund',
#   'symbol': 'buidl',
#   'name': 'BlackRock USD Institutional Digital Liquidity Fund',
#   'image': 'https://coin-images.coingecko.com/coins/images/36291/large/blackrock.png?1711013223',
#   'current_price': 90.65,
#   'market_cap': 166837820335,
#   'market_cap_rank': 41,
#   'fully_diluted_valuation': 166837820335,
#   'total_volume': None,
#   'high_24h': 90.74,
#   'low_24h': 90.48,
#   'price_change_24h': 0.080614,
#   'price_change_percentage_24h': 0.08901,
#   'market_cap_change_24h': 3587631627,
#   'market_cap_change_percentage_24h': 2.19763,
#   'circulating_supply': 1840412389.420449,
#   'total_supply': 1840412389.420449,
#   'max_supply': None,
#   'ath': 92.2,
#   'ath_change_percentage': -1.66131,
#   'ath_date': '2026-01-28T16:00:11.347Z',
#   'atl': 83.81,
#   'atl_change_percentage': 8.18555,
#   'atl_date': '2025-05-02T06:30:16.890Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:05:04.799Z'},
#  {'id': 'falcon-finance',
#   'symbol': 'usdf',
#   'name': 'Falcon USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/54558/large/ff_200_X_200.png?1740741076',
#   'current_price': 90.37,
#   'market_cap': 159148865140,
#   'market_cap_rank': 42,
#   'fully_diluted_valuation': 159148865140,
#   'total_volume': 55983554,
#   'high_24h': 90.48,
#   'low_24h': 90.11,
#   'price_change_24h': 0.106119,
#   'price_change_percentage_24h': 0.11756,
#   'market_cap_change_24h': 144656845,
#   'market_cap_change_percentage_24h': 0.09098,
#   'circulating_supply': 1760988714.68948,
#   'total_supply': 1760988714.68948,
#   'max_supply': None,
#   'ath': 92.45,
#   'ath_change_percentage': -2.30899,
#   'ath_date': '2025-05-08T21:25:42.071Z',
#   'atl': 80.47,
#   'atl_change_percentage': 12.23459,
#   'atl_date': '2025-05-13T17:40:35.908Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:42.759Z'},
#  {'id': 'aster-2',
#   'symbol': 'aster',
#   'name': 'Aster',
#   'image': 'https://coin-images.coingecko.com/coins/images/69040/large/_ASTER.png?1757326782',
#   'current_price': 59.17,
#   'market_cap': 145299450585,
#   'market_cap_rank': 44,
#   'fully_diluted_valuation': 463014105492,
#   'total_volume': 29808133164,
#   'high_24h': 60.38,
#   'low_24h': 56.95,
#   'price_change_24h': 2.22,
#   'price_change_percentage_24h': 3.89029,
#   'market_cap_change_24h': 5914635075,
#   'market_cap_change_percentage_24h': 4.24339,
#   'circulating_supply': 2454947754.91,
#   'total_supply': 7822985112.446448,
#   'max_supply': 8000000000.0,
#   'ath': 213.7,
#   'ath_change_percentage': -72.31369,
#   'ath_date': '2025-09-24T11:18:14.634Z',
#   'atl': 8.76,
#   'atl_change_percentage': 575.42941,
#   'atl_date': '2025-09-17T12:05:36.771Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.009Z'},
#  {'id': 'bitget-token',
#   'symbol': 'bgb',
#   'name': 'Bitget Token',
#   'image': 'https://coin-images.coingecko.com/coins/images/11610/large/Bitget_logo.png?1736925727',
#   'current_price': 206.91,
#   'market_cap': 144834436406,
#   'market_cap_rank': 43,
#   'fully_diluted_valuation': 189721120060,
#   'total_volume': 2741097830,
#   'high_24h': 230.23,
#   'low_24h': 207.84,
#   'price_change_24h': -23.28259555444808,
#   'price_change_percentage_24h': -10.11446,
#   'market_cap_change_24h': -16297631465.02887,
#   'market_cap_change_percentage_24h': -10.11446,
#   'circulating_supply': 699992035.9787906,
#   'total_supply': 916931610.9787906,
#   'max_supply': 2000000000.0,
#   'ath': 722.65,
#   'ath_change_percentage': -71.21366,
#   'ath_date': '2024-12-27T11:41:24.992Z',
#   'atl': 1.081,
#   'atl_change_percentage': 19141.59187,
#   'atl_date': '2020-06-25T04:17:05.895Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:44.834Z'},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'image': 'https://coin-images.coingecko.com/coins/images/12645/large/aave-token-round.png?1720472354',
#   'current_price': 9534.95,
#   'market_cap': 144752669060,
#   'market_cap_rank': 45,
#   'fully_diluted_valuation': 152468182232,
#   'total_volume': 18776172894,
#   'high_24h': 10003.62,
#   'low_24h': 9504.76,
#   'price_change_24h': -326.8857808037883,
#   'price_change_percentage_24h': -3.31465,
#   'market_cap_change_24h': -5004722795.220612,
#   'market_cap_change_percentage_24h': -3.34189,
#   'circulating_supply': 15190334.606571734,
#   'total_supply': 16000000.0,
#   'max_supply': 16000000.0,
#   'ath': 48387,
#   'ath_change_percentage': -80.35091,
#   'ath_date': '2021-05-18T21:19:59.514Z',
#   'atl': 1933.39,
#   'atl_change_percentage': 391.76164,
#   'atl_date': '2020-11-05T09:20:11.928Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.345Z'},
#  {'id': 'global-dollar',
#   'symbol': 'usdg',
#   'name': 'Global Dollar',
#   'image': 'https://coin-images.coingecko.com/coins/images/51281/large/GDN_USDG_Token_200x200.png?1730484111',
#   'current_price': 90.66,
#   'market_cap': 143231932480,
#   'market_cap_rank': 46,
#   'fully_diluted_valuation': 143231932480,
#   'total_volume': 2813365020,
#   'high_24h': 90.74,
#   'low_24h': 90.47,
#   'price_change_24h': 0.117546,
#   'price_change_percentage_24h': 0.12982,
#   'market_cap_change_24h': 163622769,
#   'market_cap_change_percentage_24h': 0.11437,
#   'circulating_supply': 1579822398.447444,
#   'total_supply': 1579822398.447444,
#   'max_supply': None,
#   'ath': 143.35,
#   'ath_change_percentage': -36.76589,
#   'ath_date': '2025-01-30T00:11:05.728Z',
#   'atl': 76.61,
#   'atl_change_percentage': 18.32065,
#   'atl_date': '2024-11-11T23:55:50.604Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.498Z'},
#  {'id': 'hashnote-usyc',
#   'symbol': 'usyc',
#   'name': 'Circle USYC',
#   'image': 'https://coin-images.coingecko.com/coins/images/51054/large/Hashnote_SDYC_200x200.png?1730370965',
#   'current_price': 101.11,
#   'market_cap': 143216750855,
#   'market_cap_rank': 47,
#   'fully_diluted_valuation': 143216750855,
#   'total_volume': 4044.32,
#   'high_24h': None,
#   'low_24h': None,
#   'price_change_24h': None,
#   'price_change_percentage_24h': None,
#   'market_cap_change_24h': None,
#   'market_cap_change_percentage_24h': None,
#   'circulating_supply': 1416473350.04677,
#   'total_supply': 1416473350.04677,
#   'max_supply': None,
#   'ath': 102.4,
#   'ath_change_percentage': -1.25715,
#   'ath_date': '2026-01-30T13:28:05.498Z',
#   'atl': 86.89,
#   'atl_change_percentage': 16.3626,
#   'atl_date': '2024-12-05T22:31:20.475Z',
#   'roi': None,
#   'last_updated': '2026-02-10T05:42:11.457Z'},
#  {'id': 'ripple-usd',
#   'symbol': 'rlusd',
#   'name': 'Ripple USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/39651/large/RLUSD_200x200_%281%29.png?1727376633',
#   'current_price': 90.65,
#   'market_cap': 137960445668,
#   'market_cap_rank': 48,
#   'fully_diluted_valuation': 137960445668,
#   'total_volume': 11882470875,
#   'high_24h': 90.74,
#   'low_24h': 90.48,
#   'price_change_24h': 0.061487,
#   'price_change_percentage_24h': 0.06788,
#   'market_cap_change_24h': 87761639,
#   'market_cap_change_percentage_24h': 0.06365,
#   'circulating_supply': 1521941230.127497,
#   'total_supply': 1521941230.127497,
#   'max_supply': None,
#   'ath': 92.15,
#   'ath_change_percentage': -1.62832,
#   'ath_date': '2026-01-28T19:15:21.035Z',
#   'atl': 81.72,
#   'atl_change_percentage': 10.93155,
#   'atl_date': '2024-12-18T04:40:40.880Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.139Z'},
#  {'id': 'htx-dao',
#   'symbol': 'htx',
#   'name': 'HTX DAO',
#   'image': 'https://coin-images.coingecko.com/coins/images/35491/large/Frame_1321318576.png?1708908626',
#   'current_price': 0.00015012,
#   'market_cap': 137587515910,
#   'market_cap_rank': 49,
#   'fully_diluted_valuation': 137587515910,
#   'total_volume': 830900198,
#   'high_24h': 0.00015189,
#   'low_24h': 0.00015006,
#   'price_change_24h': -4.72394737925e-07,
#   'price_change_percentage_24h': -0.31369,
#   'market_cap_change_24h': -457949137.8360901,
#   'market_cap_change_percentage_24h': -0.33174,
#   'circulating_supply': 916533066327098.8,
#   'total_supply': 916533066327098.8,
#   'max_supply': 999990000000000.0,
#   'ath': 0.00031771,
#   'ath_change_percentage': -52.75374,
#   'ath_date': '2024-12-04T00:16:20.770Z',
#   'atl': 6.739e-05,
#   'atl_change_percentage': 122.73052,
#   'atl_date': '2024-08-05T13:31:33.427Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:48.575Z'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'image': 'https://coin-images.coingecko.com/coins/images/4463/large/WeChat_Image_20220118095654.png?1696505053',
#   'current_price': 6541.02,
#   'market_cap': 137278182233,
#   'market_cap_rank': 50,
#   'fully_diluted_valuation': 137278182233,
#   'total_volume': 1659910758,
#   'high_24h': 6909.46,
#   'low_24h': 6526.03,
#   'price_change_24h': -255.55309053642395,
#   'price_change_percentage_24h': -3.76003,
#   'market_cap_change_24h': -5608300838.692886,
#   'market_cap_change_percentage_24h': -3.925,
#   'circulating_supply': 21000000.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 22313,
#   'ath_change_percentage': -70.74641,
#   'ath_date': '2025-08-22T01:56:37.898Z',
#   'atl': 40.86,
#   'atl_change_percentage': 15874.20667,
#   'atl_date': '2019-01-14T00:00:00.000Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.045Z'},
#  {'id': 'pepe',
#   'symbol': 'pepe',
#   'name': 'Pepe',
#   'image': 'https://coin-images.coingecko.com/coins/images/29850/large/pepe-token.jpeg?1696528776',
#   'current_price': 0.00032014,
#   'market_cap': 134679682929,
#   'market_cap_rank': 51,
#   'fully_diluted_valuation': 134679682929,
#   'total_volume': 24323400357,
#   'high_24h': 0.00033556,
#   'low_24h': 0.00031877,
#   'price_change_24h': -1.1588301433646e-05,
#   'price_change_percentage_24h': -3.49332,
#   'market_cap_change_24h': -4889449184.706604,
#   'market_cap_change_percentage_24h': -3.50325,
#   'circulating_supply': 420690000000000.0,
#   'total_supply': 420690000000000.0,
#   'max_supply': 420690000000000.0,
#   'ath': 0.00237833,
#   'ath_change_percentage': -86.53932,
#   'ath_date': '2024-12-09T16:30:35.828Z',
#   'atl': 4.52e-06,
#   'atl_change_percentage': 6982.17868,
#   'atl_date': '2023-04-18T02:14:41.591Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.037Z'},
#  {'id': 'sky',
#   'symbol': 'sky',
#   'name': 'Sky',
#   'image': 'https://coin-images.coingecko.com/coins/images/39925/large/sky.jpg?1724827980',
#   'current_price': 5.76,
#   'market_cap': 132500699854,
#   'market_cap_rank': 52,
#   'fully_diluted_valuation': 135085416387,
#   'total_volume': 1560779252,
#   'high_24h': 6.37,
#   'low_24h': 5.76,
#   'price_change_24h': -0.533952748757275,
#   'price_change_percentage_24h': -8.48925,
#   'market_cap_change_24h': -12336812537.651245,
#   'market_cap_change_percentage_24h': -8.51769,
#   'circulating_supply': 23013731871.383068,
#   'total_supply': 23462665147.36596,
#   'max_supply': 23462665147.3,
#   'ath': 8.62,
#   'ath_change_percentage': -33.1218,
#   'ath_date': '2025-07-28T05:30:56.088Z',
#   'atl': 3.12,
#   'atl_change_percentage': 84.56021,
#   'atl_date': '2025-02-03T05:01:48.626Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:43.748Z'},
#  {'id': 'bittensor',
#   'symbol': 'tao',
#   'name': 'Bittensor',
#   'image': 'https://coin-images.coingecko.com/coins/images/28452/large/ARUsPeNQ_400x400.jpeg?1696527447',
#   'current_price': 13232.71,
#   'market_cap': 126988591888,
#   'market_cap_rank': 53,
#   'fully_diluted_valuation': 277860164666,
#   'total_volume': 6199710018,
#   'high_24h': 14335.15,
#   'low_24h': 13172.19,
#   'price_change_24h': -969.4528174855932,
#   'price_change_percentage_24h': -6.82609,
#   'market_cap_change_24h': -9372414507.777924,
#   'market_cap_change_percentage_24h': -6.87324,
#   'circulating_supply': 9597491.0,
#   'total_supply': 21000000.0,
#   'max_supply': 21000000.0,
#   'ath': 62722,
#   'ath_change_percentage': -78.96913,
#   'ath_date': '2024-12-06T12:15:28.199Z',
#   'atl': 2535.93,
#   'atl_change_percentage': 420.16432,
#   'atl_date': '2023-05-14T08:57:53.732Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:09:47.701Z'},
#  {'id': 'bfusd',
#   'symbol': 'bfusd',
#   'name': 'BFUSD',
#   'image': 'https://coin-images.coingecko.com/coins/images/68227/large/bfusd.png?1755132827',
#   'current_price': 90.61,
#   'market_cap': 119607795249,
# ...
#   'symbol': 'sats',
#   'name': 'SATS (Ordinals)',
#   'image': 'https://coin-images.coingecko.com/coins/images/30666/large/_dD8qr3M_400x400.png?1702913020',
#   'current_price': 9.95057e-07,
#   'market_cap': 2089369664,
#   'market_cap_rank': 733,
#   'fully_diluted_valuation': 2089369664,
#   'total_volume': 235626115,
#   'high_24h': 1.05e-06,
#   'low_24h': 9.90528e-07,
#   'price_change_24h': -4.2459988915e-08,
#   'price_change_percentage_24h': -4.09246,
#   'market_cap_change_24h': -88975314.70238185,
#   'market_cap_change_percentage_24h': -4.08454,
#   'circulating_supply': 2100000000000000.0,
#   'total_supply': 2100000000000000.0,
#   'max_supply': 2100000000000000.0,
#   'ath': 7.675e-05,
#   'ath_change_percentage': -98.70861,
#   'ath_date': '2023-12-26T00:45:04.378Z',
#   'atl': 2.63579e-07,
#   'atl_change_percentage': 276.02675,
#   'atl_date': '2023-07-08T13:03:18.882Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:10:07.659Z'},
#  {'id': 'dia-data',
#   'symbol': 'dia',
#   'name': 'DIA',
#   'image': 'https://coin-images.coingecko.com/coins/images/11955/large/Token_Logo.png?1696511815',
#   'current_price': 17.42,
#   'market_cap': 2083983498,
#   'market_cap_rank': 737,
#   'fully_diluted_valuation': 2939704312,
#   'total_volume': 196535571,
#   'high_24h': 18.28,
#   'low_24h': 17.15,
#   'price_change_24h': -0.5364808060702231,
#   'price_change_percentage_24h': -2.98841,
#   'market_cap_change_24h': -63814660.670353174,
#   'market_cap_change_percentage_24h': -2.97117,
#   'circulating_supply': 119676104.0,
#   'total_supply': 168817248.0,
#   'max_supply': 200000000.0,
#   'ath': 423.11,
#   'ath_change_percentage': -95.90022,
#   'ath_date': '2021-05-05T12:14:13.955Z',
#   'atl': 15.34,
#   'atl_change_percentage': 13.04981,
#   'atl_date': '2026-02-06T00:26:14.700Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:10:07.671Z'},
#  {'id': 'nockchain',
#   'symbol': 'nock',
#   'name': 'Nockchain',
#   'image': 'https://coin-images.coingecko.com/coins/images/68474/large/GrCcG9N9_400x400.jpg?1755845184',
#   'current_price': 1.076,
#   'market_cap': 2080812064,
#   'market_cap_rank': 734,
#   'fully_diluted_valuation': 4622294890,
#   'total_volume': 18625505,
#   'high_24h': 1.082,
#   'low_24h': 1.03,
#   'price_change_24h': 0.02057981,
#   'price_change_percentage_24h': 1.94931,
#   'market_cap_change_24h': 39320347,
#   'market_cap_change_percentage_24h': 1.92606,
#   'circulating_supply': 1933459456.0,
#   'total_supply': 4294967296.0,
#   'max_supply': 4294967296.0,
#   'ath': 18.5,
#   'ath_change_percentage': -94.18454,
#   'ath_date': '2025-10-17T15:40:33.597Z',
#   'atl': 0.617629,
#   'atl_change_percentage': 74.22634,
#   'atl_date': '2026-02-05T23:16:34.677Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:10:07.668Z'},
#  {'id': 'og-fan-token',
#   'symbol': 'og',
#   'name': 'OG Fan Token',
#   'image': 'https://coin-images.coingecko.com/coins/images/11663/large/OG_400px_%282%29.png?1769068991',
#   'current_price': 453.9,
#   'market_cap': 2080695242,
#   'market_cap_rank': 738,
#   'fully_diluted_valuation': 2269246478,
#   'total_volume': 3041689811,
#   'high_24h': 457.44,
#   'low_24h': 390.05,
#   'price_change_24h': 63.58,
#   'price_change_percentage_24h': 16.28804,
#   'market_cap_change_24h': 291877351,
#   'market_cap_change_percentage_24h': 16.31677,
#   'circulating_supply': 4584551.0,
#   'total_supply': 5000000.0,
#   'max_supply': 5000000.0,
#   'ath': 2181.6,
#   'ath_change_percentage': -79.28392,
#   'ath_date': '2025-09-10T22:17:25.303Z',
#   'atl': 91.71,
#   'atl_change_percentage': 392.77818,
#   'atl_date': '2022-05-12T06:17:01.402Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:10:07.658Z'},
#  {'id': 'ao-computer',
#   'symbol': 'ao',
#   'name': 'ao Computer',
#   'image': 'https://coin-images.coingecko.com/coins/images/38335/large/ao.png?1717120361',
#   'current_price': 345.48,
#   'market_cap': 2077853745,
#   'market_cap_rank': 735,
#   'fully_diluted_valuation': 2077853745,
#   'total_volume': 15340933,
#   'high_24h': 348.55,
#   'low_24h': 342.97,
#   'price_change_24h': 1.65,
#   'price_change_percentage_24h': 0.47999,
#   'market_cap_change_24h': 8041519,
#   'market_cap_change_percentage_24h': 0.38851,
#   'circulating_supply': 6015800.0,
#   'total_supply': 6015800.0,
#   'max_supply': 21000000.0,
#   'ath': 4281.57,
#   'ath_change_percentage': -91.93549,
#   'ath_date': '2025-04-07T04:32:48.977Z',
#   'atl': 303.95,
#   'atl_change_percentage': 13.60039,
#   'atl_date': '2026-02-06T21:46:40.182Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:10:07.601Z'},
#  {'id': 'pinksale',
#   'symbol': 'pinksale',
#   'name': 'PinkSale',
#   'image': 'https://coin-images.coingecko.com/coins/images/17377/large/4cC4Fgs.png?1696516927',
#   'current_price': 20740,
#   'market_cap': 2073962495,
#   'market_cap_rank': 736,
#   'fully_diluted_valuation': 2073962495,
#   'total_volume': 660.79,
#   'high_24h': None,
#   'low_24h': None,
#   'price_change_24h': None,
#   'price_change_percentage_24h': None,
#   'market_cap_change_24h': None,
#   'market_cap_change_percentage_24h': None,
#   'circulating_supply': 100000.0,
#   'total_supply': 100000.0,
#   'max_supply': 100000.0,
#   'ath': 44812,
#   'ath_change_percentage': -53.71816,
#   'ath_date': '2025-10-13T08:47:05.389Z',
#   'atl': 3523.92,
#   'atl_change_percentage': 488.53767,
#   'atl_date': '2021-08-27T01:01:33.665Z',
#   'roi': None,
#   'last_updated': '2026-02-10T09:33:52.786Z'},
#  {'id': 'chromaway',
#   'symbol': 'chr',
#   'name': 'Chromia',
#   'image': 'https://coin-images.coingecko.com/coins/images/5000/large/Chromia.png?1696505533',
#   'current_price': 2.43,
#   'market_cap': 2076280195,
#   'market_cap_rank': 742,
#   'fully_diluted_valuation': 2076280195,
#   'total_volume': 203943526,
#   'high_24h': 2.48,
#   'low_24h': 2.41,
#   'price_change_24h': -0.011616376702638487,
#   'price_change_percentage_24h': -0.47502,
#   'market_cap_change_24h': -7410188.658062458,
#   'market_cap_change_percentage_24h': -0.35563,
#   'circulating_supply': 853631914.378197,
#   'total_supply': 853631914.378197,
#   'max_supply': 978064789.0,
#   'ath': 110.77,
#   'ath_change_percentage': -97.81779,
#   'ath_date': '2021-11-20T09:59:59.379Z',
#   'atl': 0.659872,
#   'atl_change_percentage': 266.30346,
#   'atl_date': '2020-03-13T02:25:03.256Z',
#   'roi': {'times': -0.463169196606179,
#    'currency': 'usd',
#    'percentage': -46.3169196606179},
#   'last_updated': '2026-02-11T11:10:07.638Z'},
#  {'id': 'limitless-3',
#   'symbol': 'lmts',
#   'name': 'Limitless',
#   'image': 'https://coin-images.coingecko.com/coins/images/69506/large/limitless.png?1758786338',
#   'current_price': 15.72,
#   'market_cap': 2068240501,
#   'market_cap_rank': 740,
#   'fully_diluted_valuation': 15716270867,
#   'total_volume': 177230308,
#   'high_24h': 15.75,
#   'low_24h': 15.37,
#   'price_change_24h': 0.210289,
#   'price_change_percentage_24h': 1.35585,
#   'market_cap_change_24h': 28302144,
#   'market_cap_change_percentage_24h': 1.3874,
#   'circulating_supply': 131598680.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 60.89,
#   'ath_change_percentage': -74.18876,
#   'ath_date': '2025-10-22T13:04:10.225Z',
#   'atl': 4.4,
#   'atl_change_percentage': 257.14115,
#   'atl_date': '2026-01-28T23:06:22.875Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:10:07.676Z'},
#  {'id': 'aevo-exchange',
#   'symbol': 'aevo',
#   'name': 'Aevo',
#   'image': 'https://coin-images.coingecko.com/coins/images/35893/large/aevo.png?1710138340',
#   'current_price': 2.26,
#   'market_cap': 2066514660,
#   'market_cap_rank': 741,
#   'fully_diluted_valuation': 2255620512,
#   'total_volume': 552608826,
#   'high_24h': 2.47,
#   'low_24h': 2.25,
#   'price_change_24h': -0.19232766076418883,
#   'price_change_percentage_24h': -7.84478,
#   'market_cap_change_24h': -175323423.02062035,
#   'market_cap_change_percentage_24h': -7.82052,
#   'circulating_supply': 916162381.6383989,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 313.13,
#   'ath_change_percentage': -99.28051,
#   'ath_date': '2024-03-28T00:05:46.673Z',
#   'atl': 2.25,
#   'atl_change_percentage': 0.31388,
#   'atl_date': '2026-02-11T10:52:16.876Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:10:07.649Z'},
#  {'id': 'konnect',
#   'symbol': 'kct',
#   'name': 'Konnect',
#   'image': 'https://coin-images.coingecko.com/coins/images/25756/large/EAO_5JhW_400x400.jpg?1696524842',
#   'current_price': 0.280151,
#   'market_cap': 2065906575,
#   'market_cap_rank': 739,
#   'fully_diluted_valuation': 2801229240,
#   'total_volume': 39600865,
#   'high_24h': 0.284456,
#   'low_24h': 0.279484,
#   'price_change_24h': 0.00035418,
#   'price_change_percentage_24h': 0.12658,
#   'market_cap_change_24h': 6280198,
#   'market_cap_change_percentage_24h': 0.30492,
#   'circulating_supply': 7375000040.0,
#   'total_supply': 10000000000.0,
#   'max_supply': 10000000000.0,
#   'ath': 12.12,
#   'ath_change_percentage': -97.68522,
#   'ath_date': '2022-06-06T10:43:58.003Z',
#   'atl': 0.00123459,
#   'atl_change_percentage': 22618.13949,
#   'atl_date': '2024-12-16T01:55:33.301Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:10:07.623Z'},
#  {'id': 'autonomi',
#   'symbol': 'ant',
#   'name': 'Autonomi',
#   'image': 'https://coin-images.coingecko.com/coins/images/54388/large/Autonomi_Icon_Coin_200x200.png?1740037316',
#   'current_price': 6.88,
#   'market_cap': 2061342939,
#   'market_cap_rank': 745,
#   'fully_diluted_valuation': 8256240445,
#   'total_volume': 30584604,
#   'high_24h': 7.04,
#   'low_24h': 6.87,
#   'price_change_24h': -0.08240488809902313,
#   'price_change_percentage_24h': -1.183,
#   'market_cap_change_24h': -26322866.031981945,
#   'market_cap_change_percentage_24h': -1.26088,
#   'circulating_supply': 299605073.6725304,
#   'total_supply': 1200000000.0,
#   'max_supply': 1200000000.0,
#   'ath': 28.84,
#   'ath_change_percentage': -76.16659,
#   'ath_date': '2025-02-25T11:11:51.438Z',
#   'atl': 0.253538,
#   'atl_change_percentage': 2610.85843,
#   'atl_date': '2025-08-10T06:36:13.837Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:10:07.607Z'},
#  {'id': 'particle-network',
#   'symbol': 'parti',
#   'name': 'Particle Network',
#   'image': 'https://coin-images.coingecko.com/coins/images/54955/large/parti-token-200.png?1742822558',
#   'current_price': 8.84,
#   'market_cap': 2060786189,
#   'market_cap_rank': 746,
#   'fully_diluted_valuation': 8844575917,
#   'total_volume': 683813440,
#   'high_24h': 9.25,
#   'low_24h': 8.77,
#   'price_change_24h': -0.30418202282459106,
#   'price_change_percentage_24h': -3.3269,
#   'market_cap_change_24h': -72063434.48477697,
#   'market_cap_change_percentage_24h': -3.37874,
#   'circulating_supply': 233000000.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 35.76,
#   'ath_change_percentage': -75.33224,
#   'ath_date': '2025-05-13T11:45:41.615Z',
#   'atl': 3.86,
#   'atl_change_percentage': 128.81497,
#   'atl_date': '2025-10-10T21:31:07.039Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:10:07.710Z'},
#  {'id': 'metronome-synth-usd',
#   'symbol': 'msusd',
#   'name': 'Metronome Synth USD',
#   'image': 'https://coin-images.coingecko.com/coins/images/67504/large/metronome_msusd.png?1753015705',
#   'current_price': 90.21,
#   'market_cap': 2060595842,
#   'market_cap_rank': 743,
#   'fully_diluted_valuation': 2060595842,
#   'total_volume': 1200000889,
#   'high_24h': 90.32,
#   'low_24h': 89.84,
#   'price_change_24h': 0.128366,
#   'price_change_percentage_24h': 0.1425,
#   'market_cap_change_24h': 97139206,
#   'market_cap_change_percentage_24h': 4.94736,
#   'circulating_supply': 22840511.74697052,
#   'total_supply': 22840511.74697052,
#   'max_supply': None,
#   'ath': 301.63,
#   'ath_change_percentage': -70.0982,
#   'ath_date': '2025-10-16T10:58:22.559Z',
#   'atl': 37.98,
#   'atl_change_percentage': 137.49417,
#   'atl_date': '2025-10-09T03:53:06.683Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:10:07.712Z'},
#  {'id': 'dkargo',
#   'symbol': 'dka',
#   'name': 'dKargo',
#   'image': 'https://coin-images.coingecko.com/coins/images/11875/large/DKA_ticker.png?1732553189',
#   'current_price': 0.411764,
#   'market_cap': 2058686539,
#   'market_cap_rank': 744,
#   'fully_diluted_valuation': 2058686539,
#   'total_volume': 42533286,
#   'high_24h': 0.43204,
#   'low_24h': 0.410311,
#   'price_change_24h': -0.005507043328741634,
#   'price_change_percentage_24h': -1.31978,
#   'market_cap_change_24h': -44067545.18385959,
#   'market_cap_change_percentage_24h': -2.09571,
#   'circulating_supply': 5000000000.0,
#   'total_supply': 5000000000.0,
#   'max_supply': 5000000000.0,
#   'ath': 51.01,
#   'ath_change_percentage': -99.19258,
#   'ath_date': '2021-03-16T03:34:23.945Z',
#   'atl': 0.382807,
#   'atl_change_percentage': 7.59922,
#   'atl_date': '2026-02-06T00:34:55.538Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:10:07.670Z'},
#  {'id': 'sanctum-2',
#   'symbol': 'cloud',
#   'name': 'Cloud',
#   'image': 'https://coin-images.coingecko.com/coins/images/38485/large/CLOUD_128x128.png?1721331750',
#   'current_price': 3.82,
#   'market_cap': 2043781261,
#   'market_cap_rank': 747,
#   'fully_diluted_valuation': 3815304079,
#   'total_volume': 125905935,
#   'high_24h': 4.29,
#   'low_24h': 3.79,
#   'price_change_24h': -0.02997534769005128,
#   'price_change_percentage_24h': -0.77914,
#   'market_cap_change_24h': -17331944.413721323,
#   'market_cap_change_percentage_24h': -0.8409,
#   'circulating_supply': 535679783.0,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 52.79,
#   'ath_change_percentage': -92.78867,
#   'ath_date': '2024-11-13T19:17:35.212Z',
#   'atl': 3.48,
#   'atl_change_percentage': 9.4549,
#   'atl_date': '2026-02-05T22:26:01.979Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:10:07.727Z'},
#  {'id': 'definitive',
#   'symbol': 'edge',
#   'name': 'Definitive',
#   'image': 'https://coin-images.coingecko.com/coins/images/55072/large/EDGE-120x120.png?1743598652',
#   'current_price': 10.01,
#   'market_cap': 2035724558,
#   'market_cap_rank': 748,
#   'fully_diluted_valuation': 10026980748,
#   'total_volume': 133430483,
#   'high_24h': 11.13,
#   'low_24h': 9.94,
#   'price_change_24h': -0.30878476242349606,
#   'price_change_percentage_24h': -2.99286,
#   'market_cap_change_24h': -50374889.01418805,
#   'market_cap_change_percentage_24h': -2.41479,
#   'circulating_supply': 203024680.07272866,
#   'total_supply': 1000000000.0,
#   'max_supply': 1000000000.0,
#   'ath': 75.6,
#   'ath_change_percentage': -86.7249,
#   'ath_date': '2025-08-17T16:37:15.669Z',
#   'atl': 2.34,
#   'atl_change_percentage': 328.32208,
#   'atl_date': '2025-04-02T17:36:20.649Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:10:07.803Z'},
#  {'id': 'bifrost',
#   'symbol': 'bfc',
#   'name': 'Bifrost',
#   'image': 'https://coin-images.coingecko.com/coins/images/4639/large/BFC_Symbol.png?1696505208',
#   'current_price': 1.46,
#   'market_cap': 2027817749,
#   'market_cap_rank': 749,
#   'fully_diluted_valuation': 3452282506,
#   'total_volume': 55800109,
#   'high_24h': 1.5,
#   'low_24h': 1.45,
#   'price_change_24h': -0.037218169535715884,
#   'price_change_percentage_24h': -2.48821,
#   'market_cap_change_24h': -53409579.53352308,
#   'market_cap_change_percentage_24h': -2.56625,
#   'circulating_supply': 1391269925.662982,
#   'total_supply': 2368584074.0,
#   'max_supply': None,
#   'ath': 57.84,
#   'ath_change_percentage': -97.47873,
#   'ath_date': '2021-08-19T00:15:06.996Z',
#   'atl': 1.19,
#   'atl_change_percentage': 22.09418,
#   'atl_date': '2021-01-03T05:20:35.561Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:10:07.701Z'},
#  {'id': 'smooth-love-potion',
#   'symbol': 'slp',
#   'name': 'Smooth Love Potion',
#   'image': 'https://coin-images.coingecko.com/coins/images/10366/large/SLP.png?1696510368',
#   'current_price': 0.055432,
#   'market_cap': 2018931743,
#   'market_cap_rank': 752,
#   'fully_diluted_valuation': 2018931743,
#   'total_volume': 187835239,
#   'high_24h': 0.057711,
#   'low_24h': 0.055245,
#   'price_change_24h': -0.001686329253364344,
#   'price_change_percentage_24h': -2.95236,
#   'market_cap_change_24h': -60304633.224832535,
#   'market_cap_change_percentage_24h': -2.90033,
#   'circulating_supply': 36431755800.0,
#   'total_supply': 36431755800.0,
#   'max_supply': None,
#   'ath': 29.77,
#   'ath_change_percentage': -99.81436,
#   'ath_date': '2021-07-13T10:04:32.975Z',
#   'atl': 0.04963607,
#   'atl_change_percentage': 11.34339,
#   'atl_date': '2026-02-06T00:25:45.545Z',
#   'roi': None,
#   'last_updated': '2026-02-11T11:10:07.769Z'}]

# %%
import datetime

filtered_cryptocurrency = []

for coin in cryptocurrency:
    filtered_coin = {
        'id': coin.get('id'),
        'symbol': coin.get('symbol'),
        'name': coin.get('name'),
        'current_price': coin.get('current_price'),
        'market_cap': coin.get('market_cap'),
        'market_cap_rank': coin.get('market_cap_rank'),
        'total_volume': coin.get('total_volume'),
        'circulating_supply': coin.get('circulating_supply'),
        'total_supply': coin.get('total_supply'),
        'ath': coin.get('ath'),
        'atl': coin.get('atl')
    }

    # Extract only the date part from 'last_updated'
    last_updated_str = coin.get('last_updated')
    if last_updated_str:
        try:
            # Assuming format like '2026-02-06T13:19:11.648Z'
            dt_object = datetime.datetime.fromisoformat(last_updated_str.replace('Z', '+00:00'))
            filtered_coin['last_updated_date'] = dt_object.date().isoformat()
        except ValueError:
            filtered_coin['last_updated_date'] = None # Handle cases where date format might differ
    else:
        filtered_coin['last_updated_date'] = None

    filtered_cryptocurrency.append(filtered_coin)

cryptocurrency = filtered_cryptocurrency

print(f"Total filtered records: {len(cryptocurrency)}")
display(cryptocurrency)
# Out:
# Total filtered records: 750
# [{'id': 'bitcoin',
#   'symbol': 'btc',
#   'name': 'Bitcoin',
#   'current_price': 6041232,
#   'market_cap': 120766082622498,
#   'market_cap_rank': 1,
#   'total_volume': 4147390140782,
#   'circulating_supply': 19987525.0,
#   'total_supply': 19987525.0,
#   'ath': 11187013,
#   'atl': 3993.42,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'ethereum',
#   'symbol': 'eth',
#   'name': 'Ethereum',
#   'current_price': 176026,
#   'market_cap': 21248040341250,
#   'market_cap_rank': 2,
#   'total_volume': 1571438248607,
#   'circulating_supply': 120692569.8584684,
#   'total_supply': 120692569.8584684,
#   'ath': 431946,
#   'atl': 28.13,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'tether',
#   'symbol': 'usdt',
#   'name': 'Tether',
#   'current_price': 90.62,
#   'market_cap': 16711108679531,
#   'market_cap_rank': 3,
#   'total_volume': 6394472496241,
#   'circulating_supply': 184394018025.3612,
#   'total_supply': 189860955264.5262,
#   'ath': 105.52,
#   'atl': 36.86,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'ripple',
#   'symbol': 'xrp',
#   'name': 'XRP',
#   'current_price': 123.61,
#   'market_cap': 7530697117919,
#   'market_cap_rank': 4,
#   'total_volume': 219790712184,
#   'circulating_supply': 60917315351.0,
#   'total_supply': 99985721048.0,
#   'ath': 313.99,
#   'atl': 0.159343,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'binancecoin',
#   'symbol': 'bnb',
#   'name': 'BNB',
#   'current_price': 53462,
#   'market_cap': 7292089686813,
#   'market_cap_rank': 5,
#   'total_volume': 118219371188,
#   'circulating_supply': 136359497.93,
#   'total_supply': 136359497.93,
#   'ath': 121422,
#   'atl': 2.58,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'usd-coin',
#   'symbol': 'usdc',
#   'name': 'USDC',
#   'current_price': 90.65,
#   'market_cap': 6642217525415,
#   'market_cap_rank': 6,
#   'total_volume': 1108238216485,
#   'circulating_supply': 73269292074.75745,
#   'total_supply': 73277201114.08936,
#   'ath': 1327.87,
#   'atl': 65.31,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'solana',
#   'symbol': 'sol',
#   'name': 'Solana',
#   'current_price': 7330.6,
#   'market_cap': 4161712865370,
#   'market_cap_rank': 7,
#   'total_volume': 322209752189,
#   'circulating_supply': 567716500.5575353,
#   'total_supply': 620122095.2652178,
#   'ath': 25396,
#   'atl': 38.03,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'tron',
#   'symbol': 'trx',
#   'name': 'TRON',
#   'current_price': 24.85,
#   'market_cap': 2353376546675,
#   'market_cap_rank': 8,
#   'total_volume': 47828831965,
#   'circulating_supply': 94721477637.8709,
#   'total_supply': 94721503015.1996,
#   'ath': 36.53,
#   'atl': 0.117589,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'figure-heloc',
#   'symbol': 'figr_heloc',
#   'name': 'Figure Heloc',
#   'current_price': 93.43,
#   'market_cap': 1407485365287,
#   'market_cap_rank': 9,
#   'total_volume': 2600794743,
#   'circulating_supply': 15065146581.537,
#   'total_supply': 15065146581.537,
#   'ath': 120.96,
#   'atl': 13.78,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'dogecoin',
#   'symbol': 'doge',
#   'name': 'Dogecoin',
#   'current_price': 8.14,
#   'market_cap': 1373120408430,
#   'market_cap_rank': 10,
#   'total_volume': 77749413415,
#   'circulating_supply': 168669383126.5791,
#   'total_supply': 168695053126.579,
#   'ath': 53.62,
#   'atl': 0.00552883,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'whitebit',
#   'symbol': 'wbt',
#   'name': 'WhiteBIT Coin',
#   'current_price': 4557.84,
#   'market_cap': 974146510209,
#   'market_cap_rank': 11,
#   'total_volume': 5435225249,
#   'circulating_supply': 213729819.0,
#   'total_supply': 320229819.0,
#   'ath': 5758.63,
#   'atl': 245.71,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'bitcoin-cash',
#   'symbol': 'bch',
#   'name': 'Bitcoin Cash',
#   'current_price': 46245,
#   'market_cap': 924603877162,
#   'market_cap_rank': 12,
#   'total_volume': 29469401905,
#   'circulating_supply': 19993209.27165078,
#   'total_supply': 19993231.14665078,
#   'ath': 242198,
#   'atl': 5536.54,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'usds',
#   'symbol': 'usds',
#   'name': 'USDS',
#   'current_price': 90.66,
#   'market_cap': 868175253438,
#   'market_cap_rank': 13,
#   'total_volume': 352790889,
#   'circulating_supply': 9575179112.131311,
#   'total_supply': 9575179112.131311,
#   'ath': 92.23,
#   'atl': 79.67,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'cardano',
#   'symbol': 'ada',
#   'name': 'Cardano',
#   'current_price': 23.0,
#   'market_cap': 846326769298,
#   'market_cap_rank': 14,
#   'total_volume': 29734264559,
#   'circulating_supply': 36794311012.29324,
#   'total_supply': 45000000000.0,
#   'ath': 225.26,
#   'atl': 1.38,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'leo-token',
#   'symbol': 'leo',
#   'name': 'LEO Token',
#   'current_price': 754.55,
#   'market_cap': 695239828646,
#   'market_cap_rank': 15,
#   'total_volume': 142730278,
#   'circulating_supply': 921393276.9,
#   'total_supply': 985239504.0,
#   'ath': 888.26,
#   'atl': 56.97,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'hyperliquid',
#   'symbol': 'hype',
#   'name': 'Hyperliquid',
#   'current_price': 2585.41,
#   'market_cap': 616739986042,
#   'market_cap_rank': 16,
#   'total_volume': 26117737356,
#   'circulating_supply': 238385315.9541414,
#   'total_supply': 962274028.9541414,
#   'ath': 5213.52,
#   'atl': 321.88,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'ethena-usde',
#   'symbol': 'usde',
#   'name': 'Ethena USDe',
#   'current_price': 90.56,
#   'market_cap': 581978839456,
#   'market_cap_rank': 17,
#   'total_volume': 8034341412,
#   'circulating_supply': 6424043098.098995,
#   'total_supply': 6424043098.098995,
#   'ath': 92.91,
#   'atl': 78.05,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'monero',
#   'symbol': 'xmr',
#   'name': 'Monero',
#   'current_price': 31115,
#   'market_cap': 573770703296,
#   'market_cap_rank': 18,
#   'total_volume': 9011688065,
#   'circulating_supply': 18446744.07370955,
#   'total_supply': 18446744.07370955,
#   'ath': 72026,
#   'atl': 13.57,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'canton-network',
#   'symbol': 'cc',
#   'name': 'Canton',
#   'current_price': 14.75,
#   'market_cap': 556250531838,
#   'market_cap_rank': 19,
#   'total_volume': 1126169204,
#   'circulating_supply': 37711955931.79735,
#   'total_supply': 37711841846.96147,
#   'ath': 17.72,
#   'atl': 5.31,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'chainlink',
#   'symbol': 'link',
#   'name': 'Chainlink',
#   'current_price': 746.57,
#   'market_cap': 528384894772,
#   'market_cap_rank': 20,
#   'total_volume': 27238204632,
#   'circulating_supply': 708099970.4525867,
#   'total_supply': 1000000000.0,
#   'ath': 3862.15,
#   'atl': 9.55,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'usd1-wlfi',
#   'symbol': 'usd1',
#   'name': 'USD1',
#   'current_price': 90.61,
#   'market_cap': 488447692120,
#   'market_cap_rank': 21,
#   'total_volume': 158307896614,
#   'circulating_supply': 5389664312.189111,
#   'total_supply': 5389664312.189111,
#   'ath': 92.17,
#   'atl': 83.75,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'stellar',
#   'symbol': 'xlm',
#   'name': 'Stellar',
#   'current_price': 13.9,
#   'market_cap': 455062238935,
#   'market_cap_rank': 22,
#   'total_volume': 9795574728,
#   'circulating_supply': 32726837450.34228,
#   'total_supply': 50001786883.65895,
#   'ath': 58.01,
#   'atl': 0.02966141,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'dai',
#   'symbol': 'dai',
#   'name': 'Dai',
#   'current_price': 90.64,
#   'market_cap': 379934915710,
#   'market_cap_rank': 23,
#   'total_volume': 5183010314,
#   'circulating_supply': 4191460782.630203,
#   'total_supply': 4191460782.630203,
#   'ath': 92.29,
#   'atl': 64.85,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'litecoin',
#   'symbol': 'ltc',
#   'name': 'Litecoin',
#   'current_price': 4698.24,
#   'market_cap': 360979638147,
#   'market_cap_rank': 24,
#   'total_volume': 24774625605,
#   'circulating_supply': 76830789.48347135,
#   'total_supply': 76836195.73347135,
#   'ath': 30082,
#   'atl': 72.12,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'paypal-usd',
#   'symbol': 'pyusd',
#   'name': 'PayPal USD',
#   'current_price': 90.63,
#   'market_cap': 353271682845,
#   'market_cap_rank': 25,
#   'total_volume': 32614916556,
#   'circulating_supply': 3898111593.792355,
#   'total_supply': 3898111593.920528,
#   'ath': 92.2,
#   'atl': 80.95,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'hedera-hashgraph',
#   'symbol': 'hbar',
#   'name': 'Hedera',
#   'current_price': 8.0,
#   'market_cap': 344019426954,
#   'market_cap_rank': 26,
#   'total_volume': 7412961282,
#   'circulating_supply': 43003138665.46997,
#   'total_supply': 50000000000.0,
#   'ath': 41.81,
#   'atl': 0.703644,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'zcash',
#   'symbol': 'zec',
#   'name': 'Zcash',
#   'current_price': 20249,
#   'market_cap': 334821510263,
#   'market_cap_rank': 27,
#   'total_volume': 28559191787,
#   'circulating_supply': 16511426.7280448,
#   'total_supply': 16511426.7280448,
#   'ath': 211171,
#   'atl': 1342.38,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'avalanche-2',
#   'symbol': 'avax',
#   'name': 'Avalanche',
#   'current_price': 774.26,
#   'market_cap': 334315558784,
#   'market_cap_rank': 28,
#   'total_volume': 22829599025,
#   'circulating_supply': 431771961.1772119,
#   'total_supply': 463441061.1772119,
#   'ath': 10772.35,
#   'atl': 204.63,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'shiba-inu',
#   'symbol': 'shib',
#   'name': 'Shiba Inu',
#   'current_price': 0.00052534,
#   'market_cap': 309552261426,
#   'market_cap_rank': 30,
#   'total_volume': 12174446638,
#   'circulating_supply': 589243881085228.2,
#   'total_supply': 589500418260677.5,
#   'ath': 0.00645756,
#   'atl': 4.169e-09,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'sui',
#   'symbol': 'sui',
#   'name': 'Sui',
#   'current_price': 80.48,
#   'market_cap': 309478134867,
#   'market_cap_rank': 29,
#   'total_volume': 41743441736,
#   'circulating_supply': 3846172527.429665,
#   'total_supply': 10000000000.0,
#   'ath': 458.6,
#   'atl': 30.36,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'rain',
#   'symbol': 'rain',
#   'name': 'Rain',
#   'current_price': 0.904729,
#   'market_cap': 307277610045,
#   'market_cap_rank': 31,
#   'total_volume': 3092528408,
#   'circulating_supply': 339864219027.60913,
#   'total_supply': 1149930169180.052,
#   'ath': 0.989197,
#   'atl': 0.196087,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'the-open-network',
#   'symbol': 'ton',
#   'name': 'Toncoin',
#   'current_price': 117.62,
#   'market_cap': 287926049170,
#   'market_cap_rank': 32,
#   'total_volume': 8677821794,
#   'circulating_supply': 2448493143.82322,
#   'total_supply': 5153811737.731104,
#   'ath': 689.6,
#   'atl': 38.25,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'crypto-com-chain',
#   'symbol': 'cro',
#   'name': 'Cronos',
#   'current_price': 6.83,
#   'market_cap': 272373714935,
#   'market_cap_rank': 33,
#   'total_volume': 1452937923,
#   'circulating_supply': 39854177848.64204,
#   'total_supply': 98387046017.4802,
#   'ath': 72.06,
#   'atl': 0.864137,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'world-liberty-financial',
#   'symbol': 'wlfi',
#   'name': 'World Liberty Financial',
#   'current_price': 9.09,
#   'market_cap': 247589731350,
#   'market_cap_rank': 34,
#   'total_volume': 9009231553,
#   'circulating_supply': 27243802538.151154,
#   'total_supply': 100000000000.0,
#   'ath': 29.22,
#   'atl': 8.91,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'tether-gold',
#   'symbol': 'xaut',
#   'name': 'Tether Gold',
#   'current_price': 459715,
#   'market_cap': 238916429862,
#   'market_cap_rank': 35,
#   'total_volume': 33349626323,
#   'circulating_supply': 519825.641699,
#   'total_supply': 712747.089,
#   'ath': 514631,
#   'atl': 108167,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'memecore',
#   'symbol': 'm',
#   'name': 'MemeCore',
#   'current_price': 127.6,
#   'market_cap': 221320653459,
#   'market_cap_rank': 36,
#   'total_volume': 717819089,
#   'circulating_supply': 1734462867.741956,
#   'total_supply': 5334462877.634027,
#   'ath': 260.79,
#   'atl': 4.05,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'pax-gold',
#   'symbol': 'paxg',
#   'name': 'PAX Gold',
#   'current_price': 462158,
#   'market_cap': 212119722307,
#   'market_cap_rank': 37,
#   'total_volume': 23341853420,
#   'circulating_supply': 459009.975,
#   'total_supply': 459009.975,
#   'ath': 516779,
#   'atl': 100361,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'polkadot',
#   'symbol': 'dot',
#   'name': 'Polkadot',
#   'current_price': 112.08,
#   'market_cap': 186528671616,
#   'market_cap_rank': 38,
#   'total_volume': 8153389278,
#   'circulating_supply': 1664267932.778928,
#   'total_supply': 1664267932.778928,
#   'ath': 4095.22,
#   'atl': 103.91,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'uniswap',
#   'symbol': 'uni',
#   'name': 'Uniswap',
#   'current_price': 294.23,
#   'market_cap': 186513494229,
#   'market_cap_rank': 39,
#   'total_volume': 10981115771,
#   'circulating_supply': 633923278.1680214,
#   'total_supply': 898908420.0366304,
#   'ath': 3333.06,
#   'atl': 75.81,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'mantle',
#   'symbol': 'mnt',
#   'name': 'Mantle',
#   'current_price': 54.88,
#   'market_cap': 178519056784,
#   'market_cap_rank': 40,
#   'total_volume': 2790615298,
#   'circulating_supply': 3252944055.63684,
#   'total_supply': 6219316794.89,
#   'ath': 253.43,
#   'atl': 25.64,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'blackrock-usd-institutional-digital-liquidity-fund',
#   'symbol': 'buidl',
#   'name': 'BlackRock USD Institutional Digital Liquidity Fund',
#   'current_price': 90.65,
#   'market_cap': 166837820335,
#   'market_cap_rank': 41,
#   'total_volume': None,
#   'circulating_supply': 1840412389.420449,
#   'total_supply': 1840412389.420449,
#   'ath': 92.2,
#   'atl': 83.81,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'falcon-finance',
#   'symbol': 'usdf',
#   'name': 'Falcon USD',
#   'current_price': 90.37,
#   'market_cap': 159148865140,
#   'market_cap_rank': 42,
#   'total_volume': 55983554,
#   'circulating_supply': 1760988714.68948,
#   'total_supply': 1760988714.68948,
#   'ath': 92.45,
#   'atl': 80.47,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'aster-2',
#   'symbol': 'aster',
#   'name': 'Aster',
#   'current_price': 59.17,
#   'market_cap': 145299450585,
#   'market_cap_rank': 44,
#   'total_volume': 29808133164,
#   'circulating_supply': 2454947754.91,
#   'total_supply': 7822985112.446448,
#   'ath': 213.7,
#   'atl': 8.76,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'bitget-token',
#   'symbol': 'bgb',
#   'name': 'Bitget Token',
#   'current_price': 206.91,
#   'market_cap': 144834436406,
#   'market_cap_rank': 43,
#   'total_volume': 2741097830,
#   'circulating_supply': 699992035.9787906,
#   'total_supply': 916931610.9787906,
#   'ath': 722.65,
#   'atl': 1.081,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'aave',
#   'symbol': 'aave',
#   'name': 'Aave',
#   'current_price': 9534.95,
#   'market_cap': 144752669060,
#   'market_cap_rank': 45,
#   'total_volume': 18776172894,
#   'circulating_supply': 15190334.606571734,
#   'total_supply': 16000000.0,
#   'ath': 48387,
#   'atl': 1933.39,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'global-dollar',
#   'symbol': 'usdg',
#   'name': 'Global Dollar',
#   'current_price': 90.66,
#   'market_cap': 143231932480,
#   'market_cap_rank': 46,
#   'total_volume': 2813365020,
#   'circulating_supply': 1579822398.447444,
#   'total_supply': 1579822398.447444,
#   'ath': 143.35,
#   'atl': 76.61,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'hashnote-usyc',
#   'symbol': 'usyc',
#   'name': 'Circle USYC',
#   'current_price': 101.11,
#   'market_cap': 143216750855,
#   'market_cap_rank': 47,
#   'total_volume': 4044.32,
#   'circulating_supply': 1416473350.04677,
#   'total_supply': 1416473350.04677,
#   'ath': 102.4,
#   'atl': 86.89,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'ripple-usd',
#   'symbol': 'rlusd',
#   'name': 'Ripple USD',
#   'current_price': 90.65,
#   'market_cap': 137960445668,
#   'market_cap_rank': 48,
#   'total_volume': 11882470875,
#   'circulating_supply': 1521941230.127497,
#   'total_supply': 1521941230.127497,
#   'ath': 92.15,
#   'atl': 81.72,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'htx-dao',
#   'symbol': 'htx',
#   'name': 'HTX DAO',
#   'current_price': 0.00015012,
#   'market_cap': 137587515910,
#   'market_cap_rank': 49,
#   'total_volume': 830900198,
#   'circulating_supply': 916533066327098.8,
#   'total_supply': 916533066327098.8,
#   'ath': 0.00031771,
#   'atl': 6.739e-05,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'okb',
#   'symbol': 'okb',
#   'name': 'OKB',
#   'current_price': 6541.02,
#   'market_cap': 137278182233,
#   'market_cap_rank': 50,
#   'total_volume': 1659910758,
#   'circulating_supply': 21000000.0,
#   'total_supply': 21000000.0,
#   'ath': 22313,
#   'atl': 40.86,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'pepe',
#   'symbol': 'pepe',
#   'name': 'Pepe',
#   'current_price': 0.00032014,
#   'market_cap': 134679682929,
#   'market_cap_rank': 51,
#   'total_volume': 24323400357,
#   'circulating_supply': 420690000000000.0,
#   'total_supply': 420690000000000.0,
#   'ath': 0.00237833,
#   'atl': 4.52e-06,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'sky',
#   'symbol': 'sky',
#   'name': 'Sky',
#   'current_price': 5.76,
#   'market_cap': 132500699854,
#   'market_cap_rank': 52,
#   'total_volume': 1560779252,
#   'circulating_supply': 23013731871.383068,
#   'total_supply': 23462665147.36596,
#   'ath': 8.62,
#   'atl': 3.12,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'bittensor',
#   'symbol': 'tao',
#   'name': 'Bittensor',
#   'current_price': 13232.71,
#   'market_cap': 126988591888,
#   'market_cap_rank': 53,
#   'total_volume': 6199710018,
#   'circulating_supply': 9597491.0,
#   'total_supply': 21000000.0,
#   'ath': 62722,
#   'atl': 2535.93,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'bfusd',
#   'symbol': 'bfusd',
#   'name': 'BFUSD',
#   'current_price': 90.61,
#   'market_cap': 119607795249,
#   'market_cap_rank': 54,
#   'total_volume': 431644282,
#   'circulating_supply': 1320000000.0,
#   'total_supply': 1320000000.0,
#   'ath': 92.02,
#   'atl': 86.85,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'internet-computer',
#   'symbol': 'icp',
#   'name': 'Internet Computer',
#   'current_price': 208.22,
#   'market_cap': 114076902342,
#   'market_cap_rank': 55,
#   'total_volume': 3999776272,
#   'circulating_supply': 548120915.7279859,
#   'total_supply': 548120915.7279859,
#   'ath': 51433,
#   'atl': 187.57,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'ethereum-classic',
#   'symbol': 'etc',
#   'name': 'Ethereum Classic',
#   'current_price': 730.26,
#   'market_cap': 113546052741,
#   'market_cap_rank': 56,
#   'total_volume': 4246356380,
#   'circulating_supply': 155487351.7557799,
#   'total_supply': 155487351.7557799,
#   'ath': 12296.58,
#   'atl': 41.44,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'near',
#   'symbol': 'near',
#   'name': 'NEAR Protocol',
#   'current_price': 86.08,
#   'market_cap': 110828952225,
#   'market_cap_rank': 57,
#   'total_volume': 13634471617,
#   'circulating_supply': 1287479372.0,
#   'total_supply': 1287479399.0,
#   'ath': 1518.16,
#   'atl': 39.17,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'pi-network',
#   'symbol': 'pi',
#   'name': 'Pi Network',
#   'current_price': 12.09,
#   'market_cap': 108936681511,
#   'market_cap_rank': 58,
#   'total_volume': 1116755628,
#   'circulating_supply': 9012515463.944277,
#   'total_supply': 13858494030.47686,
#   'ath': 260.4,
#   'atl': 11.96,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'ondo-finance',
#   'symbol': 'ondo',
#   'name': 'Ondo',
#   'current_price': 21.61,
#   'market_cap': 105225016754,
#   'market_cap_rank': 59,
#   'total_volume': 4319614336,
#   'circulating_supply': 4869330647.0,
#   'total_supply': 10000000000.0,
#   'ath': 181.52,
#   'atl': 6.83,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'gatechain-token',
#   'symbol': 'gt',
#   'name': 'Gate',
#   'current_price': 618.23,
#   'market_cap': 103919175936,
#   'market_cap_rank': 60,
#   'total_volume': 225031517,
#   'circulating_supply': 115180573.04885802,
#   'total_supply': 115180573.04885802,
#   'ath': 2235.58,
#   'atl': 19.44,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'pump-fun',
#   'symbol': 'pump',
#   'name': 'Pump.fun',
#   'current_price': 0.168234,
#   'market_cap': 99242498944,
#   'market_cap_rank': 61,
#   'total_volume': 8183499496,
#   'circulating_supply': 590000000000.0,
#   'total_supply': 999989199086.1426,
#   'ath': 0.77853,
#   'atl': 0.150889,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'kucoin-shares',
#   'symbol': 'kcs',
#   'name': 'KuCoin',
#   'current_price': 715.92,
#   'market_cap': 94624264216,
#   'market_cap_rank': 62,
#   'total_volume': 318226898,
#   'circulating_supply': 132155021.7355671,
#   'total_supply': 142155021.7355671,
#   'ath': 2158.41,
#   'atl': 24.48,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'worldcoin-wld',
#   'symbol': 'wld',
#   'name': 'Worldcoin',
#   'current_price': 33.0,
#   'market_cap': 93141912308,
#   'market_cap_rank': 63,
#   'total_volume': 8223516431,
#   'circulating_supply': 2822045061.813433,
#   'total_supply': 10000000000.0,
#   'ath': 971.56,
#   'atl': 28.73,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'superstate-short-duration-us-government-securities-fund-ustb',
#   'symbol': 'ustb',
#   'name': 'Superstate Short Duration U.S. Government Securities Fund (USTB)',
#   'current_price': 995.9,
#   'market_cap': 91556468959,
#   'market_cap_rank': 64,
#   'total_volume': None,
#   'circulating_supply': 91933165.840072,
#   'total_supply': 91933165.840072,
#   'ath': 1011.63,
#   'atl': 876.83,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'usdd',
#   'symbol': 'usdd',
#   'name': 'USDD',
#   'current_price': 90.6,
#   'market_cap': 91120274384,
#   'market_cap_rank': 65,
#   'total_volume': 312407446,
#   'circulating_supply': 1005832837.0,
#   'total_supply': 1005791636.0,
#   'ath': 92.2,
#   'atl': 72.35,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'hash-2',
#   'symbol': 'hash',
#   'name': 'Provenance Blockchain',
#   'current_price': 1.67,
#   'market_cap': 91058272203,
#   'market_cap_rank': 66,
#   'total_volume': 9524825,
#   'circulating_supply': 54488686919.0,
#   'total_supply': 100000000000.0,
#   'ath': 5.31,
#   'atl': 0.877643,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'quant-network',
#   'symbol': 'qnt',
#   'name': 'Quant',
#   'current_price': 6224.21,
#   'market_cap': 90534760013,
#   'market_cap_rank': 67,
#   'total_volume': 1507723051,
#   'circulating_supply': 14544176.164081175,
#   'total_supply': 14612493.0,
#   'ath': 31427,
#   'atl': 15.06,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'polygon-ecosystem-token',
#   'symbol': 'pol',
#   'name': 'POL (ex-MATIC)',
#   'current_price': 8.04,
#   'market_cap': 85156476133,
#   'market_cap_rank': 69,
#   'total_volume': 6605836021,
#   'circulating_supply': 10589625381.75776,
#   'total_supply': 10589625381.75776,
#   'ath': 106.68,
#   'atl': 7.85,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'myx-finance',
#   'symbol': 'myx',
#   'name': 'MYX Finance',
#   'current_price': 446.1,
#   'market_cap': 85136368490,
#   'market_cap_rank': 68,
#   'total_volume': 2308759083,
#   'circulating_supply': 190768939.69,
#   'total_supply': 1000000000.0,
#   'ath': 1677.44,
#   'atl': 4.08,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'cosmos',
#   'symbol': 'atom',
#   'name': 'Cosmos Hub',
#   'current_price': 171.24,
#   'market_cap': 84253543180,
#   'market_cap_rank': 70,
#   'total_volume': 3313062632,
#   'circulating_supply': 492732152.873201,
#   'total_supply': 492732152.873201,
#   'ath': 3301.61,
#   'atl': 87.61,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'ethena',
#   'symbol': 'ena',
#   'name': 'Ethena',
#   'current_price': 9.89,
#   'market_cap': 81337842295,
#   'market_cap_rank': 71,
#   'total_volume': 7035431039,
#   'circulating_supply': 8225000000.0,
#   'total_supply': 15000000000.0,
#   'ath': 126.48,
#   'atl': 9.4,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'usdtb',
#   'symbol': 'usdtb',
#   'name': 'USDtb',
#   'current_price': 90.59,
#   'market_cap': 77399605708,
#   'market_cap_rank': 72,
#   'total_volume': 636267759,
#   'circulating_supply': 854399750.0161825,
#   'total_supply': 854399750.0161825,
#   'ath': 95.66,
#   'atl': 77.41,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'kaspa',
#   'symbol': 'kas',
#   'name': 'Kaspa',
#   'current_price': 2.8,
#   'market_cap': 74848504791,
#   'market_cap_rank': 73,
#   'total_volume': 1420464909,
#   'circulating_supply': 26777148610.50726,
#   'total_supply': 27193324199.74955,
#   'ath': 17.36,
#   'atl': 0.01327337,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'midnight-3',
#   'symbol': 'night',
#   'name': 'Midnight',
#   'current_price': 4.35,
#   'market_cap': 72238327468,
#   'market_cap_rank': 74,
#   'total_volume': 756013444,
#   'circulating_supply': 16607399400.63495,
#   'total_supply': 24000000000.0,
#   'ath': 10.66,
#   'atl': 2.14,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'nexo',
#   'symbol': 'nexo',
#   'name': 'NEXO',
#   'current_price': 72.25,
#   'market_cap': 72076643871,
#   'market_cap_rank': 75,
#   'total_volume': 1004566163,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'ath': 298.99,
#   'atl': 3.25,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'algorand',
#   'symbol': 'algo',
#   'name': 'Algorand',
#   'current_price': 8.11,
#   'market_cap': 71900384850,
#   'market_cap_rank': 76,
#   'total_volume': 2935929608,
#   'circulating_supply': 8870434813.738161,
#   'total_supply': 8870771667.221222,
#   'ath': 247.29,
#   'atl': 7.26,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'flare-networks',
#   'symbol': 'flr',
#   'name': 'Flare',
#   'current_price': 0.836706,
#   'market_cap': 70846471422,
#   'market_cap_rank': 77,
#   'total_volume': 329763875,
#   'circulating_supply': 84702357423.53589,
#   'total_supply': 104903478576.3326,
#   'ath': 12.35,
#   'atl': 0.687929,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'aptos',
#   'symbol': 'apt',
#   'name': 'Aptos',
#   'current_price': 86.79,
#   'market_cap': 66562333737,
#   'market_cap_rank': 78,
#   'total_volume': 6631293613,
#   'circulating_supply': 766889632.5315155,
#   'total_supply': 1195798391.148419,
#   'ath': 1622.34,
#   'atl': 84.41,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'janus-henderson-anemoy-aaa-clo-fund',
#   'symbol': 'jaaa',
#   'name': 'Janus Henderson Anemoy AAA CLO Fund',
#   'current_price': 93.01,
#   'market_cap': 66038324577,
#   'market_cap_rank': 79,
#   'total_volume': None,
#   'circulating_supply': 710021691.915383,
#   'total_supply': 710021691.915383,
#   'ath': 94.38,
#   'atl': 89.64,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'official-trump',
#   'symbol': 'trump',
#   'name': 'Official Trump',
#   'current_price': 283.52,
#   'market_cap': 65885750679,
#   'market_cap_rank': 80,
#   'total_volume': 6719536849,
#   'circulating_supply': 232498807.465716,
#   'total_supply': 1000000000.0,
#   'ath': 6357.94,
#   'atl': 282.93,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'eutbl',
#   'symbol': 'eutbl',
#   'name': 'Spiko EU T-Bills Money Market Fund',
#   'current_price': 113.12,
#   'market_cap': 64934691935,
#   'market_cap_rank': 81,
#   'total_volume': None,
#   'circulating_supply': 574034711.71872,
#   'total_supply': 574034711.71872,
#   'ath': 115.38,
#   'atl': 84.72,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'ondo-us-dollar-yield',
#   'symbol': 'usdy',
#   'name': 'Ondo US Dollar Yield',
#   'current_price': 101.69,
#   'market_cap': 63986324121,
#   'market_cap_rank': 82,
#   'total_volume': 130568948,
#   'circulating_supply': 629239542.3596164,
#   'total_supply': 1164752243.712908,
#   'ath': 105.8,
#   'atl': 77.42,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'ousg',
#   'symbol': 'ousg',
#   'name': 'OUSG',
#   'current_price': 10357.06,
#   'market_cap': 63546268557,
#   'market_cap_rank': 83,
#   'total_volume': 0.0,
#   'circulating_supply': 6135549.864477077,
#   'total_supply': 6135549.864477077,
#   'ath': 10520.12,
#   'atl': 7844.42,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'xdce-crowd-sale',
#   'symbol': 'xdc',
#   'name': 'XDC Network',
#   'current_price': 3.19,
#   'market_cap': 63542633628,
#   'market_cap_rank': 84,
#   'total_volume': 1555474543,
#   'circulating_supply': 19931717965.32,
#   'total_supply': 38050716121.5,
#   'ath': 14.32,
#   'atl': 0.02721364,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'filecoin',
#   'symbol': 'fil',
#   'name': 'Filecoin',
#   'current_price': 78.7,
#   'market_cap': 59188122084,
#   'market_cap_rank': 85,
#   'total_volume': 7271471542,
#   'circulating_supply': 752236460.0,
#   'total_supply': 1958288538.0,
#   'ath': 17367.85,
#   'atl': 73.41,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'render-token',
#   'symbol': 'render',
#   'name': 'Render',
#   'current_price': 113.77,
#   'market_cap': 59015316522,
#   'market_cap_rank': 86,
#   'total_volume': 3907620114,
#   'circulating_supply': 518714713.0140741,
#   'total_supply': 533474886.2940741,
#   'ath': 1121.89,
#   'atl': 2.79,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'vechain',
#   'symbol': 'vet',
#   'name': 'VeChain',
#   'current_price': 0.676026,
#   'market_cap': 58097611884,
#   'market_cap_rank': 87,
#   'total_volume': 1361143491,
#   'circulating_supply': 85985041177.0,
#   'total_supply': 85985041177.0,
#   'ath': 20.95,
#   'atl': 0.144791,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'arbitrum',
#   'symbol': 'arb',
#   'name': 'Arbitrum',
#   'current_price': 9.68,
#   'market_cap': 56385531120,
#   'market_cap_rank': 88,
#   'total_volume': 6584890244,
#   'circulating_supply': 5826785045.0,
#   'total_supply': 10000000000.0,
#   'ath': 198.19,
#   'atl': 8.93,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'beldex',
#   'symbol': 'bdx',
#   'name': 'Beldex',
#   'current_price': 7.25,
#   'market_cap': 55174982187,
#   'market_cap_rank': 89,
#   'total_volume': 1074099003,
#   'circulating_supply': 7605572756.406113,
#   'total_supply': 9935871511.40607,
#   'ath': 32.42,
#   'atl': 0.01949843,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'morpho',
#   'symbol': 'morpho',
#   'name': 'Morpho',
#   'current_price': 98.59,
#   'market_cap': 53849663080,
#   'market_cap_rank': 90,
#   'total_volume': 1222616423,
#   'circulating_supply': 546195090.8115237,
#   'total_supply': 1000000000.0,
#   'ath': 361.23,
#   'atl': 60.2,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'usual-usd',
#   'symbol': 'usd0',
#   'name': 'Usual USD',
#   'current_price': 90.54,
#   'market_cap': 51854932038,
#   'market_cap_rank': 91,
#   'total_volume': 358780490,
#   'circulating_supply': 572709719.0223286,
#   'total_supply': 572709719.0223286,
#   'ath': 110.74,
#   'atl': 81.88,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'janus-henderson-anemoy-treasury-fund',
#   'symbol': 'jtrsy',
#   'name': 'Janus Henderson Anemoy Treasury Fund',
#   'current_price': 99.19,
#   'market_cap': 51411259489,
#   'market_cap_rank': 92,
#   'total_volume': None,
#   'circulating_supply': 518328892.305495,
#   'total_supply': 518328892.305495,
#   'ath': 100.75,
#   'atl': 95.98,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'usdai',
#   'symbol': 'usdai',
#   'name': 'USDai',
#   'current_price': 90.65,
#   'market_cap': 50061081559,
#   'market_cap_rank': 93,
#   'total_volume': 507954747,
#   'circulating_supply': 552304375.5160904,
#   'total_supply': 552304375.5160904,
#   'ath': 104.92,
#   'atl': 68.25,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'gho',
#   'symbol': 'gho',
#   'name': 'GHO',
#   'current_price': 90.67,
#   'market_cap': 47825888487,
#   'market_cap_rank': 94,
#   'total_volume': 1385703094,
#   'circulating_supply': 527437881.2934199,
#   'total_supply': 527437881.2934199,
#   'ath': 92.12,
#   'atl': 76.18,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'bonk',
#   'symbol': 'bonk',
#   'name': 'Bonk',
#   'current_price': 0.0005229,
#   'market_cap': 46012148976,
#   'market_cap_rank': 95,
#   'total_volume': 4602809982,
#   'circulating_supply': 87995156245690.39,
#   'total_supply': 87995156319577.3,
#   'ath': 0.00491619,
#   'atl': 7.14e-06,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'a7a5',
#   'symbol': 'a7a5',
#   'name': 'A7A5',
#   'current_price': 1.16,
#   'market_cap': 45294136754,
#   'market_cap_rank': 96,
#   'total_volume': 252002,
#   'circulating_supply': 39189098366.91073,
#   'total_supply': 39189098366.91073,
#   'ath': 20.14,
#   'atl': 0.00091492,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'true-usd',
#   'symbol': 'tusd',
#   'name': 'TrueUSD',
#   'current_price': 90.56,
#   'market_cap': 44787625428,
#   'market_cap_rank': 97,
#   'total_volume': 698608531,
#   'circulating_supply': 494515083.0,
#   'total_supply': 494515083.0,
#   'ath': 112.93,
#   'atl': 64.32,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'fasttoken',
#   'symbol': 'ftn',
#   'name': 'Fasttoken',
#   'current_price': 98.83,
#   'market_cap': 42876980862,
#   'market_cap_rank': 98,
#   'total_volume': 1004604604,
#   'circulating_supply': 433857414.6,
#   'total_supply': 870742437.0,
#   'ath': 403.42,
#   'atl': 30.21,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'layerzero',
#   'symbol': 'zro',
#   'name': 'LayerZero',
#   'current_price': 209.41,
#   'market_cap': 42424494907,
#   'market_cap_rank': 99,
#   'total_volume': 56032854552,
#   'circulating_supply': 202629028.12286997,
#   'total_supply': 1000000000.0,
#   'ath': 632.92,
#   'atl': 99.55,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'sei-network',
#   'symbol': 'sei',
#   'name': 'Sei',
#   'current_price': 6.4,
#   'market_cap': 42324326264,
#   'market_cap_rank': 100,
#   'total_volume': 3448637903,
#   'circulating_supply': 6612222222.0,
#   'total_supply': 10000000000.0,
#   'ath': 94.47,
#   'atl': 6.23,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'euro-coin',
#   'symbol': 'eurc',
#   'name': 'EURC',
#   'current_price': 107.99,
#   'market_cap': 41361905737,
#   'market_cap_rank': 101,
#   'total_volume': 3496212834,
#   'circulating_supply': 382960201.1675681,
#   'total_supply': 382960201.1675681,
#   'ath': 111.47,
#   'atl': 4.35,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'jupiter-exchange-solana',
#   'symbol': 'jup',
#   'name': 'Jupiter',
#   'current_price': 12.58,
#   'market_cap': 40728279378,
#   'market_cap_rank': 102,
#   'total_volume': 2327261706,
#   'circulating_supply': 3243891294.88,
#   'total_supply': 6863982888.464856,
#   'ath': 166.05,
#   'atl': 12.52,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'blockstack',
#   'symbol': 'stx',
#   'name': 'Stacks',
#   'current_price': 22.56,
#   'market_cap': 39975255236,
#   'market_cap_rank': 103,
#   'total_volume': 1090154144,
#   'circulating_supply': 1776346416.13918,
#   'total_supply': 1776346416.13918,
#   'ath': 322.23,
#   'atl': 3.44,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'pippin',
#   'symbol': 'pippin',
#   'name': 'pippin',
#   'current_price': 39.56,
#   'market_cap': 39363773603,
#   'market_cap_rank': 104,
#   'total_volume': 5158725494,
#   'circulating_supply': 999937507.199715,
#   'total_supply': 999937507.199715,
#   'ath': 50.39,
#   'atl': 0.473545,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'pancakeswap-token',
#   'symbol': 'cake',
#   'name': 'PancakeSwap',
#   'current_price': 115.19,
#   'market_cap': 38259425169,
#   'market_cap_rank': 105,
#   'total_volume': 2497549986,
#   'circulating_supply': 332119051.2484415,
#   'total_supply': 345453343.4723421,
#   'ath': 3259.75,
#   'atl': 14.48,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'tezos',
#   'symbol': 'xtz',
#   'name': 'Tezos',
#   'current_price': 35.22,
#   'market_cap': 37866401035,
#   'market_cap_rank': 106,
#   'total_volume': 1536211515,
#   'circulating_supply': 1075072292.371302,
#   'total_supply': 1095132530.071092,
#   'ath': 676.89,
#   'atl': 24.73,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'dash',
#   'symbol': 'dash',
#   'name': 'Dash',
#   'current_price': 2989.31,
#   'market_cap': 37622848458,
#   'market_cap_rank': 107,
#   'total_volume': 5195022818,
#   'circulating_supply': 12585131.26300869,
#   'total_supply': 12585131.26300869,
#   'ath': 95552,
#   'atl': 13.82,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'decred',
#   'symbol': 'dcr',
#   'name': 'Decred',
#   'current_price': 2098.63,
#   'market_cap': 36241547661,
#   'market_cap_rank': 108,
#   'total_volume': 494530854,
#   'circulating_supply': 17269150.33333832,
#   'total_supply': 17270177.21996998,
#   'ath': 18443.33,
#   'atl': 29.25,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'chiliz',
#   'symbol': 'chz',
#   'name': 'Chiliz',
#   'current_price': 3.51,
#   'market_cap': 36069199504,
#   'market_cap_rank': 109,
#   'total_volume': 5251766170,
#   'circulating_supply': 10269527040.0,
#   'total_supply': 10269527040.0,
#   'ath': 63.87,
#   'atl': 0.290329,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'first-digital-usd',
#   'symbol': 'fdusd',
#   'name': 'First Digital USD',
#   'current_price': 90.54,
#   'market_cap': 35799747533,
#   'market_cap_rank': 110,
#   'total_volume': 5057896655,
#   'circulating_supply': 395412031.279425,
#   'total_supply': 395412031.279425,
#   'ath': 100.07,
#   'atl': 78.29,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'story-2',
#   'symbol': 'ip',
#   'name': 'Story',
#   'current_price': 102.2,
#   'market_cap': 35790722909,
#   'market_cap_rank': 111,
#   'total_volume': 3443831438,
#   'circulating_supply': 350252819.46,
#   'total_supply': 1023773431.02,
#   'ath': 1302.35,
#   'atl': 87.81,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'kinesis-gold',
#   'symbol': 'kau',
#   'name': 'Kinesis Gold',
#   'current_price': 14815.62,
#   'market_cap': 35353446675,
#   'market_cap_rank': 112,
#   'total_volume': 23002939,
#   'circulating_supply': 2386227.8342,
#   'total_supply': 2386227.8342,
#   'ath': 16353.61,
#   'atl': 3614.27,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'river',
#   'symbol': 'river',
#   'name': 'River',
#   'current_price': 1778.97,
#   'market_cap': 34895629966,
#   'market_cap_rank': 113,
#   'total_volume': 7358059968,
#   'circulating_supply': 19600000.0,
#   'total_supply': 100000000.0,
#   'ath': 8042.31,
#   'atl': 140.15,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'optimism',
#   'symbol': 'op',
#   'name': 'Optimism',
#   'current_price': 15.92,
#   'market_cap': 33680084365,
#   'market_cap_rank': 114,
#   'total_volume': 4421345735,
#   'circulating_supply': 2116007431.0,
#   'total_supply': 4294967296.0,
#   'ath': 401.58,
#   'atl': 14.88,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'pudgy-penguins',
#   'symbol': 'pengu',
#   'name': 'Pudgy Penguins',
#   'current_price': 0.534681,
#   'market_cap': 33595937489,
#   'market_cap_rank': 116,
#   'total_volume': 5779104455,
#   'circulating_supply': 62860396090.0,
#   'total_supply': 79734013531.17758,
#   'ath': 5.81,
#   'atl': 0.320882,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'stable-2',
#   'symbol': 'stable',
#   'name': '\u200b\u200bStable',
#   'current_price': 1.86,
#   'market_cap': 33417081573,
#   'market_cap_rank': 115,
#   'total_volume': 3800006999,
#   'circulating_supply': 18000000000.0,
#   'total_supply': 100000000000.0,
#   'ath': 2.93,
#   'atl': 0.827533,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'just',
#   'symbol': 'jst',
#   'name': 'JUST',
#   'current_price': 3.68,
#   'market_cap': 32429263846,
#   'market_cap_rank': 117,
#   'total_volume': 1738275393,
#   'circulating_supply': 8815108920.581306,
#   'total_supply': 8815108920.581306,
#   'ath': 14.19,
#   'atl': 0.359754,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'virtual-protocol',
#   'symbol': 'virtual',
#   'name': 'Virtuals Protocol',
#   'current_price': 48.86,
#   'market_cap': 32063984965,
#   'market_cap_rank': 118,
#   'total_volume': 4840344054,
#   'circulating_supply': 656282621.3333926,
#   'total_supply': 1000000000.0,
#   'ath': 434.45,
#   'atl': 0.622571,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'lighter',
#   'symbol': 'lit',
#   'name': 'Lighter',
#   'current_price': 127.38,
#   'market_cap': 31847961868,
#   'market_cap_rank': 119,
#   'total_volume': 2277670005,
#   'circulating_supply': 250000000.0,
#   'total_supply': 1000000000.0,
#   'ath': 705.52,
#   'atl': 123.01,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'c8ntinuum',
#   'symbol': 'ctm',
#   'name': 'c8ntinuum',
#   'current_price': 7.29,
#   'market_cap': 31800914161,
#   'market_cap_rank': 120,
#   'total_volume': 98853616,
#   'circulating_supply': 4359542107.432732,
#   'total_supply': 8888888888.0,
#   'ath': 13.05,
#   'atl': 0.709073,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'fetch-ai',
#   'symbol': 'fet',
#   'name': 'Artificial Superintelligence Alliance',
#   'current_price': 13.73,
#   'market_cap': 31381696589,
#   'market_cap_rank': 121,
#   'total_volume': 2863428083,
#   'circulating_supply': 2282861718.9251046,
#   'total_supply': 2714384546.672,
#   'ath': 287.87,
#   'atl': 0.616804,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'curve-dao-token',
#   'symbol': 'crv',
#   'name': 'Curve DAO',
#   'current_price': 20.56,
#   'market_cap': 30332648219,
#   'market_cap_rank': 122,
#   'total_volume': 6745238759,
#   'circulating_supply': 1475327113.0,
#   'total_supply': 2351327263.108556,
#   'ath': 1150.14,
#   'atl': 15.17,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'bittorrent',
#   'symbol': 'btt',
#   'name': 'BitTorrent',
#   'current_price': 3.018e-05,
#   'market_cap': 29792455650,
#   'market_cap_rank': 123,
#   'total_volume': 1024267900,
#   'circulating_supply': 987037885840674.8,
#   'total_supply': 990000000000000.0,
#   'ath': 0.00025579,
#   'atl': 2.748e-05,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'kite-2',
#   'symbol': 'kite',
#   'name': 'Kite',
#   'current_price': 16.15,
#   'market_cap': 29078165912,
#   'market_cap_rank': 124,
#   'total_volume': 4763337436,
#   'circulating_supply': 1800000000.0,
#   'total_supply': 10000000000.0,
#   'ath': 17.82,
#   'atl': 5.48,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'gnosis',
#   'symbol': 'gno',
#   'name': 'Gnosis',
#   'current_price': 10983.46,
#   'market_cap': 28992357664,
#   'market_cap_rank': 125,
#   'total_volume': 472386301,
#   'circulating_supply': 2639589.0,
#   'total_supply': 3000000.0,
#   'ath': 47603,
#   'atl': 519.75,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'sun-token',
#   'symbol': 'sun',
#   'name': 'Sun Token',
#   'current_price': 1.5,
#   'market_cap': 28841430396,
#   'market_cap_rank': 126,
#   'total_volume': 2936730068,
#   'circulating_supply': 19208721222.33119,
#   'total_supply': 19900730000.0,
#   'ath': 4880.96,
#   'atl': 0.374246,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'kinesis-silver',
#   'symbol': 'kag',
#   'name': 'Kinesis Silver',
#   'current_price': 7725.97,
#   'market_cap': 28755779069,
#   'market_cap_rank': 127,
#   'total_volume': 82180074,
#   'circulating_supply': 3721963.8196,
#   'total_supply': 3721963.8196,
#   'ath': 11907.44,
#   'atl': 362.2,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'kaia',
#   'symbol': 'kaia',
#   'name': 'Kaia',
#   'current_price': 4.88,
#   'market_cap': 28564451768,
#   'market_cap_rank': 128,
#   'total_volume': 670018870,
#   'circulating_supply': 5856641747.106198,
#   'total_supply': 5856641936.044253,
#   'ath': 34.46,
#   'atl': 4.23,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'syrup',
#   'symbol': 'syrup',
#   'name': 'Maple Finance',
#   'current_price': 24.36,
#   'market_cap': 28180966562,
#   'market_cap_rank': 129,
#   'total_volume': 625790413,
#   'circulating_supply': 1157190702.5885315,
#   'total_supply': 1216127147.998563,
#   'ath': 56.23,
#   'atl': 7.31,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'apenft',
#   'symbol': 'nft',
#   'name': 'AINFT',
#   'current_price': 2.821e-05,
#   'market_cap': 27934697360,
#   'market_cap_rank': 130,
#   'total_volume': 1249131755,
#   'circulating_supply': 990105667256391.5,
#   'total_supply': 990105667256391.5,
#   'ath': 0.00054965,
#   'atl': 2.463e-05,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'ether-fi',
#   'symbol': 'ethfi',
#   'name': 'Ether.fi',
#   'current_price': 39.11,
#   'market_cap': 27347601445,
#   'market_cap_rank': 131,
#   'total_volume': 2904225611,
#   'circulating_supply': 699363510.0,
#   'total_supply': 998535999.0,
#   'ath': 711.06,
#   'atl': 34.7,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'injective-protocol',
#   'symbol': 'inj',
#   'name': 'Injective',
#   'current_price': 269.08,
#   'market_cap': 26902501540,
#   'market_cap_rank': 132,
#   'total_volume': 3021319639,
#   'circulating_supply': 100000000.0,
#   'total_supply': 100000000.0,
#   'ath': 4364.19,
#   'atl': 49.02,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'usx',
#   'symbol': 'usx',
#   'name': 'USX',
#   'current_price': 90.62,
#   'market_cap': 26638206608,
#   'market_cap_rank': 133,
#   'total_volume': 490562809,
#   'circulating_supply': 293923154.85157,
#   'total_supply': 293923154.85157,
#   'ath': 95.56,
#   'atl': 74.4,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'crvusd',
#   'symbol': 'crvusd',
#   'name': 'crvUSD',
#   'current_price': 90.57,
#   'market_cap': 26547525437,
#   'market_cap_rank': 134,
#   'total_volume': 3197965520,
#   'circulating_supply': 293139910.0775291,
#   'total_supply': 293139910.0775291,
#   'ath': 96.91,
#   'atl': 78.57,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'resolv-usr',
#   'symbol': 'usr',
#   'name': 'Resolv USR',
#   'current_price': 90.64,
#   'market_cap': 26488956196,
#   'market_cap_rank': 135,
#   'total_volume': 16069216,
#   'circulating_supply': 292218786.5781541,
#   'total_supply': 292218786.5781541,
#   'ath': 92.16,
#   'atl': 82.39,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'hastra-prime',
#   'symbol': 'prime',
#   'name': 'PRIME',
#   'current_price': 92.31,
#   'market_cap': 26224409035,
#   'market_cap_rank': 136,
#   'total_volume': 850953476,
#   'circulating_supply': 284077374.273613,
#   'total_supply': 284077374.273613,
#   'ath': 94.01,
#   'atl': 89.31,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'iota',
#   'symbol': 'iota',
#   'name': 'IOTA',
#   'current_price': 5.87,
#   'market_cap': 25169845729,
#   'market_cap_rank': 137,
#   'total_volume': 615244680,
#   'circulating_supply': 4284289920.0,
#   'total_supply': 4816217593.0,
#   'ath': 336.22,
#   'atl': 5.75,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'floki',
#   'symbol': 'floki',
#   'name': 'FLOKI',
#   'current_price': 0.00259457,
#   'market_cap': 25061055268,
#   'market_cap_rank': 138,
#   'total_volume': 2234492742,
#   'circulating_supply': 9655017300149.0,
#   'total_supply': 10000000000000.0,
#   'ath': 0.02877055,
#   'atl': 6.26e-06,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'lido-dao',
#   'symbol': 'ldo',
#   'name': 'Lido DAO',
#   'current_price': 29.42,
#   'market_cap': 24936557730,
#   'market_cap_rank': 139,
#   'total_volume': 2061783108,
#   'circulating_supply': 848066802.5927889,
#   'total_supply': 1000000000.0,
#   'ath': 543.56,
#   'atl': 26.78,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'bitcoin-cash-sv',
#   'symbol': 'bsv',
#   'name': 'Bitcoin SV',
#   'current_price': 1242.72,
#   'market_cap': 24838205656,
#   'market_cap_rank': 141,
#   'total_volume': 378173177,
#   'circulating_supply': 19986987.5,
#   'total_supply': 19987037.5,
#   'ath': 36495,
#   'atl': 1043.89,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'frax',
#   'symbol': 'frax',
#   'name': 'Legacy Frax Dollar',
#   'current_price': 89.89,
#   'market_cap': 24812395728,
#   'market_cap_rank': 140,
#   'total_volume': 481530692,
#   'circulating_supply': 276015184.0102677,
#   'total_supply': 276015184.0102677,
#   'ath': 91.66,
#   'atl': 67.16,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'the-graph',
#   'symbol': 'grt',
#   'name': 'The Graph',
#   'current_price': 2.32,
#   'market_cap': 24772163389,
#   'market_cap_rank': 142,
#   'total_volume': 1156215693,
#   'circulating_supply': 10707361829.17138,
#   'total_supply': 10800262816.04821,
#   'ath': 206.81,
#   'atl': 2.12,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'olympus',
#   'symbol': 'ohm',
#   'name': 'Olympus',
#   'current_price': 1557.3,
#   'market_cap': 24358807259,
#   'market_cap_rank': 143,
#   'total_volume': 9464498,
#   'circulating_supply': 15645551.38895166,
#   'total_supply': 21038226.95428537,
#   'ath': 121096,
#   'atl': 616.08,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'celestia',
#   'symbol': 'tia',
#   'name': 'Celestia',
#   'current_price': 27.32,
#   'market_cap': 24000221343,
#   'market_cap_rank': 144,
#   'total_volume': 2079560072,
#   'circulating_supply': 878520222.358706,
#   'total_supply': 1161386648.78766,
#   'ath': 1730.96,
#   'atl': 25.29,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'jasmycoin',
#   'symbol': 'jasmy',
#   'name': 'JasmyCoin',
#   'current_price': 0.485317,
#   'market_cap': 23973915006,
#   'market_cap_rank': 145,
#   'total_volume': 1152567175,
#   'circulating_supply': 49444999677.59027,
#   'total_supply': 50000000000.0,
#   'ath': 347.8,
#   'atl': 0.227783,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'aerodrome-finance',
#   'symbol': 'aero',
#   'name': 'Aerodrome Finance',
#   'current_price': 26.15,
#   'market_cap': 23959503779,
#   'market_cap_rank': 146,
#   'total_volume': 1068430474,
#   'circulating_supply': 916337463.7834435,
#   'total_supply': 1835471885.041677,
#   'ath': 196.44,
#   'atl': 0.0015484,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'spx6900',
#   'symbol': 'spx',
#   'name': 'SPX6900',
#   'current_price': 25.53,
#   'market_cap': 23765773407,
#   'market_cap_rank': 147,
#   'total_volume': 1036666412,
#   'circulating_supply': 930993080.908372,
#   'total_supply': 930993080.908372,
#   'ath': 196.84,
#   'atl': 0.109402,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'humanity',
#   'symbol': 'h',
#   'name': 'Humanity',
#   'current_price': 12.8,
#   'market_cap': 23354360345,
#   'market_cap_rank': 148,
#   'total_volume': 1643700912,
#   'circulating_supply': 1825000000.0,
#   'total_supply': 10000000000.0,
#   'ath': 34.11,
#   'atl': 1.55,
#   'last_updated_date': '2026-02-11'},
# ...
#   'total_supply': 19125243138.1881,
#   'ath': 52.97,
#   'atl': 0.1369,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'kyber-network-crystal',
#   'symbol': 'knc',
#   'name': 'Kyber Network Crystal',
#   'current_price': 13.1,
#   'market_cap': 2227797840,
#   'market_cap_rank': 703,
#   'total_volume': 796685700,
#   'circulating_supply': 170152851.23024455,
#   'total_supply': 240893671.044645,
#   'ath': 436.19,
#   'atl': 12.59,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'blockv',
#   'symbol': 'vee',
#   'name': 'BLOCKv',
#   'current_price': 0.611492,
#   'market_cap': 2226700863,
#   'market_cap_rank': 702,
#   'total_volume': 69424703,
#   'circulating_supply': 3646271241.200255,
#   'total_supply': 3646271241.200255,
#   'ath': 22.59,
#   'atl': 0.00080618,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'marsmi',
#   'symbol': 'marsmi',
#   'name': 'MarsMi',
#   'current_price': 2.23,
#   'market_cap': 2226790052,
#   'market_cap_rank': 704,
#   'total_volume': 13355556,
#   'circulating_supply': 999999978.227557,
#   'total_supply': 999999978.227557,
#   'ath': 16.22,
#   'atl': 2.04,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'radix',
#   'symbol': 'xrd',
#   'name': 'Radix',
#   'current_price': 0.165752,
#   'market_cap': 2220888139,
#   'market_cap_rank': 705,
#   'total_volume': 20553371,
#   'circulating_supply': 13360278049.10772,
#   'total_supply': 13360713233.3373,
#   'ath': 48.43,
#   'atl': 0.091247,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'momentum-3',
#   'symbol': 'mmt',
#   'name': 'Momentum',
#   'current_price': 10.87,
#   'market_cap': 2215589136,
#   'market_cap_rank': 708,
#   'total_volume': 535230819,
#   'circulating_supply': 204095424.0,
#   'total_supply': 1000000000.0,
#   'ath': 357.49,
#   'atl': 10.51,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'micron-technology-ondo-tokenized-stock',
#   'symbol': 'muon',
#   'name': 'Micron Technology (Ondo Tokenized Stock)',
#   'current_price': 34175,
#   'market_cap': 2213951743,
#   'market_cap_rank': 706,
#   'total_volume': 392034439,
#   'circulating_supply': 64789.90876803699,
#   'total_supply': 64789.90876803699,
#   'ath': 41937,
#   'atl': 10205.02,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'sharp-token',
#   'symbol': 'sharp',
#   'name': 'Sharp Token',
#   'current_price': 0.654194,
#   'market_cap': 2208657414,
#   'market_cap_rank': 709,
#   'total_volume': 3516875,
#   'circulating_supply': 3376492186.6666665,
#   'total_supply': 68230000000.0,
#   'ath': 1.056,
#   'atl': 0.289404,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'cargox',
#   'symbol': 'cxo',
#   'name': 'CargoX',
#   'current_price': 13.18,
#   'market_cap': 2203084870,
#   'market_cap_rank': 707,
#   'total_volume': 271507,
#   'circulating_supply': 167160147.72525844,
#   'total_supply': 215119016.0,
#   'ath': 43.58,
#   'atl': 0.00284545,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'across-protocol',
#   'symbol': 'acx',
#   'name': 'Across Protocol',
#   'current_price': 3.2,
#   'market_cap': 2195483074,
#   'market_cap_rank': 711,
#   'total_volume': 123529190,
#   'circulating_supply': 686623512.3841444,
#   'total_supply': 1000000000.0,
#   'ath': 143.0,
#   'atl': 2.84,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'electronic-usd',
#   'symbol': 'eusd',
#   'name': 'Electronic USD',
#   'current_price': 90.61,
#   'market_cap': 2195457137,
#   'market_cap_rank': 710,
#   'total_volume': 44487115,
#   'circulating_supply': 24232437.8884462,
#   'total_supply': 24232437.8884462,
#   'ath': 94.57,
#   'atl': 71.88,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'mimbogamegroup',
#   'symbol': 'mgg',
#   'name': 'MimboGameGroup',
#   'current_price': 0.271697,
#   'market_cap': 2187378481,
#   'market_cap_rank': 712,
#   'total_volume': 266948271,
#   'circulating_supply': 8049787558.90125,
#   'total_supply': 110059787559.0,
#   'ath': 0.271819,
#   'atl': 0.02524465,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'medibloc',
#   'symbol': 'med',
#   'name': 'Medibloc',
#   'current_price': 0.204762,
#   'market_cap': 2179831488,
#   'market_cap_rank': 715,
#   'total_volume': 24861965,
#   'circulating_supply': 10644041819.0,
#   'total_supply': 11434259731.0,
#   'ath': 25.79,
#   'atl': 0.121837,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'gyroscope-gyd',
#   'symbol': 'gyd',
#   'name': 'Gyroscope GYD',
#   'current_price': 90.99,
#   'market_cap': 2202811214,
#   'market_cap_rank': 714,
#   'total_volume': 53.0,
#   'circulating_supply': 24208960.0029494,
#   'total_supply': 24208960.0029494,
#   'ath': 93.94,
#   'atl': 68.25,
#   'last_updated_date': '2026-02-01'},
#  {'id': 'torch-of-liberty',
#   'symbol': 'liberty',
#   'name': 'Torch of Liberty',
#   'current_price': 2.18,
#   'market_cap': 2176092972,
#   'market_cap_rank': 713,
#   'total_volume': 102057283,
#   'circulating_supply': 1000000000.0,
#   'total_supply': 1000000000.0,
#   'ath': 12.67,
#   'atl': 0.989222,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'degen-base',
#   'symbol': 'degen',
#   'name': 'Degen',
#   'current_price': 0.058567,
#   'market_cap': 2157553077,
#   'market_cap_rank': 716,
#   'total_volume': 179640408,
#   'circulating_supply': 36965730333.0,
#   'total_supply': 36965730333.0,
#   'ath': 5.38,
#   'atl': 0.00186847,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'warden-2',
#   'symbol': 'ward',
#   'name': 'Warden',
#   'current_price': 8.71,
#   'market_cap': 2141172789,
#   'market_cap_rank': 720,
#   'total_volume': 16611671210,
#   'circulating_supply': 250320000.0,
#   'total_supply': 1000000000.0,
#   'ath': 13.24,
#   'atl': 6.65,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'bitlayer-bitvm',
#   'symbol': 'btr',
#   'name': 'Bitlayer',
#   'current_price': 8.15,
#   'market_cap': 2136167197,
#   'market_cap_rank': 721,
#   'total_volume': 299127615,
#   'circulating_supply': 261600000.0,
#   'total_supply': 1000000000.0,
#   'ath': 15.22,
#   'atl': 2.13,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'faith-tribe',
#   'symbol': 'ftrb',
#   'name': 'Faith Tribe',
#   'current_price': 0.661887,
#   'market_cap': 2133618376,
#   'market_cap_rank': 718,
#   'total_volume': 43927747,
#   'circulating_supply': 3229510514.05,
#   'total_supply': 5000000000.0,
#   'ath': 5.36,
#   'atl': 0.145084,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'the-grays-currency',
#   'symbol': 'ptgc',
#   'name': 'The Grays Currency',
#   'current_price': 0.00733509,
#   'market_cap': 2133181739,
#   'market_cap_rank': 723,
#   'total_volume': 3352579,
#   'circulating_supply': 289865242498.8118,
#   'total_supply': 289865242498.8118,
#   'ath': 0.115141,
#   'atl': 0.00018075,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'honey-3',
#   'symbol': 'honey',
#   'name': 'Honey',
#   'current_price': 90.45,
#   'market_cap': 2133011836,
#   'market_cap_rank': 719,
#   'total_volume': 127855215,
#   'circulating_supply': 23581288.13380286,
#   'total_supply': 23581298.13450964,
#   'ath': 137.3,
#   'atl': 80.3,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'huobi-token',
#   'symbol': 'ht',
#   'name': 'Huobi',
#   'current_price': 19.49,
#   'market_cap': 2132191393,
#   'market_cap_rank': 729,
#   'total_volume': 13272758,
#   'circulating_supply': 109395689.2524321,
#   'total_supply': 109395689.2524321,
#   'ath': 2918.58,
#   'atl': 12.64,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'planet-ix',
#   'symbol': 'aix',
#   'name': 'Planet IX',
#   'current_price': 11.71,
#   'market_cap': 2125746790,
#   'market_cap_rank': 717,
#   'total_volume': 9798966,
#   'circulating_supply': 181600000.0,
#   'total_supply': 306000000.0,
#   'ath': 40.83,
#   'atl': 10.04,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'global-commercial-business',
#   'symbol': 'gcb',
#   'name': 'Global Commercial Business',
#   'current_price': 1.77,
#   'market_cap': 2125347527,
#   'market_cap_rank': 722,
#   'total_volume': 24301,
#   'circulating_supply': 1201844746.3739874,
#   'total_supply': 1201844746.3739874,
#   'ath': 28.6,
#   'atl': 1.75,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'hippo-protocol',
#   'symbol': 'hp',
#   'name': 'Hippo Protocol',
#   'current_price': 1.64,
#   'market_cap': 2117701835,
#   'market_cap_rank': 724,
#   'total_volume': 29617463,
#   'circulating_supply': 1292020058.457474,
#   'total_supply': 1293318654.200507,
#   'ath': 5.83,
#   'atl': 1.52,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'cartesi',
#   'symbol': 'ctsi',
#   'name': 'Cartesi',
#   'current_price': 2.34,
#   'market_cap': 2115204280,
#   'market_cap_rank': 726,
#   'total_volume': 152335014,
#   'circulating_supply': 903782031.7900137,
#   'total_supply': 1000000000.0,
#   'ath': 127.9,
#   'atl': 2.01,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'metal',
#   'symbol': 'mtl',
#   'name': 'Metal DAO',
#   'current_price': 23.68,
#   'market_cap': 2112065341,
#   'market_cap_rank': 725,
#   'total_volume': 76100417,
#   'circulating_supply': 89153205.0,
#   'total_supply': 89153205.0,
#   'ath': 1160.85,
#   'atl': 8.85,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'midas-mapollo',
#   'symbol': 'mapollo',
#   'name': 'Midas mAPOLLO',
#   'current_price': 97.02,
#   'market_cap': 2099346151,
#   'market_cap_rank': 727,
#   'total_volume': 96.08,
#   'circulating_supply': 21642678.94816491,
#   'total_supply': 21642678.94816491,
#   'ath': 98.58,
#   'atl': 89.62,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'chainflip',
#   'symbol': 'flip',
#   'name': 'Chainflip',
#   'current_price': 31.72,
#   'market_cap': 2096832519,
#   'market_cap_rank': 728,
#   'total_volume': 21159756,
#   'circulating_supply': 66265694.6831149,
#   'total_supply': 92921608.76730537,
#   'ath': 784.36,
#   'atl': 26.5,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'circle-xstock',
#   'symbol': 'crclx',
#   'name': 'Circle xStock',
#   'current_price': 5298.46,
#   'market_cap': 2094717187,
#   'market_cap_rank': 730,
#   'total_volume': 1669363234,
#   'circulating_supply': 395353.7217778788,
#   'total_supply': 2124985.48356901,
#   'ath': 22140,
#   'atl': 4337.07,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'usual',
#   'symbol': 'usual',
#   'name': 'Usual',
#   'current_price': 1.28,
#   'market_cap': 2092528078,
#   'market_cap_rank': 732,
#   'total_volume': 256374691,
#   'circulating_supply': 1638804642.6200483,
#   'total_supply': 1642723230.364071,
#   'ath': 137.03,
#   'atl': 0.931235,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'invesco-qqq-etf-ondo-tokenized-etf',
#   'symbol': 'qqqon',
#   'name': 'Invesco QQQ ETF (Ondo Tokenized ETF)',
#   'current_price': 55499,
#   'market_cap': 2090771882,
#   'market_cap_rank': 731,
#   'total_volume': 101817452,
#   'circulating_supply': 37675.77986243896,
#   'total_supply': 37675.77986243896,
#   'ath': 58660,
#   'atl': 49290,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'sats-ordinals',
#   'symbol': 'sats',
#   'name': 'SATS (Ordinals)',
#   'current_price': 9.95057e-07,
#   'market_cap': 2089369664,
#   'market_cap_rank': 733,
#   'total_volume': 235626115,
#   'circulating_supply': 2100000000000000.0,
#   'total_supply': 2100000000000000.0,
#   'ath': 7.675e-05,
#   'atl': 2.63579e-07,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'dia-data',
#   'symbol': 'dia',
#   'name': 'DIA',
#   'current_price': 17.42,
#   'market_cap': 2083983498,
#   'market_cap_rank': 737,
#   'total_volume': 196535571,
#   'circulating_supply': 119676104.0,
#   'total_supply': 168817248.0,
#   'ath': 423.11,
#   'atl': 15.34,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'nockchain',
#   'symbol': 'nock',
#   'name': 'Nockchain',
#   'current_price': 1.076,
#   'market_cap': 2080812064,
#   'market_cap_rank': 734,
#   'total_volume': 18625505,
#   'circulating_supply': 1933459456.0,
#   'total_supply': 4294967296.0,
#   'ath': 18.5,
#   'atl': 0.617629,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'og-fan-token',
#   'symbol': 'og',
#   'name': 'OG Fan Token',
#   'current_price': 453.9,
#   'market_cap': 2080695242,
#   'market_cap_rank': 738,
#   'total_volume': 3041689811,
#   'circulating_supply': 4584551.0,
#   'total_supply': 5000000.0,
#   'ath': 2181.6,
#   'atl': 91.71,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'ao-computer',
#   'symbol': 'ao',
#   'name': 'ao Computer',
#   'current_price': 345.48,
#   'market_cap': 2077853745,
#   'market_cap_rank': 735,
#   'total_volume': 15340933,
#   'circulating_supply': 6015800.0,
#   'total_supply': 6015800.0,
#   'ath': 4281.57,
#   'atl': 303.95,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'pinksale',
#   'symbol': 'pinksale',
#   'name': 'PinkSale',
#   'current_price': 20740,
#   'market_cap': 2073962495,
#   'market_cap_rank': 736,
#   'total_volume': 660.79,
#   'circulating_supply': 100000.0,
#   'total_supply': 100000.0,
#   'ath': 44812,
#   'atl': 3523.92,
#   'last_updated_date': '2026-02-10'},
#  {'id': 'chromaway',
#   'symbol': 'chr',
#   'name': 'Chromia',
#   'current_price': 2.43,
#   'market_cap': 2076280195,
#   'market_cap_rank': 742,
#   'total_volume': 203943526,
#   'circulating_supply': 853631914.378197,
#   'total_supply': 853631914.378197,
#   'ath': 110.77,
#   'atl': 0.659872,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'limitless-3',
#   'symbol': 'lmts',
#   'name': 'Limitless',
#   'current_price': 15.72,
#   'market_cap': 2068240501,
#   'market_cap_rank': 740,
#   'total_volume': 177230308,
#   'circulating_supply': 131598680.0,
#   'total_supply': 1000000000.0,
#   'ath': 60.89,
#   'atl': 4.4,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'aevo-exchange',
#   'symbol': 'aevo',
#   'name': 'Aevo',
#   'current_price': 2.26,
#   'market_cap': 2066514660,
#   'market_cap_rank': 741,
#   'total_volume': 552608826,
#   'circulating_supply': 916162381.6383989,
#   'total_supply': 1000000000.0,
#   'ath': 313.13,
#   'atl': 2.25,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'konnect',
#   'symbol': 'kct',
#   'name': 'Konnect',
#   'current_price': 0.280151,
#   'market_cap': 2065906575,
#   'market_cap_rank': 739,
#   'total_volume': 39600865,
#   'circulating_supply': 7375000040.0,
#   'total_supply': 10000000000.0,
#   'ath': 12.12,
#   'atl': 0.00123459,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'autonomi',
#   'symbol': 'ant',
#   'name': 'Autonomi',
#   'current_price': 6.88,
#   'market_cap': 2061342939,
#   'market_cap_rank': 745,
#   'total_volume': 30584604,
#   'circulating_supply': 299605073.6725304,
#   'total_supply': 1200000000.0,
#   'ath': 28.84,
#   'atl': 0.253538,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'particle-network',
#   'symbol': 'parti',
#   'name': 'Particle Network',
#   'current_price': 8.84,
#   'market_cap': 2060786189,
#   'market_cap_rank': 746,
#   'total_volume': 683813440,
#   'circulating_supply': 233000000.0,
#   'total_supply': 1000000000.0,
#   'ath': 35.76,
#   'atl': 3.86,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'metronome-synth-usd',
#   'symbol': 'msusd',
#   'name': 'Metronome Synth USD',
#   'current_price': 90.21,
#   'market_cap': 2060595842,
#   'market_cap_rank': 743,
#   'total_volume': 1200000889,
#   'circulating_supply': 22840511.74697052,
#   'total_supply': 22840511.74697052,
#   'ath': 301.63,
#   'atl': 37.98,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'dkargo',
#   'symbol': 'dka',
#   'name': 'dKargo',
#   'current_price': 0.411764,
#   'market_cap': 2058686539,
#   'market_cap_rank': 744,
#   'total_volume': 42533286,
#   'circulating_supply': 5000000000.0,
#   'total_supply': 5000000000.0,
#   'ath': 51.01,
#   'atl': 0.382807,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'sanctum-2',
#   'symbol': 'cloud',
#   'name': 'Cloud',
#   'current_price': 3.82,
#   'market_cap': 2043781261,
#   'market_cap_rank': 747,
#   'total_volume': 125905935,
#   'circulating_supply': 535679783.0,
#   'total_supply': 1000000000.0,
#   'ath': 52.79,
#   'atl': 3.48,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'definitive',
#   'symbol': 'edge',
#   'name': 'Definitive',
#   'current_price': 10.01,
#   'market_cap': 2035724558,
#   'market_cap_rank': 748,
#   'total_volume': 133430483,
#   'circulating_supply': 203024680.07272866,
#   'total_supply': 1000000000.0,
#   'ath': 75.6,
#   'atl': 2.34,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'bifrost',
#   'symbol': 'bfc',
#   'name': 'Bifrost',
#   'current_price': 1.46,
#   'market_cap': 2027817749,
#   'market_cap_rank': 749,
#   'total_volume': 55800109,
#   'circulating_supply': 1391269925.662982,
#   'total_supply': 2368584074.0,
#   'ath': 57.84,
#   'atl': 1.19,
#   'last_updated_date': '2026-02-11'},
#  {'id': 'smooth-love-potion',
#   'symbol': 'slp',
#   'name': 'Smooth Love Potion',
#   'current_price': 0.055432,
#   'market_cap': 2018931743,
#   'market_cap_rank': 752,
#   'total_volume': 187835239,
#   'circulating_supply': 36431755800.0,
#   'total_supply': 36431755800.0,
#   'ath': 29.77,
#   'atl': 0.04963607,
#   'last_updated_date': '2026-02-11'}]

# %%
import pandas as pd

df_cryptocurrency = pd.DataFrame(cryptocurrency)

display(df_cryptocurrency)
# Out:
#                      id symbol                name  current_price  \
# 0               bitcoin    btc             Bitcoin   6.041232e+06
# 1              ethereum    eth            Ethereum   1.760260e+05
# 2                tether   usdt              Tether   9.062000e+01
# 3                ripple    xrp                 XRP   1.236100e+02
# 4           binancecoin    bnb                 BNB   5.346200e+04
# ..                  ...    ...                 ...            ...
# 745              dkargo    dka              dKargo   4.117640e-01
# 746           sanctum-2  cloud               Cloud   3.820000e+00
# 747          definitive   edge          Definitive   1.001000e+01
# 748             bifrost    bfc             Bifrost   1.460000e+00
# 749  smooth-love-potion    slp  Smooth Love Potion   5.543200e-02
#
#           market_cap  market_cap_rank  total_volume  circulating_supply  \
# 0    120766082622498                1  4.147390e+12        1.998752e+07
# 1     21248040341250                2  1.571438e+12        1.206926e+08
# 2     16711108679531                3  6.394472e+12        1.843940e+11
# 3      7530697117919                4  2.197907e+11        6.091732e+10
# 4      7292089686813                5  1.182194e+11        1.363595e+08
# ..               ...              ...           ...                 ...
# 745       2058686539              744  4.253329e+07        5.000000e+09
# 746       2043781261              747  1.259059e+08        5.356798e+08
# 747       2035724558              748  1.334305e+08        2.030247e+08
# 748       2027817749              749  5.580011e+07        1.391270e+09
# 749       2018931743              752  1.878352e+08        3.643176e+10
#
#      total_supply          ath          atl last_updated_date
# 0    1.998752e+07  11187013.00  3993.420000        2026-02-11
# 1    1.206926e+08    431946.00    28.130000        2026-02-11
# 2    1.898610e+11       105.52    36.860000        2026-02-11
# 3    9.998572e+10       313.99     0.159343        2026-02-11
# 4    1.363595e+08    121422.00     2.580000        2026-02-11
# ..            ...          ...          ...               ...
# 745  5.000000e+09        51.01     0.382807        2026-02-11
# 746  1.000000e+09        52.79     3.480000        2026-02-11
# 747  1.000000e+09        75.60     2.340000        2026-02-11
# 748  2.368584e+09        57.84     1.190000        2026-02-11
# 749  3.643176e+10        29.77     0.049636        2026-02-11
#
# [750 rows x 12 columns]

# %%
top_3_coin_ids = df_cryptocurrency.sort_values(by='market_cap_rank').head(3)['id'].tolist()
print(top_3_coin_ids)
# Out:
# ['bitcoin', 'ethereum', 'tether']

# %%
all_historical_data = []
import time
import requests

for coin_id in top_3_coin_ids:
    url = f"https://api.coingecko.com/api/v3/coins/{coin_id}/market_chart?vs_currency=inr&days=365"
    response = requests.get(url)
    if response.status_code == 200:
        data = response.json()
        all_historical_data.append(data)
    else:
        print(f"Failed to fetch historical data for {coin_id}. Status code: {response.status_code}")
    time.sleep(10)

print(f"Collected historical data for {len(all_historical_data)} cryptocurrencies.")
# Out:
# Failed to fetch historical data for bitcoin. Status code: 429
# Failed to fetch historical data for ethereum. Status code: 429
# Collected historical data for 1 cryptocurrencies.

# %%
historical_prices_list = []

for i, coin_data in enumerate(all_historical_data):
    coin_id = top_3_coin_ids[i]

    # Check if 'prices' key exists in coin_data
    if 'prices' in coin_data:
        # Extract price entries from the current coin's historical data
        prices = coin_data['prices']

        for price_record in prices:
            timestamp = price_record[0]
            price_inr = price_record[1]

            # Convert timestamp (milliseconds) to datetime object and format to YYYY-MM-DD
            date = pd.to_datetime(timestamp, unit='ms').strftime('%Y-%m-%d')

            # Create a dictionary for the current record
            record = {
                'coin_id': coin_id,
                'date': date,
                'price_inr': price_inr
            }
            historical_prices_list.append(record)
    else:
        print(f"Warning: 'prices' data not found for coin_id: {coin_id}. Skipping this coin.")

print(f"Processed {len(historical_prices_list)} historical price records.")
# Out:
# Processed 366 historical price records.

# %%
import pandas as pd
pd.set_option('display.float_format', '{:.2f}'.format)

df_historical_prices = pd.DataFrame(historical_prices_list)
display(df_historical_prices)
# Out:
#      coin_id        date  price_inr
# 0    bitcoin  2025-02-12      86.77
# 1    bitcoin  2025-02-13      86.98
# 2    bitcoin  2025-02-14      86.75
# 3    bitcoin  2025-02-15      86.67
# 4    bitcoin  2025-02-16      86.64
# ..       ...         ...        ...
# 361  bitcoin  2026-02-08      90.54
# 362  bitcoin  2026-02-09      90.52
# 363  bitcoin  2026-02-10      90.74
# 364  bitcoin  2026-02-11      90.54
# 365  bitcoin  2026-02-11      90.63
#
# [366 rows x 3 columns]

# %%
import pandas as pd

# Load the dataset from the GitHub URL
url = "https://raw.githubusercontent.com/datasets/oil-prices/main/data/wti-daily.csv"
df_oil = pd.read_csv(url)

# Display the original DataFrame info and head to inspect it
print("Original DataFrame Info:")
df_oil.info()
print("\nOriginal DataFrame Head:")
display(df_oil)
# Out:
# Original DataFrame Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10090 entries, 0 to 10089
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Date    10090 non-null  object
#  1   Price   10090 non-null  float64
# dtypes: float64(1), object(1)
# memory usage: 157.8+ KB
#
# Original DataFrame Head:
#              Date  Price
# 0      1986-01-02  25.56
# 1      1986-01-03  26.00
# 2      1986-01-06  26.53
# 3      1986-01-07  25.85
# 4      1986-01-08  25.87
# ...           ...    ...
# 10085  2026-01-27  62.04
# 10086  2026-01-28  62.75
# 10087  2026-01-29  64.77
# 10088  2026-01-30  64.50
# 10089  2026-02-02  61.60
#
# [10090 rows x 2 columns]

# %%
df_oil['Date'] = pd.to_datetime(df_oil['Date'])

start_date = '2020-01-01'
end_date = '2026-02-05'

# Filter df_oil in place
df_oil = df_oil[(df_oil['Date'] >= start_date) & (df_oil['Date'] <= end_date)]

print(f"Filtered df_oil DataFrame shape: {df_oil.shape}")
display(df_oil)
# Out:
# Filtered df_oil DataFrame shape: (1521, 2)
#             Date  Price
# 8569  2020-01-02  61.17
# 8570  2020-01-03  63.00
# 8571  2020-01-06  63.27
# 8572  2020-01-07  62.70
# 8573  2020-01-08  59.65
# ...          ...    ...
# 10085 2026-01-27  62.04
# 10086 2026-01-28  62.75
# 10087 2026-01-29  64.77
# 10088 2026-01-30  64.50
# 10089 2026-02-02  61.60
#
# [1521 rows x 2 columns]

# %%
# !pip install yfinance
# Out:
# Requirement already satisfied: yfinance in /usr/local/lib/python3.12/dist-packages (0.2.66)
# Requirement already satisfied: pandas>=1.3.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.2.2)
# Requirement already satisfied: numpy>=1.16.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.0.2)
# Requirement already satisfied: requests>=2.31 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.32.4)
# Requirement already satisfied: multitasking>=0.0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.0.12)
# Requirement already satisfied: platformdirs>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.5.1)
# Requirement already satisfied: pytz>=2022.5 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2025.2)
# Requirement already satisfied: frozendict>=2.3.4 in /usr/local/lib/python3.12/dist-packages (from yfinance) (2.4.7)
# Requirement already satisfied: peewee>=3.16.2 in /usr/local/lib/python3.12/dist-packages (from yfinance) (3.19.0)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /usr/local/lib/python3.12/dist-packages (from yfinance) (4.13.5)
# Requirement already satisfied: curl_cffi>=0.7 in /usr/local/lib/python3.12/dist-packages (from yfinance) (0.14.0)
# Requirement already satisfied: protobuf>=3.19.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (5.29.6)
# Requirement already satisfied: websockets>=13.0 in /usr/local/lib/python3.12/dist-packages (from yfinance) (15.0.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (2.8.3)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.12/dist-packages (from beautifulsoup4>=4.11.1->yfinance) (4.15.0)
# Requirement already satisfied: cffi>=1.12.0 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2.0.0)
# Requirement already satisfied: certifi>=2024.2.2 in /usr/local/lib/python3.12/dist-packages (from curl_cffi>=0.7->yfinance) (2026.1.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2.9.0.post0)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas>=1.3.0->yfinance) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.31->yfinance) (2.5.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.12/dist-packages (from cffi>=1.12.0->curl_cffi>=0.7->yfinance) (3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas>=1.3.0->yfinance) (1.17.0)

# %%
import yfinance as yf
import pandas as pd

tickers = ["^GSPC", "^IXIC", "^NSEI"]
start_date = "2020-01-01"
end_date = "2026-02-05"

df_stocks = yf.download(tickers, start=start_date, end=end_date)

print(f"Downloaded stock data for {len(tickers)} tickers from {start_date} to {end_date}.")
display(df_stocks)
# Out:
# /tmp/ipython-input-301512804.py:8: FutureWarning: YF.download() has changed argument auto_adjust default to True
#   df_stocks = yf.download(tickers, start=start_date, end=end_date)
# [*********************100%***********************]  3 of 3 completed
# Downloaded stock data for 3 tickers from 2020-01-01 to 2026-02-05.
# Price        Close                      High                       Low  \
# Ticker       ^GSPC    ^IXIC    ^NSEI   ^GSPC    ^IXIC    ^NSEI   ^GSPC
# Date
# 2020-01-01     NaN      NaN 12182.50     NaN      NaN 12222.20     NaN
# 2020-01-02 3257.85  9092.19 12282.20 3258.14  9093.43 12289.90 3235.53
# 2020-01-03 3234.85  9020.77 12226.65 3246.15  9065.76 12265.60 3222.34
# 2020-01-06 3246.28  9071.47 11993.05 3246.84  9072.41 12179.10 3214.64
# 2020-01-07 3237.18  9068.58 12052.95 3244.91  9091.93 12152.15 3232.43
# ...            ...      ...      ...     ...      ...      ...     ...
# 2026-01-29 6969.01 23685.12 25418.90 6992.84 23840.55 25458.15 6870.80
# 2026-01-30 6939.03 23461.82 25320.65 6964.09 23662.25 25370.70 6893.48
# 2026-02-02 6976.44 23592.11 25088.40 6991.92 23686.83 25108.10 6914.34
# 2026-02-03 6917.81 23255.19 25727.55 6993.08 23691.60 26341.20 6862.05
# 2026-02-04 6882.72 22904.58 25776.00 6936.09 23270.07 25818.55 6838.80
#
# Price                           Open                          Volume  \
# Ticker        ^IXIC    ^NSEI   ^GSPC    ^IXIC    ^NSEI         ^GSPC
# Date
# 2020-01-01      NaN 12165.30     NaN      NaN 12202.15           NaN
# 2020-01-02  9010.89 12195.25 3244.67  9039.46 12198.55 3459930000.00
# 2020-01-03  8976.43 12191.35 3226.36  8976.43 12261.10 3484700000.00
# 2020-01-06  8943.50 11974.20 3217.55  8943.50 12170.60 3702460000.00
# 2020-01-07  9042.55 12005.35 3241.86  9076.64 12079.10 3435910000.00
# ...             ...      ...     ...      ...      ...           ...
# 2026-01-29 23232.78 25159.80 6977.74 23830.92 25345.00 6877780000.00
# 2026-01-30 23351.55 25213.65 6947.27 23578.96 25247.55 6697340000.00
# 2026-02-02 23356.40 24679.40 6916.64 23370.54 24796.50 5772050000.00
# 2026-02-03 23027.21 25641.30 6985.45 23667.44 26308.05 7017660000.00
# 2026-02-04 22684.51 25563.95 6924.50 23217.02 25675.05 7475750000.00
#
# Price
# Ticker              ^IXIC     ^NSEI
# Date
# 2020-01-01            NaN 304100.00
# 2020-01-02  2862700000.00 407700.00
# 2020-01-03  2586520000.00 428800.00
# 2020-01-06  2810450000.00 396500.00
# 2020-01-07  2381740000.00 447800.00
# ...                   ...       ...
# 2026-01-29  8782210000.00 582400.00
# 2026-01-30  9255930000.00 508400.00
# 2026-02-02  8882530000.00 449200.00
# 2026-02-03 10306320000.00 637300.00
# 2026-02-04 10862000000.00 429800.00
#
# [1581 rows x 15 columns]

# %%
print("Missing values before handling:")
display(df_stocks.isnull().sum())
# Out:
# Missing values before handling:
# Price   Ticker
# Close   ^GSPC     50
#         ^IXIC     50
#         ^NSEI     72
# High    ^GSPC     50
#         ^IXIC     50
#         ^NSEI     72
# Low     ^GSPC     50
#         ^IXIC     50
#         ^NSEI     72
# Open    ^GSPC     50
#         ^IXIC     50
#         ^NSEI     72
# Volume  ^GSPC     50
#         ^IXIC     50
#         ^NSEI     72
# dtype: int64

# %%
# Forward-fill missing values in df_stocks
df_stocks_filled = df_stocks.ffill()

# Reset the index and rename columns for easier access
df_stocks_filled = df_stocks_filled.stack(level=1).reset_index()
df_stocks_filled.columns = ['Date', 'Ticker', 'Price_Close', 'Price_High', 'Price_Low', 'Price_Open', 'Price_Volume']

print("Missing values after handling:")
display(df_stocks_filled.isnull().sum())

display(df_stocks_filled.head())
# Out:
# Missing values after handling:
# /tmp/ipython-input-2246665882.py:5: FutureWarning: The previous implementation of stack is deprecated and will be removed in a future version of pandas. See the What's New notes for pandas 2.1.0 for details. Specify future_stack=True to adopt the new implementation and silence this warning.
#   df_stocks_filled = df_stocks_filled.stack(level=1).reset_index()
# Date            0
# Ticker          0
# Price_Close     0
# Price_High      0
# Price_Low       0
# Price_Open      0
# Price_Volume    0
# dtype: int64
#         Date Ticker  Price_Close  Price_High  Price_Low  Price_Open  \
# 0 2020-01-01  ^NSEI     12182.50    12222.20   12165.30    12202.15
# 1 2020-01-02  ^GSPC      3257.85     3258.14    3235.53     3244.67
# 2 2020-01-02  ^IXIC      9092.19     9093.43    9010.89     9039.46
# 3 2020-01-02  ^NSEI     12282.20    12289.90   12195.25    12198.55
# 4 2020-01-03  ^GSPC      3234.85     3246.15    3222.34     3226.36
#
#    Price_Volume
# 0     304100.00
# 1 3459930000.00
# 2 2862700000.00
# 3     407700.00
# 4 3484700000.00

# %%
df_stocks = df_stocks_filled
print("df_stocks now contains the cleaned and processed data:")
display(df_stocks)
# Out:
# df_stocks now contains the cleaned and processed data:
#            Date Ticker  Price_Close  Price_High  Price_Low  Price_Open  \
# 0    2020-01-01  ^NSEI     12182.50    12222.20   12165.30    12202.15
# 1    2020-01-02  ^GSPC      3257.85     3258.14    3235.53     3244.67
# 2    2020-01-02  ^IXIC      9092.19     9093.43    9010.89     9039.46
# 3    2020-01-02  ^NSEI     12282.20    12289.90   12195.25    12198.55
# 4    2020-01-03  ^GSPC      3234.85     3246.15    3222.34     3226.36
# ...         ...    ...          ...         ...        ...         ...
# 4736 2026-02-03  ^IXIC     23255.19    23691.60   23027.21    23667.44
# 4737 2026-02-03  ^NSEI     25727.55    26341.20   25641.30    26308.05
# 4738 2026-02-04  ^GSPC      6882.72     6936.09    6838.80     6924.50
# 4739 2026-02-04  ^IXIC     22904.58    23270.07   22684.51    23217.02
# 4740 2026-02-04  ^NSEI     25776.00    25818.55   25563.95    25675.05
#
#        Price_Volume
# 0         304100.00
# 1     3459930000.00
# 2     2862700000.00
# 3         407700.00
# 4     3484700000.00
# ...             ...
# 4736 10306320000.00
# 4737      637300.00
# 4738  7475750000.00
# 4739 10862000000.00
# 4740      429800.00
#
# [4741 rows x 7 columns]

# %%
import sqlite3

conn = sqlite3.connect("mydatabase.db")
cursor = conn.cursor()

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')
cursor = conn.cursor()

# Drop the table if it already exists to ensure the schema is updated
cursor.execute('DROP TABLE IF EXISTS cryptocurrency;')

# Create the cryptocurrency table with the specified schema
cursor.execute('''
CREATE TABLE cryptocurrency (
    id TEXT PRIMARY KEY,
    symbol TEXT,
    name TEXT,
    current_price REAL,
    market_cap INTEGER,
    market_cap_rank INTEGER,
    total_volume INTEGER,
    circulating_supply REAL,
    total_supply REAL,
    ath REAL,
    atl REAL,
    date TEXT
);
''')

# Prepare data for insertion by renaming the 'last_updated_date' column to 'date'
cryptocurrency_data_for_sql = df_cryptocurrency.rename(columns={'last_updated_date': 'date'})

# Insert data into the cryptocurrency table
# Using executemany for better performance and to handle potential DataFrame NaNs
# which should become NULL in SQL

# Ensure all columns exist, fill missing with None for SQL insertion
columns_to_insert = [
    'id', 'symbol', 'name', 'current_price', 'market_cap',
    'market_cap_rank', 'total_volume', 'circulating_supply',
    'total_supply', 'ath', 'atl', 'date'
]

# Replace NaN with None for SQLite compatibility
records = cryptocurrency_data_for_sql[columns_to_insert].where(pd.notnull(cryptocurrency_data_for_sql[columns_to_insert]), None).values.tolist()

insert_query = '''
INSERT OR REPLACE INTO cryptocurrency (
    id, symbol, name, current_price, market_cap, market_cap_rank,
    total_volume, circulating_supply, total_supply, ath, atl, date
)
VALUES (?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?, ?)
'''

cursor.executemany(insert_query, records)

conn.commit()
conn.close()
print("df_cryptocurrency successfully pushed to the 'cryptocurrency' table.")
# Out:
# df_cryptocurrency successfully pushed to the 'cryptocurrency' table.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')
cursor = conn.cursor()

# Drop the table if it already exists to ensure the schema is updated
cursor.execute('DROP TABLE IF EXISTS historical_prices;')

# Create the historical_prices table with the specified schema
cursor.execute('''
CREATE TABLE historical_prices (
    coin_id TEXT,
    date TEXT,
    price_inr REAL,
    PRIMARY KEY (coin_id, date),
    FOREIGN KEY (coin_id) REFERENCES cryptocurrency(id)
);
''')

# Prepare data for insertion
# Ensure all columns exist, fill missing with None for SQL insertion
columns_to_insert = ['coin_id', 'date', 'price_inr']

# Replace NaN with None for SQLite compatibility
records = df_historical_prices[columns_to_insert].where(pd.notnull(df_historical_prices[columns_to_insert]), None).values.tolist()

insert_query = '''
INSERT OR REPLACE INTO historical_prices (
    coin_id, date, price_inr
)
VALUES (?, ?, ?)
'''

cursor.executemany(insert_query, records)

conn.commit()
conn.close()
print("df_historical_prices successfully pushed to the 'historical_prices' table.")
# Out:
# df_historical_prices successfully pushed to the 'historical_prices' table.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')
cursor = conn.cursor()

# Drop the table if it already exists to ensure the schema is updated
cursor.execute('DROP TABLE IF EXISTS oil_prices;')

# Create the oil_prices table with the specified schema
cursor.execute('''
CREATE TABLE oil_prices (
    date TEXT PRIMARY KEY,
    price_usd REAL
);
''')

# Prepare data for insertion: rename 'Price' to 'price_usd' and ensure 'Date' is text for PRIMARY KEY
df_oil_for_sql = df_oil.copy()
df_oil_for_sql['date'] = df_oil_for_sql['Date'].dt.strftime('%Y-%m-%d')
df_oil_for_sql = df_oil_for_sql.rename(columns={'Price': 'price_usd'})

# Ensure only the necessary columns are selected and handle potential NaNs
columns_to_insert = ['date', 'price_usd']
records = df_oil_for_sql[columns_to_insert].where(pd.notnull(df_oil_for_sql[columns_to_insert]), None).values.tolist()

insert_query = '''
INSERT OR REPLACE INTO oil_prices (
    date, price_usd
)
VALUES (?, ?)
'''

cursor.executemany(insert_query, records)

conn.commit()
conn.close()
print("df_oil successfully pushed to the 'oil_prices' table.")
# Out:
# df_oil successfully pushed to the 'oil_prices' table.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')
cursor = conn.cursor()

# Drop the table if it already exists to ensure the schema is updated
cursor.execute('DROP TABLE IF EXISTS stock_prices;')

# Create the stock_prices table with the specified schema
cursor.execute('''
CREATE TABLE stock_prices (
    date TEXT,
    open REAL,
    high REAL,
    low REAL,
    close REAL,
    volume INTEGER,
    ticker TEXT,
    PRIMARY KEY (date, ticker)
);
''')

# Prepare data for insertion: rename DataFrame columns to match SQL table columns
df_stocks_for_sql = df_stocks.copy()
df_stocks_for_sql['date'] = df_stocks_for_sql['Date'].dt.strftime('%Y-%m-%d')
df_stocks_for_sql = df_stocks_for_sql.rename(columns={
    'Price_Open': 'open',
    'Price_High': 'high',
    'Price_Low': 'low',
    'Price_Close': 'close',
    'Price_Volume': 'volume',
    'Ticker': 'ticker'
})

# Ensure only the necessary columns are selected and handle potential NaNs
columns_to_insert = ['date', 'open', 'high', 'low', 'close', 'volume', 'ticker']
records = df_stocks_for_sql[columns_to_insert].where(pd.notnull(df_stocks_for_sql[columns_to_insert]), None).values.tolist()

insert_query = '''
INSERT OR REPLACE INTO stock_prices (
    date, open, high, low, close, volume, ticker
)
VALUES (?, ?, ?, ?, ?, ?, ?)
'''

cursor.executemany(insert_query, records)

conn.commit()
conn.close()
print("df_stocks successfully pushed to the 'stock_prices' table.")
# Out:
# df_stocks successfully pushed to the 'stock_prices' table.

# %%
import sqlite3

conn = sqlite3.connect('mydatabase.db')
cursor = conn.cursor()

cursor.execute("SELECT name FROM sqlite_master WHERE type='table';")
tables = cursor.fetchall()

print("Tables in the database:")
if tables:
    for table in tables:
        print(table[0])
else:
    print("No tables found in the database.")

conn.close()
# Out:
# Tables in the database:
# cryptocurrency
# historical_prices
# oil_prices
# stock_prices

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query the stock_prices table
oil_prices_sql = pd.read_sql_query("SELECT * FROM oil_prices", conn)

conn.close()

print("Contents of the 'oil_prices' table:")
display(oil_prices_sql)
# Out:
# Contents of the 'oil_prices' table:
#             date  price_usd
# 0     2020-01-02      61.17
# 1     2020-01-03      63.00
# 2     2020-01-06      63.27
# 3     2020-01-07      62.70
# 4     2020-01-08      59.65
# ...          ...        ...
# 1516  2026-01-27      62.04
# 1517  2026-01-28      62.75
# 1518  2026-01-29      64.77
# 1519  2026-01-30      64.50
# 1520  2026-02-02      61.60
#
# [1521 rows x 2 columns]

# %%
#top 3 cryptocurrencies by market cap

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')
cursor = conn.cursor()

# Query to find the top 3 cryptocurrencies by market cap
query = """
SELECT id, name, market_cap, market_cap_rank
FROM cryptocurrency
ORDER BY market_cap_rank ASC
LIMIT 3;
"""

top_3_cryptos = pd.read_sql_query(query, conn)

conn.close()

print("Top 3 Cryptocurrencies by Market Cap:")
display(top_3_cryptos)
# Out:
# Top 3 Cryptocurrencies by Market Cap:
#          id      name       market_cap  market_cap_rank
# 0   bitcoin   Bitcoin  120766082622498                1
# 1  ethereum  Ethereum   21248040341250                2
# 2    tether    Tether   16711108679531                3

# %% [markdown]
# coins where circulating_supply > 90% of total_supply

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find coins where circulating_supply > 90% of total_supply
query = """
SELECT id, name, circulating_supply, total_supply
FROM cryptocurrency
WHERE (circulating_supply * 1.0 / total_supply) > 0.9 AND total_supply IS NOT NULL AND total_supply > 0;
"""

high_circulating_supply_coins = pd.read_sql_query(query, conn)

conn.close()

print("Cryptocurrencies with circulating supply > 90% of total supply:")
display(high_circulating_supply_coins)
# Out:
# Cryptocurrencies with circulating supply > 90% of total supply:
#                       id                 name  circulating_supply  \
# 0                bitcoin              Bitcoin         19987525.00
# 1               ethereum             Ethereum        120692569.86
# 2                 tether               Tether     184394018025.36
# 3            binancecoin                  BNB        136359497.93
# 4               usd-coin                 USDC      73269292074.76
# ..                   ...                  ...                 ...
# 394            chromaway              Chromia        853631914.38
# 395        aevo-exchange                 Aevo        916162381.64
# 396  metronome-synth-usd  Metronome Synth USD         22840511.75
# 397               dkargo               dKargo       5000000000.00
# 398   smooth-love-potion   Smooth Love Potion      36431755800.00
#
#        total_supply
# 0       19987525.00
# 1      120692569.86
# 2   189860955264.53
# 3      136359497.93
# 4    73277201114.09
# ..              ...
# 394    853631914.38
# 395   1000000000.00
# 396     22840511.75
# 397   5000000000.00
# 398  36431755800.00
#
# [399 rows x 4 columns]

# %% [markdown]
# coins within 10% of their all-time-high (ATH)

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find coins within 10% of their all-time-high (ATH)
query = """
SELECT id, name, current_price, ath
FROM cryptocurrency
WHERE current_price >= (ath * 0.9) AND ath IS NOT NULL;
"""

coins_near_ath = pd.read_sql_query(query, conn)

conn.close()

print("Cryptocurrencies within 10% of their All-Time-High (ATH):")
display(coins_near_ath)
# Out:
# Cryptocurrencies within 10% of their All-Time-High (ATH):
#                                     id                                  name  \
# 0                                 usds                                  USDS
# 1                          ethena-usde                           Ethena USDe
# 2                            usd1-wlfi                                  USD1
# 3                                  dai                                   Dai
# 4                           paypal-usd                            PayPal USD
# ..                                 ...                                   ...
# 94                      electronic-usd                        Electronic USD
# 95                      mimbogamegroup                        MimboGameGroup
# 96                       gyroscope-gyd                         Gyroscope GYD
# 97                       midas-mapollo                         Midas mAPOLLO
# 98  invesco-qqq-etf-ondo-tokenized-etf  Invesco QQQ ETF (Ondo Tokenized ETF)
#
#     current_price      ath
# 0           90.66    92.23
# 1           90.56    92.91
# 2           90.61    92.17
# 3           90.64    92.29
# 4           90.63    92.20
# ..            ...      ...
# 94          90.61    94.57
# 95           0.27     0.27
# 96          90.99    93.94
# 97          97.02    98.58
# 98       55499.00 58660.00
#
# [99 rows x 4 columns]

# %% [markdown]
# Average market cap rank of coins with total volume above $1 Billion(100crore.inr)

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find the average market cap rank of coins with volume above $1B
query = """
SELECT AVG(market_cap_rank) as average_market_cap_rank
FROM cryptocurrency
WHERE total_volume > 1000000000;
"""

average_rank_high_volume = pd.read_sql_query(query, conn)

conn.close()

print("Average market cap rank of coins with total volume above $1 Billion:")
display(average_rank_high_volume)
# Out:
# Average market cap rank of coins with total volume above $1 Billion:
#    average_market_cap_rank
# 0                   212.51

# %% [markdown]
# #most recently updated coin

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find the most recently updated coin
query = """
SELECT id, name, date
FROM cryptocurrency
ORDER BY date DESC
LIMIT 1;
"""

most_recent_coin = pd.read_sql_query(query, conn)

conn.close()

print("Most recently updated coin:")
display(most_recent_coin)
# Out:
# Most recently updated coin:
#         id     name        date
# 0  bitcoin  Bitcoin  2026-02-11

# %% [markdown]
# The highest daily price of Bitcoin in the last 365 days.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find the highest daily price of Bitcoin in the last 365 days
query = """
SELECT coin_id, date, price_inr
FROM historical_prices
WHERE coin_id = 'bitcoin'
ORDER BY price_inr DESC
LIMIT 1;
"""

bitcoin_highest_price = pd.read_sql_query(query, conn)

conn.close()

print("Highest daily price of Bitcoin in the last 365 days:")
display(bitcoin_highest_price)
# Out:
# Highest daily price of Bitcoin in the last 365 days:
#    coin_id        date  price_inr
# 0  bitcoin  2026-01-29      91.91

# %% [markdown]
# The average daily price of Ethereum in the past 1 year.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find the average daily price of Ethereum in the past 1 year
query = """
SELECT AVG(price_inr) as average_ethereum_price
FROM historical_prices
WHERE coin_id = 'ethereum';
"""

ethereum_average_price = pd.read_sql_query(query, conn)

conn.close()

print("Average daily price of Ethereum in the past 1 year:")
display(ethereum_average_price)
# Out:
# Average daily price of Ethereum in the past 1 year:
#   average_ethereum_price
# 0                   None

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find the daily price trend of Bitcoin in January 2025
query = """
SELECT date, price_inr
FROM historical_prices
WHERE coin_id = 'bitcoin'
  AND date BETWEEN '2025-02-01' AND '2025-02-31'
ORDER BY date ASC;
"""

bitcoin_jan_2025_prices = pd.read_sql_query(query, conn)

conn.close()

print("Daily price trend of Bitcoin in January 2025:")
display(bitcoin_jan_2025_prices)
# Out:
# Daily price trend of Bitcoin in January 2025:
#           date  price_inr
# 0   2025-02-12      86.77
# 1   2025-02-13      86.98
# 2   2025-02-14      86.75
# 3   2025-02-15      86.67
# 4   2025-02-16      86.64
# 5   2025-02-17      86.65
# 6   2025-02-18      86.85
# 7   2025-02-19      86.83
# 8   2025-02-20      86.87
# 9   2025-02-21      86.48
# 10  2025-02-22      86.60
# 11  2025-02-23      86.61
# 12  2025-02-24      86.60
# 13  2025-02-25      86.66
# 14  2025-02-26      86.99
# 15  2025-02-27      87.05
# 16  2025-02-28      87.24

# %% [markdown]
# The coin with the highest average price over 1 year

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find the coin with the highest average price over 1 year
query = """
SELECT
    coin_id,
    AVG(price_inr) AS average_price
FROM
    historical_prices
GROUP BY
    coin_id
ORDER BY
    average_price DESC
LIMIT 1;
"""

highest_avg_price_coin = pd.read_sql_query(query, conn)

conn.close()

print("Coin with the highest average price over 1 year:")
display(highest_avg_price_coin)
# Out:
# Coin with the highest average price over 1 year:
#    coin_id  average_price
# 0  bitcoin          87.63

# %% [markdown]
#  % change in Bitcoin’s price between Sep 2025 and jan 2026.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Get the price for Bitcoin at the start of September 2025
query_start_price = """
SELECT price_inr
FROM historical_prices
WHERE coin_id = 'bitcoin' AND date >= '2025-09-01'
ORDER BY date ASC
LIMIT 1;
"""

start_price_df = pd.read_sql_query(query_start_price, conn)
start_price = start_price_df['price_inr'].iloc[0] if not start_price_df.empty else None

# Get the price for Bitcoin at the end of January 2026
query_end_price = """
SELECT price_inr
FROM historical_prices
WHERE coin_id = 'bitcoin' AND date <= '2026-01-31'
ORDER BY date DESC
LIMIT 1;
"""

end_price_df = pd.read_sql_query(query_end_price, conn)
end_price = end_price_df['price_inr'].iloc[0] if not end_price_df.empty else None

conn.close()

if start_price is not None and end_price is not None:
    percentage_change = ((end_price - start_price) / start_price) * 100
    print(f"Bitcoin price at the start of Sep 2025: {start_price:.2f} INR")
    print(f"Bitcoin price at the end of Jan 2026: {end_price:.2f} INR")
    print(f"Percentage change in Bitcoin's price between Sep 2025 and Jan 2026: {percentage_change:.2f}%")
else:
    print("Could not retrieve prices for the specified period. Please check data availability.")
# Out:
# Bitcoin price at the start of Sep 2025: 88.19 INR
# Bitcoin price at the end of Jan 2026: 91.55 INR
# Percentage change in Bitcoin's price between Sep 2025 and Jan 2026: 3.81%

# %% [markdown]
# The highest oil price in the last 5 years.

# %%
import sqlite3
import pandas as pd
import datetime

conn = sqlite3.connect('mydatabase.db')

# Calculate the date 5 years ago from the latest date in the oil_prices table
# First, find the maximum date in the table
max_date_query = "SELECT MAX(date) FROM oil_prices;"
max_date_result = pd.read_sql_query(max_date_query, conn)
latest_date_str = max_date_result.iloc[0, 0]

# Convert to datetime object and subtract 5 years
latest_date = datetime.datetime.strptime(latest_date_str, '%Y-%m-%d').date()
five_years_ago = latest_date - datetime.timedelta(days=5*365) # Approximate 5 years

# Query to find the highest oil price in the last 5 years
query = f"""
SELECT date, price_usd
FROM oil_prices
WHERE date >= '{five_years_ago.isoformat()}'
ORDER BY price_usd DESC
LIMIT 1;
"""

highest_oil_price = pd.read_sql_query(query, conn)

conn.close()

print("Highest oil price in the last 5 years:")
display(highest_oil_price)
# Out:
# Highest oil price in the last 5 years:
#          date  price_usd
# 0  2022-03-08     123.64

# %% [markdown]
# The average oil price per year.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to get the average oil price per year
query = """
SELECT
    STRFTIME('%Y', date) AS year,
    AVG(price_usd) AS average_price_usd
FROM
    oil_prices
GROUP BY
    year
ORDER BY
    year ASC;
"""

average_oil_price_per_year = pd.read_sql_query(query, conn)

conn.close()

print("Average oil price per year:")
display(average_oil_price_per_year)
# Out:
# Average oil price per year:
#    year  average_price_usd
# 0  2020              39.16
# 1  2021              68.14
# 2  2022              94.90
# 3  2023              77.58
# 4  2024              76.63
# 5  2025              65.39
# 6  2026              60.11

# %% [markdown]
# The oil prices during COVID crash (March–April 2020).

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find oil prices during the COVID crash (March-April 2020)
query = """
SELECT date, price_usd
FROM oil_prices
WHERE date BETWEEN '2020-03-01' AND '2020-04-30'
ORDER BY date ASC;
"""

oil_prices_covid_crash = pd.read_sql_query(query, conn)

conn.close()

print("Oil prices during COVID crash (March–April 2020):")
display(oil_prices_covid_crash)
# Out:
# Oil prices during COVID crash (March–April 2020):
#           date  price_usd
# 0   2020-03-02      46.78
# 1   2020-03-03      47.27
# 2   2020-03-04      46.78
# 3   2020-03-05      45.90
# 4   2020-03-06      41.14
# 5   2020-03-09      31.05
# 6   2020-03-10      34.47
# 7   2020-03-11      33.13
# 8   2020-03-12      31.56
# 9   2020-03-13      31.72
# 10  2020-03-16      28.96
# 11  2020-03-17      26.96
# 12  2020-03-18      20.48
# 13  2020-03-19      25.09
# 14  2020-03-20      19.48
# 15  2020-03-23      23.33
# 16  2020-03-24      21.03
# 17  2020-03-25      20.75
# 18  2020-03-26      16.60
# 19  2020-03-27      15.48
# 20  2020-03-30      14.10
# 21  2020-03-31      20.51
# 22  2020-04-01      20.28
# 23  2020-04-02      25.18
# 24  2020-04-03      28.36
# 25  2020-04-06      26.21
# 26  2020-04-07      23.54
# 27  2020-04-08      24.97
# 28  2020-04-09      22.90
# 29  2020-04-13      22.36
# 30  2020-04-14      20.15
# 31  2020-04-15      19.96
# 32  2020-04-16      19.82
# 33  2020-04-17      18.31
# 34  2020-04-20     -36.98
# 35  2020-04-21       8.91
# 36  2020-04-22      13.64
# 37  2020-04-23      15.06
# 38  2020-04-24      15.99
# 39  2020-04-27      12.17
# 40  2020-04-28      12.40
# 41  2020-04-29      15.04
# 42  2020-04-30      19.23

# %% [markdown]
#  lowest price of oil in the last 10 years.

# %%
import sqlite3
import pandas as pd
import datetime

conn = sqlite3.connect('mydatabase.db')

# Calculate the date 10 years ago from the latest date in the oil_prices table
# First, find the maximum date in the table
max_date_query = "SELECT MAX(date) FROM oil_prices;"
max_date_result = pd.read_sql_query(max_date_query, conn)
latest_date_str = max_date_result.iloc[0, 0]

# Convert to datetime object and subtract 10 years
latest_date = datetime.datetime.strptime(latest_date_str, '%Y-%m-%d').date()
ten_years_ago = latest_date - datetime.timedelta(days=10*365) # Approximate 10 years

# Query to find the lowest oil price in the last 10 years
query = f"""
SELECT date, price_usd
FROM oil_prices
WHERE date >= '{ten_years_ago.isoformat()}'
ORDER BY price_usd ASC
LIMIT 1;
"""

lowest_oil_price = pd.read_sql_query(query, conn)

conn.close()

print("Lowest oil price in the last 10 years:")
display(lowest_oil_price)
# Out:
# Lowest oil price in the last 10 years:
#          date  price_usd
# 0  2020-04-20     -36.98

# %% [markdown]
# The volatility of oil prices (max-min difference per year).

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to calculate the volatility of oil prices (max-min difference per year)
query = """
SELECT
    STRFTIME('%Y', date) AS year,
    MAX(price_usd) - MIN(price_usd) AS volatility_usd
FROM
    oil_prices
GROUP BY
    year
ORDER BY
    year ASC;
"""

oil_price_volatility = pd.read_sql_query(query, conn)

conn.close()

print("Volatility of oil prices (max-min difference per year):")
display(oil_price_volatility)
# Out:
# Volatility of oil prices (max-min difference per year):
#    year  volatility_usd
# 0  2020          100.25
# 1  2021           38.17
# 2  2022           52.59
# 3  2023           27.06
# 4  2024           20.96
# 5  2025           25.29
# 6  2026            8.76

# %% [markdown]
#  all stock prices for a given ticker

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Get all unique tickers from the stock_prices table
query_tickers = """
SELECT DISTINCT ticker
FROM stock_prices;
"""
available_tickers_df = pd.read_sql_query(query_tickers, conn)
available_tickers = available_tickers_df['ticker'].tolist()

print(f"Retrieving data for tickers: {', '.join(available_tickers)}")

for ticker in available_tickers:
    print(f"\n--- Stock Prices for {ticker} ---")
    query = f"""
    SELECT date, open, high, low, close, volume
    FROM stock_prices
    WHERE ticker = '{ticker}'
    ORDER BY date ASC;
    """
    stock_prices_by_ticker = pd.read_sql_query(query, conn)

    if not stock_prices_by_ticker.empty:
        display(stock_prices_by_ticker)
    else:
        print(f"No stock data found for ticker: {ticker}.")

conn.close()
# Out:
# Retrieving data for tickers: ^NSEI, ^GSPC, ^IXIC
#
# --- Stock Prices for ^NSEI ---
#             date     open     high      low    close  volume
# 0     2020-01-01 12202.15 12222.20 12165.30 12182.50  304100
# 1     2020-01-02 12198.55 12289.90 12195.25 12282.20  407700
# 2     2020-01-03 12261.10 12265.60 12191.35 12226.65  428800
# 3     2020-01-06 12170.60 12179.10 11974.20 11993.05  396500
# 4     2020-01-07 12079.10 12152.15 12005.35 12052.95  447800
# ...          ...      ...      ...      ...      ...     ...
# 1576  2026-01-29 25345.00 25458.15 25159.80 25418.90  582400
# 1577  2026-01-30 25247.55 25370.70 25213.65 25320.65  508400
# 1578  2026-02-02 24796.50 25108.10 24679.40 25088.40  449200
# 1579  2026-02-03 26308.05 26341.20 25641.30 25727.55  637300
# 1580  2026-02-04 25675.05 25818.55 25563.95 25776.00  429800
#
# [1581 rows x 6 columns]
# --- Stock Prices for ^GSPC ---
#             date    open    high     low   close      volume
# 0     2020-01-02 3244.67 3258.14 3235.53 3257.85  3459930000
# 1     2020-01-03 3226.36 3246.15 3222.34 3234.85  3484700000
# 2     2020-01-06 3217.55 3246.84 3214.64 3246.28  3702460000
# 3     2020-01-07 3241.86 3244.91 3232.43 3237.18  3435910000
# 4     2020-01-08 3238.59 3267.07 3236.67 3253.05  3726840000
# ...          ...     ...     ...     ...     ...         ...
# 1575  2026-01-29 6977.74 6992.84 6870.80 6969.01  6877780000
# 1576  2026-01-30 6947.27 6964.09 6893.48 6939.03  6697340000
# 1577  2026-02-02 6916.64 6991.92 6914.34 6976.44  5772050000
# 1578  2026-02-03 6985.45 6993.08 6862.05 6917.81  7017660000
# 1579  2026-02-04 6924.50 6936.09 6838.80 6882.72  7475750000
#
# [1580 rows x 6 columns]
# --- Stock Prices for ^IXIC ---
#             date     open     high      low    close       volume
# 0     2020-01-02  9039.46  9093.43  9010.89  9092.19   2862700000
# 1     2020-01-03  8976.43  9065.76  8976.43  9020.77   2586520000
# 2     2020-01-06  8943.50  9072.41  8943.50  9071.47   2810450000
# 3     2020-01-07  9076.64  9091.93  9042.55  9068.58   2381740000
# 4     2020-01-08  9068.03  9168.89  9059.38  9129.24   2472620000
# ...          ...      ...      ...      ...      ...          ...
# 1575  2026-01-29 23830.92 23840.55 23232.78 23685.12   8782210000
# 1576  2026-01-30 23578.96 23662.25 23351.55 23461.82   9255930000
# 1577  2026-02-02 23370.54 23686.83 23356.40 23592.11   8882530000
# 1578  2026-02-03 23667.44 23691.60 23027.21 23255.19  10306320000
# 1579  2026-02-04 23217.02 23270.07 22684.51 22904.58  10862000000
#
# [1580 rows x 6 columns]

# %% [markdown]
# ### Highest closing price for NASDAQ (^IXIC)

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find the highest closing price for NASDAQ (^IXIC)
query = """
SELECT date, close
FROM stock_prices
WHERE ticker = '^IXIC'
ORDER BY close DESC
LIMIT 1;
"""

highest_nasdaq_close = pd.read_sql_query(query, conn)

conn.close()

print("Highest closing price for NASDAQ (^IXIC):")
display(highest_nasdaq_close)
# Out:
# Highest closing price for NASDAQ (^IXIC):
#          date    close
# 0  2025-10-29 23958.47

# %% [markdown]
# ### Top 5 days with highest price difference (high - low) for S&P 500 (^GSPC)

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to find the top 5 days with the highest price difference (high - low) for S&P 500 (^GSPC)
query = """
SELECT
    date,
    (high - low) AS price_difference
FROM
    stock_prices
WHERE
    ticker = '^GSPC'
ORDER BY
    price_difference DESC
LIMIT 5;
"""

top_5_gspc_diff = pd.read_sql_query(query, conn)

conn.close()

print("Top 5 days with highest price difference for S&P 500 (^GSPC):")
display(top_5_gspc_diff)
# Out:
# Top 5 days with highest price difference for S&P 500 (^GSPC):
#          date  price_difference
# 0  2025-04-09            532.91
# 1  2025-04-07            411.53
# 2  2025-04-08            357.05
# 3  2025-04-10            237.88
# 4  2025-11-20            236.30

# %% [markdown]
# ### Monthly Average Closing Price for Each Ticker

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to get the monthly average closing price for each ticker
query = """
SELECT
    ticker,
    STRFTIME('%Y-%m', date) AS year_month,
    AVG(close) AS average_closing_price
FROM
    stock_prices
GROUP BY
    ticker, year_month
ORDER BY
    ticker, year_month ASC;
"""

monthly_avg_close_price = pd.read_sql_query(query, conn)

conn.close()

print("Monthly average closing price for each ticker:")
display(monthly_avg_close_price)
# Out:
# Monthly average closing price for each ticker:
#     ticker year_month  average_closing_price
# 0    ^GSPC    2020-01                3280.54
# 1    ^GSPC    2020-02                3282.46
# 2    ^GSPC    2020-03                2652.39
# 3    ^GSPC    2020-04                2761.98
# 4    ^GSPC    2020-05                2919.61
# ..     ...        ...                    ...
# 217  ^NSEI    2025-10               25481.77
# 218  ^NSEI    2025-11               25879.98
# 219  ^NSEI    2025-12               25997.74
# 220  ^NSEI    2026-01               25626.07
# 221  ^NSEI    2026-02               25530.65
#
# [222 rows x 3 columns]

# %% [markdown]
# ### Average trading volume of NSEI in 2024

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to get the average trading volume of NSEI in 2024
query = """
SELECT
    AVG(volume) AS average_volume
FROM
    stock_prices
WHERE
    ticker = '^NSEI' AND STRFTIME('%Y', date) = '2024';
"""

nsei_avg_volume_2024 = pd.read_sql_query(query, conn)

conn.close()

print("Average trading volume of NSEI in 2024:")
display(nsei_avg_volume_2024)
# Out:
# Average trading volume of NSEI in 2024:
#    average_volume
# 0       313371.15

# %% [markdown]
# ### Compare Bitcoin vs Oil average price in 2025

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query for Bitcoin's average price in 2025
query_bitcoin_avg = """
SELECT AVG(price_inr) AS average_bitcoin_price_2025
FROM historical_prices
WHERE coin_id = 'bitcoin' AND STRFTIME('%Y', date) = '2025';
"""
bitcoin_avg_price = pd.read_sql_query(query_bitcoin_avg, conn)

# Query for Oil's average price in 2025
query_oil_avg = """
SELECT AVG(price_usd) AS average_oil_price_2025
FROM oil_prices
WHERE STRFTIME('%Y', date) = '2025';
"""
oil_avg_price = pd.read_sql_query(query_oil_avg, conn)

conn.close()

print("Average prices for 2025:")
display(bitcoin_avg_price)
display(oil_avg_price)
# Out:
# Average prices for 2025:
#    average_bitcoin_price_2025
# 0                       87.23
#    average_oil_price_2025
# 0                   65.39

# %% [markdown]
# ## Calculate Bitcoin Average Price for 2025

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query for Bitcoin's average price in 2025
query_bitcoin_avg = """
SELECT AVG(price_inr) AS average_bitcoin_price_2025
FROM historical_prices
WHERE coin_id = 'bitcoin' AND STRFTIME('%Y', date) = '2025';
"""
bitcoin_avg_price = pd.read_sql_query(query_bitcoin_avg, conn)

# Query for Oil's average price in 2025
query_oil_avg = """
SELECT AVG(price_usd) AS average_oil_price_2025
FROM oil_prices
WHERE STRFTIME('%Y', date) = '2025';
"""
oil_avg_price = pd.read_sql_query(query_oil_avg, conn)

conn.close()

print("Average prices for 2025:")
display(bitcoin_avg_price)
display(oil_avg_price)
# Out:
# Average prices for 2025:
#    average_bitcoin_price_2025
# 0                       87.23
#    average_oil_price_2025
# 0                   65.39

# %%
combined_avg_prices = pd.concat([bitcoin_avg_price, oil_avg_price], axis=1)

# Rename columns for clarity
combined_avg_prices = combined_avg_prices.rename(columns={
    'average_bitcoin_price_2025': 'Bitcoin_Avg_Price_2025',
    'average_oil_price_2025': 'Oil_Avg_Price_2025'
})

# Convert to a tidy format if preferred for presentation, though not strictly required by the prompt.
# For direct comparison, the current wide format is also good.
# If a long format is desired:
# combined_avg_prices_long = combined_avg_prices.melt(var_name='Asset', value_name='Average Price (2025)')
# display(combined_avg_prices_long)

print("Comparison of Average Bitcoin and Oil Prices in 2025:")
display(combined_avg_prices)
# Out:
# Comparison of Average Bitcoin and Oil Prices in 2025:
#    Bitcoin_Avg_Price_2025  Oil_Avg_Price_2025
# 0                   87.23               65.39

# %% [markdown]
# Ethereum and NASDAQ Daily Prices for 2025

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

query_combined_prices = """
SELECT
    hp.date,
    hp.price_inr AS ethereum_price,
    sp.close AS nasdaq_close
FROM
    historical_prices AS hp
INNER JOIN
    stock_prices AS sp ON hp.date = sp.date
WHERE
    hp.coin_id = 'ethereum'
    AND sp.ticker = '^IXIC'
    AND STRFTIME('%Y', hp.date) = '2025'
ORDER BY
    hp.date ASC;
"""

combined_prices_2025 = pd.read_sql_query(query_combined_prices, conn)

conn.close()

print("Combined Ethereum and NASDAQ daily prices for 2025:")
display(combined_prices_2025)
# Out:
# Combined Ethereum and NASDAQ daily prices for 2025:
# Empty DataFrame
# Columns: [date, ethereum_price, nasdaq_close]
# Index: []

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')
cursor = conn.cursor()

# Drop the table if it already exists to ensure the schema is updated
cursor.execute('DROP TABLE IF EXISTS historical_prices;')

# Create the historical_prices table with the specified schema
cursor.execute('''
CREATE TABLE historical_prices (
    coin_id TEXT,
    date TEXT,
    price_inr REAL,
    PRIMARY KEY (coin_id, date),
    FOREIGN KEY (coin_id) REFERENCES cryptocurrency(id)
);
''')

# Prepare data for insertion
# Ensure all columns exist, fill missing with None for SQL insertion
columns_to_insert = ['coin_id', 'date', 'price_inr']

# Replace NaN with None for SQLite compatibility
records = df_historical_prices[columns_to_insert].where(pd.notnull(df_historical_prices[columns_to_insert]), None).values.tolist()

insert_query = '''
INSERT OR REPLACE INTO historical_prices (
    coin_id, date, price_inr
)
VALUES (?, ?, ?)
'''

cursor.executemany(insert_query, records)

conn.commit()
conn.close()
print("df_historical_prices successfully pushed to the 'historical_prices' table.")
# Out:
# df_historical_prices successfully pushed to the 'historical_prices' table.

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

query_combined_prices = """
SELECT
    hp.date,
    hp.price_inr AS ethereum_price,
    sp.close AS nasdaq_close
FROM
    historical_prices AS hp
INNER JOIN
    stock_prices AS sp ON hp.date = sp.date
WHERE
    hp.coin_id = 'ethereum'
    AND sp.ticker = '^IXIC'
    AND STRFTIME('%Y', hp.date) = '2025'
ORDER BY
    hp.date ASC;
"""

combined_prices_2025 = pd.read_sql_query(query_combined_prices, conn)

conn.close()

print("Combined Ethereum and NASDAQ daily prices for 2025:")
display(combined_prices_2025)
# Out:
# Combined Ethereum and NASDAQ daily prices for 2025:
# Empty DataFrame
# Columns: [date, ethereum_price, nasdaq_close]
# Index: []

# %%
import pandas as pd

# Calculate descriptive statistics for both price series
ethereum_stats = combined_prices_2025['ethereum_price'].describe().to_frame(name='Ethereum Price (INR)')
nasdaq_stats = combined_prices_2025['nasdaq_close'].describe().to_frame(name='NASDAQ Close (USD)')

# Combine the descriptive statistics for display
price_stats = pd.concat([ethereum_stats, nasdaq_stats], axis=1)

# Calculate the Pearson correlation coefficient
correlation = combined_prices_2025['ethereum_price'].corr(combined_prices_2025['nasdaq_close'])

print("Descriptive Statistics for Ethereum Price and NASDAQ Close (2025):")
display(price_stats)

print(f"\nPearson Correlation between Ethereum Price and NASDAQ Close: {correlation:.4f}")
# Out:
# Descriptive Statistics for Ethereum Price and NASDAQ Close (2025):
#        Ethereum Price (INR) NASDAQ Close (USD)
# count                     0                  0
# unique                    0                  0
# top                     NaN                NaN
# freq                    NaN                NaN
# Pearson Correlation between Ethereum Price and NASDAQ Close: nan

# %% [markdown]
# ## Calculate Daily Oil Price Change

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query the oil_prices table
df_oil_prices = pd.read_sql_query("SELECT date, price_usd FROM oil_prices", conn)

# Convert 'date' column to datetime objects
df_oil_prices['date'] = pd.to_datetime(df_oil_prices['date'])

# Sort the DataFrame by date
df_oil_prices = df_oil_prices.sort_values(by='date').reset_index(drop=True)

conn.close()

print("Oil prices data loaded and sorted:")
display(df_oil_prices.head())
# Out:
# Oil prices data loaded and sorted:
#         date  price_usd
# 0 2020-01-02      61.17
# 1 2020-01-03      63.00
# 2 2020-01-06      63.27
# 3 2020-01-07      62.70
# 4 2020-01-08      59.65

# %%
df_oil_prices['daily_price_change'] = df_oil_prices['price_usd'].pct_change() * 100

print("Oil prices with daily percentage change:")
display(df_oil_prices.head())
# Out:
# Oil prices with daily percentage change:
#         date  price_usd  daily_price_change
# 0 2020-01-02      61.17                 NaN
# 1 2020-01-03      63.00                2.99
# 2 2020-01-06      63.27                0.43
# 3 2020-01-07      62.70               -0.90
# 4 2020-01-08      59.65               -4.86

# %% [markdown]
# ## Identify Oil Price Spikes

# %%
import numpy as np

# Calculate the 99th percentile of the absolute daily_price_change values
spike_threshold = df_oil_prices['daily_price_change'].abs().quantile(0.99)

# Filter df_oil_prices to select rows where the absolute daily_price_change is greater than or equal to spike_threshold
df_oil_spikes = df_oil_prices[df_oil_prices['daily_price_change'].abs() >= spike_threshold]

print(f"Calculated spike threshold (99th percentile of absolute daily change): {spike_threshold:.2f}%")
print(f"Total number of oil price spikes identified: {len(df_oil_spikes)}")
print("Identified oil price spikes (first 5 rows):")
display(df_oil_spikes.head())
# Out:
# Calculated spike threshold (99th percentile of absolute daily change): 12.51%
# Total number of oil price spikes identified: 16
# Identified oil price spikes (first 5 rows):
#          date  price_usd  daily_price_change
# 45 2020-03-09      31.05              -24.53
# 52 2020-03-18      20.48              -24.04
# 53 2020-03-19      25.09               22.51
# 54 2020-03-20      19.48              -22.36
# 55 2020-03-23      23.33               19.76

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Extract the 'date' column from df_oil_spikes and convert it to a list of date strings
oil_spike_dates = df_oil_spikes['date'].dt.strftime('%Y-%m-%d').tolist()

# Construct an SQL query to select Bitcoin's prices on these dates
# Using IN clause for the list of dates, correctly formatting the date strings
query = f"""
SELECT date, price_inr
FROM historical_prices
WHERE coin_id = 'bitcoin' AND date IN ({','.join([f"'{d}'" for d in oil_spike_dates])})
ORDER BY date ASC;
"""

df_bitcoin_spike_prices = pd.read_sql_query(query, conn)

conn.close()

print("Bitcoin prices on oil price spike days:")
display(df_bitcoin_spike_prices.head())
# Out:
# Bitcoin prices on oil price spike days:
# Empty DataFrame
# Columns: [date, price_inr]
# Index: []

# %% [markdown]
# ## Compare and Analyze Prices on Spike Days

# %%
import pandas as pd

# Ensure 'date' column in df_oil_spikes is datetime
df_oil_spikes['date'] = pd.to_datetime(df_oil_spikes['date'])

# Ensure 'date' column in df_bitcoin_spike_prices is datetime
df_bitcoin_spike_prices['date'] = pd.to_datetime(df_bitcoin_spike_prices['date'])

# Merge the two DataFrames on the 'date' column
df_combined_spike_data = pd.merge(df_oil_spikes, df_bitcoin_spike_prices, on='date', how='inner')

print("Combined oil price spikes and Bitcoin prices (first 5 rows):")
display(df_combined_spike_data.head())

print(f"Number of rows in df_combined_spike_data: {len(df_combined_spike_data)}")
# Out:
# Combined oil price spikes and Bitcoin prices (first 5 rows):
# /tmp/ipython-input-2776312890.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_oil_spikes['date'] = pd.to_datetime(df_oil_spikes['date'])
# Empty DataFrame
# Columns: [date, price_usd, daily_price_change, price_inr]
# Index: []
# Number of rows in df_combined_spike_data: 0

# %%
import sqlite3
import pandas as pd
import numpy as np

# Establish a connection to the database
conn = sqlite3.connect('mydatabase.db')

# --- RECALCULATE df_oil_prices and df_oil_spikes to ensure date overlap with Bitcoin data ---

# 1. Get all oil prices from the database and ensure datetime format
df_oil_prices = pd.read_sql_query("SELECT date, price_usd FROM oil_prices", conn)
df_oil_prices['date'] = pd.to_datetime(df_oil_prices['date'])
df_oil_prices = df_oil_prices.sort_values(by='date').reset_index(drop=True)

# 2. Get the date range for Bitcoin historical prices available in the database
# df_historical_prices is available in the kernel, so we can use it.
# Ensure 'date' column in df_historical_prices is treated as datetime for min/max comparison
df_historical_prices['date_dt'] = pd.to_datetime(df_historical_prices['date'])
min_bitcoin_date = df_historical_prices[df_historical_prices['coin_id'] == 'bitcoin']['date_dt'].min()
max_bitcoin_date = df_historical_prices[df_historical_prices['coin_id'] == 'bitcoin']['date_dt'].max()

# 3. Filter df_oil_prices to this common period
# Use .copy() to prevent SettingWithCopyWarning
df_oil_prices_filtered_to_bitcoin_range = df_oil_prices[
    (df_oil_prices['date'] >= min_bitcoin_date) &
    (df_oil_prices['date'] <= max_bitcoin_date)
].copy()

# 4. Recalculate daily_price_change for the relevant oil prices
df_oil_prices_filtered_to_bitcoin_range['daily_price_change'] = df_oil_prices_filtered_to_bitcoin_range['price_usd'].pct_change() * 100

# 5. Recalculate df_oil_spikes using the newly filtered data
# Handle cases where the filtered DataFrame might be too small for quantile
if not df_oil_prices_filtered_to_bitcoin_range.empty and len(df_oil_prices_filtered_to_bitcoin_range) > 1:
    spike_threshold = df_oil_prices_filtered_to_bitcoin_range['daily_price_change'].abs().quantile(0.99)
    df_oil_spikes = df_oil_prices_filtered_to_bitcoin_range[
        df_oil_prices_filtered_to_bitcoin_range['daily_price_change'].abs() >= spike_threshold
    ].copy()
else:
    df_oil_spikes = pd.DataFrame(columns=['date', 'price_usd', 'daily_price_change'])
    print("Not enough oil price data in the Bitcoin historical range to identify spikes.")


# --- ORIGINAL SUBTASK LOGIC STARTS HERE, now with correctly prepared df_oil_spikes ---

# Ensure 'date' column in df_oil_spikes is datetime (already handled above, but for clarity/safety)
df_oil_spikes['date'] = pd.to_datetime(df_oil_spikes['date'])

# Extract the 'date' column from df_oil_spikes and convert it to a list of date strings
oil_spike_dates = df_oil_spikes['date'].dt.strftime('%Y-%m-%d').tolist()

# Query Bitcoin prices for these spike dates
df_bitcoin_spike_prices = pd.DataFrame() # Initialize as empty
if oil_spike_dates: # Only query if there are spike dates
    query_bitcoin_spike_prices = f"""
    SELECT date, price_inr
    FROM historical_prices
    WHERE coin_id = 'bitcoin' AND date IN ({','.join([f"'{d}'" for d in oil_spike_dates])})
    ORDER BY date ASC;
    """
    df_bitcoin_spike_prices = pd.read_sql_query(query_bitcoin_spike_prices, conn)
    # Ensure 'date' column is datetime for merging
    df_bitcoin_spike_prices['date'] = pd.to_datetime(df_bitcoin_spike_prices['date'])

conn.close() # Close the connection after all queries

# Merge the two DataFrames on the 'date' column
# Only merge if both DataFrames have data
if not df_oil_spikes.empty and not df_bitcoin_spike_prices.empty:
    df_combined_spike_data = pd.merge(df_oil_spikes, df_bitcoin_spike_prices, on='date', how='inner')
else:
    df_combined_spike_data = pd.DataFrame(columns=['date', 'price_usd', 'daily_price_change', 'price_inr'])
    print("No valid oil spikes or corresponding Bitcoin prices found for merging.")


print("Combined oil price spikes and Bitcoin prices (first 5 rows):")
display(df_combined_spike_data.head())

print(f"Number of rows in df_combined_spike_data: {len(df_combined_spike_data)}")

# Optional: Add analysis as requested in the subtask
if not df_combined_spike_data.empty:
    print("\nAnalysis of Oil Price Spikes and Corresponding Bitcoin Prices:")
    display(df_combined_spike_data[['date', 'daily_price_change', 'price_inr']])
    # Calculate correlation if there's enough data
    if len(df_combined_spike_data) > 1:
        correlation_spikes = df_combined_spike_data['daily_price_change'].corr(df_combined_spike_data['price_inr'])
        print(f"\nCorrelation between Oil Daily Price Change and Bitcoin Price on spike days: {correlation_spikes:.4f}")
    else:
        print("\nNot enough data points to calculate correlation.")
# Out:
# Combined oil price spikes and Bitcoin prices (first 5 rows):
#         date  price_usd  daily_price_change  price_inr
# 0 2025-04-04      62.42               -7.43      85.25
# 1 2025-06-13      73.84                7.43      85.71
# 2 2025-06-23      69.36               -8.40      86.60
# Number of rows in df_combined_spike_data: 3
#
# Analysis of Oil Price Spikes and Corresponding Bitcoin Prices:
#         date  daily_price_change  price_inr
# 0 2025-04-04               -7.43      85.25
# 1 2025-06-13                7.43      85.71
# 2 2025-06-23               -8.40      86.60
# Correlation between Oil Daily Price Change and Bitcoin Price on spike days: -0.2291

# %% [markdown]
# ## Retrieve Top 3 Coin Daily Prices

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to get daily prices for Bitcoin, Ethereum, and Tether
query = """
SELECT date, coin_id, price_inr
FROM historical_prices
WHERE coin_id IN ('bitcoin', 'ethereum', 'tether')
ORDER BY date ASC;
"""

df_crypto_prices = pd.read_sql_query(query, conn)

# Convert 'date' column to datetime objects
df_crypto_prices['date'] = pd.to_datetime(df_crypto_prices['date'])

conn.close()

print("Daily prices for Bitcoin, Ethereum, and Tether:")
display(df_crypto_prices.head())
# Out:
# Daily prices for Bitcoin, Ethereum, and Tether:
#         date  coin_id  price_inr
# 0 2025-02-12  bitcoin      86.77
# 1 2025-02-13  bitcoin      86.98
# 2 2025-02-14  bitcoin      86.75
# 3 2025-02-15  bitcoin      86.67
# 4 2025-02-16  bitcoin      86.64

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to get daily closing prices for the Nifty index (^NSEI)
query = """
SELECT date, close
FROM stock_prices
WHERE ticker = '^NSEI'
ORDER BY date ASC;
"""

df_nifty_prices = pd.read_sql_query(query, conn)

# Convert 'date' column to datetime objects
df_nifty_prices['date'] = pd.to_datetime(df_nifty_prices['date'])

conn.close()

print("Daily closing prices for Nifty index (^NSEI):")
display(df_nifty_prices.head())
# Out:
# Daily closing prices for Nifty index (^NSEI):
#         date    close
# 0 2020-01-01 12182.50
# 1 2020-01-02 12282.20
# 2 2020-01-03 12226.65
# 3 2020-01-06 11993.05
# 4 2020-01-07 12052.95

# %%
import pandas as pd

# Pivot df_crypto_prices to have coin_id as columns
df_crypto_pivoted = df_crypto_prices.pivot_table(index='date', columns='coin_id', values='price_inr')

# Flatten the column names and rename them for clarity
df_crypto_pivoted.columns = [f'{col}_price' for col in df_crypto_pivoted.columns]

# Reset index to make 'date' a column again for merging
df_crypto_pivoted = df_crypto_pivoted.reset_index()

print("Pivoted cryptocurrency prices (first 5 rows):")
display(df_crypto_pivoted.head())
# Out:
# Pivoted cryptocurrency prices (first 5 rows):
#         date  bitcoin_price
# 0 2025-02-12          86.77
# 1 2025-02-13          86.98
# 2 2025-02-14          86.75
# 3 2025-02-15          86.67
# 4 2025-02-16          86.64

# %%
import pandas as pd

# Merge the pivoted cryptocurrency DataFrame with df_nifty_prices on 'date'
df_merged_prices = pd.merge(df_crypto_pivoted, df_nifty_prices, on='date', how='inner')

# Rename the 'close' column to 'nifty_close'
df_merged_prices = df_merged_prices.rename(columns={'close': 'nifty_close'})

print("Merged cryptocurrency and Nifty prices (first 5 rows):")
display(df_merged_prices.head())
# Out:
# Merged cryptocurrency and Nifty prices (first 5 rows):
#         date  bitcoin_price  nifty_close
# 0 2025-02-12          86.77     23045.25
# 1 2025-02-13          86.98     23031.40
# 2 2025-02-14          86.75     22929.25
# 3 2025-02-17          86.65     22959.50
# 4 2025-02-18          86.85     22945.30

# %%
import pandas as pd

# Calculate daily percentage change for each price series
if 'bitcoin_price' in df_merged_prices.columns:
    df_merged_prices['bitcoin_daily_change'] = df_merged_prices['bitcoin_price'].pct_change() * 100
else:
    print("Warning: 'bitcoin_price' column not found in df_merged_prices. Skipping daily change calculation for Bitcoin.")

if 'ethereum_price' in df_merged_prices.columns:
    df_merged_prices['ethereum_daily_change'] = df_merged_prices['ethereum_price'].pct_change() * 100
else:
    print("Warning: 'ethereum_price' column not found in df_merged_prices. Skipping daily change calculation for Ethereum.")

if 'tether_price' in df_merged_prices.columns:
    df_merged_prices['tether_daily_change'] = df_merged_prices['tether_price'].pct_change() * 100
else:
    print("Warning: 'tether_price' column not found in df_merged_prices. Skipping daily change calculation for Tether.")

df_merged_prices['nifty_daily_change'] = df_merged_prices['nifty_close'].pct_change() * 100

print("Merged prices with daily percentage changes")
display(df_merged_prices)
# Out:
# Warning: 'ethereum_price' column not found in df_merged_prices. Skipping daily change calculation for Ethereum.
# Warning: 'tether_price' column not found in df_merged_prices. Skipping daily change calculation for Tether.
# Merged prices with daily percentage changes
#           date  bitcoin_price  nifty_close  bitcoin_daily_change  \
# 0   2025-02-12          86.77     23045.25                   NaN
# 1   2025-02-13          86.98     23031.40                  0.24
# 2   2025-02-14          86.75     22929.25                 -0.27
# 3   2025-02-17          86.65     22959.50                 -0.11
# 4   2025-02-18          86.85     22945.30                  0.23
# ..         ...            ...          ...                   ...
# 249 2026-01-29          91.91     25418.90                  0.54
# 250 2026-01-30          91.64     25320.65                 -0.29
# 251 2026-02-02          91.60     25088.40                 -0.04
# 252 2026-02-03          90.38     25727.55                 -1.34
# 253 2026-02-04          90.31     25776.00                 -0.08
#
#      nifty_daily_change
# 0                   NaN
# 1                 -0.06
# 2                 -0.44
# 3                  0.13
# 4                 -0.06
# ..                  ...
# 249                0.30
# 250               -0.39
# 251               -0.92
# 252                2.55
# 253                0.19
#
# [254 rows x 5 columns]

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

# Query to get daily oil prices
query = """
SELECT date, price_usd
FROM oil_prices
ORDER BY date ASC;
"""

df_oil_prices_gspc = pd.read_sql_query(query, conn)

# Convert 'date' column to datetime objects
df_oil_prices_gspc['date'] = pd.to_datetime(df_oil_prices_gspc['date'])

conn.close()

print("Daily crude oil prices:")
display(df_oil_prices_gspc.head())
# Out:
# Daily crude oil prices:
#         date  price_usd
# 0 2020-01-02      61.17
# 1 2020-01-03      63.00
# 2 2020-01-06      63.27
# 3 2020-01-07      62.70
# 4 2020-01-08      59.65

# %%
import pandas as pd

# Query to get daily closing prices for S&P 500 (^GSPC)
import sqlite3
conn = sqlite3.connect('mydatabase.db')
query_gspc = """
SELECT date, close
FROM stock_prices
WHERE ticker = '^GSPC'
ORDER BY date ASC;
"""
df_gspc_prices = pd.read_sql_query(query_gspc, conn)
df_gspc_prices['date'] = pd.to_datetime(df_gspc_prices['date'])
conn.close()

# Merge the GSPC prices DataFrame with the oil prices DataFrame on the 'date' column
df_combined_gspc_oil = pd.merge(df_gspc_prices, df_oil_prices_gspc, on='date', how='inner')

# Rename the 'close' column to 'gspc_close' for clarity
df_combined_gspc_oil = df_combined_gspc_oil.rename(columns={'close': 'gspc_close'})

print("Combined GSPC stock prices and crude oil prices (first 5 rows):")
display(df_combined_gspc_oil)
# Out:
# Combined GSPC stock prices and crude oil prices (first 5 rows):
#            date  gspc_close  price_usd
# 0    2020-01-02     3257.85      61.17
# 1    2020-01-03     3234.85      63.00
# 2    2020-01-06     3246.28      63.27
# 3    2020-01-07     3237.18      62.70
# 4    2020-01-08     3253.05      59.65
# ...         ...         ...        ...
# 1516 2026-01-27     6978.60      62.04
# 1517 2026-01-28     6978.03      62.75
# 1518 2026-01-29     6969.01      64.77
# 1519 2026-01-30     6939.03      64.50
# 1520 2026-02-02     6976.44      61.60
#
# [1521 rows x 3 columns]

# %%
import pandas as pd

# Calculate daily percentage change for GSPC closing prices
df_combined_gspc_oil['gspc_daily_change'] = df_combined_gspc_oil['gspc_close'].pct_change() * 100

# Calculate daily percentage change for crude oil prices
df_combined_gspc_oil['oil_daily_change'] = df_combined_gspc_oil['price_usd'].pct_change() * 100

print("Combined GSPC and oil prices with daily percentage changes (first 5 rows):")
display(df_combined_gspc_oil)
# Out:
# Combined GSPC and oil prices with daily percentage changes (first 5 rows):
#            date  gspc_close  price_usd  gspc_daily_change  oil_daily_change
# 0    2020-01-02     3257.85      61.17                NaN               NaN
# 1    2020-01-03     3234.85      63.00              -0.71              2.99
# 2    2020-01-06     3246.28      63.27               0.35              0.43
# 3    2020-01-07     3237.18      62.70              -0.28             -0.90
# 4    2020-01-08     3253.05      59.65               0.49             -4.86
# ...         ...         ...        ...                ...               ...
# 1516 2026-01-27     6978.60      62.04               0.41              2.61
# 1517 2026-01-28     6978.03      62.75              -0.01              1.14
# 1518 2026-01-29     6969.01      64.77              -0.13              3.22
# 1519 2026-01-30     6939.03      64.50              -0.43             -0.42
# 1520 2026-02-02     6976.44      61.60               0.54             -4.50
#
# [1521 rows x 5 columns]

# %% [markdown]
# Correlate Bitcoin closing price with crude oil closing price (same date)

# %%
import pandas as pd

# 1. Create df_bitcoin_prices
df_bitcoin_prices = df_historical_prices[df_historical_prices['coin_id'] == 'bitcoin'][['date_dt', 'price_inr']].copy()
df_bitcoin_prices = df_bitcoin_prices.rename(columns={'date_dt': 'date'})
df_bitcoin_prices['date'] = pd.to_datetime(df_bitcoin_prices['date']).dt.normalize() # Normalize date

# 2. Create df_crude_oil_prices
df_crude_oil_prices = df_oil_prices[['date', 'price_usd']].copy()
df_crude_oil_prices['date'] = pd.to_datetime(df_crude_oil_prices['date']).dt.normalize() # Normalize date

# 3. Display the first few rows of both DataFrames
print("Bitcoin prices (first 5 rows):")
display(df_bitcoin_prices.head())

print("\nCrude oil prices (first 5 rows):")
display(df_crude_oil_prices.head())
# Out:
# Bitcoin prices (first 5 rows):
#         date  price_inr
# 0 2025-02-12      86.77
# 1 2025-02-13      86.98
# 2 2025-02-14      86.75
# 3 2025-02-15      86.67
# 4 2025-02-16      86.64
# Crude oil prices (first 5 rows):
#         date  price_usd
# 0 2020-01-02      61.17
# 1 2020-01-03      63.00
# 2 2020-01-06      63.27
# 3 2020-01-07      62.70
# 4 2020-01-08      59.65

# %%
import pandas as pd

# Merge the two DataFrames on the 'date' column
df_combined_btc_oil = pd.merge(df_bitcoin_prices, df_crude_oil_prices, on='date', how='inner')

# Calculate the Pearson correlation coefficient between Bitcoin price and crude oil price
correlation = df_combined_btc_oil['price_inr'].corr(df_combined_btc_oil['price_usd'])

print("Combined Bitcoin and Crude Oil Prices (first 5 rows):")
display(df_combined_btc_oil.head())

print(f"\nPearson Correlation between Bitcoin Price and Crude Oil Price: {correlation:.4f}")
# Out:
# Combined Bitcoin and Crude Oil Prices (first 5 rows):
#         date  price_inr  price_usd
# 0 2025-02-12      86.77      71.72
# 1 2025-02-13      86.98      71.66
# 2 2025-02-14      86.75      71.05
# 3 2025-02-18      86.85      72.21
# 4 2025-02-19      86.83      72.58
# Pearson Correlation between Bitcoin Price and Crude Oil Price: -0.5473

# %% [markdown]
# Comparision on NASDAQ (^IXIC) with Ethereum price trends

# %%
import pandas as pd

# 1. Filter df_historical_prices for Ethereum and select relevant columns
df_ethereum_prices = df_historical_prices[df_historical_prices['coin_id'] == 'ethereum'][['date_dt', 'price_inr']].copy()
# 2. Rename the 'date_dt' column to 'date'
df_ethereum_prices = df_ethereum_prices.rename(columns={'date_dt': 'date'})

# 3. Filter df_stocks for NASDAQ (^IXIC) and select relevant columns
df_nasdaq_prices = df_stocks[df_stocks['Ticker'] == '^IXIC'][['Date', 'Price_Close']].copy()
# 4. Rename 'Date' to 'date' and 'Price_Close' to 'nasdaq_close'
df_nasdaq_prices = df_nasdaq_prices.rename(columns={'Date': 'date', 'Price_Close': 'nasdaq_close'})

# Ensure 'date' columns are datetime objects for proper merging later
df_ethereum_prices['date'] = pd.to_datetime(df_ethereum_prices['date'])
df_nasdaq_prices['date'] = pd.to_datetime(df_nasdaq_prices['date'])

print("Ethereum daily prices (first 5 rows):")
display(df_ethereum_prices.head())

print("\nNASDAQ daily closing prices (first 5 rows):")
display(df_nasdaq_prices.head())
# Out:
# Ethereum daily prices (first 5 rows):
# Empty DataFrame
# Columns: [date, price_inr]
# Index: []
# NASDAQ daily closing prices (first 5 rows):
#          date  nasdaq_close
# 2  2020-01-02       9092.19
# 5  2020-01-03       9020.77
# 8  2020-01-06       9071.47
# 11 2020-01-07       9068.58
# 14 2020-01-08       9129.24

# %%
import pandas as pd

# Merge df_ethereum_prices and df_nasdaq_prices on the 'date' column
df_merged_eth_nasdaq = pd.merge(df_ethereum_prices, df_nasdaq_prices, on='date', how='inner')

print("Combined Ethereum and NASDAQ daily prices (first 5 rows):")
display(df_merged_eth_nasdaq.head())
# Out:
# Combined Ethereum and NASDAQ daily prices (first 5 rows):
# Empty DataFrame
# Columns: [date, price_inr, nasdaq_close]
# Index: []

# %%
import pandas as pd

# Calculate descriptive statistics for both price series
etherum_stats = df_merged_eth_nasdaq['price_inr'].describe().to_frame(name='Ethereum Price (INR)')
nasdaq_stats = df_merged_eth_nasdaq['nasdaq_close'].describe().to_frame(name='NASDAQ Close (USD)')

# Combine the descriptive statistics for display
price_stats = pd.concat([etherum_stats, nasdaq_stats], axis=1)

# Calculate the Pearson correlation coefficient
correlation = df_merged_eth_nasdaq['price_inr'].corr(df_merged_eth_nasdaq['nasdaq_close'])

print("Descriptive Statistics for Ethereum Price and NASDAQ Close:")
display(price_stats)

print(f"\nPearson Correlation between Ethereum Price and NASDAQ Close: {correlation:.4f}")
# Out:
# Descriptive Statistics for Ethereum Price and NASDAQ Close:
#        Ethereum Price (INR)  NASDAQ Close (USD)
# count                  0.00                0.00
# mean                    NaN                 NaN
# std                     NaN                 NaN
# min                     NaN                 NaN
# 25%                     NaN                 NaN
# 50%                     NaN                 NaN
# 75%                     NaN                 NaN
# max                     NaN                 NaN
# Pearson Correlation between Ethereum Price and NASDAQ Close: nan

# %% [markdown]
# The top 3 crypto coins with stock indices for 2025

# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('mydatabase.db')

query_combined = """
WITH crypto_prices_2025 AS (
    SELECT
        date,
        MAX(CASE WHEN coin_id = 'bitcoin' THEN price_inr ELSE NULL END) AS bitcoin_price,
        MAX(CASE WHEN coin_id = 'ethereum' THEN price_inr ELSE NULL END) AS ethereum_price,
        MAX(CASE WHEN coin_id = 'tether' THEN price_inr ELSE NULL END) AS tether_price
    FROM
        historical_prices
    WHERE
        STRFTIME('%Y', date) = '2025'
        AND coin_id IN ('bitcoin', 'ethereum', 'tether')
    GROUP BY
        date
),
stock_prices_2025 AS (
    SELECT
        date,
        MAX(CASE WHEN ticker = '^GSPC' THEN close ELSE NULL END) AS gspc_close,
        MAX(CASE WHEN ticker = '^IXIC' THEN close ELSE NULL END) AS ixic_close,
        MAX(CASE WHEN ticker = '^NSEI' THEN close ELSE NULL END) AS nsei_close
    FROM
        stock_prices
    WHERE
        STRFTIME('%Y', date) = '2025'
        AND ticker IN ('^GSPC', '^IXIC', '^NSEI')
    GROUP BY
        date
)
SELECT
    cp.date,
    cp.bitcoin_price,
    cp.ethereum_price,
    cp.tether_price,
    sp.gspc_close,
    sp.ixic_close,
    sp.nsei_close
FROM
    crypto_prices_2025 AS cp
LEFT JOIN
    stock_prices_2025 AS sp ON cp.date = sp.date
ORDER BY
    cp.date ASC;
"""

df_combined_crypto_stocks_2025 = pd.read_sql_query(query_combined, conn)

conn.close()

print("Combined daily prices for top 3 cryptocurrencies and stock indices for 2025:")
display(df_combined_crypto_stocks_2025.head())
print(f"DataFrame shape: {df_combined_crypto_stocks_2025.shape}")
# Out:
# Combined daily prices for top 3 cryptocurrencies and stock indices for 2025:
#          date  bitcoin_price ethereum_price tether_price  gspc_close  \
# 0  2025-02-12          86.77           None         None     6051.97
# 1  2025-02-13          86.98           None         None     6115.07
# 2  2025-02-14          86.75           None         None     6114.63
# 3  2025-02-15          86.67           None         None         NaN
# 4  2025-02-16          86.64           None         None         NaN
#
#    ixic_close  nsei_close
# 0    19649.95    23045.25
# 1    19945.64    23031.40
# 2    20026.77    22929.25
# 3         NaN         NaN
# 4         NaN         NaN
# DataFrame shape: (323, 7)

# %% [markdown]
# stock prices, oil prices, and Bitcoin prices for daily comparison

# %%
import pandas as pd

# 1. Prepare df_bitcoin_prices
df_bitcoin_prices = df_historical_prices[df_historical_prices['coin_id'] == 'bitcoin'][['date_dt', 'price_inr']].copy()
df_bitcoin_prices = df_bitcoin_prices.rename(columns={'date_dt': 'date'})
# Ensure 'date' column is datetime (it was created from date_dt which is already datetime)
df_bitcoin_prices['date'] = pd.to_datetime(df_bitcoin_prices['date'])

# 2. Prepare df_crude_oil_prices
df_crude_oil_prices = df_oil_prices[['date', 'price_usd']].copy()
# Ensure 'date' column is datetime (it already is from previous steps)
df_crude_oil_prices['date'] = pd.to_datetime(df_crude_oil_prices['date'])

# 3. Prepare df_gspc_prices
df_gspc_prices = df_stocks[df_stocks['Ticker'] == '^GSPC'][['Date', 'Price_Close']].copy()
df_gspc_prices = df_gspc_prices.rename(columns={'Date': 'date', 'Price_Close': 'close'})
# Ensure 'date' column is datetime
df_gspc_prices['date'] = pd.to_datetime(df_gspc_prices['date'])

print("Bitcoin prices (first 5 rows):")
display(df_bitcoin_prices.head())

print("\nCrude oil prices (first 5 rows):")
display(df_crude_oil_prices.head())

print("\nS&P 500 (^GSPC) closing prices (first 5 rows):")
display(df_gspc_prices)
# Out:
# Bitcoin prices (first 5 rows):
#         date  price_inr
# 0 2025-02-12      86.77
# 1 2025-02-13      86.98
# 2 2025-02-14      86.75
# 3 2025-02-15      86.67
# 4 2025-02-16      86.64
# Crude oil prices (first 5 rows):
#         date  price_usd
# 0 2020-01-02      61.17
# 1 2020-01-03      63.00
# 2 2020-01-06      63.27
# 3 2020-01-07      62.70
# 4 2020-01-08      59.65
# S&P 500 (^GSPC) closing prices (first 5 rows):
#            date   close
# 1    2020-01-02 3257.85
# 4    2020-01-03 3234.85
# 7    2020-01-06 3246.28
# 10   2020-01-07 3237.18
# 13   2020-01-08 3253.05
# ...         ...     ...
# 4726 2026-01-29 6969.01
# 4729 2026-01-30 6939.03
# 4732 2026-02-02 6976.44
# 4735 2026-02-03 6917.81
# 4738 2026-02-04 6882.72
#
# [1580 rows x 2 columns]

# %%
import pandas as pd

# 1. Merge df_bitcoin_prices and df_crude_oil_prices
df_merged_btc_oil = pd.merge(df_bitcoin_prices, df_crude_oil_prices, on='date', how='inner')

# 2. Merge df_merged_btc_oil with df_gspc_prices
df_final_merged_data = pd.merge(df_merged_btc_oil, df_gspc_prices, on='date', how='inner')

# Rename columns for clarity
df_final_merged_data = df_final_merged_data.rename(columns={
    'price_inr': 'bitcoin_price_inr',
    'price_usd': 'oil_price_usd',
    'close': 'gspc_close'
})

# 3. Display the first 5 rows of df_final_merged_data
print("Final Merged DataFrame (Bitcoin, Oil, S&P 500 prices) head:")
display(df_final_merged_data)
# Out:
# Final Merged DataFrame (Bitcoin, Oil, S&P 500 prices) head:
#           date  bitcoin_price_inr  oil_price_usd  gspc_close
# 0   2025-02-12              86.77          71.72     6051.97
# 1   2025-02-13              86.98          71.66     6115.07
# 2   2025-02-14              86.75          71.05     6114.63
# 3   2025-02-18              86.85          72.21     6129.58
# 4   2025-02-19              86.83          72.58     6144.15
# ..         ...                ...            ...         ...
# 237 2026-01-27              91.62          62.04     6978.60
# 238 2026-01-28              91.42          62.75     6978.03
# 239 2026-01-29              91.91          64.77     6969.01
# 240 2026-01-30              91.64          64.50     6939.03
# 241 2026-02-02              91.60          61.60     6976.44
#
# [242 rows x 4 columns]

# %% [markdown]
# # Task
# Create a Streamlit application with three pages: "Filters & Data Exploration" to display average prices and a daily market snapshot of Bitcoin, Oil, S&P 500, and NIFTY based on a user-selected date range; "SQL Query Runner" to allow users to select and execute predefined SQL queries against the loaded data; and "Top Crypto Analysis" to visualize and present daily price trends and raw data for selected top cryptocurrencies within a specified period. Finally, expose this application publicly using Ngrok, and provide the generated Ngrok URL along with a summary of the application's features.

# %% [markdown]
# ## Install Streamlit and Pyngrok
#
# ### Subtask:
# Install the `streamlit` and `pyngrok` libraries which are essential for building and exposing the web application.

# %% [markdown]
# **Reasoning**:
# The subtask requires installing two libraries: `streamlit` and `pyngrok`. I will use `!pip install` commands within a code block to install these packages.

# %%
# !pip install streamlit pyngrok
# Out:
# Collecting streamlit
#   Downloading streamlit-1.54.0-py3-none-any.whl.metadata (9.8 kB)
# Collecting pyngrok
#   Downloading pyngrok-7.5.0-py3-none-any.whl.metadata (8.1 kB)
# Requirement already satisfied: altair!=5.4.0,!=5.4.1,<7,>=4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.5.0)
# Requirement already satisfied: blinker<2,>=1.5.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (1.9.0)
# Collecting cachetools<7,>=5.5 (from streamlit)
#   Downloading cachetools-6.2.6-py3-none-any.whl.metadata (5.6 kB)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (8.3.1)
# Requirement already satisfied: gitpython!=3.1.19,<4,>=3.0.7 in /usr/local/lib/python3.12/dist-packages (from streamlit) (3.1.46)
# Requirement already satisfied: numpy<3,>=1.23 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.0.2)
# Requirement already satisfied: packaging>=20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (26.0)
# Requirement already satisfied: pandas<3,>=1.4.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.2.2)
# Requirement already satisfied: pillow<13,>=7.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (11.3.0)
# Collecting pydeck<1,>=0.8.0b4 (from streamlit)
#   Downloading pydeck-0.9.1-py2.py3-none-any.whl.metadata (4.1 kB)
# Requirement already satisfied: protobuf<7,>=3.20 in /usr/local/lib/python3.12/dist-packages (from streamlit) (5.29.6)
# Requirement already satisfied: pyarrow>=7.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (18.1.0)
# Requirement already satisfied: requests<3,>=2.27 in /usr/local/lib/python3.12/dist-packages (from streamlit) (2.32.4)
# Requirement already satisfied: tenacity<10,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (9.1.3)
# Requirement already satisfied: toml<2,>=0.10.1 in /usr/local/lib/python3.12/dist-packages (from streamlit) (0.10.2)
# Requirement already satisfied: tornado!=6.5.0,<7,>=6.0.3 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.5.1)
# Requirement already satisfied: typing-extensions<5,>=4.10.0 in /usr/local/lib/python3.12/dist-packages (from streamlit) (4.15.0)
# Requirement already satisfied: watchdog<7,>=2.1.5 in /usr/local/lib/python3.12/dist-packages (from streamlit) (6.0.0)
# Requirement already satisfied: PyYAML>=5.1 in /usr/local/lib/python3.12/dist-packages (from pyngrok) (6.0.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.1.6)
# Requirement already satisfied: jsonschema>=3.0 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (4.26.0)
# Requirement already satisfied: narwhals>=1.14.2 in /usr/local/lib/python3.12/dist-packages (from altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.12/dist-packages (from gitpython!=3.1.19,<4,>=3.0.7->streamlit) (4.0.12)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.12/dist-packages (from pandas<3,>=1.4.0->streamlit) (2025.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2.27->streamlit) (2026.1.4)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.12/dist-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.19,<4,>=3.0.7->streamlit) (5.0.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.12/dist-packages (from jinja2->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (3.0.3)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (25.4.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.12/dist-packages (from jsonschema>=3.0->altair!=5.4.0,!=5.4.1,<7,>=4.0->streamlit) (0.30.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.12/dist-packages (from python-dateutil>=2.8.2->pandas<3,>=1.4.0->streamlit) (1.17.0)
# Downloading streamlit-1.54.0-py3-none-any.whl (9.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.1/9.1 MB 35.6 MB/s eta 0:00:00
# Downloading pyngrok-7.5.0-py3-none-any.whl (24 kB)
# Downloading cachetools-6.2.6-py3-none-any.whl (11 kB)
# Downloading pydeck-0.9.1-py2.py3-none-any.whl (6.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.9/6.9 MB 71.0 MB/s eta 0:00:00
# Installing collected packages: pyngrok, cachetools, pydeck, streamlit
#   Attempting uninstall: cachetools
#     Found existing installation: cachetools 7.0.0
#     Uninstalling cachetools-7.0.0:
#       Successfully uninstalled cachetools-7.0.0
# Successfully installed cachetools-6.2.6 pydeck-0.9.1 pyngrok-7.5.0 streamlit-1.54.0

# %% [markdown]
# ## Create Streamlit App File
#
# ### Subtask:
# Generate a Python script named `app.py` that will house all the Streamlit application's code. This file will serve as the entry point for the web application.

# %% [markdown]
# **Reasoning**:
# To generate the `app.py` file as specified in the instructions, I will use the `%%writefile` magic command and include the necessary imports and the basic structure of the Streamlit application within the `app()` function.

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd

def app():
    st.set_page_config(layout="wide")
    st.title("Market Analysis Dashboard")

if __name__ == '__main__':
    app()
# Out:
# Writing app.py

# %% [markdown]
# **Reasoning**:
# The previous step created a basic `app.py` file. Now, I need to populate this file with the actual Streamlit application logic, including database connection, data loading functions, and the implementation of the three required pages: 'Filters & Data Exploration', 'SQL Query Runner', and 'Top Crypto Analysis'. This will replace the placeholder `app.py` content with the complete application structure.

# %%
# %%writefile app.py
import streamlit as st
import pandas as pd
import sqlite3
import altair as alt
import datetime

# Database connection function
@st.cache_resource
def get_db_connection():
    conn = sqlite3.connect('mydatabase.db')
    return conn

# --- Data Loading Functions ---
@st.cache_data(ttl=600)
def load_cryptocurrency_data():
    conn = get_db_connection()
    df = pd.read_sql_query("SELECT * FROM cryptocurrency", conn)
    return df

@st.cache_data(ttl=600)
def load_historical_prices(coin_id=None, start_date=None, end_date=None):
    conn = get_db_connection()
    query = "SELECT coin_id, date, price_inr FROM historical_prices WHERE 1=1"
    params = []
    if coin_id:
        query += " AND coin_id = ?"
        params.append(coin_id)
    if start_date:
        query += " AND date >= ?"
        params.append(start_date)
    if end_date:
        query += " AND date <= ?"
        params.append(end_date)
    query += " ORDER BY date ASC"
    df = pd.read_sql_query(query, conn, params=params)
    df['date'] = pd.to_datetime(df['date'])
    return df

@st.cache_data(ttl=600)
def load_oil_prices(start_date=None, end_date=None):
    conn = get_db_connection()
    query = "SELECT date, price_usd FROM oil_prices WHERE 1=1"
    params = []
    if start_date:
        query += " AND date >= ?"
        params.append(start_date)
    if end_date:
        query += " AND date <= ?"
        params.append(end_date)
    query += " ORDER BY date ASC"
    df = pd.read_sql_query(query, conn, params=params)
    df['date'] = pd.to_datetime(df['date'])
    return df

@st.cache_data(ttl=600)
def load_stock_prices(ticker=None, start_date=None, end_date=None):
    conn = get_db_connection()
    query = "SELECT date, ticker, open, high, low, close, volume FROM stock_prices WHERE 1=1"
    params = []
    if ticker:
        query += " AND ticker = ?"
        params.append(ticker)
    if start_date:
        query += " AND date >= ?"
        params.append(start_date)
    if end_date:
        query += " AND date <= ?"
        params.append(end_date)
    query += " ORDER BY date ASC"
    df = pd.read_sql_query(query, conn, params=params)
    df['date'] = pd.to_datetime(df['date'])
    return df


# --- Page 1: Filters & Data Exploration ---
def filters_and_data_exploration_page():
    st.title("Filters & Data Exploration")

    st.header("Global Market Snapshot")

    # Date Range Selector
    col1, col2 = st.columns(2)
    with col1:
        default_start_date = datetime.date(2025, 1, 1)
        start_date = st.date_input("Start Date", value=default_start_date)
    with col2:
        default_end_date = datetime.date(2026, 2, 9)
        end_date = st.date_input("End Date", value=default_end_date)

    start_date_str = start_date.isoformat()
    end_date_str = end_date.isoformat()

    st.subheader("Average Prices within Selected Date Range")

    # Load and display average prices
    df_bitcoin = load_historical_prices(coin_id='bitcoin', start_date=start_date_str, end_date=end_date_str)
    df_oil = load_oil_prices(start_date=start_date_str, end_date=end_date_str)
    df_gspc = load_stock_prices(ticker='^GSPC', start_date=start_date_str, end_date=end_date_str)
    df_nsei = load_stock_prices(ticker='^NSEI', start_date=start_date_str, end_date=end_date_str)

    st.info(f"Bitcoin data shape: {df_bitcoin.shape}")
    st.info(f"Oil data shape: {df_oil.shape}")
    st.info(f"GSPC data shape: {df_gspc.shape}")
    st.info(f"NSEI data shape: {df_nsei.shape}")

    avg_bitcoin_price = df_bitcoin['price_inr'].mean() if not df_bitcoin.empty else 0
    avg_oil_price = df_oil['price_usd'].mean() if not df_oil.empty else 0
    avg_gspc_close = df_gspc['close'].mean() if not df_gspc.empty else 0
    avg_nsei_close = df_nsei['close'].mean() if not df_nsei.empty else 0

    st.info(f"Avg Bitcoin: {avg_bitcoin_price}")
    st.info(f"Avg Oil: {avg_oil_price}")
    st.info(f"Avg GSPC: {avg_gspc_close}")
    st.info(f"Avg NSEI: {avg_nsei_close}")

    avg_data = {
        'Asset': ['Bitcoin (INR)', 'Crude Oil (USD)', 'S&P 500 (^GSPC)', 'NIFTY 50 (^NSEI)']
    }

    if avg_bitcoin_price != 0:
        avg_data['Average Price'] = [f'{avg_bitcoin_price:,.2f}', f'{avg_oil_price:,.2f}', f'{avg_gspc_close:,.2f}', f'{avg_nsei_close:,.2f}']
    else:
        avg_data['Average Price'] = ['N/A', 'N/A', 'N/A', 'N/A']

    st.dataframe(pd.DataFrame(avg_data), hide_index=True)

    st.subheader("Daily Market Snapshot")

    # Prepare data for plotting
    # Bitcoin
    if not df_bitcoin.empty:
        df_bitcoin_plot = df_bitcoin[['date', 'price_inr']].copy()
        df_bitcoin_plot.columns = ['date', 'value']
        df_bitcoin_plot['asset'] = 'Bitcoin'

    # Crude Oil
    if not df_oil.empty:
        df_oil_plot = df_oil[['date', 'price_usd']].copy()
        df_oil_plot.columns = ['date', 'value']
        df_oil_plot['asset'] = 'Crude Oil'

    # S&P 500
    if not df_gspc.empty:
        df_gspc_plot = df_gspc[['date', 'close']].copy()
        df_gspc_plot.columns = ['date', 'value']
        df_gspc_plot['asset'] = 'S&P 500'

    # NIFTY 50
    if not df_nsei.empty:
        df_nsei_plot = df_nsei[['date', 'close']].copy()
        df_nsei_plot.columns = ['date', 'value']
        df_nsei_plot['asset'] = 'NIFTY 50'

    # Combine all plot dataframes for Altair
    all_plot_data = []
    if 'df_bitcoin_plot' in locals() and not df_bitcoin_plot.empty: all_plot_data.append(df_bitcoin_plot)
    if 'df_oil_plot' in locals() and not df_oil_plot.empty: all_plot_data.append(df_oil_plot)
    if 'df_gspc_plot' in locals() and not df_gspc_plot.empty: all_plot_data.append(df_gspc_plot)
    if 'df_nsei_plot' in locals() and not df_nsei_plot.empty: all_plot_data.append(df_nsei_plot)

    if all_plot_data:
        df_combined_plot = pd.concat(all_plot_data)

        # Create the interactive chart
        chart = alt.Chart(df_combined_plot).mark_line().encode(
            x=alt.X('date:T', axis=alt.Axis(title='Date')),
            y=alt.Y('value:Q', axis=alt.Axis(title='Price')),
            color='asset:N',
            tooltip=['date:T', 'asset:N', alt.Tooltip('value:Q', format='.2f')]
        ).properties(
            title='Daily Prices Over Time'
        ).interactive()

        st.altair_chart(chart, width='stretch')
    else:
        st.warning("No data available for the selected date range.")


# --- Page 2: SQL Query Runner ---
def sql_query_runner_page():
    st.title("SQL Query Runner")
    st.markdown("Execute predefined SQL queries against the database.")

    # Predefined queries
    predefined_queries = {
        "Top 3 Cryptocurrencies by Market Cap": "SELECT id, name, market_cap, market_cap_rank FROM cryptocurrency ORDER BY market_cap_rank ASC LIMIT 3;",
        "Coins with >90% Circulating Supply": "SELECT id, name, circulating_supply, total_supply FROM cryptocurrency WHERE (circulating_supply * 1.0 / total_supply) > 0.9 AND total_supply IS NOT NULL AND total_supply > 0;",
        "Coins within 10% of ATH": "SELECT id, name, current_price, ath FROM cryptocurrency WHERE current_price >= (ath * 0.9) AND ath IS NOT NULL;",
        "Average Market Cap Rank of High Volume Coins (>$1B)": "SELECT AVG(market_cap_rank) as average_market_cap_rank FROM cryptocurrency WHERE total_volume > 1000000000;",
        "Most Recently Updated Coin": "SELECT id, name, date FROM cryptocurrency ORDER BY date DESC LIMIT 1;",
        "Highest Bitcoin Price (Last Year)": "SELECT coin_id, date, price_inr FROM historical_prices WHERE coin_id = 'bitcoin' ORDER BY price_inr DESC LIMIT 1;",
        "Average Ethereum Price (Last Year)": "SELECT AVG(price_inr) as average_ethereum_price FROM historical_prices WHERE coin_id = 'ethereum';",
        "Daily Bitcoin Price (Feb 2025)": "SELECT date, price_inr FROM historical_prices WHERE coin_id = 'bitcoin' AND date BETWEEN '2025-02-01' AND '2025-02-28' ORDER BY date ASC;",
        "Coin with Highest Average Price (Last Year)": "SELECT coin_id, AVG(price_inr) AS average_price FROM historical_prices GROUP BY coin_id ORDER BY average_price DESC LIMIT 1;",
        "Bitcoin % Change (Sep 2025 - Jan 2026)": "SELECT ( (SELECT price_inr FROM historical_prices WHERE coin_id = 'bitcoin' AND date <= '2026-01-31' ORDER BY date DESC LIMIT 1) - (SELECT price_inr FROM historical_prices WHERE coin_id = 'bitcoin' AND date >= '2025-09-01' ORDER BY date ASC LIMIT 1) ) * 100.0 / (SELECT price_inr FROM historical_prices WHERE coin_id = 'bitcoin' AND date >= '2025-09-01' ORDER BY date ASC LIMIT 1) AS percentage_change;",
        "Highest Oil Price (Last 5 Years)": "SELECT date, price_usd FROM oil_prices WHERE date >= STRFTIME('%Y-%m-%d', DATE('now', '-5 years')) ORDER BY price_usd DESC LIMIT 1;",
        "Average Oil Price Per Year": "SELECT STRFTIME('%Y', date) AS year, AVG(price_usd) AS average_price_usd FROM oil_prices GROUP BY year ORDER BY year ASC;",
        "Oil Prices During COVID Crash (Mar-Apr 2020)": "SELECT date, price_usd FROM oil_prices WHERE date BETWEEN '2020-03-01' AND '2020-04-30' ORDER BY date ASC;",
        "Lowest Oil Price (Last 10 Years)": "SELECT date, price_usd FROM oil_prices WHERE date >= STRFTIME('%Y-%m-%d', DATE('now', '-10 years')) ORDER BY price_usd ASC LIMIT 1;",
        "Oil Price Volatility (Max-Min per Year)": "SELECT STRFTIME('%Y', date) AS year, MAX(price_usd) - MIN(price_usd) AS volatility_usd FROM oil_prices GROUP BY year ORDER BY year ASC;",
        "Highest NASDAQ Closing Price": "SELECT date, close FROM stock_prices WHERE ticker = '^IXIC' ORDER BY close DESC LIMIT 1;",
        "Top 5 S&P 500 Price Differences (High-Low)": "SELECT date, (high - low) AS price_difference FROM stock_prices WHERE ticker = '^GSPC' ORDER BY price_difference DESC LIMIT 5;",
        "Monthly Average Closing Price for Each Ticker": "SELECT ticker, STRFTIME('%Y-%m', date) AS year_month, AVG(close) AS average_closing_price FROM stock_prices GROUP BY ticker, year_month ORDER BY ticker, year_month ASC;",
        "Average NSEI Volume (2024)": "SELECT AVG(volume) AS average_volume FROM stock_prices WHERE ticker = '^NSEI' AND STRFTIME('%Y', date) = '2024';"
    }

    selected_query_name = st.selectbox("Select a predefined query:", list(predefined_queries.keys()))
    query = predefined_queries[selected_query_name]

    st.code(query, language='sql')

    if st.button("Run Query"):
        if query:
            try:
                conn = get_db_connection()
                result_df = pd.read_sql_query(query, conn)
                if not result_df.empty:
                    st.success("Query executed successfully!")
                    st.dataframe(result_df)
                else:
                    st.info("Query executed successfully, but returned no results.")
            except Exception as e:
                st.error(f"Error executing query: {e}")
        else:
            st.warning("Please select a query to run.")


# --- Page 3: Top Crypto Analysis ---
def top_crypto_analysis_page():
    st.title("Top Cryptocurrency Analysis")
    st.markdown("Visualize daily price trends and raw data for selected top cryptocurrencies.")

    df_crypto = load_cryptocurrency_data()
    top_3_coins = df_crypto.sort_values(by='market_cap_rank').head(3)
    top_3_coin_ids = top_3_coins['id'].tolist()
    top_3_coin_names = top_3_coins['name'].tolist()

    st.subheader("Select Cryptocurrencies to Analyze")
    selected_coins = st.multiselect(
        "Choose cryptocurrencies (up to 3)",
        options=df_crypto['name'].tolist(),
        default=top_3_coin_names,
        max_selections=3
    )

    if not selected_coins:
        st.warning("Please select at least one cryptocurrency.")
        return

    # Get corresponding IDs
    selected_coin_ids = df_crypto[df_crypto['name'].isin(selected_coins)]['id'].tolist()

    st.subheader("Date Range for Analysis")
    col1, col2 = st.columns(2)
    with col1:
        default_start_date = datetime.date(2025, 1, 1)
        start_date = st.date_input("Start Date", value=default_start_date, key='crypto_start_date')
    with col2:
        default_end_date = datetime.date(2026, 2, 9)
        end_date = st.date_input("End Date", value=default_end_date, key='crypto_end_date')

    start_date_str = start_date.isoformat()
    end_date_str = end_date.isoformat()

    all_historical_df = pd.DataFrame()
    for coin_id in selected_coin_ids:
        historical_df = load_historical_prices(coin_id, start_date=start_date_str, end_date=end_date_str)
        if not historical_df.empty:
            all_historical_df = pd.concat([all_historical_df, historical_df])

    if not all_historical_df.empty:
        st.subheader("Daily Price Trends")
        chart = alt.Chart(all_historical_df).mark_line().encode(
            x=alt.X('date:T', axis=alt.Axis(title='Date')),
            y=alt.Y('price_inr:Q', axis=alt.Axis(title='Price in INR')),
            color='coin_id:N',
            tooltip=['date:T', 'coin_id:N', alt.Tooltip('price_inr:Q', format='.2f')]
        ).properties(
            title='Daily Price Trend of Selected Cryptocurrencies'
        ).interactive()
        st.altair_chart(chart, width='stretch')

        st.subheader("Raw Historical Price Data")
        st.dataframe(all_historical_df)
    else:
        st.info("No historical data available for the selected cryptocurrencies in the given date range.")


# --- Main Streamlit App ---
def app():
    st.sidebar.title("Navigation")
    page = st.sidebar.radio(
        "Go to",
        ["Filters & Data Exploration", "SQL Query Runner", "Top Crypto Analysis"]
    )

    if page == "Filters & Data Exploration":
        filters_and_data_exploration_page()
    elif page == "SQL Query Runner":
        sql_query_runner_page()
    elif page == "Top Crypto Analysis":
        top_crypto_analysis_page()

if __name__ == '__main__':
    app()
# Out:
# Overwriting app.py

# %% [markdown]
# **Reasoning**:
# The Streamlit application `app.py` has been created. The next step is to run this application using Streamlit and then expose it publicly using Ngrok, as specified in the main task. I will start the Streamlit app in the background and then use `pyngrok` to create a public URL.

# %%
import subprocess
import time
from pyngrok import ngrok
import os
from google.colab import userdata

print("Attempting to kill any existing Streamlit processes...")
try:
    # Find process IDs listening on port 8501
    lsof_output = subprocess.check_output(['lsof', '-t', '-i:8501'], text=True)
    pids = lsof_output.strip().split('\n')
    for pid in pids:
        if pid:
            try:
                os.kill(int(pid), 9) # Kill with SIGKILL
                print(f"Killed process {pid} on port 8501.")
            except ProcessLookupError:
                print(f"Process {pid} not found.")
    time.sleep(2) # Give some time for processes to terminate
except subprocess.CalledProcessError:
    print("No processes found listening on port 8501.")
except Exception as e:
    print(f"Error while trying to kill processes: {e}")

# Start Streamlit in the background
print("Starting Streamlit app in background...")
# Redirecting output to streamlit.log
# Disabling CORS and XSRF protection for easier public access in a Colab environment
streamlit_command = [
    "streamlit", "run", "app.py",
    "--server.port", "8501",
    "--server.enableCORS", "false",
    "--server.enableXsrfProtection", "false"
]
# Use preexec_fn=os.setsid to create a new session, detaching the process from the current shell
# Redirect stdout and stderr to /dev/null to prevent hanging and clutter
process = subprocess.Popen(streamlit_command, stdout=subprocess.DEVNULL, stderr=subprocess.DEVNULL, preexec_fn=os.setsid)

time.sleep(5) # Give Streamlit some time to start

# Authenticate ngrok
print("Configuring ngrok authentication...")
NGROK_AUTH_TOKEN = userdata.get('NGROK_AUTH_TOKEN')
ngrok.set_auth_token(NGROK_AUTH_TOKEN)

# Open a ngrok tunnel to the Streamlit port
print("Opening ngrok tunnel...")
# Ensure any existing tunnels are disconnected before trying to create a new one
ngrok.kill()
tunnel = ngrok.connect(8501)
public_url = tunnel.public_url

print(f"Streamlit App is live at: {public_url}")
print("Please copy this URL and open it in your browser.")
print("If the app doesn't load correctly, try refreshing the Ngrok URL.")
# Out:
# Attempting to kill any existing Streamlit processes...
# No processes found listening on port 8501.
# Starting Streamlit app in background...
# Configuring ngrok authentication...
# Opening ngrok tunnel...
# Streamlit App is live at: https://concha-coreless-habitably.ngrok-free.dev
# Please copy this URL and open it in your browser.
# If the app doesn't load correctly, try refreshing the Ngrok URL.
